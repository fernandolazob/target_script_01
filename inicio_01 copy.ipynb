# %%
import sys 
sys.path.append('C:/Users/DATA/Documents/datos/01_script/inicio/funciones')
from funciones import *
from variables_inicio import *
from utils_sql import *

# %%
query = "SELECT * FROM CRONOX.dbo.Llave_Financiera_Efe"
df_efe_consumo=get_data_sql(query, params_sa)

# %%
df_efe_consumo.describe()
# Out:
#        Order_Numero  Hora_Llamada  Mejor_Hora_Telefono  Mejor_Hora_Cliente  \
# count      535021.0  14667.000000        535021.000000       535021.000000
# mean            1.0     12.556828             0.350975            1.544857
# std             0.0      2.747144             2.116197            4.232692
# min             1.0      8.000000             0.000000            0.000000
# 25%             1.0     10.000000             0.000000            0.000000
# 50%             1.0     12.000000             0.000000            0.000000
# 75%             1.0     15.000000             0.000000            0.000000
# max             1.0     18.000000            18.000000           18.000000
#
#         ULT_Hora_Cli   ULT_Hora_Tel  Veces_Cliente  Veces_Telefono  \
# count  535021.000000  535021.000000   65960.000000    14667.000000
# mean        0.344231       0.351596       1.056443        1.026658
# std         2.100200       2.119535       0.270798        0.199306
# min         0.000000       0.000000       1.000000        1.000000
# 25%         0.000000       0.000000       1.000000        1.000000
# 50%         0.000000       0.000000       1.000000        1.000000
# 75%         0.000000       0.000000       1.000000        1.000000
# max        18.000000      18.000000      10.000000       10.000000
#
#         REPITENCIAS  Cantidad_Sin_Discador  Cantidad_Discador        TELEFO1  \
# count  24684.000000            2352.000000      535021.000000  383638.000000
# mean       1.395641               1.031888           0.023608      -0.967428
# std        1.598704               0.302132           0.154317       0.255015
# min        0.000000               1.000000           0.000000      -1.000000
# 25%        0.000000               1.000000           0.000000      -1.000000
# 50%        1.000000               1.000000           0.000000      -1.000000
# 75%        2.000000               1.000000           0.000000      -1.000000
# max       10.000000               9.000000           2.000000       5.000000
#
#              TELEFO2        TELEFO3
# count  417306.000000  452203.000000
# mean       -0.990110      -0.995407
# std         0.142418       0.097780
# min        -1.000000      -1.000000
# 25%        -1.000000      -1.000000
# 50%        -1.000000      -1.000000
# 75%        -1.000000      -1.000000
# max         6.000000      10.000000

# %%
import numpy as np
import matplotlib.pyplot as plt

numeric_cols = df_efe_consumo.select_dtypes(include=np.number).columns

df_efe_consumo[numeric_cols].hist(bins=30, figsize=(12,8))
plt.tight_layout()
plt.show()

# %%
# Out:
# ['LAST NAME', 'FIRST NAME', 'ADDRESS1', 'ADDRESS3', 'COMMENTS', 'VENDOR LEAD CODE', 'PROVINCE', 'CITY', 'EMAIL', 'COMMENTS_2', 'PHONE NUMBER', 'Order_Numero', 'Oferta', 'Tip_Prioridad', 'MARCA_2025', 'NOMCOMERCIAL', 'Perfil_ic', 'tipocliente', 'TIPOINGRESO', 'ASIGNACION', 'LINEA_FT', 'LINEA_HS_RS', 'LINEA_HS_PLUS', 'LINEA_FULL', 'MARCA', 'TIP_TELF', 'PROVEEDOR', 'PERFIL', 'SEGMENTO', 'SCORE', 'TASA', 'RANGO_TASA', 'ZONA', 'Tipo_Telf', 'Fecha_Llam', 'Hora_Llamada', 'FECHA_ENVIO', 'RETIRO', 'Mejor_Estado_Telefono', 'Mejor_Sub_Estado_Telefono', 'Mejor_Descripcion_Telefono', 'Mejor_Fecha_Telefono', 'Mejor_Hora_Telefono', 'Mejor_Durac_Telefono', 'Mejor_Estado_Cliente', 'Mejor_Sub_Estado_Cliente', 'Mejor_Descripcion_Cliente', 'Mejor_fecha_Cliente', 'Mejor_Hora_Cliente', 'Mejor_Durac_Cliente', 'ULT_Descripcion_Cli', 'ULT_fecha_Cli', 'ULT_Hora_Cli', 'ULT_Durac_Cli', 'ULT_Descripcion_Tel', 'ULT_fecha_Tel', 'ULT_Hora_Tel', 'ULT_Durac_Tel', 'Veces_Cliente', 'Veces_Telefono', 'REPITENCIAS', 'Cantidad_Sin_Discador', 'Cantidad_Discador', 'TELEFO1', 'TELEFO2', 'TELEFO3', 'REGION', 'MARCADESBASE', 'MARCA2', 'FLGSUBPROCESO_HS', 'SITUACIONLABORAL']

# %%
df_efe_consumo['RANGO_TASA'].unique()
# Out:
# <StringArray>
# ['6.70 A 80%', '8.90 A mas', '5.60 A 70%', '7.80 A 90%', '2.30 A 40%',
#  '4.50 A 60%']
# Length: 6, dtype: str

# %%
df_uno=pd.read_excel("C:\\Users\\DATA\\Documents\\datos\\01_script\\inicio\\alto_medio_cencosud_03032026.xlsx")

# %%
['TITLE', 'FIRST NAME', '', 'ADDRESS1', 'Address2', 'Address3', 'COMMENTS', 'SECURITY PHRASE', 'EMAIL', 'COMMENTS_CD', 'VENDOR LEAD CODE', 'PROVINCE', 'CITY', 'PHONE NUMBER', 'PRODUCTO', 'SIN_DISCADOR', 'FEC_FACTURACION', 'MARCA', '', 'TIP_TELF', 'PROVEEDOR', 'TEA_SEG', 'RANGO_EDAD', 'REGIMEN_LABORAL', 'EDAD', 'LINEA_SAE', 'LINEA_DESEMBOLSAR', '', 'PROPENSION', 'Frescura', 'RECORRIDO_HOY', 'Antiguedad', 'Antiguedad2', 'Antiguedad3', 'Cantidad_Sin_Discador', 'BURNED', 'Fecha_Llam', '', 'FECHA_ENVIO', '', '', '', 'RANGO_VECES_TELEFONOS', 'REPITENCIAS', 'Mejor_Estado_Telefono', 'Mejor_Sub_Estado_Telefono', 'Mejor_Descripcion_Telefono', 'Mejor_Fecha_Telefono', 'Mejor_Duracion_Telefono', 'Mejor_Estado_Cliente', 'Mejor_Sub_Estado_Cliente', 'Mejor_Descripcion_Cliente', 'Mejor_Fecha_Cliente', 'Mejor_Duracion_Cliente', 'Ultimo_Descripcion_Telefono', 'Ultimo_Fecha_Telefono', 'Ultima_Duracion_Telefono', 'Ultimo_Descripcion_Cli', 'Ultimo_Fecha_Cli', 'Ultima_Duracion_Cli', 'DNI_Ejecutivo', 'Codigo_Paleta', 'flg_mejora']

['PROVEEDOR','Veces_Cliente','Veces_Telefono','Tipo_Telf','LAST NAME','PROPENSION','Segmentacion_Montos','TITLE','MARCA','Hora_Llamada','TEA']
# Out:
# ['TITLE', 'FIRST NAME', 'LAST NAME', 'ADDRESS1', 'Address2', 'Address3', 'COMMENTS', 'SECURITY PHRASE', 'EMAIL', 'COMMENTS_CD', 'VENDOR LEAD CODE', 'PROVINCE', 'CITY', 'PHONE NUMBER', 'PRODUCTO', 'SIN_DISCADOR', 'FEC_FACTURACION', 'MARCA', 'TEA', 'TIP_TELF', 'PROVEEDOR', 'TEA_SEG', 'RANGO_EDAD', 'REGIMEN_LABORAL', 'EDAD', 'LINEA_SAE', 'LINEA_DESEMBOLSAR', 'Segmentacion_Montos', 'PROPENSION', 'Frescura', 'RECORRIDO_HOY', 'Antiguedad', 'Antiguedad2', 'Antiguedad3', 'Cantidad_Sin_Discador', 'BURNED', 'Fecha_Llam', 'Hora_Llamada', 'FECHA_ENVIO', 'Tipo_Telf', 'Veces_Cliente', 'Veces_Telefono', 'RANGO_VECES_TELEFONOS', 'REPITENCIAS', 'Mejor_Estado_Telefono', 'Mejor_Sub_Estado_Telefono', 'Mejor_Descripcion_Telefono', 'Mejor_Fecha_Telefono', 'Mejor_Duracion_Telefono', 'Mejor_Estado_Cliente', 'Mejor_Sub_Estado_Cliente', 'Mejor_Descripcion_Cliente', 'Mejor_Fecha_Cliente', 'Mejor_Duracion_Cliente', 'Ultimo_Descripcion_Telefono', 'Ultimo_Fecha_Telefono', 'Ultima_Duracion_Telefono', 'Ultimo_Descripcion_Cli', 'Ultimo_Fecha_Cli', 'Ultima_Duracion_Cli', 'DNI_Ejecutivo', 'Codigo_Paleta', 'flg_mejora']

# %%
df_uno[['PROVEEDOR','Veces_Cliente','Veces_Telefono','Tipo_Telf','LAST NAME','PROPENSION','Segmentacion_Montos','TITLE','MARCA','Hora_Llamada','TEA']].head()
# Out:
#   PROVEEDOR  Veces_Cliente  Veces_Telefono   Tipo_Telf LAST NAME PROPENSION  \
# 0       BCO            NaN             NaN  BBDD CEL01      LIMA       BAJO
# 1       BCO            NaN             NaN  BBDD CEL01    CALLAO       BAJO
# 2       BCO            NaN             NaN  BBDD CEL01  AREQUIPA       BAJO
# 3       BCO            NaN             NaN  BBDD CEL01      LIMA       BAJO
# 4       BCO            NaN             NaN  BBDD CEL01      LIMA       BAJO
#
#   Segmentacion_Montos TITLE MARCA  Hora_Llamada    TEA
# 0       10000 a 14999   SAE     N           NaN  0.519
# 1       20000 a 24999   SAE     Y           NaN  0.149
# 2       10000 a 14999   SAE     N           NaN  0.529
# 3       15000 a 19999   SAE     N           NaN  0.499
# 4       20000 a 24999   SAE     N           NaN  0.229

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(7,4))
sns.countplot(data=df_uno, x="PROPENSION", order=df_uno["PROPENSION"].value_counts().index)
plt.title("Distribución de Propensión")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(data=df_uno, x="PROPENSION", y="Segmentacion_Montos")
plt.title("Segmentacion_Montos por Nivel de Propensión")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(data=df_uno, x="PROPENSION", y="TEA")
plt.title("TEA por Nivel de Propensión")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

tabla = pd.crosstab(df_uno["Segmentacion_Montos"], df_uno["PROPENSION"])

plt.figure(figsize=(8,5))
sns.heatmap(tabla, annot=True, fmt="d", cmap="Blues")
plt.title("Propensión vs Segmentación de Montos")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=df_uno, x="Segmentacion_Montos", y="TEA", hue="PROPENSION")
plt.xticks(rotation=45)
plt.title("TEA por Segmento y Propensión")
plt.show()

# %%
corr = df_uno[["TEA","Veces_Cliente","Veces_Telefono"]].corr()

plt.figure(figsize=(6,4))
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Matriz de Correlación")
plt.show()

# %%
df_uno[['PROVEEDOR','Veces_Cliente','Veces_Telefono','Tipo_Telf','LAST NAME','PROPENSION','Segmentacion_Montos','TITLE','MARCA','Hora_Llamada','TEA']].describe()
# Out:
#        Veces_Cliente  Veces_Telefono  Hora_Llamada          TEA
# count         3219.0          3191.0   3219.000000  4086.000000
# mean             1.0             1.0     11.724138     0.278256
# std              0.0             0.0      1.601646     0.162232
# min              1.0             1.0      9.000000     0.099000
# 25%              1.0             1.0     11.000000     0.149000
# 50%              1.0             1.0     12.000000     0.229000
# 75%              1.0             1.0     13.000000     0.499000
# max              1.0             1.0     16.000000     0.709000

# %%
df_uno.describe()
# Out:
#           Address3  VENDOR LEAD CODE  PHONE NUMBER  SIN_DISCADOR  \
# count  4086.000000      4.086000e+03  4.086000e+03         158.0
# mean     12.054821      2.204080e+07  9.710442e+08           1.0
# std       5.666706      1.665567e+07  2.346631e+07           0.0
# min       6.000000      7.011100e+04  9.006337e+08           1.0
# 25%       7.000000      8.446051e+06  9.528735e+08           1.0
# 50%      10.000000      1.575430e+07  9.766857e+08           1.0
# 75%      20.000000      4.019524e+07  9.922696e+08           1.0
# max      25.000000      8.065386e+07  9.999989e+08           1.0
#
#        FEC_FACTURACION          TEA         EDAD     LINEA_SAE  \
# count      4086.000000  4086.000000  4086.000000   4086.000000
# mean         12.054821     0.278256    56.347283  21699.583945
# std           5.666706     0.162232    11.909596   9013.306215
# min           6.000000     0.099000    27.000000  10000.000000
# 25%           7.000000     0.149000    48.000000  15000.000000
# 50%          10.000000     0.229000    56.000000  20000.000000
# 75%          20.000000     0.499000    66.000000  26400.000000
# max          25.000000     0.709000    80.000000  40000.000000
#
#        LINEA_DESEMBOLSAR     Frescura  ...  Cantidad_Sin_Discador  BURNED  \
# count                0.0  4086.000000  ...                  158.0     0.0
# mean                 NaN     0.510279  ...                    1.0     NaN
# std                  NaN     0.499956  ...                    0.0     NaN
# min                  NaN     0.000000  ...                    1.0     NaN
# 25%                  NaN     0.000000  ...                    1.0     NaN
# 50%                  NaN     1.000000  ...                    1.0     NaN
# 75%                  NaN     1.000000  ...                    1.0     NaN
# max                  NaN     1.000000  ...                    1.0     NaN
#
#        Hora_Llamada  Veces_Cliente  Veces_Telefono  REPITENCIAS  \
# count   3219.000000         3219.0          3191.0   569.000000
# mean      11.724138            1.0             1.0     4.831283
# std        1.601646            0.0             0.0     2.236778
# min        9.000000            1.0             1.0     0.000000
# 25%       11.000000            1.0             1.0     3.000000
# 50%       12.000000            1.0             1.0     5.000000
# 75%       13.000000            1.0             1.0     7.000000
# max       16.000000            1.0             1.0     9.000000
#
#        Mejor_Duracion_Telefono  Mejor_Duracion_Cliente  \
# count              4086.000000             4086.000000
# mean                  0.752814                0.773128
# std                   5.331469                5.377288
# min                   0.000000                0.000000
# 25%                   0.000000                0.000000
# 50%                   0.000000                0.000000
# 75%                   0.000000                0.000000
# max                 216.000000              216.000000
#
#        Ultima_Duracion_Telefono  Ultima_Duracion_Cli
# count               4086.000000          4086.000000
# mean                   0.752814             0.773128
# std                    5.331469             5.377288
# min                    0.000000             0.000000
# 25%                    0.000000             0.000000
# 50%                    0.000000             0.000000
# 75%                    0.000000             0.000000
# max                  216.000000           216.000000
#
# [8 rows x 21 columns]

# %%
sns.pairplot(df_uno[["PROPENSION","Segmentacion_Montos","TEA"]])
plt.show()

# %%
df_uno.head()
# Out:
#   TITLE          FIRST NAME LAST NAME                   ADDRESS1  \
# 0   SAE  Regimen Lab. INFOR      LIMA      MAITA HOYOS MARGARITA
# 1   SAE  Regimen Lab. INDEP    CALLAO         RAMIREZ DIAZ ANGIE
# 2   SAE  Regimen Lab. INFOR  AREQUIPA        TRIVEÑO LUQUE ANDRE
# 3   SAE  Regimen Lab. INFOR      LIMA       SOPLIN PASTOR MIGUEL
# 4   SAE    Regimen Lab. DEP      LIMA  ESPINOZA OSCANOA MARICRUZ
#
#                                             Address2  Address3  \
# 0  AVENIDA LOS JAZMINES SN URBANIZACION SN MZ.E1 ...        10
# 1  JIRON PACIFICO VILLA SEÑOR DE LOS MILAGROS 584...        20
# 2  AVENIDA SN QUINTA RESIDENCIAL CAYMA URBANIZACI...        21
# 3                      AVENIDA BELLO HORIZONTE 153          10
# 4  JIRON LOS ZORZALES HORIZONTE DE ZARATE URBANIZ...        10
#
#                                             COMMENTS  SECURITY PHRASE  \
# 0  DEUDA_ACTUAL Sin Fecha MONTO_DESEMBOLSAR Sin M...  LINEA SAE 10000
# 1  DEUDA_ACTUAL Sin Fecha MONTO_DESEMBOLSAR Sin M...  LINEA SAE 22600
# 2  DEUDA_ACTUAL Sin Fecha MONTO_DESEMBOLSAR Sin M...  LINEA SAE 10000
# 3  DEUDA_ACTUAL Sin Fecha MONTO_DESEMBOLSAR Sin M...  LINEA SAE 15000
# 4  DEUDA_ACTUAL Sin Fecha MONTO_DESEMBOLSAR Sin M...  LINEA SAE 25000
#
#                   EMAIL                                        COMMENTS_CD  \
# 0   PCT: 038 TEA: 0.519  //CONSENTIMIENTO:N//ENTIDAD1://DEUDA1://ENTIDA...
# 1   PCT: 018 TEA: 0.149  //CONSENTIMIENTO:Y//ENTIDAD1://DEUDA1://ENTIDA...
# 2   PCT: 039 TEA: 0.529  //CONSENTIMIENTO:N//ENTIDAD1://DEUDA1://ENTIDA...
# 3   PCT: 037 TEA: 0.499  //CONSENTIMIENTO:N//ENTIDAD1://DEUDA1://ENTIDA...
# 4   PCT: 022 TEA: 0.229  //CONSENTIMIENTO:N//ENTIDAD1://DEUDA1://ENTIDA...
#
#    ...  Mejor_Duracion_Cliente Ultimo_Descripcion_Telefono  \
# 0  ...                       0               1.SIN GESTION
# 1  ...                       0               1.SIN GESTION
# 2  ...                       0               1.SIN GESTION
# 3  ...                       0               1.SIN GESTION
# 4  ...                       0               1.SIN GESTION
#
#          Ultimo_Fecha_Telefono  Ultima_Duracion_Telefono  \
# 0  1900-01-01 00:00:00.0000000                         0
# 1  1900-01-01 00:00:00.0000000                         0
# 2  1900-01-01 00:00:00.0000000                         0
# 3  1900-01-01 00:00:00.0000000                         0
# 4  1900-01-01 00:00:00.0000000                         0
#
#   Ultimo_Descripcion_Cli             Ultimo_Fecha_Cli  Ultima_Duracion_Cli  \
# 0          1.SIN GESTION  1900-01-01 00:00:00.0000000                    0
# 1          1.SIN GESTION  1900-01-01 00:00:00.0000000                    0
# 2          1.SIN GESTION  1900-01-01 00:00:00.0000000                    0
# 3          1.SIN GESTION  1900-01-01 00:00:00.0000000                    0
# 4          1.SIN GESTION  1900-01-01 00:00:00.0000000                    0
#
#   DNI_Ejecutivo  Codigo_Paleta flg_mejora
# 0           NaN            NaN        NaN
# 1           NaN            NaN        NaN
# 2           NaN            NaN        NaN
# 3           NaN            NaN        NaN
# 4           NaN            NaN        NaN
#
# [5 rows x 63 columns]

# %%
df_uno.describe()
# Out:
#           Address3  VENDOR LEAD CODE  PHONE NUMBER  SIN_DISCADOR  \
# count  4960.000000      4.960000e+03  4.960000e+03         195.0
# mean     12.132863      2.221066e+07  9.706631e+08           1.0
# std       5.682879      1.683073e+07  2.362714e+07           0.0
# min       6.000000      7.011100e+04  9.004344e+08           1.0
# 25%       7.000000      8.483736e+06  9.518889e+08           1.0
# 50%      10.000000      1.596432e+07  9.762936e+08           1.0
# 75%      20.000000      4.030398e+07  9.921487e+08           1.0
# max      25.000000      8.067752e+07  9.999989e+08           1.0
#
#        FEC_FACTURACION          TEA         EDAD     LINEA_SAE  \
# count      4960.000000  4960.000000  4960.000000   4960.000000
# mean         12.132863     0.298234    56.259073  21447.177419
# std           5.682879     0.165609    11.919506   8905.960271
# min           6.000000     0.099000    27.000000  10000.000000
# 25%           7.000000     0.149000    47.000000  14700.000000
# 50%          10.000000     0.229000    56.000000  20000.000000
# 75%          20.000000     0.499000    66.000000  25625.000000
# max          25.000000     0.709000    80.000000  40000.000000
#
#        LINEA_DESEMBOLSAR     Frescura  ...  Cantidad_Sin_Discador  BURNED  \
# count                0.0  4960.000000  ...                  195.0     0.0
# mean                 NaN     0.512097  ...                    1.0     NaN
# std                  NaN     0.499904  ...                    0.0     NaN
# min                  NaN     0.000000  ...                    1.0     NaN
# 25%                  NaN     0.000000  ...                    1.0     NaN
# 50%                  NaN     1.000000  ...                    1.0     NaN
# 75%                  NaN     1.000000  ...                    1.0     NaN
# max                  NaN     1.000000  ...                    1.0     NaN
#
#        Hora_Llamada  Veces_Cliente  Veces_Telefono  REPITENCIAS  \
# count   4087.000000         4087.0          4059.0   700.000000
# mean      11.306827            1.0             1.0     4.904286
# std        1.673498            0.0             0.0     2.239133
# min        9.000000            1.0             1.0     0.000000
# 25%       10.000000            1.0             1.0     3.000000
# 50%       12.000000            1.0             1.0     6.000000
# 75%       12.000000            1.0             1.0     7.000000
# max       17.000000            1.0             1.0     9.000000
#
#        Mejor_Duracion_Telefono  Mejor_Duracion_Cliente  \
# count              4960.000000             4960.000000
# mean                  0.781250                0.797984
# std                   5.223762                5.262222
# min                   0.000000                0.000000
# 25%                   0.000000                0.000000
# 50%                   0.000000                0.000000
# 75%                   0.000000                0.000000
# max                 216.000000              216.000000
#
#        Ultima_Duracion_Telefono  Ultima_Duracion_Cli
# count               4960.000000          4960.000000
# mean                   0.781250             0.797984
# std                    5.223762             5.262222
# min                    0.000000             0.000000
# 25%                    0.000000             0.000000
# 50%                    0.000000             0.000000
# 75%                    0.000000             0.000000
# max                  216.000000           216.000000
#
# [8 rows x 21 columns]

# %%
df_uno.columns
# Out:
# Index(['TITLE', 'FIRST NAME', 'LAST NAME', 'ADDRESS1', 'Address2', 'Address3',
#        'COMMENTS', 'SECURITY PHRASE', 'EMAIL', 'COMMENTS_CD',
#        'VENDOR LEAD CODE', 'PROVINCE', 'CITY', 'PHONE NUMBER', 'PRODUCTO',
#        'SIN_DISCADOR', 'FEC_FACTURACION', 'MARCA', 'TEA', 'TIP_TELF',
#        'PROVEEDOR', 'TEA_SEG', 'RANGO_EDAD', 'REGIMEN_LABORAL', 'EDAD',
#        'LINEA_SAE', 'LINEA_DESEMBOLSAR', 'Segmentacion_Montos', 'PROPENSION',
#        'Frescura', 'RECORRIDO_HOY', 'Antiguedad', 'Antiguedad2', 'Antiguedad3',
#        'Cantidad_Sin_Discador', 'BURNED', 'Fecha_Llam', 'Hora_Llamada',
#        'FECHA_ENVIO', 'Tipo_Telf', 'Veces_Cliente', 'Veces_Telefono',
#        'RANGO_VECES_TELEFONOS', 'REPITENCIAS', 'Mejor_Estado_Telefono',
#        'Mejor_Sub_Estado_Telefono', 'Mejor_Descripcion_Telefono',
#        'Mejor_Fecha_Telefono', 'Mejor_Duracion_Telefono',
#        'Mejor_Estado_Cliente', 'Mejor_Sub_Estado_Cliente',
#        'Mejor_Descripcion_Cliente', 'Mejor_Fecha_Cliente',
#        'Mejor_Duracion_Cliente', 'Ultimo_Descripcion_Telefono',
#        'Ultimo_Fecha_Telefono', 'Ultima_Duracion_Telefono',
#        'Ultimo_Descripcion_Cli', 'Ultimo_Fecha_Cli', 'Ultima_Duracion_Cli',
#        'DNI_Ejecutivo', 'Codigo_Paleta', 'flg_mejora'],
#       dtype='str')

# %%
from sklearn.model_selection import StratifiedKFold

skf = StratifiedKFold(n_splits=6, shuffle=True, random_state=42)

partes = []

for _, test_index in skf.split(df_uno, df_uno["LINEA_HS_PLUS"]):
    partes.append(df_uno.iloc[test_index])

df1, df2, df3, df4, df5, df6 = partes
# Out:
# c:\Users\DATA\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_split.py:813: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=6.
#   warnings.warn(

# %%
df_uno=pd.read_excel("C:\\Users\\DATA\\Documents\\datos\\01_script\\inicio\\27-02 SGT.xlsx")

# %%
df_uno['LINEA_HS_PLUS'].unique()
# Out:
# array([ 9253, 10500,  8610, ...,  7730, 10304,  7016], shape=(4766,))

# %%
df1.describe()
# Out:
#        COMMENTS  VENDOR LEAD CODE  PHONE NUMBER  Order_Numero  Oferta  \
# count       0.0      5.837000e+03  5.837000e+03        5837.0     0.0
# mean        NaN      3.257117e+07  9.677591e+08           1.0     NaN
# std         NaN      2.034171e+07  2.334152e+07           0.0     NaN
# min         NaN      1.197600e+04  9.000929e+08           1.0     NaN
# 25%         NaN      1.041902e+07  9.492513e+08           1.0     NaN
# 50%         NaN      4.040659e+07  9.691452e+08           1.0     NaN
# 75%         NaN      4.465598e+07  9.894510e+08           1.0     NaN
# max         NaN      8.065477e+07  1.000000e+09           1.0     NaN
#
#        Tip_Prioridad  MARCA_2025  Perfil_ic     LINEA_FT   LINEA_HS_RS  \
# count            0.0         0.0        0.0  3908.000000   5837.000000
# mean             NaN         NaN        NaN  2998.720573   8802.673462
# std              NaN         NaN        NaN    35.750761   1560.203425
# min              NaN         NaN        NaN  2000.000000   3000.000000
# 25%              NaN         NaN        NaN  3000.000000   7000.000000
# 50%              NaN         NaN        NaN  3000.000000   9390.000000
# 75%              NaN         NaN        NaN  3000.000000  10376.000000
# max              NaN         NaN        NaN  3000.000000  10500.000000
#
#        LINEA_HS_PLUS
# count    5837.000000
# mean     9372.756724
# std      3969.137697
# min      6001.000000
# 25%      7000.000000
# 50%      9434.000000
# 75%     10500.000000
# max     50000.000000

# %%
import numpy as np
import matplotlib.pyplot as plt

numeric_cols = df1.select_dtypes(include=np.number).columns

df1[numeric_cols].hist(bins=30, figsize=(12,8))
plt.tight_layout()
plt.show()

# %%
df1.shape
# Out:
# (5837, 23)

# %%
df1.to_csv("C:\\Users\\DATA\\Documents\\datos\\01_script\\inicio\\df1.csv", index=False)

# %%
df_uno.describe()
# Out:
#        COMMENTS  VENDOR LEAD CODE  PHONE NUMBER  Order_Numero  Oferta  \
# count       0.0      3.501800e+04  3.501800e+04       35018.0     0.0
# mean        NaN      3.257255e+07  9.683459e+08           1.0     NaN
# std         NaN      2.020312e+07  2.299886e+07           0.0     NaN
# min         NaN      1.070600e+04  9.000072e+08           1.0     NaN
# 25%         NaN      1.045454e+07  9.497392e+08           1.0     NaN
# 50%         NaN      4.039511e+07  9.699901e+08           1.0     NaN
# 75%         NaN      4.462279e+07  9.893569e+08           1.0     NaN
# max         NaN      8.183122e+07  1.000000e+09           1.0     NaN
#
#        Tip_Prioridad  MARCA_2025  Perfil_ic      LINEA_FT   LINEA_HS_RS  \
# count            0.0         0.0        0.0  23614.000000  35018.000000
# mean             NaN         NaN        NaN   2998.687219   8788.205637
# std              NaN         NaN        NaN     36.209290   1557.807950
# min              NaN         NaN        NaN   2000.000000   3000.000000
# 25%              NaN         NaN        NaN   3000.000000   7000.000000
# 50%              NaN         NaN        NaN   3000.000000   9330.000000
# 75%              NaN         NaN        NaN   3000.000000  10271.000000
# max              NaN         NaN        NaN   3000.000000  10500.000000
#
#        LINEA_HS_PLUS
# count   35018.000000
# mean     9349.642070
# std      3933.039001
# min      6000.000000
# 25%      7000.000000
# 50%      9382.500000
# 75%     10425.000000
# max     50000.000000

# %%
35018/6000
# Out:
# 5.836333333333333

# %%
import pyodbc

conn = pyodbc.connect(
    "DRIVER={ODBC Driver 17 for SQL Server};"
    "SERVER=tu_servidor;"
    "DATABASE=CRONOX;"
    "UID=tu_usuario;"
    "PWD=tu_password;"
)

cursor = conn.cursor()

# Ejecutar el stored procedure
cursor.execute("EXEC dbo.SP_Generador_CENCOSUD_SAE")

# Confirmar cambios (MUY IMPORTANTE)
conn.commit()

cursor.close()
conn.close()

print("Stored Procedure ejecutado correctamente")

# %%
query = "SELECT * FROM CRONOX.dbo.Llave_Cenco_SAE"
df_cen=get_data_sql(query, params_sa)

# query = "SELECT * FROM CRONOX.dbo.Llave_Financiera_Efe_Neg"
# df_efe_neg=get_data_sql(query, params_sa)

# query = "SELECT * FROM CRONOX.dbo.Llave_Financiera_Efe"
# df_efe_consumo=get_data_sql(query, params_sa)

# %%
df_cen.head()
# Out:
#   TITLE          FIRST NAME LAST NAME                             ADDRESS1  \
# 0   SAE  Regimen Lab. INDEP      LIMA                CORREA LINARES CARLOS
# 1   SAE  Regimen Lab. INDEP      LIMA                CORREA LINARES CARLOS
# 2   SAE  Regimen Lab. INDEP      LIMA                CORREA LINARES CARLOS
# 3   SAE  Regimen Lab. INDEP      LIMA  MAGUINA RODRIGUEZ DE VELASQUEZ ROSA
# 4   SAE  Regimen Lab. INDEP      LIMA  MAGUINA RODRIGUEZ DE VELASQUEZ ROSA
#
#                                             Address2 Address3  \
# 0  AVENIDA PASEO DE LA REPUBLICA SAN ANTONIO 6266...       10
# 1  AVENIDA PASEO DE LA REPUBLICA SAN ANTONIO 6266...       10
# 2  AVENIDA PASEO DE LA REPUBLICA SAN ANTONIO 6266...       10
# 3  AVENIDA ENRIQUE MEIGGS URBANIZACION 262 URBANI...       15
# 4  AVENIDA ENRIQUE MEIGGS URBANIZACION 262 URBANI...       15
#
#                                             COMMENTS  SECURITY PHRASE  \
# 0  DEUDA_ACTUAL Sin Fecha MONTO_DESEMBOLSAR Sin M...  LINEA SAE 25000
# 1  DEUDA_ACTUAL Sin Fecha MONTO_DESEMBOLSAR Sin M...  LINEA SAE 25000
# 2  DEUDA_ACTUAL Sin Fecha MONTO_DESEMBOLSAR Sin M...  LINEA SAE 25000
# 3  DEUDA_ACTUAL Sin Fecha MONTO_DESEMBOLSAR Sin M...   LINEA SAE 1500
# 4  DEUDA_ACTUAL Sin Fecha MONTO_DESEMBOLSAR Sin M...   LINEA SAE 1500
#
#                   EMAIL                                        COMMENTS_CD  \
# 0   PCT: 016 TEA: 0.099  //CONSENTIMIENTO:Y//ENTIDAD1://DEUDA1://ENTIDA...
# 1   PCT: 016 TEA: 0.099  //CONSENTIMIENTO:Y//ENTIDAD1://DEUDA1://ENTIDA...
# 2   PCT: 016 TEA: 0.099  //CONSENTIMIENTO:Y//ENTIDAD1://DEUDA1://ENTIDA...
# 3   PCT: 035 TEA: 0.459  //CONSENTIMIENTO:Y//ENTIDAD1://DEUDA1://ENTIDA...
# 4   PCT: 035 TEA: 0.459  //CONSENTIMIENTO:Y//ENTIDAD1://DEUDA1://ENTIDA...
#
#    ... Mejor_Fecha_Cliente Mejor_Duracion_Cliente Ultimo_Descripcion_Telefono  \
# 0  ... 2026-02-25 15:27:28                      8               1.SIN GESTION
# 1  ... 2026-02-25 15:27:28                      8               1.SIN GESTION
# 2  ... 2026-02-25 15:27:28                      8               1.SIN GESTION
# 3  ... 2026-02-20 11:16:14                      0               1.SIN GESTION
# 4  ... 2026-02-20 11:16:14                      0               1.SIN GESTION
#
#   Ultimo_Fecha_Telefono Ultima_Duracion_Telefono  \
# 0            1900-01-01                        0
# 1            1900-01-01                        0
# 2            1900-01-01                        0
# 3            1900-01-01                        0
# 4            1900-01-01                        0
#
#              Ultimo_Descripcion_Cli    Ultimo_Fecha_Cli Ultima_Duracion_Cli  \
# 0  MENSAJE EN CASILLA DE VOZ (AUTO) 2026-02-27 11:43:28                   0
# 1  MENSAJE EN CASILLA DE VOZ (AUTO) 2026-02-27 11:43:28                   0
# 2  MENSAJE EN CASILLA DE VOZ (AUTO) 2026-02-27 11:43:28                   0
# 3  MENSAJE EN CASILLA DE VOZ (AUTO) 2026-02-20 11:16:14                   0
# 4  MENSAJE EN CASILLA DE VOZ (AUTO) 2026-02-20 11:16:14                   0
#
#   DNI_Ejecutivo Codigo_Paleta
# 0        PFC021           NaN
# 1        PFC021           NaN
# 2        PFC021           NaN
# 3          VDAD           NaN
# 4          VDAD           NaN
#
# [5 rows x 62 columns]

# %%
orden_01=df_efe_consumo.columns.to_list

# %%
df_uno=pd.read_excel("C:\\Users\\DATA\\Documents\\datos\\01_script\\inicio\\27-02 SGT.xlsx")

# %%
df_uno.columns = (
    df_uno.columns
    .str.strip()
    .str.upper()
    .str.replace("Á","A")
    .str.replace("É","E")
    .str.replace("Í","I")
    .str.replace("Ó","O")
    .str.replace("Ú","U")
)

# %%
df_uno['PHONE NUMBER'] = df_uno['NUMERO'].astype(str)

# %%
df_uno=df_uno[['DNI', 'NOMBRE', 'PHONE NUMBER']]

# %%
df_uno=df_uno.merge(df_efe_consumo, left_on='PHONE NUMBER', right_on='PHONE NUMBER', how='left')

# %%
Index(['LAST NAME', 'FIRST NAME', 'ADDRESS1', 'ADDRESS3', 'COMMENTS',
       'VENDOR LEAD CODE', 'PROVINCE', 'CITY', 'EMAIL', 'COMMENTS_2',
       'PHONE NUMBER', 'Order_Numero', 'Oferta', 'Tip_Prioridad', 'MARCA_2025',
       'NOMCOMERCIAL', 'Perfil_ic', 'tipocliente', 'TIPOINGRESO', 'ASIGNACION',
       'LINEA_FT', 'LINEA_HS_RS', 'LINEA_HS_PLUS', 'LINEA_FULL', 'MARCA',
       'TIP_TELF', 'PROVEEDOR', 'PERFIL', 'SEGMENTO', 'SCORE', 'TASA',
       'RANGO_TASA', 'ZONA', 'Tipo_Telf', 'Fecha_Llam', 'Hora_Llamada',
       'FECHA_ENVIO', 'RETIRO', 'Mejor_Estado_Telefono',
       'Mejor_Sub_Estado_Telefono', 'Mejor_Descripcion_Telefono',
       'Mejor_Fecha_Telefono', 'Mejor_Hora_Telefono', 'Mejor_Durac_Telefono',
       'Mejor_Estado_Cliente', 'Mejor_Sub_Estado_Cliente',
       'Mejor_Descripcion_Cliente', 'Mejor_fecha_Cliente',
       'Mejor_Hora_Cliente', 'Mejor_Durac_Cliente', 'ULT_Descripcion_Cli',
       'ULT_fecha_Cli', 'ULT_Hora_Cli', 'ULT_Durac_Cli', 'ULT_Descripcion_Tel',
       'ULT_fecha_Tel', 'ULT_Hora_Tel', 'ULT_Durac_Tel', 'Veces_Cliente',
       'Veces_Telefono', 'REPITENCIAS', 'Cantidad_Sin_Discador',
       'Cantidad_Discador', 'TELEFO1', 'TELEFO2', 'TELEFO3', 'REGION',
       'MARCADESBASE', 'MARCA2', 'FLGSUBPROCESO_HS', 'SITUACIONLABORAL']pho
# Out:
# Index(['LAST NAME', 'FIRST NAME', 'ADDRESS1', 'ADDRESS3', 'COMMENTS',
#        'VENDOR LEAD CODE', 'PROVINCE', 'CITY', 'EMAIL', 'COMMENTS_2',
#        'PHONE NUMBER', 'Order_Numero', 'Oferta', 'Tip_Prioridad', 'MARCA_2025',
#        'NOMCOMERCIAL', 'Perfil_ic', 'tipocliente', 'TIPOINGRESO', 'ASIGNACION',
#        'LINEA_FT', 'LINEA_HS_RS', 'LINEA_HS_PLUS', 'LINEA_FULL', 'MARCA',
#        'TIP_TELF', 'PROVEEDOR', 'PERFIL', 'SEGMENTO', 'SCORE', 'TASA',
#        'RANGO_TASA', 'ZONA', 'Tipo_Telf', 'Fecha_Llam', 'Hora_Llamada',
#        'FECHA_ENVIO', 'RETIRO', 'Mejor_Estado_Telefono',
#        'Mejor_Sub_Estado_Telefono', 'Mejor_Descripcion_Telefono',
#        'Mejor_Fecha_Telefono', 'Mejor_Hora_Telefono', 'Mejor_Durac_Telefono',
#        'Mejor_Estado_Cliente', 'Mejor_Sub_Estado_Cliente',
#        'Mejor_Descripcion_Cliente', 'Mejor_fecha_Cliente',
#        'Mejor_Hora_Cliente', 'Mejor_Durac_Cliente', 'ULT_Descripcion_Cli',
#        'ULT_fecha_Cli', 'ULT_Hora_Cli', 'ULT_Durac_Cli', 'ULT_Descripcion_Tel',
#        'ULT_fecha_Tel', 'ULT_Hora_Tel', 'ULT_Durac_Tel', 'Veces_Cliente',
#        'Veces_Telefono', 'REPITENCIAS', 'Cantidad_Sin_Discador',
#        'Cantidad_Discador', 'TELEFO1', 'TELEFO2', 'TELEFO3', 'REGION',
#        'MARCADESBASE', 'MARCA2', 'FLGSUBPROCESO_HS', 'SITUACIONLABORAL'],
#       dtype='str')

# %%
df_uno=df_uno[['LAST NAME', 'FIRST NAME', 'ADDRESS1', 'ADDRESS3', 'COMMENTS',
       'VENDOR LEAD CODE', 'PROVINCE', 'CITY', 'EMAIL', 'COMMENTS_2',
       'PHONE NUMBER']]

# %%
df_uno

# %%
df_uno.to_csv("C:\\Users\\DATA\\Documents\\datos\\01_script\\inicio\\base_01.csv", index=False,sep=';')

# %%
# Out:
# (593162, 71)

# %%
# df_efe_consumo['Mejor_Sub_Estado_Cliente'].unique()
    ['Mejor_Descripcion_Cliente'].unique()
# Out:
# <StringArray>
# [                             'NO QUIERE',
#                  'NO NECESITA / NO DESEA',
#                               'SI QUIERE',
#                          'ESTA ENDEUDADO',
#                         'DESEA MAS MONTO',
#                         'VOLVER A LLAMAR',
#                                   'OTROS',
#                      'CREDITO CONCRETADO',
#                          'LO VA A PENSAR',
#                        'CLIENTE DE VIAJE',
#                      'INTERESES ELEVADOS',
#         'TITULAR NO CALIFICA - DESEMPLEO',
#                         'ABONO EN CUENTA',
#             'CASA EN ZONA NO COBERTURADA',
#                   'SOLICITA SER RETIRADO',
#          'NEGOCIO EN ZONA NO COBERTURADA',
#              'MALA EXPERIENCIA (TDA/FNC)',
#  'TITULAR NO CALIFICA- GIRO RESTRINGIDO9',
#                          'CONFIRMAR CITA',
#       'TITULAR CONTAGIADO CON COVID - 19',
#                           'DESEA ELECTRO',
#                       'CLIENTE RECHAZADO']
# Length: 22, dtype: str

# %%
df_efe_consumo[df_efe_consumo['VENDOR LEAD CODE']=='47905540'].head()
# Out:
# Empty DataFrame
# Columns: [LAST NAME, FIRST NAME, ADDRESS1, ADDRESS3, COMMENTS, VENDOR LEAD CODE, PROVINCE, CITY, EMAIL, COMMENTS_2, PHONE NUMBER, Order_Numero, Oferta, Tip_Prioridad, MARCA_2025, NOMCOMERCIAL, Perfil_ic, tipocliente, TIPOINGRESO, ASIGNACION, LINEA_FT, LINEA_HS_RS, LINEA_HS_PLUS, LINEA_FULL, MARCA, TIP_TELF, PROVEEDOR, PERFIL, SEGMENTO, SCORE, TASA, RANGO_TASA, ZONA, Tipo_Telf, Fecha_Llam, Hora_Llamada, FECHA_ENVIO, RETIRO, Mejor_Estado_Telefono, Mejor_Sub_Estado_Telefono, Mejor_Descripcion_Telefono, Mejor_Fecha_Telefono, Mejor_Hora_Telefono, Mejor_Durac_Telefono, Mejor_Estado_Cliente, Mejor_Sub_Estado_Cliente, Mejor_Descripcion_Cliente, Mejor_fecha_Cliente, Mejor_Hora_Cliente, Mejor_Durac_Cliente, ULT_Descripcion_Cli, ULT_fecha_Cli, ULT_Hora_Cli, ULT_Durac_Cli, ULT_Descripcion_Tel, ULT_fecha_Tel, ULT_Hora_Tel, ULT_Durac_Tel, Veces_Cliente, Veces_Telefono, REPITENCIAS, Cantidad_Sin_Discador, Cantidad_Discador, TELEFO1, TELEFO2, TELEFO3, REGION, MARCADESBASE, MARCA2, FLGSUBPROCESO_HS, SITUACIONLABORAL]
# Index: []
#
# [0 rows x 71 columns]

# %%
df_efe_consumo.columns
# Out:
# Index(['LAST NAME', 'FIRST NAME', 'ADDRESS1', 'ADDRESS3', 'COMMENTS',
#        'VENDOR LEAD CODE', 'PROVINCE', 'CITY', 'EMAIL', 'COMMENTS_2',
#        'PHONE NUMBER', 'Order_Numero', 'Oferta', 'Tip_Prioridad', 'MARCA_2025',
#        'NOMCOMERCIAL', 'Perfil_ic', 'tipocliente', 'TIPOINGRESO', 'ASIGNACION',
#        'LINEA_FT', 'LINEA_HS_RS', 'LINEA_HS_PLUS', 'LINEA_FULL', 'MARCA',
#        'TIP_TELF', 'PROVEEDOR', 'PERFIL', 'SEGMENTO', 'SCORE', 'TASA',
#        'RANGO_TASA', 'ZONA', 'Tipo_Telf', 'Fecha_Llam', 'Hora_Llamada',
#        'FECHA_ENVIO', 'RETIRO', 'Mejor_Estado_Telefono',
#        'Mejor_Sub_Estado_Telefono', 'Mejor_Descripcion_Telefono',
#        'Mejor_Fecha_Telefono', 'Mejor_Hora_Telefono', 'Mejor_Durac_Telefono',
#        'Mejor_Estado_Cliente', 'Mejor_Sub_Estado_Cliente',
#        'Mejor_Descripcion_Cliente', 'Mejor_fecha_Cliente',
#        'Mejor_Hora_Cliente', 'Mejor_Durac_Cliente', 'ULT_Descripcion_Cli',
#        'ULT_fecha_Cli', 'ULT_Hora_Cli', 'ULT_Durac_Cli', 'ULT_Descripcion_Tel',
#        'ULT_fecha_Tel', 'ULT_Hora_Tel', 'ULT_Durac_Tel', 'Veces_Cliente',
#        'Veces_Telefono', 'REPITENCIAS', 'Cantidad_Sin_Discador',
#        'Cantidad_Discador', 'TELEFO1', 'TELEFO2', 'TELEFO3', 'REGION',
#        'MARCADESBASE', 'MARCA2', 'FLGSUBPROCESO_HS', 'SITUACIONLABORAL'],
#       dtype='str')
