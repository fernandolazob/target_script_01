# %%
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
import sys 
sys.path.append('C:/Users/DATA/Documents/datos/01_script/inicio/funciones')
from funciones import *
from funciones_spark import *
from variables_inicio import *
from utils_sql import *
from unidecode import unidecode
from sqlalchemy import create_engine
from sqlalchemy import text

fecha_mes_base='2026-08-01'

server_sql = server_kishin
db_sql = "DANTALION"
user_sql = user_kishin
pwd_sql = pwd_kishin

tipi_cond1='RECLUTAMIENTO'
servidor_01=64

engine_kishin = create_engine(
    f"mssql+pyodbc://{user_sql}:{pwd_sql}@{server_sql}/{db_sql}"
    "?driver=ODBC+Driver+17+for+SQL+Server"
)

server_sql = server_zeus
db_sql = "ODIN"
user_sql = user_zeus
pwd_sql = pwd_zeus
engine_zeus = create_engine(
    f"mssql+pyodbc://{user_sql}:{pwd_sql}@{server_sql}/{db_sql}"
    "?driver=ODBC+Driver+17+for+SQL+Server"
)

# %%
# filename='BASE GENERAL.xlsx'
filename='Avance Reclutamiento y Capacitacion 01 al 07 de agosto.xlsx'
# filename='BASE DE DATOS TRABAJADA JULIO 2026.xlsx'
ruta_archivo = os.path.join(ruta_rrhh, filename)
# df_embudo = pd.read_excel(ruta_archivo,sheet_name='EMBUDO JUNIO 2')
# df_embudo = pd.read_excel(ruta_archivo,sheet_name='JULIO 2026')
df_embudo = pd.read_excel(ruta_archivo,sheet_name='Avance Agosto 01 al 07')

df_embudo.columns = [
    unidecode(col)          # quita tildes y ñ -> n
    .lower()                # minúsculas
    .strip()                # quita espacios al inicio y final
    .replace(" ", "_")      # espacios por _
    for col in df_embudo.columns
]

mapeo = {
    "telefono_1": "cel01",
    "telefono_2": "cel02",
}

df_embudo.rename(columns=mapeo, inplace=True)


columnas_fecha = [
    'fecha_de_inscripcion',
    'fecha_de_gestion',
    'fecha_entrevista',
    'fecha_inicio_de_capacitacion',
    'fecha_de_ingreso',
    'fecha_de_nacimiento'
]

for col in columnas_fecha:
    df_embudo[col] = pd.to_datetime(
        df_embudo[col],
        dayfirst=True,
        errors='coerce'
    )

df_embudo = df_embudo[
    df_embudo['reclutador'].notna() &
    df_embudo['fecha_de_gestion'].notna()
]

df_embudo['numero_de_documento'] = (
    df_embudo['numero_de_documento']
    .fillna('')
    .astype(str)
    .str.replace(r'\.0$', '', regex=True)
)

# %%
df_embudo.head()
# Out:
#         reclutador fecha_de_gestion              nombre        apellido  \
# 0  FHERGIE INFANTE       2026-08-01       Isabel Maruja   Capcha Robles
# 1  FHERGIE INFANTE       2026-08-01  Evellyn del Carmen   Mendo Toribio
# 2  FHERGIE INFANTE       2026-08-01       Gloria Pamela  Yaranga Vargas
# 3  FHERGIE INFANTE       2026-08-01     Sonia milagros      Jorge Calle
# 4  FHERGIE INFANTE       2026-08-01     Piero Alexander  Gavilan Solano
#
#   tipo_de_documento numero_de_documento fecha_de_inscripcion  \
# 0               DNI            45413244           2026-07-31
# 1               DNI            46517946           2026-07-25
# 2               DNI            72001700           2026-07-24
# 3               DNI            42327057           2026-07-27
# 4               DNI            76306636           2026-07-30
#
#   fuentes_laborales              correo_electronico        cel01        cel02  \
# 0      COMPUTRABAJO         icapcharobles@gmail.com  920006767.0          NaN
# 1      COMPUTRABAJO            ebedelca30@gmail.com  930249412.0          NaN
# 2      COMPUTRABAJO  pamelayarangavargas5@gmail.com  924794558.0          NaN
# 3      COMPUTRABAJO        soniajorge1111@gmail.com  941178094.0          NaN
# 4      COMPUTRABAJO        gavilanpiero33@gmail.com  923884487.0  936958473.0
#
#   departamento                 distrito  \
# 0         LIMA  VILLA MARIA DEL TRIUNFO
# 1         LIMA            INDEPENDENCIA
# 2         LIMA          CERCADO DE LIMA
# 3         LIMA              EL AGUSTINO
# 4         LIMA              EL AGUSTINO
#
#                                                   direccion  \
# 0                            Av. Jose olaya 227-san gabriel
# 1    CALLE LAS LUCUMAS 149 URB ERL ERMITAÑO - INDEPENDENCIA
# 2                                PSJE CAHUIDE MZ D2 LOTE 11
# 3  3cdr Av Riva agüero calle la granada  psj trinitaria 422
# 4                              Mz Ñ Lt 24 AAHH 4to Programa
#
#   fecha_de_nacimiento  edad     genero estado_civil nacionalidad  \
# 0          1987-07-08  39.0   FEMENINO      SOLTERO      PERUANA
# 1          1987-12-26  38.0   FEMENINO      SOLTERO      PERUANA
# 2          1997-04-06  29.0   FEMENINO      SOLTERO      PERUANA
# 3          1980-11-11  45.0   FEMENINO      SOLTERO      PERUANA
# 4          2004-03-24  22.0  MASCULINO      SOLTERO      PERUANA
#
#              campana   modalidad    jornada   turno  \
# 0          DINERS TC  PRESENCIAL  FULL TIME  MAÑANA
# 1  EFECTIVA NEGOCIOS  PRESENCIAL  SEMI FULL  MAÑANA
# 2  EFECTIVA NEGOCIOS  PRESENCIAL  SEMI FULL   TARDE
# 3  EFECTIVA NEGOCIOS  PRESENCIAL  SEMI FULL  MAÑANA
# 4        DINERS SSFF  PRESENCIAL  SEMI FULL  MAÑANA
#
#                       horario_de_trabajo planilla          supervisor  sede  \
# 0   L - V 9:00 a 18:00; y S 9:00 a 14:00    MICRO        WILMER ACEDO  LIMA
# 1  L - V 11:00 a 18:00; y S 9:00 a 14:01    MICRO  KRISSEL CÁRDENAS    LIMA
# 2  L - V 11:00 a 18:00; y S 9:00 a 14:02    MICRO  KRISSEL CÁRDENAS    LIMA
# 3  L - V 11:00 a 18:00; y S 9:00 a 14:01    MICRO  KRISSEL CÁRDENAS    LIMA
# 4    L - V 9:00 a 16:00 y S 9:00 a 14:06    MICRO      JOHANA ARTEAGA  LIMA
#
#      llamada_1 status_llamada_1  llamada_2  status_llamada_2  \
# 0  NO CONTESTA    NO CONTACTADO        NaN               NaN
# 1     CONTESTA           CITADO        NaN               NaN
# 2     CONTESTA           CITADO        NaN               NaN
# 3    CONTESTA            CITADO        NaN               NaN
# 4     CONTESTA           CITADO        NaN               NaN
#
#   mensaje_whats_app status_whats_app fecha_entrevista entrevista  \
# 0               NaN              NaN              NaT        NaN
# 1               NaN              NaN       2026-08-01   PRESENTE
# 2               NaN              NaN       2026-08-01   PRESENTE
# 3               NaN              NaN       2026-08-01   PRESENTE
# 4               NaN              NaN       2026-07-31   PRESENTE
#
#   status_entrevista fecha_inicio_de_capacitacion       capacitacion  \
# 0               NaN                          NaT                NaN
# 1              APTO                   2026-08-01  ASISTE PRIMER DÍA
# 2              APTO                   2026-08-01  ASISTE PRIMER DÍA
# 3              APTO                   2026-08-01  ASISTE PRIMER DÍA
# 4              APTO                   2026-08-03  ASISTE PRIMER DÍA
#
#   motivo_capacitacion                 ojt              motivo_ojt  \
# 0                 NaN                 NaN                     NaN
# 1          EN PROCESO  ASISTE PRIMER DÍA                 COMPLETÓ
# 2          EN PROCESO  ASISTE PRIMER DÍA                 COMPLETÓ
# 3          EN PROCESO  ASISTE PRIMER DÍA   NO PASA CERTIFICACIÓN
# 4          EN PROCESO  ASISTE PRIMER DÍA                 COMPLETÓ
#
#   firma_de_contrato fecha_de_ingreso observacion
# 0               NaN              NaT         NaN
# 1                SÍ              NaT         NaN
# 2                SÍ              NaT         NaN
# 3               NaN              NaT         NaN
# 4                NO              NaT         NaN

# %%
df_embudo['numero_de_documento'] = (
    df_embudo['numero_de_documento']
    .astype(str)
    .str.replace(r'\D', '', regex=True)      # deja solo números
    .replace('', pd.NA)                      # vacío -> NA
    .mask(lambda s: s.str.len() > 8, pd.NA)  # >8 dígitos -> NA
    .str.zfill(8)                            # <8 dígitos -> completa con ceros
)

# %%
for columna in ['cel01', 'cel02']:
    df_embudo[f'{columna}'] = (
        df_embudo[columna]
        .astype('string')
        .str.replace(r'\D', '', regex=True)
        .str.strip()
    )
df_embudo['cel01'] = df_embudo['cel01'].fillna(
    df_embudo['cel02']
)
df_embudo["edad"] = pd.to_numeric(
    df_embudo["edad"],
    errors="coerce"
)

# %%
bins = [17, 24, 29, 39, 49, 59, 65, np.inf]

labels = [
    "18 - 24",
    "25 - 29",
    "30 - 39",
    "40 - 49",
    "50 - 59",
    "60 - 65",
    "66+"
]

df_embudo["seg_edad"] = (
    pd.cut(
        df_embudo["edad"],
        bins=bins,
        labels=labels
    )
    .cat.add_categories("No registra")
    .fillna("No registra")
)

# %%
df_embudo["llave_postulante"] = (
    df_embudo["nombre"].fillna("").str.strip().str.upper() + "|" +
    df_embudo["apellido"].fillna("").str.strip().str.upper() + "|" +
    df_embudo["cel01"].fillna("").astype(str).str.strip()
)

dni_por_llave = (
    df_embudo
    .dropna(subset=["numero_de_documento"])
    .drop_duplicates("llave_postulante")
    .set_index("llave_postulante")["numero_de_documento"]
)

df_embudo["numero_de_documento"] = (
    df_embudo["numero_de_documento"]
    .fillna(df_embudo["llave_postulante"].map(dni_por_llave))
)

dni_invalidos = [
    "00000000",
    "99999999",
    "11111111",
    "12345678"
]

df_embudo["numero_de_documento"] = (
    df_embudo["numero_de_documento"]
    .replace(dni_invalidos, pd.NA)
)

df_embudo['id_postulante'] = np.where(
    df_embudo['numero_de_documento'].notna(),
    'DNI_' + df_embudo['numero_de_documento'],
    'TELF_' + df_embudo['cel01']
)
df_embudo["numero_de_documento"] = (
    df_embudo["numero_de_documento"]
    .fillna(df_embudo["cel01"])
)

# %% [markdown]
# ## tb postulante

# %%
columnas_postulante = [
        'nombre',
        'apellido',
        'tipo_de_documento',
        'numero_de_documento',
        'fecha_de_inscripcion',
        'fuentes_laborales',
        'correo_electronico',
        'departamento',
        'distrito',
        'direccion',
        'fecha_de_nacimiento',
        'edad',
        'genero',
        'estado_civil',
        'nacionalidad',
        'fecha_de_gestion'
    ]

df_postulante = (
    df_embudo
    .sort_values(
        'fecha_de_gestion',
        ascending=False
    )[
        ['id_postulante'] + columnas_postulante
    ]
    .groupby(
        'id_postulante',
        as_index=False,
        sort=False
    )
    .first()
    .copy()
)
df_postulante = df_postulante.drop(columns='fecha_de_gestion')

# %%
columnas_eliminar = columnas_postulante.copy()
columnas_eliminar.remove('fuentes_laborales')
columnas_eliminar.remove('fecha_de_gestion')

df_embudo = (
    df_embudo
    .drop(columns=columnas_eliminar)
    .copy()
)

# %% [markdown]
# ## tabla evento

# %%
df_embudo = df_embudo[
    (df_embudo['fecha_de_gestion'] >= pd.Timestamp('2026-06-30')) &
    (df_embudo['campana'].notna())&
    (df_embudo['reclutador'].notna())
]

# %%
columnas_evento = [
    'id_postulante',
    'campana',
    'fuentes_laborales',
    'modalidad',
    'jornada',
    'turno',
    'horario_de_trabajo',
    'planilla',
    'supervisor',
    'sede',
    'fecha_de_gestion',
    'reclutador',
    'fecha_entrevista',
    'entrevista',
    'status_entrevista',
    'fecha_inicio_de_capacitacion',
    'capacitacion',
    'motivo_capacitacion',
    'ojt',
    'motivo_ojt',
    'firma_de_contrato',
    'fecha_de_ingreso',
    'observacion'
]

df_evento = df_embudo[columnas_evento].copy()

fecha_gestion_ingreso = (
    df_evento.loc[df_evento['fecha_de_ingreso'].notna()]
    .groupby(['id_postulante', 'campana'])['fecha_de_gestion']
    .max()
    .rename('fecha_gestion_ingreso')
)

df_evento = df_evento.merge(
    fecha_gestion_ingreso,
    on=['id_postulante', 'campana'],
    how='left'
)


df_evento = df_evento[
    df_evento['fecha_gestion_ingreso'].isna()
    | (df_evento['fecha_de_gestion'] <= df_evento['fecha_gestion_ingreso'])
].copy()

df_evento = (
    df_evento
    .sort_values(
        ['id_postulante', 'campana', 'fecha_de_gestion'],
        ascending=[True, True, False]
    )
    .drop_duplicates(
        subset=['id_postulante', 'campana'],
        keep='first'
    )
    .drop(columns=['fecha_gestion_ingreso'])
    .rename(columns={'fecha_de_gestion': 'fecha_de_gestion_evento'})
    .reset_index(drop=True)
)

columnas_eliminar = columnas_evento.copy()
columnas_eliminar = [
    c for c in columnas_eliminar
    if c not in {
        'fecha_de_gestion',
        'fecha_de_ingreso',
        'id_postulante',
        'reclutador',
        'campana'
    }
]

df_embudo = (
    df_embudo
    .drop(columns=columnas_eliminar)
    .copy()
)

# %%
df_postulante = df_postulante[
    df_postulante['id_postulante'].isin(df_evento['id_postulante'])
].copy()

nro_campanas = (
    df_evento
    .groupby('id_postulante')['campana']
    .nunique()
)

df_postulante['nro_campanas'] = (
    df_postulante['id_postulante']
    .map(nro_campanas)
    .fillna(0)
    .astype('int16')
)

# %% [markdown]
# ### tabla status_base

# %%
columnas_status = [
    'id_postulante',
    'campana',
    'reclutador',
    'llamada_1',
    'status_llamada_1',
    'llamada_2',
    'status_llamada_2',
    'mensaje_whats_app',
    'status_whats_app',
    'fecha_de_gestion',
    'cel01',
    'cel02'
]

df_status = df_embudo[columnas_status].copy()

columnas_status = [
    'status_llamada_1',
    'status_llamada_2',
    'status_whats_app'
]

for columna in columnas_status:
    df_status[columna] = (
        df_status[columna]
        .astype("string")
        .str.strip()
        .str.upper()
        .replace({
            "": pd.NA,
            "NAN": pd.NA,
            "NONE": pd.NA,
            "NULL": pd.NA
        })
    )
df_llamada_1 = (
    df_status[
        [
            'id_postulante',
            'campana',
            'reclutador',
            'fecha_de_gestion',
            'llamada_1',
            'status_llamada_1',
            'cel01',
            'cel02'
        ]
    ]
    .rename(columns={
        'reclutador':'reclutador_status',
        'llamada_1':'detalle_intento',
        'status_llamada_1':'status'
    })
)

df_llamada_1['tipo_intento'] = 'LLAMADA 1'
df_llamada_1['orden_intento'] = 1

df_llamada_2 = (
    df_status[
        [
            'id_postulante',
            'campana',
            'reclutador',
            'fecha_de_gestion',
            'llamada_2',
            'status_llamada_2',
            'cel01',
            'cel02'
        ]
    ]
    .rename(columns={
        'reclutador':'reclutador_status',
        'llamada_2':'detalle_intento',
        'status_llamada_2':'status'
    })
)

df_llamada_2['tipo_intento'] = 'LLAMADA 2'
df_llamada_2['orden_intento'] = 2

df_whatsapp = (
    df_status[
        [
            'id_postulante',
            'campana',
            'reclutador',
            'fecha_de_gestion',
            'mensaje_whats_app',
            'status_whats_app',
            'cel01',
            'cel02'
        ]
    ]
    .rename(columns={
        'reclutador':'reclutador_status',
        'mensaje_whats_app':'detalle_intento',
        'status_whats_app':'status'
    })
)

df_whatsapp['tipo_intento'] = 'WHATSAPP'
df_whatsapp['orden_intento'] = 3

df_status_consolidado = pd.concat(
    [
        df_llamada_1,
        df_llamada_2,
        df_whatsapp
    ],
    ignore_index=True
)
df_status_consolidado = (
    df_status_consolidado
    .dropna(subset=['status'])
    .reset_index(drop=True)
)

# %%
peso_status = {
    'CITADO': 1,
    'REPROGRAMAR LLAMADA': 2,
    'ESCRIBIR POR WHATS APP': 3,
    'LABORANDO ACTUALMENTE': 4,
    'DESEA REMOTO': 5,
    'DISTANCIA': 6,
    'NO INTERESADO EN SALARIO': 7,
    'NO INTERESADO EN PLANILLA MYPE': 8,
    'NO INTERESADO EN HORARIOS': 9,
    'NO INTERESADO EN VENTAS': 10,
    'NO INTERESADO EN LA PROPUESTA LABORAL': 11,
    'NO PERFIL': 12,
    'EDAD': 13,
    'GESTACIÓN': 14,
    'BLACK LIST': 15,
    'NO CONTACTADO': 99
}
df_status_consolidado['peso_status'] = (
    df_status_consolidado['status']
    .map(peso_status)
)

# %%
llaves = ['id_postulante', 'campana']

for intento, columna in {
    'LLAMADA 1': 'q_llamada_1',
    'LLAMADA 2': 'q_llamada_2',
    'WHATSAPP': 'q_whatsapp'
}.items():

    df_status_consolidado[columna] = (
        df_status_consolidado['tipo_intento']
        .eq(intento)
        .groupby([df_status_consolidado[c] for c in llaves])
        .transform('sum')
    )

# %%
df_status_mr = (
    df_status_consolidado
    .sort_values(
        llaves + [
            'peso_status',
            'fecha_de_gestion',
            'orden_intento'
        ],
        ascending=[
            True,
            True,
            True,
            False,
            False
        ],
        na_position='last'
    )
    .drop_duplicates(
        subset=llaves,
        keep='first'
    )
    [
        llaves + [
            'status',
            'reclutador_status',
            'peso_status',
            'fecha_de_gestion',
            'tipo_intento',
            'detalle_intento',
            'q_llamada_1',
            'q_llamada_2',
            'q_whatsapp'
        ]
    ]
    .rename(
        columns={
            'status': 'mejor_status',
            'peso_status': 'peso_mejor_status',
            'fecha_de_gestion': 'fecha_mejor_status',
            'tipo_intento': 'canal_mejor_status',
            'detalle_intento': 'detalle_mejor_intento'
        }
    )
)

# %%
df_evento = df_evento.merge(
    df_status_mr,
    on=['id_postulante', 'campana'],
    how='left'
)

# %%
df_evento['llave_postulante_campana'] = (
    df_evento['id_postulante']
    + '_'
    + df_evento['campana']
)
df_status_consolidado['llave_postulante_campana'] = (
    df_status_consolidado['id_postulante']
    + '_'
    + df_status_consolidado['campana']
)

# %%
df_postulante_campana = (
    df_evento[
        # ['llave_postulante_campana', 'id_postulante', 'campana']
        ['id_postulante', 'llave_postulante_campana', 'campana', 'jornada', 'turno', 'horario_de_trabajo', 'planilla', 'supervisor', 'sede', 'fecha_entrevista', 'capacitacion', 'motivo_capacitacion', 'ojt', 'motivo_ojt', 'observacion', 'reclutador', 'peso_mejor_status', 'fecha_mejor_status', 'modalidad','entrevista','reclutador_status','fuentes_laborales','fecha_de_ingreso','fecha_de_gestion_evento']

    ]
    .drop_duplicates()
    .reset_index(drop=True)
)

# %%
print(df_status_consolidado.shape)
print(df_postulante.shape)
print(df_evento.shape)
print(df_postulante_campana.shape)
# Out:
# (213, 15)
# (179, 17)
# (187, 33)
# (187, 24)

# %%
df_validar = df_postulante[
    ~df_postulante['id_postulante'].isin(df_evento['id_postulante'])
].copy()

# %%
df_validar.head()
# Out:
# Empty DataFrame
# Columns: [id_postulante, nombre, apellido, tipo_de_documento, numero_de_documento, fecha_de_inscripcion, fuentes_laborales, correo_electronico, departamento, distrito, direccion, fecha_de_nacimiento, edad, genero, estado_civil, nacionalidad, nro_campanas]
# Index: []

# %%
print(df_evento.columns.tolist())
# print(df_status_mr.columns.tolist())
print(df_status_consolidado.columns.tolist())
print(df_postulante.columns.tolist())
# Out:
# ['id_postulante', 'campana', 'fuentes_laborales', 'modalidad', 'jornada', 'turno', 'horario_de_trabajo', 'planilla', 'supervisor', 'sede', 'fecha_de_gestion_evento', 'reclutador', 'fecha_entrevista', 'entrevista', 'status_entrevista', 'fecha_inicio_de_capacitacion', 'capacitacion', 'motivo_capacitacion', 'ojt', 'motivo_ojt', 'firma_de_contrato', 'fecha_de_ingreso', 'observacion', 'mejor_status', 'reclutador_status', 'peso_mejor_status', 'fecha_mejor_status', 'canal_mejor_status', 'detalle_mejor_intento', 'q_llamada_1', 'q_llamada_2', 'q_whatsapp', 'llave_postulante_campana']
# ['id_postulante', 'campana', 'reclutador_status', 'fecha_de_gestion', 'detalle_intento', 'status', 'cel01', 'cel02', 'tipo_intento', 'orden_intento', 'peso_status', 'q_llamada_1', 'q_llamada_2', 'q_whatsapp', 'llave_postulante_campana']
# ['id_postulante', 'nombre', 'apellido', 'tipo_de_documento', 'numero_de_documento', 'fecha_de_inscripcion', 'fuentes_laborales', 'correo_electronico', 'departamento', 'distrito', 'direccion', 'fecha_de_nacimiento', 'edad', 'genero', 'estado_civil', 'nacionalidad', 'nro_campanas']

# %%
from sqlalchemy import text

with engine_zeus.begin() as conn:
    conn.execute(text("DROP TABLE IF EXISTS tb_rrhh_postulante"))
    conn.execute(text("DROP TABLE IF EXISTS tb_rrhh_proceso"))
    conn.execute(text("DROP TABLE IF EXISTS tb_rrhh_intentos"))
    conn.execute(text("DROP TABLE IF EXISTS tb_rrhh_postulante_campana"))
    # conn.execute(text("TRUNCATE TABLE tb_funnel_reclutamiento"))
    # conn.execute(text("TRUNCATE TABLE tb_funnel_reclutamiento"))
    # conn.execute(text("TRUNCATE TABLE tb_funnel_reclutamiento"))

# %%
display(df_postulante.head(3))
display(df_evento.head(3))
display(df_status_consolidado.head(3))
display(df_postulante_campana.head(3))
# Out:
#   id_postulante        nombre        apellido tipo_de_documento  \
# 0  DNI_74008562          Jhon    Durand Rojas               DNI
# 1  DNI_70097210  Juan carlos      Torres vara               DNI
# 2  DNI_73818083    Jason Lual  Flores Andrade               DNI
#
#   numero_de_documento fecha_de_inscripcion fuentes_laborales  \
# 0            74008562           2026-08-05      COMPUTRABAJO
# 1            70097210           2026-08-07           HUNTING
# 2            73818083           2026-08-06      COMPUTRABAJO
#
#                correo_electronico departamento           distrito  \
# 0       jhonedurand2007@gmail.com         LIMA  VILLA EL SALVADOR
# 1  Torresvarajuancarlos@gmail.com         LIMA              COMAS
# 2         floresjasonlu@gmail.com         LIMA         CARABAYLLO
#
#                              direccion fecha_de_nacimiento  edad     genero  \
# 0                                 None          2007-02-15  19.0  MASCULINO
# 1  Calle francisco de paulo quiroz 201          1993-12-23  32.0  MASCULINO
# 2                                 None          2005-11-19  20.0  MASCULINO
#
#   estado_civil nacionalidad  nro_campanas
# 0      SOLTERO      PERUANA             1
# 1      SOLTERO      PERUANA             1
# 2      SOLTERO      PERUANA             1
#   id_postulante        campana fuentes_laborales   modalidad    jornada  \
# 0  DNI_00054842  CENCOSUD SSFF      COMPUTRABAJO  PRESENCIAL  SEMI FULL
# 1  DNI_05496458  CENCOSUD SSFF      COMPUTRABAJO  PRESENCIAL  SEMI FULL
# 2  DNI_06540001  CENCOSUD SSFF      COMPUTRABAJO  PRESENCIAL  SEMI FULL
#
#    turno                     horario_de_trabajo planilla  supervisor  sede  \
# 0  TARDE  L - V 11:00 a 18:00; y S 9:00 a 14:13    MICRO  ROSA NOVOA  LIMA
# 1  TARDE  L - V 11:00 a 18:00; y S 9:00 a 14:10    MICRO  ROSA NOVOA  LIMA
# 2  TARDE  L - V 11:00 a 18:00; y S 9:00 a 14:17    MICRO  ROSA NOVOA  LIMA
#
#   fecha_de_gestion_evento         reclutador fecha_entrevista entrevista  \
# 0              2026-08-05  OCTAVIO RODRIGUEZ              NaT        NaN
# 1              2026-08-05  OCTAVIO RODRIGUEZ              NaT        NaN
# 2              2026-08-04  OCTAVIO RODRIGUEZ              NaT        NaN
#
#   status_entrevista fecha_inicio_de_capacitacion capacitacion  \
# 0               NaN                          NaT          NaN
# 1               NaN                          NaT          NaN
# 2               NaN                          NaT          NaN
#
#   motivo_capacitacion  ojt motivo_ojt firma_de_contrato fecha_de_ingreso  \
# 0                 NaN  NaN        NaN               NaN              NaT
# 1                 NaN  NaN        NaN               NaN              NaT
# 2                 NaN  NaN        NaN               NaN              NaT
#
#   observacion   mejor_status  reclutador_status  peso_mejor_status  \
# 0         NaN      NO PERFIL  OCTAVIO RODRIGUEZ               12.0
# 1         NaN  NO CONTACTADO  OCTAVIO RODRIGUEZ               99.0
# 2         NaN  NO CONTACTADO  OCTAVIO RODRIGUEZ               99.0
#
#   fecha_mejor_status canal_mejor_status detalle_mejor_intento  q_llamada_1  \
# 0         2026-08-05           WHATSAPP              CONTESTA          1.0
# 1         2026-08-05          LLAMADA 1           NO CONTESTA          1.0
# 2         2026-08-04          LLAMADA 1           NO CONTESTA          1.0
#
#    q_llamada_2  q_whatsapp    llave_postulante_campana
# 0          0.0         1.0  DNI_00054842_CENCOSUD SSFF
# 1          0.0         0.0  DNI_05496458_CENCOSUD SSFF
# 2          0.0         0.0  DNI_06540001_CENCOSUD SSFF
#   id_postulante            campana reclutador_status fecha_de_gestion  \
# 0  DNI_45413244          DINERS TC   FHERGIE INFANTE       2026-08-01
# 1  DNI_46517946  EFECTIVA NEGOCIOS   FHERGIE INFANTE       2026-08-01
# 2  DNI_72001700  EFECTIVA NEGOCIOS   FHERGIE INFANTE       2026-08-01
#
#   detalle_intento         status       cel01 cel02 tipo_intento  \
# 0     NO CONTESTA  NO CONTACTADO  9200067670  <NA>    LLAMADA 1
# 1        CONTESTA         CITADO  9302494120  <NA>    LLAMADA 1
# 2        CONTESTA         CITADO  9247945580  <NA>    LLAMADA 1
#
#    orden_intento  peso_status  q_llamada_1  q_llamada_2  q_whatsapp  \
# 0              1         99.0            1            0           0
# 1              1          1.0            1            0           0
# 2              1          1.0            1            0           0
#
#          llave_postulante_campana
# 0          DNI_45413244_DINERS TC
# 1  DNI_46517946_EFECTIVA NEGOCIOS
# 2  DNI_72001700_EFECTIVA NEGOCIOS
#   id_postulante    llave_postulante_campana        campana    jornada  turno  \
# 0  DNI_00054842  DNI_00054842_CENCOSUD SSFF  CENCOSUD SSFF  SEMI FULL  TARDE
# 1  DNI_05496458  DNI_05496458_CENCOSUD SSFF  CENCOSUD SSFF  SEMI FULL  TARDE
# 2  DNI_06540001  DNI_06540001_CENCOSUD SSFF  CENCOSUD SSFF  SEMI FULL  TARDE
#
#                       horario_de_trabajo planilla  supervisor  sede  \
# 0  L - V 11:00 a 18:00; y S 9:00 a 14:13    MICRO  ROSA NOVOA  LIMA
# 1  L - V 11:00 a 18:00; y S 9:00 a 14:10    MICRO  ROSA NOVOA  LIMA
# 2  L - V 11:00 a 18:00; y S 9:00 a 14:17    MICRO  ROSA NOVOA  LIMA
#
#   fecha_entrevista capacitacion motivo_capacitacion  ojt motivo_ojt  \
# 0              NaT          NaN                 NaN  NaN        NaN
# 1              NaT          NaN                 NaN  NaN        NaN
# 2              NaT          NaN                 NaN  NaN        NaN
#
#   observacion         reclutador  peso_mejor_status fecha_mejor_status  \
# 0         NaN  OCTAVIO RODRIGUEZ               12.0         2026-08-05
# 1         NaN  OCTAVIO RODRIGUEZ               99.0         2026-08-05
# 2         NaN  OCTAVIO RODRIGUEZ               99.0         2026-08-04
#
#     modalidad entrevista  reclutador_status fuentes_laborales  \
# 0  PRESENCIAL        NaN  OCTAVIO RODRIGUEZ      COMPUTRABAJO
# 1  PRESENCIAL        NaN  OCTAVIO RODRIGUEZ      COMPUTRABAJO
# 2  PRESENCIAL        NaN  OCTAVIO RODRIGUEZ      COMPUTRABAJO
#
#   fecha_de_ingreso fecha_de_gestion_evento
# 0              NaT              2026-08-05
# 1              NaT              2026-08-05
# 2              NaT              2026-08-04

# %%
df_postulante.to_sql(
    name="tb_rrhh_postulante",
    con=engine_zeus,
    if_exists="append",
    index=False,
    chunksize=1000
)

df_evento.to_sql(
    name="tb_rrhh_proceso",
    con=engine_zeus,
    if_exists="append",
    index=False,
    chunksize=1000
)
df_status_consolidado.to_sql(
    name="tb_rrhh_intentos",
    con=engine_zeus,
    if_exists="append",
    index=False,
    chunksize=1000
)
df_postulante_campana.to_sql(
    name="tb_rrhh_postulante_campana",
    con=engine_zeus,
    if_exists="append",
    index=False,
    chunksize=1000
)
# Out:
# 13

# %%
df_evento[df_evento['id_postulante']=='DNI_44179244']
# Out:
#     id_postulante        campana fuentes_laborales   modalidad    jornada  \
# 244  DNI_44179244  CENCOSUD SSFF           HUNTING  PRESENCIAL  SEMI FULL
# 245  DNI_44179244    DINERS SSFF    BASE RECICLADA  PRESENCIAL  SEMI FULL
#
#       turno                    horario_de_trabajo planilla      supervisor  \
# 244  MAÑANA                   11:00 AM A 06:00 PM    MICRO    JUAN CAMACHO
# 245  MAÑANA  L - V 9:00 a 18:00; y S 9:00 a 14:43    MICRO  JOHANA ARTEAGA
#
#      sede fecha_de_gestion_evento         reclutador fecha_entrevista  \
# 244  LIMA              2026-07-01    KIMBHERLY CORRO       2026-07-01
# 245  LIMA              2026-07-25  OCTAVIO RODRIGUEZ              NaT
#
#     entrevista           status_entrevista fecha_inicio_de_capacitacion  \
# 244   PRESENTE  SE RETIRA DE LA ENTREVISTA                          NaT
# 245        NaN                         NaN                          NaT
#
#     capacitacion motivo_capacitacion  ojt motivo_ojt firma_de_contrato  \
# 244          NaN                 NaN  NaN        NaN               NaN
# 245          NaN                 NaN  NaN        NaN               NaN
#
#     fecha_de_ingreso observacion   mejor_status  reclutador_status  \
# 244              NaT         NaN         CITADO    KIMBHERLY CORRO
# 245              NaT         NaN  NO CONTACTADO  OCTAVIO RODRIGUEZ
#
#      peso_mejor_status fecha_mejor_status canal_mejor_status  \
# 244                1.0         2026-07-01          LLAMADA 1
# 245               99.0         2026-07-25          LLAMADA 1
#
#     detalle_mejor_intento  q_llamada_1  q_llamada_2  q_whatsapp  \
# 244              CONTESTA          1.0          0.0         0.0
# 245           NO CONTESTA          1.0          0.0         0.0
#
#        llave_postulante_campana
# 244  DNI_44179244_CENCOSUD SSFF
# 245    DNI_44179244_DINERS SSFF

# %%
ruta_archivo = os.path.join(ruta_csv, 'negocios_1.xlsx')

df_postulante.to_excel(ruta_archivo, index=False)

# %%
# display(df_evento.head(3))
# Out:
#   id_postulante            campana   modalidad    jornada   turno  \
# 0  DNI_01481748  EFECTIVA NEGOCIOS  PRESENCIAL  SEMI FULL   TARDE
# 1  DNI_02556064        DINERS SSFF  PRESENCIAL  SEMI FULL   TARDE
# 2  DNI_02556064  EFECTIVA NEGOCIOS  PRESENCIAL  SEMI FULL  MAÑANA
#
#                       horario_de_trabajo planilla          supervisor  sede  \
# 0  L - V 11:00 a 18:00; y S 9:00 a 14:01    MICRO  KRISSEL CÁRDENAS    LIMA
# 1                    11:00 AM A 06:00 PM    MICRO      JOHANA ARTEAGA  LIMA
# 2                     11:00 am a 4:00 pm    MICRO  KRISSEL CÁRDENAS    LIMA
#
#   fecha_de_gestion_evento fecha_entrevista entrevista  \
# 0              2026-07-17       2026-07-18   PRESENTE
# 1              2026-07-09              NaT        NaN
# 2              2026-07-15       2026-06-16        NaN
#
#             status_entrevista fecha_inicio_de_capacitacion capacitacion  \
# 0  SE RETIRA DE LA ENTREVISTA                          NaT          NaN
# 1                         NaN                          NaT          NaN
# 2                         NaN                          NaT          NaN
#
#   motivo_capacitacion  ojt motivo_ojt firma_de_contrato fecha_de_ingreso  \
# 0                 NaN  NaN        NaN               NaN              NaT
# 1                 NaN  NaN        NaN               NaN              NaT
# 2                 NaN  NaN        NaN               NaN              NaT
#
#   observacion mejor_status         reclutador  peso_mejor_status  \
# 0         NaN       CITADO    KIMBHERLY CORRO                1.0
# 1         NaN    DISTANCIA  OCTAVIO RODRIGUEZ                6.0
# 2         NaN       CITADO    KIMBHERLY CORRO                1.0
#
#   fecha_mejor_status canal_mejor_status detalle_mejor_intento  q_llamada_1  \
# 0         2026-07-17          LLAMADA 1              CONTESTA          1.0
# 1         2026-07-09          LLAMADA 1              CONTESTA          1.0
# 2         2026-07-15           WHATSAPP              CONTESTA          2.0
#
#    q_llamada_2  q_whatsapp        llave_postulante_campana
# 0          0.0         0.0  DNI_01481748_EFECTIVA NEGOCIOS
# 1          0.0         0.0        DNI_02556064_DINERS SSFF
# 2          2.0         2.0  DNI_02556064_EFECTIVA NEGOCIOS

# %%
df_evento[df_evento["id_postulante"]=='DNI_01481748'].head()
# Out:
#   id_postulante            campana fuentes_laborales   modalidad    jornada  \
# 0  DNI_01481748  EFECTIVA NEGOCIOS      COMPUTRABAJO  PRESENCIAL  SEMI FULL
#
#    turno                     horario_de_trabajo planilla          supervisor  \
# 0  TARDE  L - V 11:00 a 18:00; y S 9:00 a 14:01    MICRO  KRISSEL CÁRDENAS
#
#    sede fecha_de_gestion_evento       reclutador fecha_entrevista entrevista  \
# 0  LIMA              2026-07-17  KIMBHERLY CORRO       2026-07-18   PRESENTE
#
#             status_entrevista fecha_inicio_de_capacitacion capacitacion  \
# 0  SE RETIRA DE LA ENTREVISTA                          NaT          NaN
#
#   motivo_capacitacion  ojt motivo_ojt firma_de_contrato fecha_de_ingreso  \
# 0                 NaN  NaN        NaN               NaN              NaT
#
#   observacion mejor_status reclutador_status  peso_mejor_status  \
# 0         NaN       CITADO   KIMBHERLY CORRO                1.0
#
#   fecha_mejor_status canal_mejor_status detalle_mejor_intento  q_llamada_1  \
# 0         2026-07-17          LLAMADA 1              CONTESTA          1.0
#
#    q_llamada_2  q_whatsapp        llave_postulante_campana
# 0          0.0         0.0  DNI_01481748_EFECTIVA NEGOCIOS

# %%
df_postulante_campana[df_postulante_campana['id_postulante']=='DNI_05966484'].head(3)
# Out:
#    id_postulante        llave_postulante_campana            campana  \
# 8   DNI_05966484      DNI_05966484_CENCOSUD SSFF      CENCOSUD SSFF
# 9   DNI_05966484          DNI_05966484_DINERS TC          DINERS TC
# 10  DNI_05966484  DNI_05966484_EFECTIVA NEGOCIOS  EFECTIVA NEGOCIOS
#
#       jornada   turno   horario_de_trabajo planilla          supervisor  \
# 8   SEMI FULL  MAÑANA  11:00 AM A 06:00 PM    MICRO        JUAN CAMACHO
# 9   FULL TIME  MAÑANA    9:00 am a 6:00 pm      RXH        JUAN CAMACHO
# 10  SEMI FULL   TARDE  11:00 AM A 06:00 PM    MICRO  KRISSEL CÁRDENAS
#
#      sede fecha_entrevista capacitacion motivo_capacitacion  ojt motivo_ojt  \
# 8   COMAS              NaT          NaN                 NaN  NaN        NaN
# 9   COMAS              NaT          NaN                 NaN  NaN        NaN
# 10   LIMA              NaT          NaN                 NaN  NaN        NaN
#
#    observacion       reclutador  peso_mejor_status fecha_mejor_status  \
# 8      APAGADO  FHERGIE INFANTE               99.0         2026-07-01
# 9          NaN              NaN                NaN                NaT
# 10         NaN  FHERGIE INFANTE               11.0         2026-07-08
#
#      modalidad entrevista
# 8   PRESENCIAL        NaN
# 9   PRESENCIAL        NaN
# 10  PRESENCIAL        NaN

# %%
df_evento[df_evento['id_postulante']=='DNI_05966484'].head(3)
# Out:
#    id_postulante            campana   modalidad    jornada   turno  \
# 8   DNI_05966484      CENCOSUD SSFF  PRESENCIAL  SEMI FULL  MAÑANA
# 9   DNI_05966484          DINERS TC  PRESENCIAL  FULL TIME  MAÑANA
# 10  DNI_05966484  EFECTIVA NEGOCIOS  PRESENCIAL  SEMI FULL   TARDE
#
#      horario_de_trabajo planilla          supervisor   sede  \
# 8   11:00 AM A 06:00 PM    MICRO        JUAN CAMACHO  COMAS
# 9     9:00 am a 6:00 pm      RXH        JUAN CAMACHO  COMAS
# 10  11:00 AM A 06:00 PM    MICRO  KRISSEL CÁRDENAS     LIMA
#
#    fecha_de_gestion_evento fecha_entrevista entrevista status_entrevista  \
# 8               2026-07-01              NaT        NaN               NaN
# 9               2026-07-02              NaT        NaN               NaN
# 10              2026-07-08              NaT        NaN               NaN
#
#    fecha_inicio_de_capacitacion capacitacion motivo_capacitacion  ojt  \
# 8                           NaT          NaN                 NaN  NaN
# 9                           NaT          NaN                 NaN  NaN
# 10                          NaT          NaN                 NaN  NaN
#
#    motivo_ojt firma_de_contrato fecha_de_ingreso observacion  \
# 8         NaN               NaN              NaT     APAGADO
# 9         NaN               NaN              NaT         NaN
# 10        NaN               NaN              NaT         NaN
#
#                              mejor_status       reclutador  peso_mejor_status  \
# 8                           NO CONTACTADO  FHERGIE INFANTE               99.0
# 9                                    <NA>              NaN                NaN
# 10  NO INTERESADO EN LA PROPUESTA LABORAL  FHERGIE INFANTE               11.0
#
#    fecha_mejor_status canal_mejor_status detalle_mejor_intento  q_llamada_1  \
# 8          2026-07-01          LLAMADA 1               APAGADO          1.0
# 9                 NaT                NaN                   NaN          NaN
# 10         2026-07-08          LLAMADA 1              CONTESTA          1.0
#
#     q_llamada_2  q_whatsapp        llave_postulante_campana
# 8           0.0         0.0      DNI_05966484_CENCOSUD SSFF
# 9           NaN         NaN          DNI_05966484_DINERS TC
# 10          0.0         0.0  DNI_05966484_EFECTIVA NEGOCIOS

# %%
df_evento['entrevista'].unique()
# Out:
# array(['PRESENTE', nan, 'AUSENTE', 'REPROGRAMAR ENTREVISTA'], dtype=object)

# %%
resultado = (
    df_evento
    .groupby(['entrevista'])
    .size()
    .reset_index(name='cantidad')
)

print(resultado)
# Out:
#                entrevista  cantidad
# 0                 AUSENTE       105
# 1                PRESENTE       156
# 2  REPROGRAMAR ENTREVISTA         1

# %%
df_embudo=df_embudo.merge(df_llam_postulante_solo_dni,on=['vendor_lead_code','campana'],how='left')
df_embudo=df_embudo.merge(df_llam_postulante_todo,on=['vendor_lead_code_ref','campana'],how='left')

# %%
from sqlalchemy import text

with engine_zeus.begin() as conn:
    conn.execute(text("drop TABLE tb_funnel_reclutamiento"))
    # conn.execute(text("TRUNCATE TABLE tb_funnel_reclutamiento"))

# %%
df_embudo.columns = [
    unidecode(col)
    .lower()
    .strip()
    .replace(" ", "_")
    for col in df_embudo.columns
]

df_embudo["edad"] = pd.to_numeric(
    df_embudo["edad"],
    errors="coerce"
)

bins = [17, 24, 29, 39, 49, 59, 65, np.inf]

labels = [
    "18 - 24",
    "25 - 29",
    "30 - 39",
    "40 - 49",
    "50 - 59",
    "60 - 65",
    "66+"
]

df_embudo["seg_edad"] = (
    pd.cut(
        df_embudo["edad"],
        bins=bins,
        labels=labels
    )
    .cat.add_categories("No registra")
    .fillna("No registra")
)
df_embudo['tipo_base'] = np.where(
    df_embudo['vendor_lead_code'].isna(),
    'FUERA DE BASE',
    'EN BASE'
)

# %%
df_embudo["estado"] = df_embudo["estado"].fillna("NO GESTIONADO")
df_embudo["descripcion"] = df_embudo["descripcion"].fillna("PENDIENTE")
df_embudo["sub_estado"] = df_embudo["sub_estado"].fillna("PENDIENTE")
df_embudo["distrito"] = df_embudo["distrito"].fillna("Sin información")

# %%
dic_nombres = {
    "OCTAVIO RODRIGUEZ MORI": "OCTAVIO RODRIGUEZ",
    "KIMBHERLY GIOVANNA CORRO CARRASCO": "KIMBHERLY CORRO",
    "RAMON JOSE CRUZ QUISPE": "RAMÓN CRUZ"
}

mask = (
    df_embudo["reclutador"].isna() |
    (df_embudo["reclutador"].str.strip() == "")
)

df_embudo.loc[mask, "reclutador"] = (
    df_embudo.loc[mask, "ejecutivo"]
    .replace(dic_nombres)
)

# %%
import locale

locale.setlocale(locale.LC_TIME, "Spanish_Peru.1252")
df_embudo["fecha_de_gestion_bi"] = df_embudo["fecha_de_gestion"].dt.strftime("%Y-%m-%d")

df_embudo["dia"] = pd.to_datetime(df_embudo["fecha_de_gestion"]).dt.day
df_embudo["nombre_dia"] = pd.to_datetime(df_embudo["fecha_de_gestion"]).dt.day_name()

df_embudo["semana"] = pd.to_datetime(df_embudo["fecha_de_gestion"]).dt.isocalendar().week
df_embudo["semana_mes"] = (
    (pd.to_datetime(df_embudo["fecha_de_gestion"]).dt.day - 1) // 7 + 1
)

df_embudo["fecha_de_gestion"] = pd.to_datetime(df_embudo["fecha_de_gestion"])

meses = {
    1: "Enero", 2: "Febrero", 3: "Marzo", 4: "Abril",
    5: "Mayo", 6: "Junio", 7: "Julio", 8: "Agosto",
    9: "Septiembre", 10: "Octubre", 11: "Noviembre", 12: "Diciembre"
}

df_embudo["mes"] = (
    df_embudo["fecha_de_gestion"].dt.strftime("%m") + " " +
    df_embudo["fecha_de_gestion"].dt.month.map(meses)
)

# %%
# df_embudo["mes"] = pd.to_datetime(df_embudo["fecha_de_gestion"]).dt.month

# %%
df_embudo.head()
# Out:
#           reclutador fecha_de_gestion    nombre   apellido tipo_de_documento  \
# 0    KIMBHERLY CORRO       2026-07-02    Rebeca     Norifo               DNI
# 1  OCTAVIO RODRIGUEZ       2026-07-06  Gabriela     Osorio               DNI
# 2  OCTAVIO RODRIGUEZ       2026-06-24  Gabriela     Osorio               DNI
# 3    FHERGIE INFANTE       2026-07-06  Gabriela     Osorio               DNI
# 4    FHERGIE INFANTE       2026-07-06     Karen  Franklink               DNI
#
#   numero_de_documento fecha_de_inscripcion postulaste_desde  \
# 0                 NaN           2026-07-02              NaN
# 1                   0           2026-07-06     COMPUTRABAJO
# 2                   0           2026-05-27   BASE RECICLADA
# 3                 NaN           2026-07-06     COMPUTRABAJO
# 4             1481748           2026-07-06     COMPUTRABAJO
#
#             correo_electronico      cel01  ...         estado descripcion  \
# 0                          NaN  912492759  ...  NO GESTIONADO   PENDIENTE
# 1  sharongaby.osorio@gmail.com  953084139  ...  NO GESTIONADO   PENDIENTE
# 2  sharongaby.osorio@gmail.com  953084139  ...  NO GESTIONADO   PENDIENTE
# 3  sharongaby.osorio@gmail.com  953084139  ...  NO GESTIONADO   PENDIENTE
# 4           kjfmmace@gmail.com  958279306  ...  NO GESTIONADO   PENDIENTE
#
#       seg_edad tipo_base fecha_de_gestion_bi   dia nombre_dia semana  \
# 0  No registra   EN BASE          2026-07-02   2.0   Thursday     27
# 1      30 - 39   EN BASE          2026-07-06   6.0     Monday     28
# 2      30 - 39   EN BASE          2026-06-24  24.0  Wednesday     26
# 3      30 - 39   EN BASE          2026-07-06   6.0     Monday     28
# 4      30 - 39   EN BASE          2026-07-06   6.0     Monday     28
#
#   semana_mes  mes
# 0        1.0  7.0
# 1        1.0  7.0
# 2        4.0  6.0
# 3        1.0  7.0
# 4        1.0  7.0
#
# [5 rows x 66 columns]

# %%
df_embudo[df_embudo['numero_de_documento']=='76386419'].head()
# Out:
#              reclutador fecha_de_gestion        nombre         apellido  \
# 1573  OCTAVIO RODRIGUEZ       2026-07-02  René Roberto  Leyzaquia Ramos
#
#      tipo_de_documento numero_de_documento fecha_de_inscripcion  \
# 1573               DNI            76386419           2026-06-25
#
#      postulaste_desde         correo_electronico      cel01  ...  \
# 1573     COMPUTRABAJO  reneleyzaquia18@gmail.com  913701896  ...
#
#              estado descripcion seg_edad tipo_base fecha_de_gestion_bi  dia  \
# 1573  NO GESTIONADO   PENDIENTE  18 - 24   EN BASE          2026-07-02  2.0
#
#      nombre_dia semana semana_mes  mes
# 1573   Thursday     27        1.0  7.0
#
# [1 rows x 66 columns]

# %%
df_embudo.to_sql(
    name="tb_funnel_reclutamiento",
    con=engine_zeus,
    if_exists="append",
    index=False,
    chunksize=1000
)
# Out:
# 41

# %%
df_embudo.shape
# Out:
# (1142, 65)

# %%
df_embudo[df_embudo['vendor_lead_code'].isnull()].head()
# Out:
#    reclutador fecha_de_gestion nombre apellido tipo_de_documento  \
# 11        NaN              NaT    NaN      NaN               NaN
# 20        NaN              NaT    NaN      NaN               NaN
# 21        NaN              NaT    NaN      NaN               NaN
# 66        NaN              NaT    NaN      NaN               NaN
# 67        NaN              NaT    NaN      NaN               NaN
#
#    vendor_lead_code fecha_de_inscripcion postulaste_desde correo_electronico  \
# 11              NaN                  NaT              NaN                NaN
# 20              NaN                  NaT              NaN                NaN
# 21              NaN                  NaT              NaN                NaN
# 66              NaN                  NaT              NaN                NaN
# 67              NaN                  NaT              NaN                NaN
#
#    cel01  ... ncant_todo dni_ejecutivo                          ejecutivo  \
# 11   NaN  ...        NaN      70564642  KIMBHERLY GIOVANNA CORRO CARRASCO
# 20   NaN  ...        NaN      77667905             RAMON JOSE CRUZ QUISPE
# 21   NaN  ...        NaN      77667905             RAMON JOSE CRUZ QUISPE
# 66   NaN  ...        NaN      70564642  KIMBHERLY GIOVANNA CORRO CARRASCO
# 67   NaN  ...        NaN      70564642  KIMBHERLY GIOVANNA CORRO CARRASCO
#
#    duracion fecha_llamada  phone_number        sub_estado  \
# 11      0.0    2026-06-11      42079074  No hubo contacto
# 20      0.0    2026-06-01   51904280045    Objetivo final
# 21      0.0    2026-06-02   51979482086    Existe interes
# 66      0.0    2026-06-04     900216391   Dato incorrecto
# 67     16.0    2026-06-10     900387135   Dato incorrecto
#
#                   estado        descripcion     seg_edad
# 11           NO CONTACTO        No contesta  No registra
# 20     CONTACTO EFECTIVO             Citado  No registra
# 21     CONTACTO EFECTIVO   LLAMAR MÁS TARDE  No registra
# 66  CONTACTO NO EFECTIVO   Número no existe  No registra
# 67  CONTACTO NO EFECTIVO  Número equivocado  No registra
#
# [5 rows x 58 columns]

# %%
# print(df_embudo["llamada_1"].unique().tolist())
# print(df_embudo["llamada_2"].unique().tolist())
print(df_embudo["capacitacion"].unique().tolist())
# Out:
# [nan, 'NO CALIFICA', 'NO ACEPTA PROPUESTA', 'DERIBAR A OTRA CUENTA', 'NO CONTACTADO', 'APTO', 'NO APTO', 'SE RETIRA DE LA ENTREVISTA', 'DESISTE']

# %%
Contrato = 
CALCULATE(
    [OJT],
    tb_funnel_reclutamiento[capacitacion] IN {
        "SI"
    }
    
)

# %%
postulaciones 
filtro cv  califica
contactados llamda12 whata contesto contesta
citados  status1 status2 status whatsaap citado
entrevistas presente
aptos  status_entrevista  apto
capacitacion EN PROCESO,COMPLETÓ,SE RETIRA DE LA CAPACITACIÓN
ASISTE PRIMER DÍA
ojt COMPLETÓ,NO COMPLETÓ,EN PROCESO
contratados firma_de_contrato SÍ

# %%
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

df_embudo.head()
# Out:
#         reclutador fecha_de_gestion            nombre           apellido  \
# 0              NaN              NaT             Vania    Allain Figueroa
# 1  KIMBHERLY CORRO       2026-06-11              Bibi               Khan
# 2  KIMBHERLY CORRO       2026-06-02  Josdaly Coromoto  Capella Figueredo
# 3  KIMBHERLY CORRO       2026-06-01   Naudy Del Valle     Fernadez Armas
# 4  KIMBHERLY CORRO       2026-06-06    Leticia Lizeth     Esquia Carasas
#
#   tipo_de_documento numero_de_documento fecha_de_inscripcion postulaste_desde  \
# 0               DNI                 NaN                  NaT              NaN
# 1               DNI             3524302           2026-06-11     COMPUTRABAJO
# 2               DNI             4285835           2026-05-27     COMPUTRABAJO
# 3               DNI             4499114           2026-05-28     COMPUTRABAJO
# 4               DNI             4712594           2026-06-05     COMPUTRABAJO
#
#                      correo_electronico      cel01      cel02 departamento  \
# 0                                   NaN        NaN        NaN          NaN
# 1                    shaliza@outlook.es  929993643        NaN         LIMA
# 2                 josscapella@gmail.com  916124014        NaN         LIMA
# 3  fernadezarmasnaudydelvalle@gmail.com  961162182        NaN         LIMA
# 4                 letizia2722@gmail.com  962590031  962590031         LIMA
#
#                  distrito                 direccion fecha_de_nacimiento  edad  \
# 0                     NaN                       NaN                 NaT   NaN
# 1  SAN JUAN DE LURIGANCHO                       NaN          1988-03-31  38.0
# 2                    LIMA                       NaN          1986-05-06  40.0
# 3             SANTA ANITA                       NaN          1994-09-10  31.0
# 4                    LIMA  jr. general cordova 2233          1992-02-27  34.0
#
#      genero estado_civil nacionalidad        campana   modalidad    jornada  \
# 0       NaN          NaN          NaN      CREDICASH  PRESENCIAL  PART TIME
# 1  FEMENINO          NaN      PERUANA  CENCOSUD SSFF      REMOTO  FULL TIME
# 2  FEMENINO          NaN      PERUANA    DINERS SSFF  PRESENCIAL  FULL TIME
# 3  FEMENINO      SOLTERO      PERUANA    DINERS SSFF  PRESENCIAL  FULL TIME
# 4  FEMENINO      SOLTERO      PERUANA  CENCOSUD SSFF      REMOTO  FULL TIME
#
#     turno horario_de_trabajo planilla      supervisor   sede    filtro_cv  \
# 0   TARDE  2:00 pm a 6:00 pm      RXH     JOSÉ LLANOS  COMAS     CALIFICA
# 1  MAÑANA  9:00 am a 6:00 pm    MICRO      ROSA NOVOA   LIMA  NO CALIFICA
# 2  MAÑANA  9:00 am a 6:00 pm      RXH  JOHANA ARTEAGA   LIMA     CALIFICA
# 3  MAÑANA  9:00 am a 6:00 pm      RXH  JOHANA ARTEAGA   LIMA  NO CALIFICA
# 4  MAÑANA  9:00 am a 6:00 pm    MICRO      ROSA NOVOA   LIMA     CALIFICA
#
#      llamada_1         status_llamada_1    llamada_2 status_llamada_2  \
# 0     CONTESTA                   CITADO          NaN              NaN
# 1     CONTESTA                NO PERFIL  NO CALIFICA      NO CALIFICA
# 2     CONTESTA  NO INTERESADO EN VENTAS          NaN              NaN
# 3  NO CALIFICA              NO CALIFICA  NO CALIFICA      NO CALIFICA
# 4     CONTESTA                   CITADO          NaN              NaN
#
#   mensaje_whats_app status_whats_app fecha_entrevista   entrevista  \
# 0               NaN              NaN              NaT          NaN
# 1       NO CALIFICA      NO CALIFICA              NaT  NO CALIFICA
# 2               NaN              NaN              NaT          NaN
# 3       NO CALIFICA      NO CALIFICA              NaT  NO CALIFICA
# 4               NaN              NaN       2026-06-08     PRESENTE
#
#      status_entrevista capacitacion motivo_capacitacion  \
# 0                  NaN          NaN                 NaN
# 1          NO CALIFICA  NO CALIFICA         NO CALIFICA
# 2                  NaN          NaN                 NaN
# 3          NO CALIFICA  NO CALIFICA         NO CALIFICA
# 4  NO ACEPTA PROPUESTA          NaN                 NaN
#
#   fecha_inicio_de_capacitacion          ojt   motivo_ojt firma_de_contrato  \
# 0                          NaT          NaN          NaN               NaN
# 1                          NaT  NO CALIFICA  NO CALIFICA       NO CALIFICA
# 2                          NaT          NaN          NaN               NaN
# 3                          NaT          NaN          NaN               NaN
# 4                          NaT          NaN          NaN               NaN
#
#   fecha_de_ingreso            observacion vendor_lead_code  \
# 0              NaT                    NaN         00000000
# 1              NaT             EXTRANJERO         03524302
# 2              NaT                    NaN         04285835
# 3              NaT  POSTULÓ A BACK OFFICE         04499114
# 4              NaT                    NaN         04712594
#
#   vendor_lead_code_ref fecha_de_inscripcion_final  ncant_solo_valido  \
# 0             00000000                        NaT                NaN
# 1             03524302                        NaT                NaN
# 2             04285835                        NaT                NaN
# 3             04499114                        NaT                NaN
# 4             04712594                        NaT                NaN
#
#    ncant_todo dni_ejecutivo ejecutivo  duracion fecha_llamada phone_number  \
# 0         NaN           NaN       NaN       NaN           NaT          NaN
# 1         NaN           NaN       NaN       NaN           NaT          NaN
# 2         NaN           NaN       NaN       NaN           NaT          NaN
# 3         NaN           NaN       NaN       NaN           NaT          NaN
# 4         NaN           NaN       NaN       NaN           NaT          NaN
#
#   sub_estado         estado descripcion     seg_edad tipo_base
# 0  PENDIENTE  NO GESTIONADO   PENDIENTE  No registra   EN BASE
# 1  PENDIENTE  NO GESTIONADO   PENDIENTE      30 - 39   EN BASE
# 2  PENDIENTE  NO GESTIONADO   PENDIENTE      40 - 49   EN BASE
# 3  PENDIENTE  NO GESTIONADO   PENDIENTE      30 - 39   EN BASE
# 4  PENDIENTE  NO GESTIONADO   PENDIENTE      30 - 39   EN BASE

# %%
print(df_embudo.columns.tolist())
# Out:
# ['reclutador', 'fecha_de_gestion', 'nombre', 'apellido', 'tipo_de_documento', 'numero_de_documento', 'fecha_de_inscripcion', 'postulaste_desde', 'correo_electronico', 'cel01', 'cel02', 'departamento', 'distrito', 'direccion', 'fecha_de_nacimiento', 'edad', 'genero', 'estado_civil', 'nacionalidad', 'campana', 'modalidad', 'jornada', 'turno', 'horario_de_trabajo', 'planilla', 'supervisor', 'sede', 'filtro_cv', 'llamada_1', 'status_llamada_1', 'llamada_2', 'status_llamada_2', 'mensaje_whats_app', 'status_whats_app', 'fecha_entrevista', 'entrevista', 'status_entrevista', 'capacitacion', 'motivo_capacitacion', 'fecha_inicio_de_capacitacion', 'ojt', 'motivo_ojt', 'firma_de_contrato', 'fecha_de_ingreso', 'observacion', 'vendor_lead_code', 'vendor_lead_code_ref', 'fecha_de_inscripcion_final', 'ncant_solo_valido', 'ncant_todo', 'dni_ejecutivo', 'ejecutivo', 'duracion', 'fecha_llamada', 'phone_number', 'sub_estado', 'estado', 'descripcion', 'seg_edad', 'tipo_base', 'fecha_de_gestion_bi', 'dia', 'nombre_dia', 'semana', 'semana_mes']

# %%
['reclutador', 'fecha_de_gestion', 'nombre', 'apellido', 'tipo_de_documento', 'numero_de_documento', 'fecha_de_inscripcion', 'postulaste_desde', 'correo_electronico', 'cel01', 'cel02', 'departamento', 'distrito', 'direccion', 'fecha_de_nacimiento', 'edad', 'genero', 'estado_civil', 'nacionalidad', 'campana', 'modalidad', 'jornada', 'turno', 'horario_de_trabajo', 'planilla', 'supervisor', 'sede', 'filtro_cv', 'llamada_1', 'status_llamada_1', 'llamada_2', 'status_llamada_2', 'mensaje_whats_app', 'status_whats_app', 'fecha_entrevista', 'entrevista', 'status_entrevista', 'capacitacion', 'motivo_capacitacion', 'fecha_inicio_de_capacitacion', 'ojt', 'motivo_ojt', 'firma_de_contrato', 'fecha_de_ingreso', 'observacion', 'vendor_lead_code', 'vendor_lead_code_ref', 'fecha_de_inscripcion_final', 'ncant_solo_valido', 'ncant_todo', 'dni_ejecutivo', 'ejecutivo', 'duracion', 'fecha_llamada', 'phone_number', 'sub_estado', 'estado', 'descripcion', 'seg_edad', 'tipo_base', 'fecha_de_gestion_bi', 'dia', 'nombre_dia', 'semana', 'semana_mes']

# %%
print(df_embudo['status_llamada_1'].unique())
# Out:
# ['NO CONTACTADO' 'NO CALIFICA' 'CITADO' 'NO PERFIL' 'DESEA REMOTO'
#  'NO INTERESADO EN PLANILLA MYPE' 'PERFIL ESCUELITA'
#  'NO INTERESADO EN SALARIO' nan 'NO INTERESADO EN HORARIOS'
#  'LABORANDO ACTUALMENTE' 'DISTANCIA' 'NO INTERESADO EN VENTAS'
#  'NO INTERESADO EN LA PROPUESTA LABORAL' 'BLACK LIST']

# %%
df_embudo[
    df_embudo['vendor_lead_code'] == '77045774'
][[
'FECHA DE INSCRIPCIÓN',
'FECHA DE GESTIÓN',
 'FECHA ENTREVISTA',
 'FECHA INICIO DE CAPACITACION',
 'FECHA DE INGRESO',
 'RECLUTADOR',
 'POSTULASTE DESDE',
 'CAMPAÑA',
 'JORNADA',
 'MODALIDAD',
 'TURNO',
 'PLANILLA',
 'vendor_lead_code',
 'NOMBRE',
 'APELLIDO',
 'TIPO DE DOCUMENTO',
 'CORREO ELECTRÓNICO',
 'CEL01',
 'CEL02',
 'DEPARTAMENTO',
 'FECHA DE NACIMIENTO',
 'DISTRITO',
 'DIRECCIÓN',
 'EDAD',
 'GÉNERO',
 'ESTADO CIVIL',
 'NACIONALIDAD',
 'HORARIO DE TRABAJO',
 'SUPERVISOR',
 'vendor_lead_code_ref',
 'SEDE',
 'LLAMADA 1',
 'STATUS LLAMADA 1',
 'LLAMADA 2',
 'STATUS LLAMADA 2',
 'MENSAJE WHATS APP',
 'STATUS WHATS APP',
 'FILTRO CV',
 'ENTREVISTA',
 'STATUS ENTREVISTA',
 'CAPACITACIÓN',
 'MOTIVO CAPACITACIÓN',
 'OJT',
 'MOTIVO OJT',
 'FIRMA DE CONTRATO',
 'OBSERVACIÓN'
]].head()
# Out:
#     FECHA DE INSCRIPCIÓN FECHA DE GESTIÓN FECHA ENTREVISTA  \
# 1             30/05/2026       01/06/2026              NaN
# 123           03/06/2026       03/06/2026              NaN
# 375           03/06/2026       09/06/2026       09/06/2026
#
#     FECHA INICIO DE CAPACITACION FECHA DE INGRESO         RECLUTADOR  \
# 1                            NaN              NaN  OCTAVIO RODRIGUEZ
# 123                          NaN              NaN    KIMBHERLY CORRO
# 375                          NaN              NaN         RAMÓN CRUZ
#
#        CAMPAÑA vendor_lead_code    LLAMADA 1 STATUS LLAMADA 1  ...  \
# 1    CREDICASH         77045774  NO CONTESTA    NO CONTACTADO  ...
# 123  DINERS TC         77045774  NO CALIFICA      NO CALIFICA  ...
# 375   EXPERTIS         77045774     CONTESTA           CITADO  ...
#
#     STATUS WHATS APP    FILTRO CV   ENTREVISTA STATUS ENTREVISTA CAPACITACIÓN  \
# 1      NO CONTACTADO     CALIFICA          NaN               NaN          NaN
# 123      NO CALIFICA  NO CALIFICA  NO CALIFICA       NO CALIFICA  NO CALIFICA
# 375           CITADO     CALIFICA      AUSENTE       NO CALIFICA  NO CALIFICA
#
#     MOTIVO CAPACITACIÓN          OJT   MOTIVO OJT FIRMA DE CONTRATO  \
# 1                   NaN          NaN          NaN               NaN
# 123         NO CALIFICA  NO CALIFICA  NO CALIFICA       NO CALIFICA
# 375         NO CALIFICA  NO CALIFICA  NO CALIFICA       NO CALIFICA
#
#         OBSERVACIÓN
# 1               NaN
# 123             NaN
# 375  NO SE PRESENTO
#
# [3 rows x 23 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[92], line 3
#       1 df_llam_postulante_todo = (
#       2     df_vicidial
# ----> 3     .groupby(['vendor_lead_code_ref','campana'], as_index=False)
#       4     .size()
#       5     .rename(columns={'size': 'nCant_todo'})
#       6 )
#       7 df_llam_postulante_solo_dni = (
#       8     df_vicidial
#       9     .groupby(['vendor_lead_code','campana'], as_index=False)
#      10     .size()
#      11     .rename(columns={'size': 'nCant_solo_valido'})
#      12 )
#      14 # cantidad_sin_dni = (
#      15 #     df_vicidial.loc[
#      16 #         df_vicidial['vendor_lead_code'].isna(),
#    (...)     19 #     .nunique()
#      20 # )
#
# File c:\Users\DATA\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:9210, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9207 if level is None and by is None:
#    9208     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9210 return DataFrameGroupBy(
#    9211     obj=self,
#    9212     keys=by,
#    9213     axis=axis,
#    9214     level=level,
#    9215     as_index=as_index,
#    9216     sort=sort,
#    9217     group_keys=group_keys,
#    9218     observed=observed,
#    9219     dropna=dropna,
#    9220 )
#
# File c:\Users\DATA\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:1331, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1328 self.dropna = dropna
#    1330 if grouper is None:
# -> 1331     grouper, exclusions, obj = get_grouper(
#    1332         obj,
#    1333         keys,
#    1334         axis=axis,
#    1335         level=level,
#    1336         sort=sort,
#    1337         observed=False if observed is lib.no_default else observed,
#    1338         dropna=self.dropna,
#    1339     )
#    1341 if observed is lib.no_default:
#    1342     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File c:\Users\DATA\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\grouper.py:1043, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041         in_axis, level, gpr = False, gpr, None
#    1042     else:
# -> 1043         raise KeyError(gpr)
#    1044 elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045     # Add key to exclusions
#    1046     exclusions.add(gpr.key)
#
# KeyError: 'vendor_lead_code_ref'

# %%
df_embudo['vendor_lead_code_ref'] = (
    df_embudo['vendor_lead_code']
    .mask(
        df_embudo['vendor_lead_code'].isna() | (df_embudo['vendor_lead_code'] == '0'),
        df_embudo['CEL01']
    )
)
df_embudo.head()
# Out:
#           RECLUTADOR FECHA DE GESTIÓN         NOMBRE        APELLIDO  \
# 0  OCTAVIO RODRIGUEZ       01/06/2026      Katherine         Aguilar
# 1  OCTAVIO RODRIGUEZ       01/06/2026          Maria         Asencio
# 2    KIMBHERLY CORRO       01/06/2026          Nardy   Curty Arteaga
# 3    KIMBHERLY CORRO       01/06/2026          Brian     Hurtado Web
# 4  OCTAVIO RODRIGUEZ       01/06/2026  Jesús Brayan   Rojas cardenas
#
#   TIPO DE DOCUMENTO vendor_lead_code FECHA DE INSCRIPCIÓN POSTULASTE DESDE  \
# 0               DNI         70723259           01/06/2026     COMPUTRABAJO
# 1               DNI         77045774           30/05/2026     COMPUTRABAJO
# 2               DNI         74720395           01/06/2026     COMPUTRABAJO
# 3               DNI         74095580           30/05/2026     COMPUTRABAJO
# 4               DNI         70986744           01/06/2026     COMPUTRABAJO
#
#             CORREO ELECTRÓNICO      CEL01  ... STATUS ENTREVISTA  \
# 0      hashy08082016@gmail.com  904571403  ...               NaN
# 1  maria27.11asencio@gmail.com  997311939  ...               NaN
# 2     nca-admi-098@hotmail.com  982037515  ...              APTO
# 3    brianhurtadoweb@gmail.com  905970554  ...       NO CALIFICA
# 4    Rojasjesus2202@gmail.com   913841097  ...              APTO
#
#                    CAPACITACIÓN MOTIVO CAPACITACIÓN  \
# 0                           NaN                 NaN
# 1                           NaN                 NaN
# 2  SE RETIRA DE LA CAPACITACIÓN    NO INDICA MOTIVO
# 3                   NO CALIFICA         NO CALIFICA
# 4                     NO ASISTE             DESISTE
#
#   FECHA INICIO DE CAPACITACION          OJT   MOTIVO OJT FIRMA DE CONTRATO  \
# 0                          NaN          NaN          NaN               NaN
# 1                          NaN          NaN          NaN               NaN
# 2                   04/06/2026   NO ASISTIÓ      DESISTE                NO
# 3                          NaN  NO CALIFICA  NO CALIFICA       NO CALIFICA
# 4                   02/06/2026   NO ASISTIÓ      DESISTE                NO
#
#   FECHA DE INGRESO                                     OBSERVACIÓN  \
# 0              NaN  NO CUMPLE CON LA EDAD, SERIA SU PRIMER TRABAJO
# 1              NaN                                             NaN
# 2              NaN                                             NaN
# 3              NaN                                 NO DESEA VENTAS
# 4              NaN                                             NaN
#
#   vendor_lead_code_ref
# 0             70723259
# 1             77045774
# 2             74720395
# 3             74095580
# 4             70986744
#
# [5 rows x 46 columns]

# %%
df_embudo[
df_embudo.duplicated(subset='vendor_lead_code_ref', keep=False)
].sort_values('vendor_lead_code_ref').head()
# Out:
#           RECLUTADOR FECHA DE GESTIÓN            NOMBRE           APELLIDO  \
# 510  KIMBHERLY CORRO       12/06/2026     Paulo Enrique    Villegas Euribe
# 489  KIMBHERLY CORRO       11/06/2026             Paulo           Villegas
# 117  KIMBHERLY CORRO       02/06/2026      Danilo Mirko       Soto Bellido
# 77   KIMBHERLY CORRO       02/06/2026      Danilo Mirko       Soto Bellido
# 89   KIMBHERLY CORRO       02/06/2026  Josdaly Coromoto  Capella Figueredo
#
#     TIPO DE DOCUMENTO vendor_lead_code FECHA DE INSCRIPCIÓN POSTULASTE DESDE  \
# 510               DNI         10784563           12/06/2026     COMPUTRABAJO
# 489               DNI         10784563           11/06/2026     COMPUTRABAJO
# 117               DNI         41420423           27/05/2026     COMPUTRABAJO
# 77                DNI         41420423           27/05/2026     COMPUTRABAJO
# 89                DNI          4285835           27/05/2026     COMPUTRABAJO
#
#             CORREO ELECTRÓNICO      CEL01  ... STATUS ENTREVISTA CAPACITACIÓN  \
# 510  paulo.villegas1@gmail.com  980462909  ...           NO APTO          NaN
# 489  paulo.villegas1@gmail.com  980462909  ...               NaN          NaN
# 117      danirko1981@gmail.com  930993992  ...               NaN          NaN
# 77       danirko1981@gmail.com  930993992  ...       NO CALIFICA  NO CALIFICA
# 89       josscapella@gmail.com  916124014  ...               NaN          NaN
#
#     MOTIVO CAPACITACIÓN FECHA INICIO DE CAPACITACION          OJT  \
# 510                 NaN                          NaN          NaN
# 489                 NaN                          NaN          NaN
# 117                 NaN                          NaN          NaN
# 77          NO CALIFICA                          NaN  NO CALIFICA
# 89                  NaN                          NaN          NaN
#
#       MOTIVO OJT FIRMA DE CONTRATO FECHA DE INGRESO  \
# 510          NaN               NaN              NaN
# 489          NaN               NaN              NaN
# 117          NaN               NaN              NaN
# 77   NO CALIFICA       NO CALIFICA              NaN
# 89           NaN               NaN              NaN
#
#                                            OBSERVACIÓN vendor_lead_code_ref
# 510            CONFLICTO DE HORARIOS CON EMPLEO ACTUAL             10784563
# 489                              SOLO MODALIDAD REMOTA             10784563
# 117  NO TIENE EXPERIENCIA EN VENTAS / DESEA BACK OF...             41420423
# 77                             NO LE GUSTAN LAS VENTAS             41420423
# 89                                                 NaN              4285835
#
# [5 rows x 46 columns]

# %%
df_vicidial[df_vicidial['vendor_lead_code'].isnull()]['phone_number'].nunique()
# Out:
# 142

# %%
df_vicidial[df_vicidial['vendor_lead_code'].isnull()].count()
# Out:
# dial_method           336
# numero_campana        336
# dni_ejecutivo         336
# ejecutivo             336
# nombre_campana        336
# fecha_hora_llamada    336
# duracion              335
# fecha_llamada         336
# call_result             2
# list_description        2
# list_name             336
# phone_number          336
# codigo                336
# estado                336
# descripcion           336
# vendor_lead_code        0
# dtype: int64

# %%
['dial_method', 'numero_campana', 'dni_ejecutivo', 'ejecutivo', 'nombre_campana', 'fecha_hora_llamada', 'duracion', 'fecha_llamada', 'call_result', 'list_description', 'list_name', 'phone_number', 'codigo', 'estado', 'descripcion']
# Out:
# ['dial_method', 'numero_campana', 'dni_ejecutivo', 'ejecutivo', 'nombre_campana', 'fecha_hora_llamada', 'duracion', 'fecha_llamada', 'call_result', 'list_description', 'list_name', 'phone_number', 'codigo', 'estado', 'descripcion']

# %%
df_tnumero=df_embudo[['vendor_lead_code','CEL01','CEL02']]

# %%
['RECLUTADOR', 'FECHA DE GESTIÓN', 'NOMBRE', 'APELLIDO', 'TIPO DE DOCUMENTO', 'NUMERO DE DOCUMENTO', 'FECHA DE INSCRIPCIÓN', 'POSTULASTE DESDE', 'CORREO ELECTRÓNICO', 'TELÉFONO 1', 'TELÉFONO 2', 'DEPARTAMENTO', 'DISTRITO', 'DIRECCIÓN', 'FECHA DE NACIMIENTO', 'EDAD', 'GÉNERO', 'ESTADO CIVIL', 'NACIONALIDAD', 'CAMPAÑA', 'MODALIDAD', 'JORNADA', 'TURNO', 'HORARIO DE TRABAJO', 'PLANILLA', 'SUPERVISOR', 'SEDE', 'FILTRO CV', 'LLAMADA 1', 'STATUS LLAMADA 1', 'LLAMADA 2', 'STATUS LLAMADA 2', 'MENSAJE WHATS APP', 'STATUS WHATS APP', 'FECHA ENTREVISTA', 'ENTREVISTA', 'STATUS ENTREVISTA', 'CAPACITACIÓN', 'MOTIVO CAPACITACIÓN', 'FECHA INICIO DE CAPACITACION', 'OJT', 'MOTIVO OJT', 'FIRMA DE CONTRATO', 'FECHA DE INGRESO', 'OBSERVACIÓN']

# %%
df_vicidial[df_vicidial['descripcion'].isnull()].head()
# Out:
# Empty DataFrame
# Columns: [vendor_lead_code, dial_method, numero_campana, dni_ejecutivo, ejecutivo, nombre_campana, fecha_hora_llamada, duracion, fecha_llamada, call_result, list_description, list_name, phone_number, codigo, estado, descripcion]
# Index: []

# %%
# print(f"df_dni filas: {df_long.shape[0]}")
# print(f"df_list filas: {df_list.shape[0]}")

# %%
print(sorted(df_embudo["observacion"].dropna().unique()))
# Out:
# ['2 MESES DE EXPERIENCIA EN CALL', 'ALTA ROTACIÓN LABORAL', 'ATC EN EL SECTOR EDUCATIVO', 'BLACK LIST', 'BLACKLIST', 'BUSCO ALGO MUCHO MEJOR', 'CAPACITACIONES POR LA TARDE', 'CLARIDAD VERBAL NO ALINEADA AL PUESTO', 'COBRANZAS', 'COMUNICACIÓN VERBAL CON BAJA PROYECCIÓN', 'CON EXPERIENCIA EN ATC / VIVE EN PROVINCIA', 'CONFLICTO DE HORARIOS CON EMPLEO ACTUAL', 'CONSIDERAR PARA UN PRÓXIMO INICIO', 'CORTA EXPERIENCIA EN CALL CENTER', 'CORTA EXPERIENCIA EN CALL CENTER / NO RUBRO FINANCIERO', 'CORTA EXPERIENCIA EN FINANCIERA', 'CORTA EXPERIENCIA EN FINANZAS (DERIVACIÓN)', 'DERIVACIÓN DE DINERS A CREDICASH / SONDEAR EXPERIENCIA', 'DERIVAR A ALFIN BANCO', 'DERIVAR A CREDICASH O EFECTIVA', 'DESEA PART TIME REMOTO', 'DESISTE POR EL PAGO DE 5 Y 20 ', 'DESISTE PORQUE QUIERE PLANILLA COMPLETA', 'DESISTIO POR PLANILLA ', 'DINERS SSFF A CREDICASH', 'DISTANCIA', 'DISTANCIA / ACTUALMENTE TRABAJANDO', 'EN SU CV SE ESPECIFICA QUE PUEDE DESPUES DE LAS 5 LOS MARTES, JUEVES ', 'ENTREVISTA LUNES 09', 'ESTUDIA DE LUNES A JUEVES DE 11:00 A.M A 4:00 P.M', 'ESTUDIA MARTES Y JUEVES POR LA MAÑANA, SE LE HARIA DIFICIL ASISTIR TEMPRANO A A LAS CAPACITACION, PERO ACEPTA SI FUERA EN LA TARDE.', 'ESTUDIA POR LA MAÑANA Y TENDRA DIFICULTADES PARA ASISTIR A LAS CAPACITACIONES', 'ESTUDIANTE', 'ESTUDIO POR LAS MAÑANAS Y SE ME HARA DIFICIL POR LAS MAÑANAS', 'EXCESIVA ROTACIÓN EN CALL CENTER', 'EXPERIENCIA EN CALL CENTER / NO RUBRO FINANCIERO', 'EXPERIENCIA EN TELECOMUNICACIONES', 'EXPERIENCIA FINANCIERA ANTIGUA', 'EXPERIENCIA NO ACORDE A LA VACANTE', 'EXPERIENCIA NO ACORDE A LA VACANTE / ALTA ROTACIÓN LABORAL', 'EXPERIENCIA NO ACORDE A VACANTE', 'EXPERIENCIA NO ACORDE A VACANTE / PROVINCIA', 'EXTRANJERO', 'El candidato refiere falta de empatía durante la capacitación y opta por retirarse del proceso.', 'FUERA DEL ANGO DE EDAD', 'FUERA DEL RANGO DE EDAD', 'FUERA DEL RANO DE EDAD', 'FUERA DEL RANO DE EDAD PARA REMOTO', 'Inicia capacitaciones por la tarde, pero quiere laborar por las mañanas', 'LABORA ACTUALMENTE', 'LO MANDE PARA DINERS POR EXP DE VENTAS', 'LO RECOMENDE PARA LA CEDE DE COMAS', 'MALA ACTITUD', 'MAYOR DE 50  ', 'MENOR AL RANGO DE EDAD', 'MENOR DEL RANGO DE EDAD', 'NO ACEPTA PLANILLA MICRO', 'NO ASISTIERON', 'NO CALIFICA EL PERFIL', 'NO CALIFICO POR LA SUPERVISORA', 'NO CONTESTA', 'NO CUMPLE CON LA EDAD, SERIA SU PRIMER TRABAJO', 'NO ES APTO', 'NO ESTAN INTERESADOS POR LA PAGO ', 'NO INGREOS', 'NO INGRESARON', 'NO INGRESO', 'NO PASO ENTREVISTA CON LA SUPER POR LAS COMISIONES ', 'NO PASO ENTREVISTA CON LA SUPER POR LAS EXPERIENCIA EN CARTERA TEMPRANO PIDEN QUE SE CARTERA CASTIGO ', 'NO PASO ENTREVISTA POR SUPERVISOR', 'NO PUEDE POR QUE ESTUDIA TODO EL DIA LOS MARTES Y JUEVES', 'NO RESPONDIO ', 'NO SE PRESENTO', 'NO TIENE EXP EN COBRANZAS ', 'NO TIENE EXPERIENCIA EN VENTAS / DESEA BACK OFFICE', 'NO TIENEN EXP', 'No asiste, sin embargo deja mensaje que desea Home', 'OTRA PROPUESTA BUSCO', 'PAGOS QUIERE QUINCENAL NO EL 5  Y 20 AUN ASI SE LE EXPLICO EL QUIERE 1 Y LOS 16', 'PAGOS QUIERE QUINCENAL NO EL 5  Y 20 AUN ASI SE LE EXPLICO EL QUIERE 1 Y LOS 17', 'PAGOS QUIERE QUINCENAL NO EL 5  Y 20 AUN ASI SE LE EXPLICO EL QUIERE 1 Y LOS 18', 'PAGOS QUIERE QUINCENAL NO EL 5  Y 20 AUN ASI SE LE EXPLICO EL QUIERE 1 Y LOS 19', 'PAGOS QUIERE QUINCENAL NO EL 5  Y 20 AUN ASI SE LE EXPLICO EL QUIERE 1 Y LOS 20', 'PENDIENTE PART TIME LIMA CENTRO', 'PERFIL ADMINISTRATIVO', 'PERFIL DIGITAL NO FINANCIERO', 'PERFIL NO ACORDE A LA VACANTE', 'PERFIL ORIENTADO A BACK OFFICE', 'PERSONAS CON QUE PASARON EL LIMITE DE EDAD DE 45', 'POR EL PAGO DE LOS CORTES', 'POR LA EDAD NO QUIERE LA SUPERVISORA ', 'POR MOTIVOS DE SUS ESTUDIOS SE RETIRA DE LA CAPACITACION', 'POSTULÓ A BACK OFFICE', 'PROBLEMAS CON LAS HORAS DE TRABAJO YA QUE ESTUDIA', 'PROVINCIA', 'Pagos de capacitaciones muy largos', 'QUIERE CAPACITACIONES TURNO TARDE', 'QUIERE ENTREVISTA LA PROXIMA SEMANA', 'QUIERE HORARIO LABORAL DESDE LAS 3:00 P.M', 'QUIERON REMOTO', 'Requiere Part-Time en Lima Centro', 'SE ENCUENTRA INTERESADO PART  ...

# %%
# Out:
# ['RECLUTADOR', 'FECHA DE GESTIÓN', 'NOMBRE', 'APELLIDO', 'TIPO DE DOCUMENTO', 'NUMERO DE DOCUMENTO', 'FECHA DE INSCRIPCIÓN', 'POSTULASTE DESDE', 'CORREO ELECTRÓNICO', 'TELÉFONO 1', 'TELÉFONO 2', 'DEPARTAMENTO', 'DISTRITO', 'DIRECCIÓN', 'FECHA DE NACIMIENTO', 'EDAD', 'GÉNERO', 'ESTADO CIVIL', 'NACIONALIDAD', 'CAMPAÑA', 'MODALIDAD', 'JORNADA', 'TURNO', 'HORARIO DE TRABAJO', 'PLANILLA', 'SUPERVISOR', 'SEDE', 'FILTRO CV', 'LLAMADA 1', 'STATUS LLAMADA 1', 'LLAMADA 2', 'STATUS LLAMADA 2', 'MENSAJE WHATS APP', 'STATUS WHATS APP', 'FECHA ENTREVISTA', 'ENTREVISTA', 'STATUS ENTREVISTA', 'CAPACITACIÓN', 'MOTIVO CAPACITACIÓN', 'FECHA INICIO DE CAPACITACION', 'OJT', 'MOTIVO OJT', 'FIRMA DE CONTRATO', 'FECHA DE INGRESO', 'OBSERVACIÓN']

# %%
filename='EMBUDO.xlsx'
name_dni='DNI'

ruta_archivo = os.path.join(ruta_csv, filename)
df = pd.read_excel(ruta_archivo)

df[f"{name_dni}"] = (
    df[f"{name_dni}"]
    .astype(str)
    .str.zfill(8)
)

df = df.rename(columns={
    f'{name_dni}': 'NUMERO_DOCUMENTO'
})
df=df[["NUMERO_DOCUMENTO"]]
df.head()
server_sql = server_kishin
db_sql = "DANTALION"
user_sql = user_kishin
pwd_sql = pwd_kishin

engine_kishin = create_engine(
    f"mssql+pyodbc://{user_sql}:{pwd_sql}@{server_sql}/{db_sql}"
    "?driver=ODBC+Driver+17+for+SQL+Server"
)

tipi_cond1='RECLUTA'
servidor_01=64
query = f"""
    SELECT *
    FROM OPENQUERY([192.168.3.{servidor_01}], '
        SELECT        
        rtrim(ltrim(d.vendor_lead_code)) AS vendor_lead_code,        
        e.dial_method,
        a.campaign_id AS numero_campana,        
        a.user AS dni_ejecutivo,
        c.full_name AS ejecutivo,
        e.campaign_name AS nombre_campana,        
        a.call_date AS fecha_hora_llamada,        
        a.length_in_sec AS duracion,        
        b.status_name AS call_result,        
        f.list_description,        
        f.list_name,        
        a.phone_number as phone_number,        
        d.alt_phone as fecha_agenda,        
        d.comments as comentarios,        
        a.status AS codigo
        FROM asterisk.vicidial_log a         
        LEFT JOIN asterisk.vicidial_list d ON a.lead_id=d.lead_id        
        LEFT JOIN asterisk.vicidial_campaigns e ON a.campaign_id=e.campaign_id        
        LEFT JOIN asterisk.vicidial_lists f ON a.list_id=f.list_id        
        LEFT JOIN asterisk.vicidial_statuses b ON a.status=b.status        
        LEFT JOIN asterisk.vicidial_users c ON a.user=c.user        
        WHERE e.campaign_name like "%{tipi_cond1}" 
        AND a.call_date >= DATE_FORMAT(''{fecha_mes_base}'', ''%Y-%m-01'')
        AND a.call_date < 
        DATE_ADD(DATE_FORMAT(''{fecha_mes_base}'', ''%Y-%m-01''), INTERVAL 1 MONTH)
    ')

    """
df_efe = pd.read_sql(query, engine_kishin)

df = df.merge(df_efe, on='NUMERO_DOCUMENTO', how='inner')
list_dni = (
    df['NUMERO_DOCUMENTO']
    .dropna()
    .drop_duplicates()
    .tolist()
)
# in_clause = ",".join(f"'{x}'" for x in list_dni)
valores = ",\n".join(f"('{dni}')" for dni in list_dni)

# %%
import sys 
sys.path.append('C:/Users/DATA/Documents/datos/01_script/inicio/funciones')
from funciones import *
from funciones_spark import *
from variables_inicio import *
from utils_sql import *

spark = SparkSession.builder \
    .appName("SparkExample") \
    .master("local[*]") \
    .config('spark.driver.extraClassPath', 'C:/spark/jars/mssql-jdbc-13.2.1.jre11.jar') \
    .config('spark.executor.extraClassPath', 'C:/spark/jars/mssql-jdbc-13.2.1.jre11.jar') \
    .config('spark.executor.memory', '8g') \
    .config('spark.driver.memory', '8g') \
    .getOrCreate()

# %%
fecha_mes_base='2026-06-01'
tipi_cond1='RECLUTAMIENTO'
tipi_cond2='xx'
tipi_cond3='xx'
tb_tipolofia='tTipologia_Reclutamiento'
servidor_01=64
tipi_cod='cod'
tipi_resp_cod='RC0'
tipi_descrip='[NIVEL 4]'
tipi_estado='[NIVEL 2]'
tipi_resp_estado='NO CONTACTO'
tipi_subdescripcion='[NIVEL 3]'
tnum_tb='tNumeroDinersTc'
tnum_dni='NUMERO_DOCUMENTO'
tlista_generada='borrar_tc_dinner'
get_base=since_base_maestra_tc_dinners

query = f"""
    SELECT *
    FROM OPENQUERY([192.168.3.{servidor_01}], '
        SELECT        
        rtrim(ltrim(d.vendor_lead_code)) AS vendor_lead_code,        
        e.dial_method,
        a.campaign_id AS numero_campana,        
        a.user AS dni_ejecutivo,
        c.full_name AS ejecutivo,
        e.campaign_name AS nombre_campana,        
        a.call_date AS fecha_hora_llamada,        
        a.length_in_sec AS duracion,        
        b.status_name AS call_result,        
        f.list_description,        
        f.list_name,        
        a.phone_number as phone_number,        
        d.alt_phone as fecha_agenda,        
        d.comments as comentarios,        
        a.status AS codigo
        FROM asterisk.vicidial_log a         
        LEFT JOIN asterisk.vicidial_list d ON a.lead_id=d.lead_id        
        LEFT JOIN asterisk.vicidial_campaigns e ON a.campaign_id=e.campaign_id        
        LEFT JOIN asterisk.vicidial_lists f ON a.list_id=f.list_id        
        LEFT JOIN asterisk.vicidial_statuses b ON a.status=b.status        
        LEFT JOIN asterisk.vicidial_users c ON a.user=c.user        
        WHERE (e.campaign_name like "%{tipi_cond1}" or e.campaign_name like "%{tipi_cond2}" or e.campaign_name like "%{tipi_cond3}")
        AND a.call_date >= DATE_FORMAT(''{fecha_mes_base}'', ''%Y-%m-01'')
        AND a.call_date < 
        DATE_ADD(DATE_FORMAT(''{fecha_mes_base}'', ''%Y-%m-01''), INTERVAL 1 MONTH)
    ')

    """
df_vicidial=obtener_tabla_sql(spark,query,server_zeus,user_zeus,pwd_zeus,db_zeus)

# %%
df_vicidial.show()
# Out:
# +----------------+--------------------+--------------+-------------+--------------------+--------------+-------------------+--------+-----------+----------------+-------------------+------------+------------+-----------+------+
# |vendor_lead_code|         dial_method|numero_campana|dni_ejecutivo|           ejecutivo|nombre_campana| fecha_hora_llamada|duracion|call_result|list_description|          list_name|phone_number|fecha_agenda|comentarios|codigo|
# +----------------+--------------------+--------------+-------------+--------------------+--------------+-------------------+--------+-----------+----------------+-------------------+------------+------------+-----------+------+
# |                |MANUAL           ...|            71|     70198430|OCTAVIO RODRIGUEZ...| RECLUTAMIENTO|2026-06-01 09:48:02|       0|       NULL|            NULL|Default Manual list|   978379897|            |           | RC003|
# |                |MANUAL           ...|            71|     70198430|OCTAVIO RODRIGUEZ...| RECLUTAMIENTO|2026-06-01 09:48:25|      56|       NULL|            NULL|Default Manual list|   978379897|            |           | RC001|
# |                |MANUAL           ...|            71|     70198430|OCTAVIO RODRIGUEZ...| RECLUTAMIENTO|2026-06-01 09:57:26|       0|       NULL|            NULL|Default Manual list|   994724281|            |           | RC003|
# |                |MANUAL           ...|            71|     70198430|OCTAVIO RODRIGUEZ...| RECLUTAMIENTO|2026-06-01 09:57:46|      20|       NULL|            NULL|Default Manual list|   908790267|            |           | RC017|
# |                |MANUAL           ...|            71|     70198430|OCTAVIO RODRIGUEZ...| RECLUTAMIENTO|2026-06-01 09:58:07|      21|       NULL|            NULL|Default Manual list|   908790267|            |           | RC017|
# |                |MANUAL           ...|            71|     70198430|OCTAVIO RODRIGUEZ...| RECLUTAMIENTO|2026-06-01 09:59:41|      94|       NULL|            NULL|Default Manual list|   929709384|            |           | RC003|
# |                |MANUAL           ...|            71|     70198430|OCTAVIO RODRIGUEZ...| RECLUTAMIENTO|2026-06-01 10:00:12|      69|       NULL|            NULL|Default Manual list|   929709384|            |           | RC001|
# |                |MANUAL           ...|            71|     70198430|OCTAVIO RODRIGUEZ...| RECLUTAMIENTO|2026-06-01 10:02:59|       0|       NULL|            NULL|Default Manual list|   994724281|            |           | RC003|
# |                |MANUAL           ...|            71|     70198430|OCTAVIO RODRIGUEZ...| RECLUTAMIENTO|2026-06-01 10:03:44|      45|       NULL|            NULL|Default Manual list|   994724281|            |           | RC003|
# |                |MANUAL           ...|            71|     70198430|OCTAVIO RODRIGUEZ...| RECLUTAMIENTO|2026-06-01 10:04:34|      50|       NULL|            NULL|Default Manual list|   922833705|            |           | RC003|
# |                |MANUAL           ...|            71|     70198430|OCTAVIO RODRIGUEZ...| RECLUTAMIENTO|2026-06-01 10:05:24|      50|       NULL|            NULL|Default Manual list|   922833705|            |           | RC003|
# |                |MANUAL           ...|            71|     70198430|OCTAVIO RODRIGUEZ...| RECLUTAMIENTO|2026-06-01 10:10:31|      27|       NULL|            NULL|Default Manual list|   936167137|            |           | RC017|
# |                |MANUAL           ...|            71|     70198430|OCTAVIO RODRIGUEZ...| RECLUTAMIENTO|2026-06-01 10:11:07|      35|       NULL|            NULL|Default Manual list|   936167137|            |           | RC003|
# |                |MANUAL           ...|            71|     70198430|OCTAVIO RODRIGUEZ...| RECLUTAMIENTO|2026-06-01 10:11:50|      34|       NULL|            NULL|Default Manual list|   936167137|            |           | RC003|
# |                |MANUAL           ...|            71|     70198430|OCTAVIO RODRIGUEZ...| RECLUTAMIENTO|2026-06-01 10:12:32|      34|       NULL|            NULL|Default Manual list|   936167137|            |           | RC003|
# |                |MANUAL           ...|            71|     70198430|OCTAVIO RODRIGUEZ...| RECLUTAMIENTO|2026-06-01 10:13:15|      35|       NULL|            NULL|Default Manual list|   936167137|            |           | RC003|
# |                |MANUAL           ...|            71|     70198430|OCTAVIO RODRIGUEZ...| RECLUTAMIENTO|2026-06-01 10:14:05|      34|       NULL|            NULL|Default Manual list|   936167137|            |           | RC003|
# |                |MANUAL           ...|            71|     70198430|OCTAVIO RODRIGUEZ...| RECLUTAMIENTO|2026-06-01 10:14:46|      37|       NULL|            NULL|Default Manual list|   936167137|            |           | RC003|
# |                |MANUAL           ...|            71|     70198430|OCTAVIO RODRIGUEZ...| RECLUTAMIENTO|2026-06-01 10:44:19|       0|       NULL|            NULL|Default Manual list|   997311393|            |           | RC003|
# |                |MANUAL           ...|            71|     70198430|OCTAVIO RODRIGUEZ...| RECLUTAMIENTO|2026-06-01 10:45:06|      47|       NULL|            NULL|Default Manual list|   997311393|            |           | RC003|
# +----------------+--------------------+--------------+-------------+--------------------+--------------+-------------------+--------+-----------+----------------+-------------------+------------+------------+-----------+------+
# only showing top 20 rows

# %%
# def resumen_vicidial(spark,fecha_mes_base,tipi_cond1,tipi_cond2,tipi_cond3,tb_tipolofia,servidor_01,tipi_cod,tipi_resp_cod,tipi_descrip,tipi_estado,tipi_resp_estado):
query = f"""
    SELECT *
    FROM OPENQUERY([192.168.3.{servidor_01}], '
        SELECT        
        rtrim(ltrim(d.vendor_lead_code)) AS vendor_lead_code,        
        e.dial_method,
        a.campaign_id AS numero_campana,        
        a.user AS dni_ejecutivo,
        c.full_name AS ejecutivo,
        e.campaign_name AS nombre_campana,        
        a.call_date AS fecha_hora_llamada,        
        a.length_in_sec AS duracion,        
        b.status_name AS call_result,        
        f.list_description,        
        f.list_name,        
        a.phone_number as phone_number,        
        d.alt_phone as fecha_agenda,        
        d.comments as comentarios,        
        a.status AS codigo
        FROM asterisk.vicidial_log a         
        LEFT JOIN asterisk.vicidial_list d ON a.lead_id=d.lead_id        
        LEFT JOIN asterisk.vicidial_campaigns e ON a.campaign_id=e.campaign_id        
        LEFT JOIN asterisk.vicidial_lists f ON a.list_id=f.list_id        
        LEFT JOIN asterisk.vicidial_statuses b ON a.status=b.status        
        LEFT JOIN asterisk.vicidial_users c ON a.user=c.user        
        WHERE (e.campaign_name like "%{tipi_cond1}" or e.campaign_name like "%{tipi_cond2}" or e.campaign_name like "%{tipi_cond3}")
        AND a.call_date >= DATE_FORMAT(''{fecha_mes_base}'', ''%Y-%m-01'')
        AND a.call_date < 
        DATE_ADD(DATE_FORMAT(''{fecha_mes_base}'', ''%Y-%m-01''), INTERVAL 1 MONTH)
    ')

    """
df_vicidial=obtener_tabla_sql(spark,query,server_zeus,user_zeus,pwd_zeus,db_zeus)

    df_vicidial = df_vicidial.withColumn(
        "vendor_lead_code",
        F.lpad(F.col("vendor_lead_code").cast("string"), 8, "0")
    )
    query = f"""
        SELECT {tipi_cod} as codigo
        , case
            when {tipi_cod}='CALLBK' then 'VOLVER A LLAMAR - call'
            else {tipi_descrip} 
        end as descripcion
        ,case 
            when {tipi_cod}='CALLBK' then 1200
            else peso 
        end as peso  FROM [ODIN].[dbo].{tb_tipolofia}
        where LEFT({tipi_cod},2)='{tipi_resp_cod}' or {tipi_estado}='{tipi_resp_estado}' or {tipi_cod}='CALLBK'
        """
    df_tipi=obtener_tabla_sql(spark,query,server_zeus,user_zeus,pwd_zeus,db_zeus)

    df_vicidial=df_vicidial.join(df_tipi,["codigo"],"left")

    return df_vicidial.select('fecha_hora_llamada','list_name','vendor_lead_code','phone_number','descripcion','dni_ejecutivo','ejecutivo','dial_method','call_result','duracion','codigo','nombre_campana')
# Out:
#   Cell In[3], line 36
#     df_vicidial = df_vicidial.withColumn(
#     ^
# IndentationError: unexpected indent

# %%
import os
import requests
import pandas as pd
import msal
from dotenv import load_dotenv

load_dotenv()

TENANT_ID = os.getenv("TENANT_ID")
CLIENT_ID = os.getenv("CLIENT_ID")

AUTHORITY = f"https://login.microsoftonline.com/{TENANT_ID}"
SCOPES = ["Files.Read.All", "Sites.Read.All"]

app = msal.PublicClientApplication(
    client_id=CLIENT_ID,
    authority=AUTHORITY
)

result = app.acquire_token_interactive(scopes=SCOPES)

if "access_token" not in result:
    raise Exception(result)

token = result["access_token"]

headers = {
    "Authorization": f"Bearer {token}"
}
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\DATA\AppData\Local\Programs\Python\Python311\Lib\site-packages\msal\authority.py:98, in Authority.__init__(self, authority_url, http_client, validate_authority, instance_discovery, oidc_authority_url)
#      97 try:
# ---> 98     openid_config = tenant_discovery(
#      99         tenant_discovery_endpoint,
#     100         self._http_client)
#     101 except ValueError:
#
# File c:\Users\DATA\AppData\Local\Programs\Python\Python311\Lib\site-packages\msal\authority.py:298, in tenant_discovery(tenant_discovery_endpoint, http_client, **kwargs)
#     295 if 400 <= resp.status_code < 500:
#     296     # Nonexist tenant would hit this path
#     297     # e.g. https://login.microsoftonline.com/nonexist_tenant/v2.0/.well-known/openid-configuration
# --> 298     raise ValueError("OIDC Discovery failed on {}. HTTP status: {}, Error: {}".format(
#     299         tenant_discovery_endpoint,
#     300         resp.status_code,
#     301         resp.text,  # Expose it as-is b/c OIDC defines no error response format
#     302         ))
#     303 # Transient network error would hit this path
#
# ValueError: OIDC Discovery failed on https://login.microsoftonline.com/None/v2.0/.well-known/openid-configuration. HTTP status: 400, Error: {"error":"invalid_tenant","error_description":"AADSTS90002: Tenant 'none' not found. Check to make sure you have the correct tenant ID and are signing into the correct cloud. Check with your subscription administrator, this may happen if there are no active subscriptions for the tenant. Trace ID: df231157-8511-4723-8d3b-9da288353700 Correlation ID: 408ffbd7-8fbb-49d8-acd3-37a410fff7ca Timestamp: 2026-06-16 01:22:49Z","error_codes":[90002],"timestamp":"2026-06-16 01:22:49Z","trace_id":"df231157-8511-4723-8d3b-9da288353700","correlation_id":"408ffbd7-8fbb-49d8-acd3-37a410fff7ca","error_uri":"https://login.microsoftonline.com/error?code=90002"}
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 15
#      12 AUTHORITY = f"https://login.microsoftonline.com/{TENANT_ID}"
#      13 SCOPES = ["Files.Read.All", "Sites.Read.All"]
# ---> 15 app = msal.PublicClientApplication(
#      16     client_id=CLIENT_ID,
#      17     authority=AUTHORITY
#      18 )
#      20 result = app.acquire_token_interactive(scopes=SCOPES)
#      22 if "access_token" not in result:
#
# File c:\Users\DATA\AppData\Local\Programs\Python\Python311\Lib\site-packages\msal\application.py:2145, in PublicClientApplication.__init__(self, client_id, client_credential, enable_broker_on_windows, enable_broker_on_mac, enable_broker_on_linux, enable_broker_on_wsl, **kwargs)
#    2136     raise ValueError("Public Client should not possess credentials")
#    2138 self._enable_broker = bool(
#    2139     enable_broker_on_windows and sys.platform == "win32"
#    2140     or enable_broker_on_mac and sys.platform == "darwin"
#    2141     or enable_broker_on_linux and sys.platform == "linux"
#    2142     or enable_broker_on_wsl and is_wsl()
#    2143     )
# -> 2145 super(PublicClientApplication, self).__init__(
#    2146     client_id, client_credential=None, **kwargs)
#
# File c:\Users\DATA\AppData\Local\Programs\Python\Python311\Lib\site-packages\msal\application.py:689, in ClientApplication.__init__(self, client_id, client_credential, authority, validate_authority, token_cache, http_client, verify, proxies, timeout, client_claims, app_name, app_version, client_capabilities, azure_region, exclude_scopes, http_cache, instance_discovery, allow_broker, enable_pii_log, oidc_authority)
#     687 try:
#     688     authority_to_use = authority or "https://{}/common/".format(WORLD_WIDE)
# --> 689     self.authority = Authority(
#     690         authority_to_use,
#     691         self.http_client,
#     692         validate_authority=validate_authority,
#     693         instance_discovery=self._instance_discovery,
#     694         oidc_authority_url=oidc_authority,
#     695         )
#     696 except ValueError:  # Those are explicit authority validation errors
#     697     raise
#
# File c:\Users\DATA\AppData\Local\Programs\Python\Python311\Lib\site-packages\msal\authority.py:114, in Authority.__init__(self, authority_url, http_client, validate_authority, instance_discovery, oidc_authority_url)
#     101 except ValueError:
#     102     error_message = (
#     103         "Unable to get OIDC authority configuration for {url} "
#     104         "because its OIDC Discovery endpoint is unavailable at "
#    (...)    112         .format(authority_url)
#     113         ) + " Also please double check your tenant name or GUID is correct."
# --> 114     raise ValueError(error_message)
#     115 self._issuer = openid_config.get('issuer')
#     116 self.authorization_endpoint = openid_config['authorization_endpoint']
#
# ValueError: Unable to get authority configuration for https://login.microsoftonline.com/None. Authority would typically be in a format of https://login.microsoftonline.com/your_tenant or https://tenant_name.ciamlogin.com or https://tenant_name.b2clogin.com/tenant.onmicrosoft.com/policy.  Also please double check your tenant name or GUID is correct.

# %%
url = "https://graph.microsoft.com/v1.0/me/drive/root:/Forms/NOMBRE_ARCHIVO.xlsx:/content"

response = requests.get(url, headers=headers)

with open("respuestas_forms.xlsx", "wb") as f:
    f.write(response.content)

df = pd.read_excel("respuestas_forms.xlsx")

print(df.head())

# %%
pip install msal requests pandas openpyxl python-dotenv

# %%
import base64
import requests
import pandas as pd
import msal

TENANT_ID = "TU_TENANT_ID"
CLIENT_ID = "TU_CLIENT_ID"

excel_url = """https://netorgft16620308-my.sharepoint.com/:x:/r/personal/seleccion_targetoutsourcing_org/_layouts/15/Doc.aspx?sourcedoc=%7BB42A55BF-161A-42B9-8592-5322FB3A3F09%7D&file=ENCUESTA%20DE%20SATISFACCI%C3%93N%20-%20TARGET%20OUTSOURCING.xlsx&action=edit&mobileredirect=true"""

authority = f"https://login.microsoftonline.com/{TENANT_ID}"
scopes = ["Files.Read.All", "Sites.Read.All"]

app = msal.PublicClientApplication(
    client_id=CLIENT_ID,
    authority=authority
)

result = app.acquire_token_interactive(scopes=scopes)

if "access_token" not in result:
    raise Exception(result)

token = result["access_token"]

headers = {
    "Authorization": f"Bearer {token}"
}

# Convertir URL a shareId
encoded_url = base64.urlsafe_b64encode(excel_url.encode()).decode().rstrip("=")
share_id = f"u!{encoded_url}"

# Descargar Excel
download_url = f"https://graph.microsoft.com/v1.0/shares/{share_id}/driveItem/content"

response = requests.get(download_url, headers=headers)

if response.status_code != 200:
    print(response.status_code)
    print(response.text)
    raise Exception("No se pudo descargar el archivo")

archivo_local = "respuestas_forms.xlsx"

with open(archivo_local, "wb") as f:
    f.write(response.content)

df = pd.read_excel(archivo_local)

print(df.head())

# %% [markdown]
# ## Inicio

# %% [markdown]
# pip install Office365-REST-Python-Client pandas openpyxl

# %%
import pandas as pd
from office365.sharepoint.client_context import ClientContext
from office365.runtime.auth.user_credential import UserCredential

usuario = "seleccion@targetoutsourcing.org"
password = "Target.2025$"

site_url = "https://netorgft16620308-my.sharepoint.com/personal/seleccion_targetoutsourcing_org"

file_url = "/personal/seleccion_targetoutsourcing_org/Documents/ENCUESTA DE SATISFACCIÓN - TARGET OUTSOURCING.xlsx"

# Archivo local donde se descargará
archivo_local = "respuestas_forms.xlsx"

ctx = ClientContext(site_url).with_credentials(
    UserCredential(usuario, password)
)

with open(archivo_local, "wb") as local_file:
    file = ctx.web.get_file_by_server_relative_url(file_url)
    file.download(local_file).execute_query()

print("Archivo descargado correctamente")

df = pd.read_excel(archivo_local)

print(df.head())
# Out:
# An error occurred while retrieving token from XML response: AADSTS90023: Invalid STS request.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 21
#      19 with open(archivo_local, "wb") as local_file:
#      20     file = ctx.web.get_file_by_server_relative_url(file_url)
# ---> 21     file.download(local_file).execute_query()
#      23 print("Archivo descargado correctamente")
#      25 df = pd.read_excel(archivo_local)
#
# File c:\Users\DATA\AppData\Local\Programs\Python\Python311\Lib\site-packages\office365\runtime\client_object.py:55, in ClientObject.execute_query(self)
#      52 def execute_query(self):
#      53     # type: () -> Self
#      54     """Submit request(s) to the server."""
# ---> 55     self.context.execute_query()
#      56     return self
#
# File c:\Users\DATA\AppData\Local\Programs\Python\Python311\Lib\site-packages\office365\runtime\client_runtime_context.py:173, in ClientRuntimeContext.execute_query(self)
#     171 while self.has_pending_request:
#     172     qry = self._get_next_query()
# --> 173     self.pending_request().execute_query(qry)
#     174 return self
#
# File c:\Users\DATA\AppData\Local\Programs\Python\Python311\Lib\site-packages\office365\runtime\client_request.py:37, in ClientRequest.execute_query(self, query)
#      35 try:
#      36     request = self.build_request(query)
# ---> 37     response = self.execute_request_direct(request)
#      38     self.process_response(response, query)
#      39     self.afterExecute.notify(response)
#
# File c:\Users\DATA\AppData\Local\Programs\Python\Python311\Lib\site-packages\office365\runtime\client_request.py:46, in ClientRequest.execute_request_direct(self, request)
#      43 def execute_request_direct(self, request):
#      44     # type: (RequestOptions) -> requests.Response
#      45     """Execute the client request"""
# ---> 46     self.beforeExecute.notify(request)
#      47     if request.method == HttpMethod.Post:
#      48         if request.is_bytes or request.is_file:
#
# File c:\Users\DATA\AppData\Local\Programs\Python\Python311\Lib\site-packages\office365\runtime\types\event_handler.py:41, in EventHandler.notify(self, *args, **kwargs)
#      39 if self._once:
#      40     self._listeners.remove(listener)
# ---> 41 listener(*args, **kwargs)
#
# File c:\Users\DATA\AppData\Local\Programs\Python\Python311\Lib\site-packages\office365\sharepoint\client_context.py:272, in ClientContext._authenticate_request(self, request)
#     269 def _authenticate_request(self, request):
#     270     # type: (RequestOptions) -> None
#     271     """Authenticate request"""
# --> 272     self.authentication_context.authenticate_request(request)
#
# File c:\Users\DATA\AppData\Local\Programs\Python\Python311\Lib\site-packages\office365\runtime\auth\authentication_context.py:275, in AuthenticationContext.authenticate_request(self, request)
#     273 if self._authenticate is None:
#     274     raise ValueError("Authentication credentials are missing or invalid")
# --> 275 self._authenticate(request)
#
# File c:\Users\DATA\AppData\Local\Programs\Python\Python311\Lib\site-packages\office365\runtime\auth\authentication_context.py:229, in AuthenticationContext.with_credentials.<locals>._authenticate(request)
#     227 def _authenticate(request):
#     228     # type: (RequestOptions) -> None
# --> 229     provider.authenticate_request(request)
#
# File c:\Users\DATA\AppData\Local\Programs\Python\Python311\Lib\site-packages\office365\runtime\auth\providers\saml_token_provider.py:81, in SamlTokenProvider.authenticate_request(self, request)
#      76 if (
#      77     self._cached_auth_cookies is None
#      78     or request_time >= self._sts_profile.expires
#      79 ):
#      80     self._sts_profile.reset()
# ---> 81     self._cached_auth_cookies = self.get_authentication_cookie()
#      82 logger.debug_secrets(self._cached_auth_cookies)
#      83 request.set_header("Cookie", self._cached_auth_cookies.cookie_header)
#
# File c:\Users\DATA\AppData\Local\Programs\Python\Python311\Lib\site-packages\office365\runtime\auth\providers\saml_token_provider.py:94, in SamlTokenProvider.get_authentication_cookie(self)
#      92 user_realm = self._get_user_realm()
#      93 if user_realm.IsFederated:
# ---> 94     token = self._acquire_service_token_from_adfs(user_realm.STSAuthUrl)
#      95 else:
#      96     token = self._acquire_service_token()
#
# File c:\Users\DATA\AppData\Local\Programs\Python\Python311\Lib\site-packages\office365\runtime\auth\providers\saml_token_provider.py:162, in SamlTokenProvider._acquire_service_token_from_adfs(self, adfs_url)
#     156 # 3. get security token
#     157 response = requests.post(
#     158     self._sts_profile.security_token_service_url,
#     159     data=payload,
#     160     headers={"Content-Type": "application/soap+xml"},
#     161 )
# --> 162 token = self._process_service_token_response(response)
#     163 logger.debug_secrets("security token: %s", token)
#     164 return token
#
# File c:\Users\DATA\AppData\Local\Programs\Python\Python311\Lib\site-packages\office365\runtime\auth\providers\saml_token_provider.py:229, in SamlTokenProvider._process_service_token_response(self, response)
#     225         self.error = "An error occurred while retrieving token from XML response: {0}".format(
#     226             error.text
#     227         )
#     228     logger.error(self.error)
# --> 229     raise ValueError(self.error)
#     231 # extract token
#     232 token = xml.find(
#     233     "{0}Body/{1}RequestSecurityTokenResponse/{1}RequestedSecurityToken/{2}BinarySecurityToken".format(
#     234         self.__ns_prefixes["s"],
#    (...)    237     )
#     238 )
#
# ValueError: An error occurred while retrieving token from XML response: AADSTS90023: Invalid STS request.

# %% [markdown]
# ### De nuevo
