# %%
import pandas as pd

# %%
df = pd.read_csv('prueba.csv')
# Out:
# C:\Users\FERNANDO\AppData\Local\Temp\ipykernel_27252\3481261566.py:1: DtypeWarning: Columns (34) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('prueba.csv')

# %%
df.head(2)
# Out:
#   LAST NAME   FIRST NAME                     ADDRESS1  \
# 0     PIURA  POTENCIALES  MAZA YARLEQUE MARIA MARITZA
# 1    ANCASH  POTENCIALES        GALLARDO CHAVEZ RONAL
#
#                           ADDRESS3  COMMENTS  VENDOR LEAD CODE  PROVINCE  \
# 0  EMP1=NULL/ EMP2=NULL/ EMP3=NULL       NaN          80275039  MORROPÓN
# 1  EMP1=NULL/ EMP2=NULL/ EMP3=NULL       NaN          42190010     SANTA
#
#              CITY             EMAIL  \
# 0      CHULUCANAS  COD_AGENCIA =213
# 1  NUEVO CHIMBOTE   COD_AGENCIA =39
#
#                                           COMMENTS_2  ...  Cantidad_Discador  \
# 0  LINEA_EXPRESS //LINEA_ESCRITORIO //LINEA_SEMIF...  ...                  0
# 1  LINEA_EXPRESS //LINEA_ESCRITORIO //LINEA_SEMIF...  ...                  0
#
#    TELEFO1  TELEFO2  TELEFO3           REGION MARCADESBASE  MARCA2  \
# 0      NaN       -1       -1  Leads Provincia          NaN     NaN
# 1      NaN       -1       -1  Leads Provincia          NaN     NaN
#
# ...

# %%
df['Veces_Cliente'].describe()
# Out:
# count    48586.000000
# mean         5.897007
# std          5.780402
# min          1.000000
# 25%          2.000000
# 50%          4.000000
# 75%          8.000000
# max         53.000000
# Name: Veces_Cliente, dtype: float64

# %%
df.describe()
# Out:
#        COMMENTS  VENDOR LEAD CODE  PHONE NUMBER  Order_Numero  Oferta  \
# count       0.0      7.795900e+04  7.795900e+04       77959.0     0.0
# mean        NaN      3.381674e+07  9.656233e+08           1.0     NaN
# std         NaN      2.099891e+07  2.346118e+07           0.0     NaN
# min         NaN      2.346000e+03  9.000005e+08           1.0     NaN
# 25%         NaN      1.641017e+07  9.481931e+08           1.0     NaN
# 50%         NaN      4.025592e+07  9.666077e+08           1.0     NaN
# 75%         NaN      4.504626e+07  9.868344e+08           1.0     NaN
# max         NaN      8.183122e+07  1.000000e+09           1.0     NaN
#
#        Tip_Prioridad  MARCA_2025  Perfil_ic      LINEA_FT   LINEA_HS_RS  ...  \
# count            0.0         0.0        0.0  28504.000000  36701.000000  ...
# mean             NaN         NaN        NaN   6503.134185   6902.950574  ...
# std              NaN         NaN        NaN   7297.943972   2837.154656  ...
# ...

# %%
print(df.columns)
# Out:
# Index(['LAST NAME', 'FIRST NAME', 'ADDRESS1', 'ADDRESS3', 'COMMENTS',
#        'VENDOR LEAD CODE', 'PROVINCE', 'CITY', 'EMAIL', 'COMMENTS_2',
#        'PHONE NUMBER', 'Order_Numero', 'Oferta', 'Tip_Prioridad', 'MARCA_2025',
#        'NOMCOMERCIAL', 'Perfil_ic', 'tipocliente', 'TIPOINGRESO', 'ASIGNACION',
#        'LINEA_FT', 'LINEA_HS_RS', 'LINEA_HS_PLUS', 'LINEA_FULL', 'MARCA',
#        'TIP_TELF', 'PROVEEDOR', 'PERFIL', 'SEGMENTO', 'SCORE', 'TASA',
#        'RANGO_TASA', 'ZONA', 'Tipo_Telf', 'Fecha_Llam', 'Hora_Llamada',
#        'FECHA_ENVIO', 'RETIRO', 'Mejor_Estado_Telefono',
#        'Mejor_Sub_Estado_Telefono', 'Mejor_Descripcion_Telefono',
#        'Mejor_Fecha_Telefono', 'Mejor_Hora_Telefono', 'Mejor_Durac_Telefono',
#        'Mejor_Estado_Cliente', 'Mejor_Sub_Estado_Cliente',
#        'Mejor_Descripcion_Cliente', 'Mejor_fecha_Cliente',
#        'Mejor_Hora_Cliente', 'Mejor_Durac_Cliente', 'ULT_Descripcion_Cli',
# ...

# %%
df['tipocliente'].unique()
# Out:
# array(['POTENCIALES', 'AFILIADOS', 'NUEVO', 'DORMIDO'], dtype=object)

# %%
df['Mejor_Sub_Estado_Cliente'].unique()
# Out:
# array(['NO CARGADO', 'EFECTIVO', 'NO EFECTIVO', 'SIN CONTACTO'],
#       dtype=object)

# %%
df['target'] = (df['Mejor_Sub_Estado_Cliente'] == 'EFECTIVO').astype(int)

df['target'].value_counts(normalize=True)
df.columns
# Out:
# Index(['LAST NAME', 'FIRST NAME', 'ADDRESS1', 'ADDRESS3', 'COMMENTS',
#        'VENDOR LEAD CODE', 'PROVINCE', 'CITY', 'EMAIL', 'COMMENTS_2',
#        'PHONE NUMBER', 'Order_Numero', 'Oferta', 'Tip_Prioridad', 'MARCA_2025',
#        'NOMCOMERCIAL', 'Perfil_ic', 'tipocliente', 'TIPOINGRESO', 'ASIGNACION',
#        'LINEA_FT', 'LINEA_HS_RS', 'LINEA_HS_PLUS', 'LINEA_FULL', 'MARCA',
#        'TIP_TELF', 'PROVEEDOR', 'PERFIL', 'SEGMENTO', 'SCORE', 'TASA',
#        'RANGO_TASA', 'ZONA', 'Tipo_Telf', 'Fecha_Llam', 'Hora_Llamada',
#        'FECHA_ENVIO', 'RETIRO', 'Mejor_Estado_Telefono',
#        'Mejor_Sub_Estado_Telefono', 'Mejor_Descripcion_Telefono',
#        'Mejor_Fecha_Telefono', 'Mejor_Hora_Telefono', 'Mejor_Durac_Telefono',
#        'Mejor_Estado_Cliente', 'Mejor_Sub_Estado_Cliente',
#        'Mejor_Descripcion_Cliente', 'Mejor_fecha_Cliente',
#        'Mejor_Hora_Cliente', 'Mejor_Durac_Cliente', 'ULT_Descripcion_Cli',
# ...

# %%
num_cols = [
    'Veces_Cliente','Veces_Telefono','REPITENCIAS',
    'Cantidad_Sin_Discador','Cantidad_Discador',
    'SCORE','TASA','Mejor_Durac_Telefono'
]
df[num_cols].head(2)
# Out:
#    Veces_Cliente  Veces_Telefono  REPITENCIAS  Cantidad_Sin_Discador  \
# 0            NaN             NaN          NaN                    NaN
# 1            NaN             NaN          NaN                    NaN
#
#    Cantidad_Discador  SCORE    TASA  Mejor_Durac_Telefono
# 0                  0    0.0  113.16                   NaN
# 1                  0    0.0  113.16                   NaN

# %%
df[num_cols].describe()
# Out:
#        Veces_Cliente  Veces_Telefono  REPITENCIAS  Cantidad_Sin_Discador  \
# count   48586.000000    31106.000000  3450.000000            7567.000000
# mean        5.897007        5.059763     0.968696               1.548434
# std         5.780402        4.491704     1.364825               0.992704
# min         1.000000        1.000000     0.000000               1.000000
# 25%         2.000000        2.000000     0.000000               1.000000
# 50%         4.000000        3.000000     1.000000               1.000000
# 75%         8.000000        7.000000     1.000000               2.000000
# max        53.000000       29.000000    10.000000              12.000000
#
#        Cantidad_Discador         SCORE          TASA  Mejor_Durac_Telefono
# count       77959.000000  46031.000000  77959.000000          38153.000000
# mean            1.868572    441.899698     88.799776              4.032396
# std             3.523844    396.507326     20.812427             17.116205
# ...

# %%
import matplotlib.pyplot as plt

df[num_cols].hist(bins=30, figsize=(15,10))
plt.tight_layout()
plt.show()

# %%
Q1 = df[num_cols].quantile(0.25)
Q3 = df[num_cols].quantile(0.75)
IQR = Q3 - Q1

outliers = ((df[num_cols] < (Q1 - 1.5 * IQR)) | 
            (df[num_cols] > (Q3 + 1.5 * IQR)))

outliers.sum()
# Out:
# Veces_Cliente            2582
# Veces_Telefono           1697
# REPITENCIAS               376
# Cantidad_Sin_Discador     377
# Cantidad_Discador        9151
# SCORE                       0
# TASA                        0
# Mejor_Durac_Telefono     9040
# dtype: int64
