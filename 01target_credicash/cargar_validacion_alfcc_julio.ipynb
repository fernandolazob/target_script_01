# %%
# def pool_tnumeros_valentina(spark,dni_valentina,tb_Numero,tb_name_tnum):

cross_columns_a1=cross_columns_int
dni_a1=dni_int
fecha_ref_a1=fecha_ref_int
peso_ref_a1=peso_int
tb_a1=tb_int

cross_columns_a2=cross_columns_web
dni_a2=dni_web
fecha_ref_a2=fecha_ref_web
peso_ref_a2=peso_web
tb_a2=tb_web

cross_columns_a3=cross_columns_hu
dni_a3=dni_hu
fecha_ref_a3=fecha_ref_hu
peso_ref_a3=peso_hu
tb_a3=tb_hu

cross_columns_a4=cross_columns_epc
dni_a4=dni_epc
fecha_ref_a4=fecha_ref_epc
peso_ref_a4=peso_epc
tb_a4=tb_epc

cross_columns_a5=cross_columns_etk
dni_a5=dni_etk
fecha_ref_a5=fecha_ref_etk
peso_ref_a5=peso_etk
tb_a5=tb_etk

query = f"""
    SELECT DISTINCT dni_cliente,contacto,tipo_telf,dias_antiguedad,peso
    FROM (

        SELECT 
            right('00000000'+a.{dni_a1},8) AS dni_cliente,
            t.contacto,
            t.tipo_telf,
            DATEDIFF(DAY, a.{fecha_ref_a1}, GETDATE()) AS dias_antiguedad,
            {peso_ref_a1} as peso
        FROM DANTALION.dbo.{tb_a1} a
        CROSS APPLY (
            VALUES {cross_columns_a1}
        ) t(tipo_telf, contacto)
        WHERE EXISTS (
            SELECT 1
            FROM DANTALION.dbo.BOORRRRRAR_CREDI_DNI b
            WHERE right('00000000'+b.NUMERO_DOCUMENTO,8) = right('00000000'+a.{dni_a1},8)
        )
        AND t.contacto IS NOT NULL
        AND t.contacto <> ''
        AND LEN(t.contacto) = 9
        AND t.contacto LIKE '9%'
        AND a.{dni_a1} IS NOT NULL

        UNION

        SELECT 
            a.{dni_a2} AS dni_cliente,
            t.contacto,
            t.tipo_telf,
            DATEDIFF(DAY, a.{fecha_ref_a2}, GETDATE()) AS dias_antiguedad,
            {peso_ref_a2} as peso
        FROM DANTALION.dbo.{tb_a2} a
        CROSS APPLY (
            VALUES {cross_columns_a2}
        ) t(tipo_telf, contacto)
        WHERE EXISTS (
            SELECT 1
            FROM DANTALION.dbo.BOORRRRRAR_CREDI_DNI b
            WHERE right('00000000'+b.NUMERO_DOCUMENTO,8) = right('00000000'+a.{dni_a2},8)
        )
        AND t.contacto IS NOT NULL
        AND t.contacto <> ''
        AND LEN(t.contacto) = 9
        AND t.contacto LIKE '9%'
        AND a.{dni_a2} IS NOT NULL

        UNION

        SELECT 
            a.{dni_a3} AS dni_cliente,
            t.contacto,
            t.tipo_telf,
            DATEDIFF(DAY, a.{fecha_ref_a3}, GETDATE()) AS dias_antiguedad,
            {peso_ref_a3} as peso
        FROM DANTALION.dbo.{tb_a3} a
        CROSS APPLY (
            VALUES {cross_columns_a3}
        ) t(tipo_telf, contacto)
        WHERE EXISTS (
            SELECT 1
            FROM DANTALION.dbo.BOORRRRRAR_CREDI_DNI b
            WHERE right('00000000'+b.NUMERO_DOCUMENTO,8) = right('00000000'+a.{dni_a3},8)
        )
        AND t.contacto IS NOT NULL
        AND t.contacto <> ''
        AND LEN(t.contacto) = 9
        AND t.contacto LIKE '9%'
        AND a.{dni_a3} IS NOT NULL

        UNION

        SELECT 
            a.{dni_a4} AS dni_cliente,
            t.contacto,
            t.tipo_telf,
            DATEDIFF(DAY, a.{fecha_ref_a4}, GETDATE()) AS dias_antiguedad,
            {peso_ref_a4} as peso
        FROM DANTALION.dbo.{tb_a4} a
        CROSS APPLY (
            VALUES {cross_columns_a4}
        ) t(tipo_telf, contacto)
        WHERE EXISTS (
            SELECT 1
            FROM DANTALION.dbo.BOORRRRRAR_CREDI_DNI b
            WHERE right('00000000'+b.NUMERO_DOCUMENTO,8) = right('00000000'+a.{dni_a4},8)
        )
        AND t.contacto IS NOT NULL
        AND t.contacto <> ''
        AND LEN(t.contacto) = 9
        AND t.contacto LIKE '9%'
        AND a.{dni_a4} IS NOT NULL

        UNION

        SELECT 
            a.{dni_a5} AS dni_cliente,
            t.contacto,
            t.tipo_telf,
            DATEDIFF(DAY, a.{fecha_ref_a5}, GETDATE()) AS dias_antiguedad,
            {peso_ref_a5} as peso
        FROM DANTALION.dbo.{tb_a5} a
        CROSS APPLY (
            VALUES {cross_columns_a5}
        ) t(tipo_telf, contacto)
        WHERE EXISTS (
            SELECT 1
            FROM DANTALION.dbo.BOORRRRRAR_CREDI_DNI b
            WHERE right('00000000'+b.NUMERO_DOCUMENTO,8) = right('00000000'+a.{dni_a5},8)
        )
        AND t.contacto IS NOT NULL
        AND t.contacto <> ''
        AND LEN(t.contacto) = 9
        AND t.contacto LIKE '9%'
        AND a.{dni_a5} IS NOT NULL

    ) t
"""

# %%
query
# Out:
# "\n    SELECT DISTINCT dni_cliente,contacto,tipo_telf,dias_antiguedad,peso\n    FROM (\n\n        SELECT \n            right('00000000'+a.dni,8) AS dni_cliente,\n            t.contacto,\n            t.tipo_telf,\n            DATEDIFF(DAY, a.fecha, GETDATE()) AS dias_antiguedad,\n            20 as peso\n        FROM DANTALION.dbo.tConsoliddoNumerosInterno a\n        CROSS APPLY (\n            VALUES ('int01', a.int1),('int02', a.int2)\n        ) t(tipo_telf, contacto)\n        WHERE EXISTS (\n            SELECT 1\n            FROM DANTALION.dbo.BOORRRRRAR_CREDI_DNI b\n            WHERE right('00000000'+b.NUMERO_DOCUMENTO,8) = right('00000000'+a.dni,8)\n        )\n        AND t.contacto IS NOT NULL\n        AND t.contacto <> ''\n        AND LEN(t.contacto) = 9\n        AND t.contacto LIKE '9%'\n        AND a.dni IS NOT NULL\n\n        UNION\n\n        SELECT \n            a.dni AS dni_cliente,\n            t.contacto,\n            t.tipo_telf,\n            DATEDIFF(DAY, a.fecha_carga, 
# ...

# %%
   SELECT DISTINCT dni_cliente,contacto,tipo_telf,dias_antiguedad,peso
   FROM (
    
       SELECT 
           right('00000000'+a.dni,8) AS dni_cliente,
           t.contacto,
           t.tipo_telf,
           DATEDIFF(DAY, a.fecha, GETDATE()) AS dias_antiguedad,
           20 as peso
       FROM DANTALION.dbo.tConsoliddoNumerosInterno a
       CROSS APPLY (
           VALUES ('int01', a.int1),('int02', a.int2)
       ) t(tipo_telf, contacto)
       WHERE EXISTS (
           SELECT 1
           FROM DANTALION.dbo.BOORRRRRAR_CREDI_DNI b
           WHERE right('00000000'+b.NUMERO_DOCUMENTO,8) = right('00000000'+a.dni,8)
       )
       AND t.contacto IS NOT NULL
       AND t.contacto <> ''
       AND LEN(t.contacto) = 9
       AND t.contacto LIKE '9%'
       AND a.dni IS NOT NULL
       
       UNION
       
       SELECT 
           a.dni AS dni_cliente,
           t.contacto,
           t.tipo_telf,
           DATEDIFF(DAY, a.fecha_carga, GETDATE()) AS dias_antiguedad,
           30 as peso
       FROM DANTALION.dbo.tConsolidadoNumerosweb a
       CROSS APPLY (
           VALUES ('ip01',a.ip1),('ip02',a.ip2),('ip03',a.ip3),('ip04',a.ip4),('ip05',a.ip5),('ip06',a.ip6),('ip07',a.ip7),('ip08',a.ip8),('ip09',a.ip9),('ip10',a.ip10),('ip11',a.ip11),('ip12',a.ip12),('ip13',a.ip13),('ip14',a.ip14),('ip15',a.ip15),('ip16',a.ip16),('ip17',a.ip17),('ip18',a.ip18),('ip19',a.ip19),('ip20',a.ip20),('ip21',a.ip21),('ip22',a.ip22),('ip23',a.ip23),('ip24',a.ip24)
       ) t(tipo_telf, contacto)
       WHERE EXISTS (
           SELECT 1
           FROM DANTALION.dbo.BOORRRRRAR_CREDI_DNI b
           WHERE right('00000000'+b.NUMERO_DOCUMENTO,8) = right('00000000'+a.dni,8)
       )
       AND t.contacto IS NOT NULL
       AND t.contacto <> ''
       AND LEN(t.contacto) = 9
       AND t.contacto LIKE '9%'
       AND a.dni IS NOT NULL
       
       UNION
       
       SELECT 
           a.dni AS dni_cliente,
           t.contacto,
           t.tipo_telf,
           DATEDIFF(DAY, a.fecha_carga, GETDATE()) AS dias_antiguedad,
           40 as peso
       FROM DANTALION.dbo.tConsolidadoNumerosHUNUS a
       CROSS APPLY (
           VALUES ('hu01',a.hu1),('hu02',a.hu2),('hu03',a.hu3),('hu04',a.hu4),('hu05',a.hu5),('hu06',a.hu6),('hu07',a.hu7),('hu08',a.hu8),('hu09',a.hu9),('hu10',a.hu10),('hu11',a.hu11),('hu12',a.hu12),('hu13',a.hu13),('hu14',a.hu14),('hu15',a.hu15),('hu16',a.hu16),('hu17',a.hu17),('hu18',a.hu18),('hu19',a.hu19),('hu20',a.hu20),('hu21',a.hu21),('hu22',a.hu22),('hu23',a.hu23),('hu24',a.hu24)
       ) t(tipo_telf, contacto)
       WHERE EXISTS (
           SELECT 1
           FROM DANTALION.dbo.BOORRRRRAR_CREDI_DNI b
           WHERE right('00000000'+b.NUMERO_DOCUMENTO,8) = right('00000000'+a.dni,8)
       )
       AND t.contacto IS NOT NULL
       AND t.contacto <> ''
       AND LEN(t.contacto) = 9
       AND t.contacto LIKE '9%'
       AND a.dni IS NOT NULL
       
       UNION
       
       SELECT 
           a.dni AS dni_cliente,
           t.contacto,
           t.tipo_telf,
           DATEDIFF(DAY, a.fecha_carga, GETDATE()) AS dias_antiguedad,
           50 as peso
       FROM DANTALION.dbo.tConsolidadoNumerosNMT a
       CROSS APPLY (
           VALUES ('nmt01',a.nmt1), ('nmt02',a.nmt2), ('nmt03',a.nmt3), ('nmt04',a.nmt4), ('nmt05',a.nmt5), ('nmt06',a.nmt6), ('nmt07',a.nmt7), ('nmt08',a.nmt8), ('nmt09',a.nmt9), ('nmt10',a.nmt10), ('nmt11',a.nmt11), ('nmt12',a.nmt12), ('nmt13',a.nmt13), ('nmt14',a.nmt14), ('nmt15',a.nmt15), ('nmt16',a.nmt16), ('nmt17',a.nmt17), ('nmt18',a.nmt18), ('nmt19',a.nmt19), ('nmt20',a.nmt20), ('nmt21',a.nmt21), ('nmt22',a.nmt22), ('nmt23',a.nmt23), ('nmt24',a.nmt24)
       ) t(tipo_telf, contacto)
       WHERE EXISTS (
           SELECT 1
           FROM DANTALION.dbo.BOORRRRRAR_CREDI_DNI b
           WHERE right('00000000'+b.NUMERO_DOCUMENTO,8) = right('00000000'+a.dni,8)
       )
       AND t.contacto IS NOT NULL
       AND t.contacto <> ''
       AND LEN(t.contacto) = 9
       AND t.contacto LIKE '9%'
       AND a.dni IS NOT NULL
       
       UNION
       
       SELECT 
           a.dni AS dni_cliente,
           t.contacto,
           t.tipo_telf,
           DATEDIFF(DAY, a.fecha_carga, GETDATE()) AS dias_antiguedad,
           60 as peso
       FROM DANTALION.dbo.tConsolidadoNumerosVCZ a
       CROSS APPLY (
           VALUES ('vcz01',a.vcz1),('vcz02',a.vcz2),('vcz03',a.vcz3),('vcz04',a.vcz4),('vcz05',a.vcz5),('vcz06',a.vcz6),('vcz07',a.vcz7),('vcz08',a.vcz8),('vcz09',a.vcz9),('vcz10',a.vcz10),('vcz11',a.vcz11),('vcz12',a.vcz12),('vcz13',a.vcz13),('vcz14',a.vcz14),('vcz15',a.vcz15),('vcz16',a.vcz16),('vcz17',a.vcz17),('vcz18',a.vcz18),('vcz19',a.vcz19),('vcz20',a.vcz20),('vcz21',a.vcz21),('vcz22',a.vcz22),('vcz23',a.vcz23),('vcz24',a.vcz24)
       ) t(tipo_telf, contacto)
       WHERE EXISTS (
           SELECT 1
           FROM DANTALION.dbo.BOORRRRRAR_CREDI_DNI b
           WHERE right('00000000'+b.NUMERO_DOCUMENTO,8) = right('00000000'+a.dni,8)
       )
       AND t.contacto IS NOT NULL
       AND t.contacto <> ''
       AND LEN(t.contacto) = 9
       AND t.contacto LIKE '9%'
       AND a.dni IS NOT NULL
       
   ) t
   "

# %%
df_ref01=obtener_tabla_sql(spark,query,server_kishin,user_kishin,pwd_kishin,db_kishin)

window_spec = Window.partitionBy("dni_cliente","contacto").orderBy(F.col("peso").asc_nulls_last(),F.col("dias_antiguedad").asc_nulls_last())
df_ref01 = df_ref01.withColumn("ref1_vici", row_number().over(window_spec))
df_ref01 = df_ref01.filter(F.col('ref1_vici')==1).drop('ref1_vici','peso')    

df_ref01 = df_ref01.withColumn(
    "dni_cliente",
    F.right(
        F.concat(F.lit("00000000"), F.col("dni_cliente")),
        F.lit(8)
    )
)

# %%
import sys 
sys.path.append('C:/Users/DATA/Documents/datos/01_script/inicio/funciones')
from funciones import *
from funciones_spark import *
from variables_inicio import *
from utils_sql import *

spark = SparkSession.builder \
    .appName("SparkExample") \
    .master("local[*]") \
    .config('spark.driver.extraClassPath', 'C:/spark/jars/mssql-jdbc-13.2.1.jre11.jar') \
    .config('spark.executor.extraClassPath', 'C:/spark/jars/mssql-jdbc-13.2.1.jre11.jar') \
    .config('spark.executor.memory', '8g') \
    .config('spark.driver.memory', '8g') \
    .getOrCreate()

# %%
ruta_archivo = os.path.join(ruta_csv, 'Data export - 2026-07-07T094054.928.csv')
df_subir_lista=cargar_archivo_csv(spark,ruta_archivo,';',True)
print(df_subir_lista.columns)
# Out:
# ['NRO', 'FICHA', 'EXCEL', 'FECHA', 'HORA', 'ESTADO', 'CLIENTE', 'DNI', 'MONTO', 'PLAZO', 'TELEFONO', 'PROMOTOR', 'AUDITOR', 'FECHA_A', 'HORA_A', 'OBSERVACION']

# %%
df_subir_lista.show()
# Out:
# +---+-----+-----+----------+--------+-----------+--------------------+--------+-----+-----+---------+--------+-------+-------+------+-----------+
# |NRO|FICHA|EXCEL|     FECHA|    HORA|     ESTADO|             CLIENTE|     DNI|MONTO|PLAZO| TELEFONO|PROMOTOR|AUDITOR|FECHA_A|HORA_A|OBSERVACION|
# +---+-----+-----+----------+--------+-----------+--------------------+--------+-----+-----+---------+--------+-------+-------+------+-----------+
# |  1| NULL| NULL|07/07/2026|00:00:03|SIN VALIDAR|YULISA ELIZABETH ...|75195170| 7000| NULL|991298792| KLUCENA|   NULL|   NULL|  NULL|       NULL|
# |  2| NULL| NULL|07/07/2026|00:05:02|SIN VALIDAR|YULISA ELIZABETH ...|75195170| 7000| NULL|991298792| KLUCENA|   NULL|   NULL|  NULL|       NULL|
# |  3| NULL| NULL|07/07/2026|00:10:02|SIN VALIDAR|YULISA ELIZABETH ...|75195170| 7000| NULL|991298792| KLUCENA|   NULL|   NULL|  NULL|       NULL|
# ...

# %%
query = """
   select *,NUMERO_DOCUMENTO as DNI from DANTALION.dbo.Base_Maestra_ALFCC_Vigente
   where cl_estado=1
    """
df_formato=obtener_tabla_sql(spark,query,server_kishin,user_kishin,pwd_kishin,db_kishin)

print(df_formato.columns)
# Out:
# ['cl_id', 'cl_telf1', 'cl_telf2', 'cl_telf3', 'cl_telf4', 'cl_telf5', 'cl_telf6', 'cl_telf7', 'cl_telf8', 'cl_telf9', 'cl_telf10', 'cl_movil', 'cl_celular', 'cl_telefono', 'cl_turno', 'cl_gestor', 'cl_asesor', 'cl_accion', 'cl_gestion', 'cl_estado', 'cl_fecha_gestion', 'cl_hora_gestion', 'cl_hits', 'cl_fecha_llamar', 'cl_prioridad', 'cl_orden', 'cl_predictivo', 'cl_tiempo', 'cl_base', 'cl_mes', 'cl_carga', 'cl_area', 'cl_externo', 'fecha_alimentacion', 'TIPO_DOCUMENTO', 'NUMERO_DOCUMENTO', 'NOMBRE', 'PERFIL', 'OFERTA', 'CME_DISPONIBLE', 'PLAZO', 'TASA', 'Tienda_IR', 'Region', 'Semaforo', 'Obs_FCC', 'Inicio', 'Fin', 'PROPENSION', 'MARCA_PD', 'FLG_AAHH', 'LOTE', 'PROVEEDOR', 'CAMPANA', 'SCORE_TELEFONO', 'GRUPO_SEGMENTO', 'FLG_PEARS', 'FLG_URB', 'SITUACION_LABORAL', 'MSI', 'DEPARTAMENTO', 'PROVINCIA', 'DISTRITO', 'DIRECCION', 'MONTO_LINEA_APROBADA', 'FECHA_VIGENCIA', 'FLG_CREDICASH', 'OFERTA_CREDICASH', 'PLAZO_CREDICASH', 'TASA_CREDICASH', 'CME_CREDICASH', 'OFERTA_ELECTRO', 'PLAZO_ELECT
# ...

# %%
['cl_id', 'cl_telf1', 'cl_telf2', 'cl_telf3', 'cl_telf4', 'cl_telf5', 'cl_telf6', 'cl_telf7', 'cl_telf8', 'cl_telf9', 'cl_telf10', 'cl_movil', 'cl_celular', 'cl_telefono', 'cl_turno', 'cl_gestor', 'cl_asesor', 'cl_accion', 'cl_gestion', 'cl_estado', 'cl_fecha_gestion', 'cl_hora_gestion', 'cl_hits', 'cl_fecha_llamar', 'cl_prioridad', 'cl_orden', 'cl_predictivo', 'cl_tiempo', 'cl_base', 'cl_mes', 'cl_carga', 'cl_area', 'cl_externo', 'fecha_alimentacion', 'TIPO_DOCUMENTO', 'NUMERO_DOCUMENTO', 'NOMBRE', 'PERFIL', 'OFERTA', 'CME_DISPONIBLE', 'PLAZO', 'TASA', 'Tienda_IR', 'Region', 'Semaforo', 'Obs_FCC', 'Inicio', 'Fin', 'PROPENSION', 'MARCA_PD', 'FLG_AAHH', 'LOTE', 'PROVEEDOR', 'CAMPANA', 'SCORE_TELEFONO', 'GRUPO_SEGMENTO', 'FLG_PEARS', 'FLG_URB', 'SITUACION_LABORAL', 'MSI', 'DEPARTAMENTO', 'PROVINCIA', 'DISTRITO', 'DIRECCION', 'MONTO_LINEA_APROBADA', 'FECHA_VIGENCIA', 'FLG_CREDICASH', 'OFERTA_CREDICASH', 'PLAZO_CREDICASH', 'TASA_CREDICASH', 'CME_CREDICASH', 'OFERTA_ELECTRO', 'PLAZO_ELECTRO', 'TASA_ELECTRO', 'CME_ELECTRO', 'PRODUCTO_EXTERNO', 'FLG_CRUCE_RECURRENTE', 'PROPENSION_ELECTRO', 'PROPENSION_CREDICASH', 'TIPO_ZONA', 'DEMANDA', 'PRIORIDAD', 'FLG_CRUCE', 'FRESCURA', 'PRODUCTO_INTERNO', 'INTENSIDAD_MAX', 'estado', 'RANGO_EDAD', 'RANGO_SUELDO', 'marca1', 'marca2', 'marca3', 'AÑO_DURACION_BASE', 'MES_DURACION_BASE', 'REP1', 'FLAT2', 'REP2', 'DNI']
fres

# %%
df_formato=df_formato.withColumn('lote_01',F.when(F.col('lote')=='REINGRESO',F.lit('05. REINGRESO'))
    .when(F.col('frescura')=='0','02. FRESCURA CERO')
    .when(F.col('grupo_segmento')=='R',F.lit('03.BASE CLIENTE'))
    .when(F.col('lote')=='INVENTARIO','01.INVENTARIO')
    .when(F.col('lote')=='PEERS_ALTA','06. PEERS_ALTA')
    .otherwise(F.lit('04.BASE REGULAR'))
)

# %%
df_formato.select('lote').distinct().show()
# Out:
# +-----------+
# |       lote|
# +-----------+
# |   CLIENTES|
# |INTERESADOS|
# | PEERS_ALTA|
# | INVENTARIO|
# +-----------+

# %%
# grupo_tasa=['None', '', '', '', '', ]
# agencia_comercial=[ 'SAN MIGUEL', 'MIRAFLORES']

df_filtrado = df_formato.filter(
    # (F.col('propension_ic').isin('1','2','3'))&
    # (F.col('proveedor').isin(['INVENTARIO TARGET 2', 'CET TARGET 2', 'CET TARGET 0', 'INVENTARIO TARGET 1', 'INVENTARIO TARGET 0', ]))&
    # (F.col('user_v3').isin(user_v3))&

    # (
    (F.col('PROPENSION_CREDICASH').isin('1'))&
    (F.col('FRESCURA').isin('1','4'))&
    # )
    (F.col('lote_01').isin('03.BASE CLIENTE'))&
    # (F.col('TIPO_CLIENTE').isin('INDEPENDIENTE'))&
    (F.col('cl_estado')==1)

)



print(df_filtrado.count())
print(df_filtrado.columns)
# Out:
# 10074
# ...

# %%
['cl_id', 'cl_telf1', 'cl_telf2', 'cl_telf3', 'cl_telf4', 'cl_telf5', 'cl_telf6', 'cl_telf7', 'cl_telf8', 'cl_telf9', 'cl_telf10', 'cl_movil', 'cl_celular', 'cl_telefono', 'cl_turno', 'cl_gestor', 'cl_asesor', 'cl_accion', 'cl_gestion', 'cl_estado', 'cl_fecha_gestion', 'cl_hora_gestion', 'cl_hits', 'cl_fecha_llamar', 'cl_prioridad', 'cl_orden', 'cl_predictivo', 'cl_tiempo', 'cl_base', 'cl_mes', 'cl_carga', 'cl_area', 'cl_externo', 'fecha_alimentacion', 'TIPO_DOCUMENTO', 'NUMERO_DOCUMENTO', 'NOMBRE', 'PERFIL', 'OFERTA', 'CME_DISPONIBLE', 'PLAZO', 'TASA', 'Tienda_IR', 'Region', 'Semaforo', 'Obs_FCC', 'Inicio', 'Fin', 'PROPENSION', 'MARCA_PD', 'FLG_AAHH', 'LOTE', 'PROVEEDOR', 'CAMPANA', 'SCORE_TELEFONO', 'GRUPO_SEGMENTO', 'FLG_PEARS', 'FLG_URB', 'SITUACION_LABORAL', 'MSI', 'DEPARTAMENTO', 'PROVINCIA', 'DISTRITO', 'DIRECCION', 'MONTO_LINEA_APROBADA', 'FECHA_VIGENCIA', 'FLG_CREDICASH', 'OFERTA_CREDICASH', 'PLAZO_CREDICASH', 'TASA_CREDICASH', 'CME_CREDICASH', 'OFERTA_ELECTRO', 'PLAZO_ELECTRO', 'TASA_ELECTRO', 'CME_ELECTRO', 'PRODUCTO_EXTERNO', 'FLG_CRUCE_RECURRENTE', 'PROPENSION_ELECTRO', 'PROPENSION_CREDICASH', 'TIPO_ZONA', 'DEMANDA', 'PRIORIDAD', 'FLG_CRUCE', 'FRESCURA', 'PRODUCTO_INTERNO', 'INTENSIDAD_MAX', 'estado', 'RANGO_EDAD', 'RANGO_SUELDO', 'marca1', 'marca2', 'marca3', 'AÑO_DURACION_BASE', 'MES_DURACION_BASE', 'REP1', 'FLAT2', 'REP2', 'DNI', 'lote_01']

# %%
from pyspark.sql import functions as F
from pyspark.sql.window import Window

w = Window.partitionBy('PROPENSION_CREDICASH','FRESCURA').orderBy(F.rand())

# df_split = df_list.filter(F.col('mejor_hora')=='10:00-11:00')
df_split = df_filtrado.withColumn("grupo_split", F.ntile(2).over(w))

df_parte_1 = df_split.filter(F.col("grupo_split") == 1).drop("grupo_split")
df_parte_2 = df_split.filter(F.col("grupo_split") == 2).drop("grupo_split")
# df_parte_3 = df_split.filter(F.col("grupo_split") == 3).drop("grupo_split")
# df_parte_3 = df_split.filter(F.col("grupo_split") == 3).drop("grupo_split")
# df_parte_4 = df_split.filter(F.col("grupo_split") == 4).drop("grupo_split")
# df_parte_5 = df_split.filter(F.col("grupo_split") == 5).drop("grupo_split")
# df_parte_6 = df_split.filter(F.col("grupo_split") == 6).drop("grupo_split")
# df_parte_7 = df_split.filter(F.col("grupo_split") == 7).drop("grupo_split")

print(
    df_parte_1.count(),
    df_parte_2.count()
    # df_parte_3.count()
    # df_parte_4.count(),
    # df_parte_5.count(),
    # df_parte_6.count(),
    # df_parte_7.count()
)
# Out:
# 5037 5037

# %%
['cl_id', 'cl_telf1', 'cl_telf2', 'cl_telf3', 'cl_telf4', 'cl_telf5', 'cl_telf6', 'cl_telf7', 'cl_telf8', 'cl_telf9', 'cl_telf10', 'cl_movil', 'cl_celular', 'cl_telefono', 'cl_turno', 'cl_gestor', 'cl_asesor', 'cl_accion', 'cl_gestion', 'cl_estado', 'cl_fecha_gestion', 'cl_hora_gestion', 'cl_hits', 'cl_fecha_llamar', 'cl_prioridad', 'cl_orden', 'cl_predictivo', 'cl_tiempo', 'cl_base', 'cl_mes', 'cl_carga', 'cl_area', 'cl_externo', 'fecha_alimentacion', 'TIPO_DOCUMENTO', 'NUMERO_DOCUMENTO', 'NOMBRE', 'PERFIL', 'OFERTA', 'CME_DISPONIBLE', 'PLAZO', 'TASA', 'Tienda_IR', 'Region', 'Semaforo', 'Obs_FCC', 'Inicio', 'Fin', 'PROPENSION', 'MARCA_PD', 'FLG_AAHH', 'LOTE', 'PROVEEDOR', 'CAMPANA', 'SCORE_TELEFONO', 'GRUPO_SEGMENTO', 'FLG_PEARS', 'FLG_URB', 'SITUACION_LABORAL', 'MSI', 'DEPARTAMENTO', 'PROVINCIA', 'DISTRITO', 'DIRECCION', 'MONTO_LINEA_APROBADA', 'FECHA_VIGENCIA', 'FLG_CREDICASH', 'OFERTA_CREDICASH', 'PLAZO_CREDICASH', 'TASA_CREDICASH', 'CME_CREDICASH', 'OFERTA_ELECTRO', 'PLAZO_ELECTRO', 'TASA_ELECTRO', 'CME_ELECTRO', 'PRODUCTO_EXTERNO', 'FLG_CRUCE_RECURRENTE', 'PROPENSION_ELECTRO', 'PROPENSION_CREDICASH', 'TIPO_ZONA', 'DEMANDA', 'PRIORIDAD', 'FLG_CRUCE', 'FRESCURA', 'PRODUCTO_INTERNO', 'INTENSIDAD_MAX', 'estado', 'RANGO_EDAD', 'RANGO_SUELDO', 'marca1', 'marca2', 'marca3', 'AÑO_DURACION_BASE', 'MES_DURACION_BASE', 'REP1', 'FLAT2', 'REP2', 'DNI', 'lote_01']nom
# Out:
# ['cl_id', 'cl_telf1', 'cl_telf2', 'cl_telf3', 'cl_telf4', 'cl_telf5', 'cl_telf6', 'cl_telf7', 'cl_telf8', 'cl_telf9', 'cl_telf10', 'cl_movil', 'cl_celular', 'cl_telefono', 'cl_turno', 'cl_gestor', 'cl_asesor', 'cl_accion', 'cl_gestion', 'cl_estado', 'cl_fecha_gestion', 'cl_hora_gestion', 'cl_hits', 'cl_fecha_llamar', 'cl_prioridad', 'cl_orden', 'cl_predictivo', 'cl_tiempo', 'cl_base', 'cl_mes', 'cl_carga', 'cl_area', 'cl_externo', 'fecha_alimentacion', 'TIPO_DOCUMENTO', 'NUMERO_DOCUMENTO', 'NOMBRE', 'PERFIL', 'OFERTA', 'CME_DISPONIBLE', 'PLAZO', 'TASA', 'Tienda_IR', 'Region', 'Semaforo', 'Obs_FCC', 'Inicio', 'Fin', 'PROPENSION', 'MARCA_PD', 'FLG_AAHH', 'LOTE', 'PROVEEDOR', 'CAMPANA', 'SCORE_TELEFONO', 'GRUPO_SEGMENTO', 'FLG_PEARS', 'FLG_URB', 'SITUACION_LABORAL', 'MSI', 'DEPARTAMENTO', 'PROVINCIA', 'DISTRITO', 'DIRECCION', 'MONTO_LINEA_APROBADA', 'FECHA_VIGENCIA', 'FLG_CREDICASH', 'OFERTA_CREDICASH', 'PLAZO_CREDICASH', 'TASA_CREDICASH', 'CME_CREDICASH', 'OFERTA_ELECTRO', 'PLAZO_ELECT
# ...

# %%
df_parte_1=df_parte_1.withColumnRenamed('NUMERO_DOCUMENTO','VENDOR LEAD CODE')
df_parte_1=df_parte_1.withColumnRenamed('cl_telf1','phone_number')
df_parte_1=df_parte_1.withColumnRenamed('NOMBRE','address1')

df_parte_1=df_parte_1.withColumnRenamed('OFERTA_CREDICASH','oferta maxima')
df_parte_1=df_parte_1.select('VENDOR LEAD CODE','phone_number','oferta maxima','PRODUCTO_EXTERNO','Region','Tienda_IR','PERFIL','address1')
df_list_filtrada = df_parte_1.toPandas()
ruta_archivo = os.path.join(ruta_csv, 'credicash_1.xlsx')
df_list_filtrada.to_excel(ruta_archivo, index=False)

# %%
df_parte_2=df_parte_2.withColumnRenamed('NUMERO_DOCUMENTO','VENDOR LEAD CODE')
df_parte_2=df_parte_2.withColumnRenamed('cl_telf1','phone_number')
df_parte_2=df_parte_2.withColumnRenamed('NOMBRE','address1')

df_parte_2=df_parte_2.withColumnRenamed('OFERTA_CREDICASH','oferta maxima')
df_parte_2=df_parte_2.select('VENDOR LEAD CODE','phone_number','oferta maxima','PRODUCTO_EXTERNO','Region','Tienda_IR','PERFIL','address1')
df_list_filtrada = df_parte_2.toPandas()
ruta_archivo = os.path.join(ruta_csv, 'credicash_2.xlsx')
df_list_filtrada.to_excel(ruta_archivo, index=False)

# %%
df_parte_1.show()
# Out:
# +----------------+------------+-------------+--------------------+------+--------------------+------+--------------------+
# |VENDOR LEAD CODE|phone_number|oferta maxima|    PRODUCTO_EXTERNO|Region|           Tienda_IR|PERFIL|            address1|
# +----------------+------------+-------------+--------------------+------+--------------------+------+--------------------+
# |        05615022|   965980871|         5100|         CREDICASH R|    R7|       CARSA_IQUITOS|    O1|MARIA TERESA CAM ...|
# |        45459509|   932744517|         4000|CREDICASH R / ELE...|    R3|CARSA MOTOS_PACAS...|    D0|LUIS EDINSON YEPE...|
# |        19697018|   983153478|         8000|CREDICASH R / ELE...|    R3|          CARSA_VIRU|    D1|FRANCISCO SOTELO ...|
# |        73062658|        NULL|         3000|         CREDICASH R|    R7|GMG_AREQUIPA PEDR...|    D2|MARLENI QUISPE MO...|
# |        04824560|   931091073|         8600|         CREDICASH R|    R7|CARSA MOTOS_PUERT...|    D1|GUILLERMO QUISPE ...|
# ...

# %%
df_parte_1=df_parte_1.withColumnRenamed('NUMERO_DOCUMENTO','VENDOR LEAD CODE')
df_parte_1=df_parte_1.withColumnRenamed('cl_telf1','phone_number')
df_parte_1=df_parte_1.withColumnRenamed('NOMBRE','address1')

df_parte_1=df_parte_1.withColumnRenamed('OFERTA_CREDICASH','oferta maxima')


df_parte_1 = df_parte_1.withColumn(
    "security_phrase",
    F.concat_ws(
        " ",
        F.lit("Oferta:"),
        F.col("OFERTA_MAX")
    )
)
df_parte_1 = df_parte_1.withColumn(
    "city",
    F.concat_ws(
        " ",
        F.lit("Departamento:"),
        F.col("DEPARTAMENTO")
    )
)
df_parte_1 = df_parte_1.withColumn(
    "province",
    F.concat_ws(
        " ",
        F.lit("Distrito:"),
        F.col("DISTRITO")
    )
)

# %%
df_subir_lista = df_subir_lista.withColumn(
    "DNI",
    F.right(
        F.concat(F.lit("00000000"), F.col("DNI")),
        F.lit(8)
    )
)
df_formato=df_formato.drop('ESTADO')
df_subir_lista=df_subir_lista.drop('PLAZO')

# %%
df_formato=df_formato.join(df_subir_lista,['DNI'],'right')

# %%
print(df_formato.columns)
print(df_subir_lista.columns)
# Out:
# ['DNI', 'cl_id', 'cl_telf1', 'cl_telf2', 'cl_telf3', 'cl_telf4', 'cl_telf5', 'cl_telf6', 'cl_telf7', 'cl_telf8', 'cl_telf9', 'cl_telf10', 'cl_movil', 'cl_celular', 'cl_telefono', 'cl_turno', 'cl_gestor', 'cl_asesor', 'cl_accion', 'cl_gestion', 'cl_estado', 'cl_fecha_gestion', 'cl_hora_gestion', 'cl_hits', 'cl_fecha_llamar', 'cl_prioridad', 'cl_orden', 'cl_predictivo', 'cl_tiempo', 'cl_base', 'cl_mes', 'cl_carga', 'cl_area', 'cl_externo', 'fecha_alimentacion', 'TIPO_DOCUMENTO', 'NUMERO_DOCUMENTO', 'NOMBRE', 'PERFIL', 'OFERTA', 'CME_DISPONIBLE', 'PLAZO', 'TASA', 'Tienda_IR', 'Region', 'Semaforo', 'Obs_FCC', 'Inicio', 'Fin', 'PROPENSION', 'MARCA_PD', 'FLG_AAHH', 'LOTE', 'PROVEEDOR', 'CAMPANA', 'SCORE_TELEFONO', 'GRUPO_SEGMENTO', 'FLG_PEARS', 'FLG_URB', 'SITUACION_LABORAL', 'MSI', 'DEPARTAMENTO', 'PROVINCIA', 'DISTRITO', 'DIRECCION', 'MONTO_LINEA_APROBADA', 'FECHA_VIGENCIA', 'FLG_CREDICASH', 'OFERTA_CREDICASH', 'PLAZO_CREDICASH', 'TASA_CREDICASH', 'CME_CREDICASH', 'OFERTA_ELECTRO', 'PLAZ
# ...

# %%
df_formato.select('FECHA', 'HORA', 'ESTADO', 'CLIENTE', 'DNI', 'MONTO','TASA', 'PLAZO', 'TELEFONO', 'PROMOTOR','Tienda_IR','PRODUCTO_EXTERNO','DIRECCION','PERFIL').show(10,truncate=False)
# Out:
# +----------+--------+-----------+------------------------------+--------+-----+----+-----+---------+--------+------------+---------------------+------------------------+------+
# |FECHA     |HORA    |ESTADO     |CLIENTE                       |DNI     |MONTO|TASA|PLAZO|TELEFONO |PROMOTOR|Tienda_IR   |PRODUCTO_EXTERNO     |DIRECCION               |PERFIL|
# +----------+--------+-----------+------------------------------+--------+-----+----+-----+---------+--------+------------+---------------------+------------------------+------+
# |07/07/2026|00:00:03|SIN VALIDAR|YULISA ELIZABETH CASTILLO PEÑA|75195170|7000 |NULL|NULL |991298792|KLUCENA |GMG_LA UNION|CREDICASH R / ELECTRO|MIGUEL CORTES MZ C LT 29|O1    |
# |07/07/2026|00:05:02|SIN VALIDAR|YULISA ELIZABETH CASTILLO PEÑA|75195170|7000 |NULL|NULL |991298792|KLUCENA |GMG_LA UNION|CREDICASH R / ELECTRO|MIGUEL CORTES MZ C LT 29|O1    |
# ...

# %%
df_filtrado=df_filtrado.select('FECHA', 'HORA', 'ESTADO', 'CLIENTE', 'DNI', 'MONTO','TASA', 'PLAZO', 'TELEFONO', 'PROMOTOR','Tienda_IR','PRODUCTO_EXTERNO','DIRECCION','PERFIL')
df_list_filtrada = df_filtrado.toPandas()
ruta_archivo = os.path.join(ruta_csv, 'credicash_1.xlsx')
df_list_filtrada.to_excel(ruta_archivo, index=False)

# %%
['NRO', 'FICHA', 'EXCEL', 'FECHA', 'HORA', 'ESTADO', 'CLIENTE', 'DNI', 'MONTO','TASA', 'PLAZO', 'TELEFONO', 'PROMOTOR', 'AUDITOR', 'FECHA_A', 'HORA_A', 'OBSERVACION']
# Out:
# ['NRO', 'FICHA', 'EXCEL', 'FECHA', 'HORA', 'ESTADO', 'CLIENTE', 'DNI', 'MONTO', 'PLAZO', 'TELEFONO', 'PROMOTOR', 'AUDITOR', 'FECHA_A', 'HORA_A', 'OBSERVACION']

# %%
df_subir_lista.show()

# %%
'FECHA','HORA','ESTADO','FECHA DESEMBOLSO','CLIENTE','DNI','MONTO','TASA','PLAZO','TELEFONO','PROMOTOR','FECHA VISITA','HORA VISITA','TIENDA','AGENCIA','ID_VENTA','PRODUCTO','DIRECCION','PERFIL'

# %%
['cl_id', 'cl_telf1', 'cl_telf2', 'cl_telf3', 'cl_telf4', 'cl_telf5', 'cl_telf6', 'cl_telf7', 'cl_telf8', 'cl_telf9', 'cl_telf10', 'cl_movil', 'cl_celular', 'cl_telefono', 'cl_turno', 'cl_gestor', 'cl_asesor', 'cl_accion', 'cl_gestion', 'cl_estado', 'cl_fecha_gestion', 'cl_hora_gestion', 'cl_hits', 'cl_fecha_llamar', 'cl_prioridad', 'cl_orden', 'cl_predictivo', 'cl_tiempo', 'cl_base', 'cl_mes', 'cl_carga', 'cl_area', 'cl_externo', 'fecha_alimentacion', 'TIPO_DOCUMENTO', 'NUMERO_DOCUMENTO', 'NOMBRE', 'PERFIL', 'OFERTA', 'CME_DISPONIBLE', 'PLAZO', 'TASA', 'Tienda_IR', 'Region', 'Semaforo', 'Obs_FCC', 'Inicio', 'Fin', 'PROPENSION', 'MARCA_PD', 'FLG_AAHH', 'LOTE', 'PROVEEDOR', 'CAMPANA', 'SCORE_TELEFONO', 'GRUPO_SEGMENTO', 'FLG_PEARS', 'FLG_URB', 'SITUACION_LABORAL', 'MSI', 'DEPARTAMENTO', 'PROVINCIA', 'DISTRITO', 'DIRECCION', 'MONTO_LINEA_APROBADA', 'FECHA_VIGENCIA', 'FLG_CREDICASH', 'OFERTA_CREDICASH', 'PLAZO_CREDICASH', 'TASA_CREDICASH', 'CME_CREDICASH', 'OFERTA_ELECTRO', 'PLAZO_ELECTRO', 'TASA_ELECTRO', 'CME_ELECTRO', 'PRODUCTO_EXTERNO', 'FLG_CRUCE_RECURRENTE', 'PROPENSION_ELECTRO', 'PROPENSION_CREDICASH', 'TIPO_ZONA', 'DEMANDA', 'PRIORIDAD', 'FLG_CRUCE', 'FRESCURA', 'PRODUCTO_INTERNO', 'INTENSIDAD_MAX', 'estado', 'RANGO_EDAD', 'RANGO_SUELDO', 'marca1', 'marca2', 'marca3', 'AÑO_DURACION_BASE', 'MES_DURACION_BASE']numero

# %%
df_formato.dropDuplicates(['NUMERO_DOCUMENTO']).count()
# Out:
# 2

# %%
df_formato=df_formato.filter(F.col('cl_telf1').isNotNull())

# %%
df_formato.show(5)
# Out:
# +-----+---------+---------+--------+--------+--------+--------+--------+--------+--------+---------+--------+----------+-----------+--------+---------+---------+---------+----------+---------+----------------+---------------+-------+---------------+------------+--------+-------------+---------+----------+------+----------+-------+----------+------------------+--------------+----------------+--------------------+------+------+--------------+-----+----+------------------+------+-----------------+-------+------+----+----------+-----------------+--------+--------+---------+-------+--------------+--------------+---------+-------+-----------------+----+------------+------------+--------------+--------------------+--------------------+--------------+-------------+----------------+---------------+--------------+-------------+--------------+-------------+------------+-----------+--------------------+--------------------+------------------+--------------------+---------+-------+---------+-----
# ...

# %%
df_base = df_base.withColumn("Campana", F.lit("202606"))
df_base = df_base.withColumn("LOTE", F.lit("BASE 2026-06-22"))
df_base = df_base.withColumn("cl_base", F.lit("Junio 2026"))
df_base = df_base.withColumn("cl_carga", F.lit("2026-06-22"))
df_base = df_base.withColumn("cl_estado", F.lit("1"))
df_base = df_base.withColumn("estado", F.lit("ACTIVO"))

# %%
df_formato=df_formato.withColumnRenamed('NUMERO_DOCUMENTO','vendor_lead_code')
df_formato=df_formato.withColumnRenamed('NOMBRE','address1')
df_formato=df_formato.withColumnRenamed('cl_telf1','phone_number')
df_formato=df_formato.withColumnRenamed('PLAZA','email')
df_formato=df_formato.withColumnRenamed('Region','comments')

df_formato=df_formato.withColumnRenamed('OFERTA_CREDICASH','oferta maxima')

# %%
df_formato.select('vendor_lead_code','address1','phone_number','comments','oferta maxima','PRODUCTO_EXTERNO','Tienda_IR','PERFIL').show(truncate=False)
# Out:
# +----------------+---------------------------------+------------+--------+-------------+-----------------------+--------------------+------+
# |vendor_lead_code|address1                         |phone_number|comments|oferta maxima|PRODUCTO_EXTERNO       |Tienda_IR           |PERFIL|
# +----------------+---------------------------------+------------+--------+-------------+-----------------------+--------------------+------+
# |03093809        |JOSE YSAUL MEZONES FLORES        |968016234   |R1      |10200        |CREDICASH / ELECTRO    |CARSA_PIURA GRAU    |D0    |
# |03653292        |LUIS MARIO GUTIERREZ VILLEGAS    |978415902   |R1      |5300         |CREDICASH / ELECTRO    |MARCIMEX_SULLANA    |O1    |
# |15746411        |JULIANA ROCIO TORRES SAURI       |995830819   |R4      |12800        |CREDICASH / ELECTRO MSI|GMG_CARABAYLLO      |D1    |
# ...

# %%
df_formato=df_formato.filter(F.col('cl_telf2')!=0)
df_formato=df_formato.filter(F.col('PROPENSION_CREDICASH').isin(1,2,'2','2'))
df_formato=df_formato.filter(F.col('frescura').isin(1,4,'1','4'))
df_formato=df_formato.filter(F.col('lote').isin('INTERESADOS'))


df_formato.count()
# Out:
# 10400

# %%
df_list_filtrada = df_formato.toPandas()
ruta_archivo = os.path.join(ruta_csv, 'credicash_1.xlsx')
df_list_filtrada.to_excel(ruta_archivo, index=False)

# %%
df_formato.groupBy('lote') \
    .count() \
    .orderBy('lote') \
    .show(30)
# Out:
# +-----------+-----+
# |       lote|count|
# +-----------+-----+
# |   CLIENTES|10005|
# |INTERESADOS|10400|
# | INVENTARIO|29309|
# | PEERS_ALTA| 3529|
# +-----------+-----+

# %%
df_formato_1=df_formato.select('vendor_lead_code','address1','phone_number','Region','oferta maxima','PRODUCTO_EXTERNO','Tienda_IR','PERFIL')

# %%
df_formato_1=df_formato_1.limit(10000)

# %%
df_formato_1.dropDuplicates(['vendor_lead_code']).count()
# Out:
# 10000

# %%
df_formato_1.count()
# Out:
# 10000

# %%
df_list_filtrada = df_formato.toPandas()
ruta_archivo = os.path.join(ruta_csv, 'tienda.xlsx')
df_list_filtrada.to_excel(ruta_archivo, index=False)

# %%
fecha_mes_base='2026-07-01'
tipi_cond1='DINERS TC'
tipi_cond2='xx'
tipi_cond3='xx'
tb_tipolofia='tTipologia_Diners_TC'
servidor_01=21
tipi_cod='cod'
tipi_resp_cod='E0'
tipi_descrip='[NIVEL 4]'
tipi_estado='[NIVEL 2]'
tipi_resp_estado='NO CONTACTO'
tipi_subdescripcion='[NIVEL 3]'
tnum_tb='tNumeroDinersTc'
tnum_dni='NUMERO_DOCUMENTO'
tlista_generada='borrar_tc_dinner'
get_base=since_base_maestra_tc_dinners

def resumen_vicidial(spark,fecha_mes_base,tipi_cond1,tipi_cond2,tipi_cond3,tb_tipolofia,servidor_01,tipi_cod,tipi_resp_cod,tipi_descrip,tipi_estado,tipi_resp_estado):
    query = f"""
        SELECT *
        FROM OPENQUERY([192.168.3.{servidor_01}], '
            SELECT        
            rtrim(ltrim(d.vendor_lead_code)) AS vendor_lead_code,        
            e.dial_method,
            a.campaign_id AS numero_campana,        
            a.user AS dni_ejecutivo,
            c.full_name AS ejecutivo,
            e.campaign_name AS nombre_campana,        
            a.call_date AS fecha_hora_llamada,        
            a.length_in_sec AS duracion,        
            b.status_name AS call_result,        
            f.list_description,        
            f.list_name,        
            a.phone_number as phone_number,        
            d.alt_phone as fecha_agenda,        
            d.comments as comentarios,        
            a.status AS codigo,
            a.term_reason,	
            a.alt_dial
            FROM asterisk.vicidial_log a         
            LEFT JOIN asterisk.vicidial_list d ON a.lead_id=d.lead_id        
            LEFT JOIN asterisk.vicidial_campaigns e ON a.campaign_id=e.campaign_id        
            LEFT JOIN asterisk.vicidial_lists f ON a.list_id=f.list_id        
            LEFT JOIN asterisk.vicidial_statuses b ON a.status=b.status        
            LEFT JOIN asterisk.vicidial_users c ON a.user=c.user        
            WHERE (e.campaign_name like "%{tipi_cond1}" or e.campaign_name like "%{tipi_cond2}" or e.campaign_name like "%{tipi_cond3}")
            AND a.call_date >= DATE_FORMAT(''{fecha_mes_base}'', ''%Y-%m-01'')
            AND a.call_date < 
            DATE_ADD(DATE_FORMAT(''{fecha_mes_base}'', ''%Y-%m-01''), INTERVAL 1 MONTH)
        ')

        """
    df_vicidial=obtener_tabla_sql(spark,query,server_zeus,user_zeus,pwd_zeus,db_zeus)

    df_vicidial = df_vicidial.withColumn(
        "vendor_lead_code",
        F.lpad(F.col("vendor_lead_code").cast("string"), 8, "0")
    )
    query = f"""
        SELECT {tipi_cod} as codigo
        , case
            when {tipi_cod}='CALLBK' then 'VOLVER A LLAMAR - call'
            else {tipi_descrip} 
        end as descripcion
        ,case 
            when {tipi_cod}='CALLBK' then 1200
            else peso 
        end as peso  FROM [ODIN].[dbo].{tb_tipolofia}
        where LEFT({tipi_cod},2)='{tipi_resp_cod}' or {tipi_estado}='{tipi_resp_estado}' or {tipi_cod}='CALLBK'
        """
    df_tipi=obtener_tabla_sql(spark,query,server_zeus,user_zeus,pwd_zeus,db_zeus)

    df_vicidial=df_vicidial.join(df_tipi,["codigo"],"left")

    return df_vicidial.select('fecha_hora_llamada','list_name','vendor_lead_code','phone_number','descripcion','dni_ejecutivo','ejecutivo','dial_method','term_reason','alt_dial','call_result','duracion','codigo','nombre_campana')

df_vici=resumen_vicidial(spark,fecha_mes_base,tipi_cond1,tipi_cond2,tipi_cond3,tb_tipolofia,servidor_01,tipi_cod,tipi_resp_cod,tipi_descrip,tipi_estado,tipi_resp_estado)
df_vici.filter(F.col('vendor_lead_code')=='73105494').orderBy(F.col('fecha_hora_llamada').desc()).show(truncate=False)
# Out:
# +-------------------+------------------+----------------+------------+-------------------------------------+-------------+----------------------------+-----------------------+------------+--------+----------------------+--------+------+-----------------+
# |fecha_hora_llamada |list_name         |vendor_lead_code|phone_number|descripcion                          |dni_ejecutivo|ejecutivo                   |dial_method            |term_reason |alt_dial|call_result           |duracion|codigo|nombre_campana   |
# +-------------------+------------------+----------------+------------+-------------------------------------+-------------+----------------------------+-----------------------+------------+--------+----------------------+--------+------+-----------------+
# ...

# %%
df_formato.select('vendor_lead_code','address1','phone_number','Region','oferta maxima','PRODUCTO_EXTERNO','Tienda_IR','PERFIL').show(truncate=False)
# Out:
# {"ts": "2026-07-06 11:32:35.859", "level": "ERROR", "logger": "DataFrameQueryContextLogger", "msg": "[UNRESOLVED_COLUMN.WITH_SUGGESTION] A column, variable, or function parameter with name `Region` cannot be resolved. Did you mean one of the following? [`Fin`, `Inicio`, `LOTE`, `MSI`, `TASA`]. SQLSTATE: 42703", "context": {"file": "java.base/jdk.internal.reflect.NativeMethodAccessorImpl.invoke0(Native Method)", "line": "", "fragment": "col", "errorClass": "UNRESOLVED_COLUMN.WITH_SUGGESTION"}, "exception": {"class": "Py4JJavaError", "msg": "An error occurred while calling o114.select.\n: org.apache.spark.sql.AnalysisException: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column, variable, or function parameter with name `Region` cannot be resolved. Did you mean one of the following? [`Fin`, `Inicio`, `LOTE`, `MSI`, `TASA`]. SQLSTATE: 42703;\n'Project [vendor_lead_code#94, address1#95, phone_number#96, 'Region, oferta maxima#98, PRODUCTO_EXTERNO#75, Tienda_IR#42, PERFIL#37]\n+- Filter cast(fr
# ...

# %%
df_formato.show()
# Out:
# +-----+---------+---------+--------+--------+--------+--------+--------+--------+--------+---------+--------+----------+-----------+--------+---------+---------+---------+----------+---------+----------------+---------------+-------+---------------+------------+--------+-------------+---------+----------+------+----------+-------+----------+------------------+--------------+----------------+--------------------+------+------+--------------+-----+----+--------------------+------+-----------------+-------+------+----+----------+--------------------+--------+--------+---------+-------+--------------+--------------+---------+-------+-----------------+----+-------------+-------------+-----------------+--------------------+--------------------+--------------+-------------+----------------+---------------+--------------+-------------+--------------+-------------+------------+-----------+--------------------+--------------------+------------------+--------------------+---------+-------+-----
# ...

# %%
['cl_id', 'cl_telf1', 'cl_telf2', 'cl_telf3', 'cl_telf4', 'cl_telf5', 'cl_telf6', 'cl_telf7', 'cl_telf8', 'cl_telf9', 'cl_telf10', 'cl_movil', 'cl_celular', 'cl_telefono', 'cl_turno', 'cl_gestor', 'cl_asesor', 'cl_accion', 'cl_gestion', 'cl_estado', 'cl_fecha_gestion', 'cl_hora_gestion', 'cl_hits', 'cl_fecha_llamar', 'cl_prioridad', 'cl_orden', 'cl_predictivo', 'cl_tiempo', 'cl_base', 'cl_mes', 'cl_carga', 'cl_area', 'cl_externo', 'fecha_alimentacion', 'TIPO_DOCUMENTO', 'NUMERO_DOCUMENTO', 'NOMBRE', 'PERFIL', 'OFERTA', 'CME_DISPONIBLE', 'PLAZO', 'TASA', 'Tienda_IR', 'Region', 'Semaforo', 'Obs_FCC', 'Inicio', 'Fin', 'PROPENSION', 'MARCA_PD', 'FLG_AAHH', 'LOTE', 'PROVEEDOR', 'CAMPANA', 'SCORE_TELEFONO', 'GRUPO_SEGMENTO', 'FLG_PEARS', 'FLG_URB', 'SITUACION_LABORAL', 'MSI', 'DEPARTAMENTO', 'PROVINCIA', 'DISTRITO', 'DIRECCION', 'MONTO_LINEA_APROBADA', 'FECHA_VIGENCIA', 'FLG_CREDICASH', 'OFERTA_CREDICASH', 'PLAZO_CREDICASH', 'TASA_CREDICASH', 'CME_CREDICASH', 'OFERTA_ELECTRO', 'PLAZO_ELECTRO', 'TASA_ELECTRO', 'CME_ELECTRO', 'PRODUCTO_EXTERNO', 'FLG_CRUCE_RECURRENTE', 'PROPENSION_ELECTRO', 'PROPENSION_CREDICASH', 'TIPO_ZONA', 'DEMANDA', 'PRIORIDAD', 'FLG_CRUCE', 'FRESCURA', 'PRODUCTO_INTERNO', 'INTENSIDAD_MAX', 'estado', 'RANGO_EDAD', 'RANGO_SUELDO', 'marca1', 'marca2', 'marca3', 'AÑO_DURACION_BASE', 'MES_DURACION_BASE']perfi

# %%
df_formato.select('vendor_lead_code','address1','phone_number','Region','oferta maxima','PRODUCTO_EXTERNO','Tienda_IR','PERFIL').show(truncate=False)

df_formato=df_formato.filter(F.col('cl_telf2')!=0)



df_formato=df_formato.filter(F.col('PROPENSION_CREDICASH').isin(1,2,'2','2'))
df_formato=df_formato.filter(F.col('frescura').isin(1,4,'1','4'))


df_formato.groupBy('lote') \
    .count() \
    .orderBy('lote') \
    .show(30)

# %%
df_formato=df_formato.filter(F.col('cl_telf2')!=0)

# %%
df_formato=df_formato.filter(F.col('PROPENSION_CREDICASH').isin(1,2,'2','2'))
df_formato=df_formato.filter(F.col('frescura').isin(1,4,'1','4'))

# %%
df_formato.filter(F.col('lote').isin('CLIENTES')).count()
# Out:
# 16527

# %%
df_formato.filter(F.col('lote').isin('INTERESADOS')).count()
# Out:
# 24750

# %%
df_formato=df_formato.filter(F.col('lote').isin('CLIENTES'))

# %%
# Out:
# +-----------+-----+
# |       lote|count|
# +-----------+-----+
# |   CLIENTES|15470|
# |INTERESADOS|16587|
# | INVENTARIO|43147|
# | PEERS_ALTA| 4886|
# +-----------+-----+

# %%
df_formato.select('lote').distinct().show(truncate=False)
# Out:
# +-----------+
# |lote       |
# +-----------+
# |CLIENTES   |
# |INTERESADOS|
# |PEERS_ALTA |
# |INVENTARIO |
# +-----------+

# %%
df_formato=df_formato.filter(F.col('frescura').isin(1,4,'1','4'))

# %%
df_prueba=df_prueba.withColumn('AÑO_DURACION_BASE',F.lit('2026'))
df_prueba=df_prueba.withColumn('MES_DURACION_BASE',F.lit('05'))
df_prueba=df_prueba.withColumn('SERVICIO',F.lit('01'))
df_prueba=df_prueba.withColumn('FECHA_ENVIO',F.lit('2026-05-27'))

# %%
['cl_id', 'cl_telf1', 'cl_telf2', 'cl_telf3', 'cl_telf4', 'cl_telf5', 'cl_telf6', 'cl_telf7', 'cl_telf8', 'cl_telf9', 'cl_telf10', 'cl_movil', 'cl_celular', 'cl_telefono', 'cl_turno', 'cl_gestor', 'cl_asesor', 'cl_accion', 'cl_gestion', 'cl_estado', 'cl_fecha_gestion', 'cl_hora_gestion', 'cl_hits', 'cl_fecha_llamar', 'cl_prioridad', 'cl_orden', 'cl_predictivo', 'cl_tiempo', 'cl_base', 'cl_mes', 'cl_carga', 'cl_area', 'cl_externo', 'fecha_alimentacion', 'TIPO_DOCUMENTO', 'NUMERO_DOCUMENTO', 'NOMBRE', 'PERFIL', 'OFERTA', 'CME_DISPONIBLE', 'PLAZO', 'TASA', 'Tienda_IR', 'Region', 'Semaforo', 'Obs_FCC', 'Inicio', 'Fin', 'PROPENSION', 'MARCA_PD', 'FLG_AAHH', 'LOTE', 'PROVEEDOR', 'CAMPANA', 'SCORE_TELEFONO', 'GRUPO_SEGMENTO', 'FLG_PEARS', 'FLG_URB', 'SITUACION_LABORAL', 'MSI', 'DEPARTAMENTO', 'PROVINCIA', 'DISTRITO', 'DIRECCION', 'MONTO_LINEA_APROBADA', 'FECHA_VIGENCIA', 'FLG_CREDICASH', 'OFERTA_CREDICASH', 'PLAZO_CREDICASH', 'TASA_CREDICASH', 'CME_CREDICASH', 'OFERTA_ELECTRO', 'PLAZO_ELECTRO', 'TASA_ELECTRO', 'CME_ELECTRO', 'PRODUCTO_EXTERNO', 'FLG_CRUCE_RECURRENTE', 'PROPENSION_ELECTRO', 'PROPENSION_CREDICASH', 'TIPO_ZONA', 'DEMANDA', 'PRIORIDAD', 'FLG_CRUCE', 'FRESCURA', 'PRODUCTO_INTERNO', 'INTENSIDAD_MAX', 'estado', 'RANGO_EDAD', 'RANGO_SUELDO',marca1,marca2,marca3]servi

# %%
query = f"""
    select NUMERO_DOCUMENTO as DNI, cl_telf1 from VALENTINA.dbo.alfcc_clientes
    where cl_telf1 is not null or cl_telf1<>0
    """
df_formato=obtener_tabla_sql(spark,query,server_sa,user_sa,pwd_sa,db_sa)
df_base=df_base.join(df_formato,['DNI'],'inner')
df_base=df_base.dropDuplicates(['DNI'])
df_base=df_base.limit(10)

# %%
filename='PRUEBA_CRED.csv'
df_base=cargar_archivo_csv(spark,filename,';',True)
df_base = df_base.withColumn(
    "NUMERO_DOCUMENTO",
    F.lpad(F.col("NUMERO_DOCUMENTO").cast("string"), 8, "0")
)

# %%
query = """
    select * from VALENTINA.dbo.alfcc_clientes
    where cl_base='julio 2026'

    """
df_formato=obtener_tabla_sql(spark,query,server_sa,user_sa,pwd_sa,db_sa)

print(df_formato.columns)

# %%
df_base.show()
# Out:
# +----------------+--------------+--------------------+------+----------------+---------------+--------------+------------------+--------------+--------------------+--------------+-------------+------------+------------------+------------------+------+--------------------+------------------+------------+-----------+--------------------+--------------------+--------+-------+---------+--------------------+--------------------+--------------------+--------+----------+------------+-----------------+--------------+--------------+---------+---------+-------+----------+----------+----------+---------+------+---------+
# ...

# %%
from pyspark.sql import functions as F

cols_int = [
    "PLAZO_CREDICASH",
    "PLAZO_ELECTRO",
    "PROPENSION_CREDICASH",
    "PROPENSION_ELECTRO",
    "FLG_AAHH",
    "FLG_URB",
    "FLG_CRUCE_RECURRENTE",
    "FRESCURA",
    "INTENSIDAD_MAX",
    "SCORE_TELEFONO",
    "cl_estado",
    "FLG_PEARS"
]

for c in cols_int:
    if c in df_base.columns:
        df_base = df_base.withColumn(
            c,
            F.when(
                F.lower(F.trim(F.col(c).cast("string"))).isin("nan", "", "null"),
                None
            ).otherwise(
                F.col(c).cast("double").cast("int")
            )
        )

# %%
cols_decimal = [
    "TASA_CREDICASH",
    "CME_CREDICASH",
    "TASA_ELECTRO",
    "CME_ELECTRO"
]

for c in cols_decimal:
    if c in df_base.columns:
        df_base = df_base.withColumn(
            c,
            F.when(
                F.lower(F.trim(F.col(c).cast("string"))).isin("nan", "", "null"),
                None
            ).otherwise(
                F.col(c).cast("double")
            )
        )

# %%
df_base.count()
# Out:
# 96157

# %%
w = Window.orderBy(F.monotonically_increasing_id())
df_base = df_base.withColumn(
    "cl_id",
    F.row_number().over(w)
)

# %%
append_table_SQL(spark,df_base,f'alfcc_clientes',server_sa,user_sa,pwd_sa,'VALENTINA')

# %%
filename='20260701_BASE_CREDICASH_TARGET_PEERS_ALTA.txt'
df_base_1=cargar_archivo_csv(spark,filename,'|',True)
df_base_1=df_base_1.withColumn('LOTE',F.lit('PEERS_ALTA'))

filename='20260701_BASE_CREDICASH_TARGET_INTERESADOS.txt'
df_base_2=cargar_archivo_csv(spark,filename,'|',True)
df_base_2=df_base_2.withColumn('LOTE',F.lit('INTERESADOS'))

filename='20260701_BASE_CREDICASH_TARGET_CLIENTES.txt'
df_base_3=cargar_archivo_csv(spark,filename,'|',True)
df_base_3=df_base_3.withColumn('LOTE',F.lit('CLIENTES'))

filename='20260701_BASE_CREDICASH_TARGET_PEERS_ALTA_TELEFONOS.txt'
df_score_1=cargar_archivo_csv(spark,filename,'|',True)
filename='20260701_BASE_CREDICASH_TARGET_INTERESADOS_TELEFONO.txt'
df_score_2=cargar_archivo_csv(spark,filename,'|',True)
filename='20260701_BASE_CREDICASH_TARGET_CLIENTES_TELEFONOS.txt'
df_score_3=cargar_archivo_csv(spark,filename,'|',True)
filename='20260701_BASE_CREDICASH_TARGET_TELEFONOS.txt'
df_score_4=cargar_archivo_csv(spark,filename,'|',True)

# %%
df_base.groupBy('PROPENSION_ELECTRO') \
    .count() \
    .orderBy('PROPENSION_ELECTRO') \
    .show(30)
# Out:
# +------------------+-----+
# |PROPENSION_ELECTRO|count|
# +------------------+-----+
# |               1.0|32270|
# |               2.0|28400|
# |               3.0|23128|
# |               nan|12359|
# +------------------+-----+

# %%
df_base=df_base_1.unionByName(df_base_2).unionByName(df_base_3)
df_score=df_score_1.unionByName(df_score_2).unionByName(df_score_3).unionByName(df_score_4)
df_base = df_base.withColumn(
    "DNI",
    F.lpad(F.col("DNI").cast("string"), 8, "0")
)

df_score = df_score.withColumn(
    "DNI",
    F.lpad(F.col("DNI").cast("string"), 8, "0")
)

df_score=df_score.dropDuplicates(['DNI'])
df_base=df_base.join(df_score,['DNI'],'left')

# %%
from pyspark.sql import functions as F

exprs = [
    F.count(F.when(F.col(c).isNotNull(), c)).alias(c)
    for c in df_base.columns
]

df_counts = df_base.agg(*exprs).collect()[0].asDict()

cols_con_data = [c for c, v in df_counts.items() if v > 0]

df_base = df_base.select(cols_con_data)

# %%
# df_score=df_score.withColumnRenamed('DNI','NUMERO_DOCUMENTO')
df_base=df_base.withColumnRenamed('DNI','NUMERO_DOCUMENTO')
df_base=df_base.withColumnRenamed('TIENDA','Tienda_IR')
df_base=df_base.withColumnRenamed('GRUPO_SEGMENTO_CREDICASH','GRUPO_SEGMENTO')
df_base=df_base.withColumnRenamed('REGION','Region')
df_base=df_base.withColumnRenamed('SEMAFORO','Semaforo')
df_base=df_base.withColumnRenamed('TIPDOC','TIPO_DOCUMENTO')
df_base=df_base.withColumnRenamed('TIPO_CLIENTE','SITUACION_LABORAL')
# df_base_inventario=df_base_inventario.withColumnRenamed('DNI','NUMERO_DOCUMENTO')
# df_base_inventario=df_base_inventario.withColumnRenamed('TIENDA','Tienda_IR')
# df_base_inventario=df_base_inventario.withColumnRenamed('GRUPO_SEGMENTO_CREDICASH','GRUPO_SEGMENTO')
# df_base_inventario=df_base_inventario.withColumnRenamed('REGION','Region')
# df_base_inventario=df_base_inventario.withColumnRenamed('SEMAFORO','Semaforo')
# df_base_inventario=df_base_inventario.withColumnRenamed('TIPDOC','TIPO_DOCUMENTO')
# # df_base_inventario=df_base_inventario.withColumnRenamed('RANGO_SUELDO','CME_CREDICASH')
# df_base_inventario=df_base_inventario.withColumnRenamed('RANGO_EDAD','DEMANDA')
# df_base_inventario=df_base_inventario.withColumnRenamed('TIPO_CLIENTE','SITUACION_LABORAL')

df_base = df_base.withColumn("CAMPANA", F.lit("202607"))
# df_base = df_base.withColumn("LOTE", F.lit("INVENTARIO"))
df_base = df_base.withColumn("cl_base", F.lit("Julio 2026"))
df_base = df_base.withColumn("cl_carga", F.lit("2026-07-01"))
df_base = df_base.withColumn("cl_estado", F.lit("1"))
df_base = df_base.withColumn("estado", F.lit("ACTIVO"))

cols = [
    c for c in df_base.columns 
    if c != "FLG_PEARS"
]

df_base = df_base.selectExpr(
    *cols,
    """
    CASE 
        WHEN upper(trim(FLG_PEARS)) = 'TRUE' THEN 1
        WHEN upper(trim(FLG_PEARS)) = 'FALSE' THEN 0
        ELSE 0
    END AS FLG_PEARS
    """
)

# %%
df_base=df_base.withColumnRenamed('CET','cl_telf1')
df_base=df_base.withColumnRenamed('CEL1','cl_telf2')
df_base=df_base.withColumnRenamed('DNI','NUMERO_DOCUMENTO')

# %%
from pyspark.sql import functions as F

cols_finales = [
    "FLG_PEARS",
    "FRESCURA",
    "OFERTA_CREDICASH",
    "OFERTA_ELECTRO",
    "PROPENSION_CREDICASH",
    "PROPENSION_ELECTRO",
    "Region",
    "Semaforo",
    "TASA_CREDICASH",
    "NUMERO_DOCUMENTO",
    "PRODUCTO_EXTERNO",
]

def limpiar_base(df):

    cols_string = [
        "FLG_PEARS",
        "FRESCURA",
        "OFERTA_CREDICASH",
        "OFERTA_ELECTRO",
        "PROPENSION_CREDICASH",
        "PROPENSION_ELECTRO",
        "Region",
        "Semaforo",
        "TASA_CREDICASH",
        "NUMERO_DOCUMENTO",
        "PRODUCTO_EXTERNO",
        'cl_telf2',
        'cl_telf1'
    ]

    for c in cols_string:
        df = df.withColumn(
            c,
            F.when(
                F.col(c).isNull() |
                (F.trim(F.col(c).cast("string")) == "") |
                (F.lower(F.trim(F.col(c).cast("string"))) == "nan") |
                (F.lower(F.trim(F.col(c).cast("string"))) == "none") |
                (F.lower(F.trim(F.col(c).cast("string"))) == "null"),
                F.lit(None)
            ).otherwise(F.trim(F.col(c).cast("string")))
        )

    cols_quitar_decimal = [
        "FRESCURA",
        "OFERTA_CREDICASH",
        "OFERTA_ELECTRO",
        "PROPENSION_CREDICASH",
        "PROPENSION_ELECTRO",
        "TASA_CREDICASH"
    ]

    for c in cols_quitar_decimal:
        df = df.withColumn(
            c,
            F.when(F.col(c).isNull(), F.col(c))
             .otherwise(F.regexp_replace(F.col(c), r"\.0$", ""))
        )

    return df

df_base = limpiar_base(df_base)
df_base=df_base.drop('DETALLE_TASA', 'DETALLE_OFERTA')

# %%
from pyspark.sql import functions as F

for c in ["cl_telf1", "cl_telf2"]:
    df_base = df_base.withColumn(
        c,
        F.when(
            F.col(c).isNull(),
            F.lit("0")
        ).otherwise(
            F.regexp_replace(
                F.col(c).cast("string"),
                r"\.0$",
                ""
            )
        )
    )

# %%
query = """
    select * from VALENTINA.dbo.alfcc_clientes
    where cl_base='julio 2026'

    """
df_formato=obtener_tabla_sql(spark,query,server_sa,user_sa,pwd_sa,db_sa)

print(df_formato.columns)
# Out:
# ['cl_id', 'cl_telf1', 'cl_telf2', 'cl_telf3', 'cl_telf4', 'cl_telf5', 'cl_telf6', 'cl_telf7', 'cl_telf8', 'cl_telf9', 'cl_telf10', 'cl_movil', 'cl_celular', 'cl_telefono', 'cl_turno', 'cl_gestor', 'cl_asesor', 'cl_accion', 'cl_gestion', 'cl_estado', 'cl_fecha_gestion', 'cl_hora_gestion', 'cl_hits', 'cl_fecha_llamar', 'cl_prioridad', 'cl_orden', 'cl_predictivo', 'cl_tiempo', 'cl_base', 'cl_mes', 'cl_carga', 'cl_area', 'cl_externo', 'fecha_alimentacion', 'TIPO_DOCUMENTO', 'NUMERO_DOCUMENTO', 'NOMBRE', 'PERFIL', 'OFERTA', 'CME_DISPONIBLE', 'PLAZO', 'TASA', 'Tienda_IR', 'Region', 'Semaforo', 'Obs_FCC', 'Inicio', 'Fin', 'PROPENSION', 'MARCA_PD', 'FLG_AAHH', 'LOTE', 'PROVEEDOR', 'CAMPANA', 'SCORE_TELEFONO', 'GRUPO_SEGMENTO', 'FLG_PEARS', 'FLG_URB', 'SITUACION_LABORAL', 'MSI', 'DEPARTAMENTO', 'PROVINCIA', 'DISTRITO', 'DIRECCION', 'MONTO_LINEA_APROBADA', 'FECHA_VIGENCIA', 'FLG_CREDICASH', 'OFERTA_CREDICASH', 'PLAZO_CREDICASH', 'TASA_CREDICASH', 'CME_CREDICASH', 'OFERTA_ELECTRO', 'PLAZO_ELECT
# ...

# %%
cols_base = set(df_base.columns)
cols_formato = set(df_formato.columns)

solo_en_base = cols_base - cols_formato
print("Solo en df_base:", solo_en_base)
# Out:
# Solo en df_base: set()

# %%
query = f"""
    SELECT *
        FROM (
            select 
            a.dni_cliente as NUMERO_DOCUMENTO,  
            a.celular as TELEFONO,
            a.Fecha as FECHA_ENVIO,
            b.nivel_1 AS TIPO_GESTION,
            b.nivel_2 AS GESTION ,2 as peso 
            FROM VALENTINA.dbo.alfin_gestion a
            inner join cronox.dbo.ref_credicash_dni C
            on a.dni_cliente COLLATE Modern_Spanish_CI_AS=C.NUMERO_DOCUMENTO   
            LEFT JOIN VALENTINA.dbo.alfin_tipificaciones B 
            ON A.Tipificacion = B.id_banco
            where a.fecha<'2026-06-01'
            UNION ALL
            select 
            a.dni_cliente as NUMERO_DOCUMENTO,  
            a.celular as TELEFONO,
            a.Fecha as FECHA_ENVIO,
            b.nivel_1 AS TIPO_GESTION,
            b.nivel_2 AS GESTION, 1 as peso 
            FROM VALENTINA.dbo.alfcc_gestion a
            inner join cronox.dbo.ref_credicash_dni C
            on a.dni_cliente COLLATE Modern_Spanish_CI_AS=C.NUMERO_DOCUMENTO   
            LEFT JOIN VALENTINA.dbo.alfcc_tipificaciones B 
            ON A.Tipificacion = B.id_banco
            where a.fecha<'2026-06-01'
        ) t
        """
df_valentina=obtener_tabla_sql(spark,query,server_sa,user_sa,pwd_sa,db_sa)

# %%
df_base=df_base.join(df_formato.select('NUMERO_DOCUMENTO'),['NUMERO_DOCUMENTO'],'leftanti')
print(df_base.count())
# Out:
# 195340

# %%
# df_subir=df_base.select('NUMERO_DOCUMENTO').filter((F.col('cl_telf1')=='0')&(F.col('cl_telf2')=='0'))
df_subir=df_base.select('NUMERO_DOCUMENTO')

# %%
print([row['NUMERO_DOCUMENTO' ] for row in df_subir_.select('NUMERO_DOCUMENTO').distinct().collect()])
# Out:
# {"ts": "2026-06-27 12:10:58.648", "level": "ERROR", "logger": "DataFrameQueryContextLogger", "msg": "[UNRESOLVED_COLUMN.WITH_SUGGESTION] A column, variable, or function parameter with name `NUMERO_DOCUMENTO` cannot be resolved. Did you mean one of the following? [`dni_cliente`, `contacto`]. SQLSTATE: 42703", "context": {"file": "jdk.internal.reflect.GeneratedMethodAccessor25.invoke(Unknown Source)", "line": "", "fragment": "col", "errorClass": "UNRESOLVED_COLUMN.WITH_SUGGESTION"}, "exception": {"class": "Py4JJavaError", "msg": "An error occurred while calling o596.select.\n: org.apache.spark.sql.AnalysisException: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column, variable, or function parameter with name `NUMERO_DOCUMENTO` cannot be resolved. Did you mean one of the following? [`dni_cliente`, `contacto`]. SQLSTATE: 42703;\n'Project ['NUMERO_DOCUMENTO]\n+- Relation [dni_cliente#661,contacto#662] csv\n\r\n\tat org.apache.spark.sql.errors.QueryCompilationErrors$.unresolvedAttributeError(Que
# ...

# %%
overwrite_table_SQL(spark,df_subir,f'ref_credicash_dni',server_zeus,user_zeus,pwd_zeus,'ODIN')
overwrite_table_SQL(spark,df_subir,f'ref_credicash_dni',server_sa,user_sa,pwd_sa,'CRONOX')

# %% [markdown]
# ## cet

# %%
query = f"""
    SELECT *
    FROM (
        SELECT a.NUMERO_DOCUMENTO, a.TELEFONO, a.TIPO_GESTION, a.GESTION, a.FECHA_ENVIO, 6 AS peso
        FROM [MAEBA].[ADM_OBJ_TG].[tGestionMesCencosudTc] a
        INNER JOIN odin.dbo.ref_credicash_dni b
            ON a.NUMERO_DOCUMENTO = b.NUMERO_DOCUMENTO
        WHERE a.TELEFONO IS NOT NULL

        UNION ALL

        SELECT a.NUMERO_DOCUMENTO, a.TELEFONO, a.TIPO_GESTION, a.GESTION, a.FECHA_ENVIO, 4 AS peso
        FROM [MAEBA].[ADM_OBJ_TG].tGestionMesDiners a
        INNER JOIN odin.dbo.ref_credicash_dni b
            ON a.NUMERO_DOCUMENTO = b.NUMERO_DOCUMENTO
        WHERE a.TELEFONO IS NOT NULL

        UNION ALL

        SELECT a.NUMERO_DOCUMENTO, a.TELEFONO, a.TIPO_GESTION, a.GESTION, a.FECHA_ENVIO, 8 AS peso
        FROM [MAEBA].[ADM_OBJ_TG].tGestionMesEfectiva a
        INNER JOIN odin.dbo.ref_credicash_dni b
            ON a.NUMERO_DOCUMENTO = b.NUMERO_DOCUMENTO
        WHERE a.TELEFONO IS NOT NULL

        UNION ALL

        SELECT a.DNI_CLIENTE AS NUMERO_DOCUMENTO,a.Telefono_Llamado AS TELEFONO,a.ESTADOS AS TIPO_GESTION, a.Descripcion AS GESTION,a.FECHA_ENVIO, 7 AS peso
        FROM [MAEBA].[ADM_OBJ_TG].tGestionAgentesEfectivaN a
        INNER JOIN odin.dbo.ref_credicash_dni b
            ON a.DNI_CLIENTE = b.NUMERO_DOCUMENTO
        WHERE a.Telefono_Llamado IS NOT NULL

        UNION ALL

        SELECT a.CODDOC AS NUMERO_DOCUMENTO, a.TELEFONO, a.TIPO_GESTION, a.GESTION, a.FECHA_ENVIO, 5 AS peso
        FROM [MAEBA].[ADM_OBJ_TG].tGestionMesCencoPP a
        INNER JOIN odin.dbo.ref_credicash_dni b
            ON a.CODDOC = b.NUMERO_DOCUMENTO
        WHERE a.TELEFONO IS NOT NULL

        UNION ALL

        SELECT a.NUMERO_DOCUMENTO, a.TELEFONO, a.TIPO_GESTION, a.GESTION, a.fecha_llamada AS FECHA_ENVIO, 3 AS peso
        FROM [MAEBA].[ADM_OBJ_TG].tGestionMesDinerstc a
        INNER JOIN odin.dbo.ref_credicash_dni b
            ON a.NUMERO_DOCUMENTO = b.NUMERO_DOCUMENTO
        WHERE a.TELEFONO IS NOT NULL
    ) t
    """
df_maeba=obtener_tabla_sql(spark,query,server_zeus,user_zeus,pwd_zeus,db_zeus)

query = f"""
    SELECT *
        FROM (
            select 
            a.dni_cliente as NUMERO_DOCUMENTO,  
            a.celular as TELEFONO,
            a.Fecha as FECHA_ENVIO,
            b.nivel_1 AS TIPO_GESTION,
            b.nivel_2 AS GESTION ,2 as peso 
            FROM VALENTINA.dbo.alfin_gestion a
            inner join cronox.dbo.ref_credicash_dni C
            on a.dni_cliente COLLATE Modern_Spanish_CI_AS=C.NUMERO_DOCUMENTO   
            LEFT JOIN VALENTINA.dbo.alfin_tipificaciones B 
            ON A.Tipificacion = B.id_banco
            where a.fecha<'2026-06-01'
            UNION ALL
            select 
            a.dni_cliente as NUMERO_DOCUMENTO,  
            a.celular as TELEFONO,
            a.Fecha as FECHA_ENVIO,
            b.nivel_1 AS TIPO_GESTION,
            b.nivel_2 AS GESTION, 1 as peso 
            FROM VALENTINA.dbo.alfcc_gestion a
            inner join cronox.dbo.ref_credicash_dni C
            on a.dni_cliente COLLATE Modern_Spanish_CI_AS=C.NUMERO_DOCUMENTO   
            LEFT JOIN VALENTINA.dbo.alfcc_tipificaciones B 
            ON A.Tipificacion = B.id_banco
            where a.fecha<'2026-06-01'
        ) t
        """
df_valentina=obtener_tabla_sql(spark,query,server_sa,user_sa,pwd_sa,db_sa)

# %%
df_cet=df_maeba.unionByName(df_valentina)

# %%
window_spec = Window.partitionBy("NUMERO_DOCUMENTO").orderBy(F.col("peso").asc(),F.col("FECHA_ENVIO").desc())
df_cet = df_cet.withColumn("ref_01", row_number().over(window_spec))
df_cet = df_cet.filter(col("ref_01") == 1).drop('ref_01','peso')

# %%
print([row['GESTION' ] for row in df_cet.select('GESTION').distinct().collect()])
# Out:
# ['EFECTIVO', 'CLIENTE ACEPTO OFERTA', 'VOLVER A LLAMAR', 'LO VA A PENSAR', 'NO SE CONCRETO LLAMADA', 'LINEA OPERATIVA', 'LLAMADA INCONCLUSA', 'YA NO TRABAJA EN EMPRESA (NO DAN MAS INFORMACION)', 'NEGOCIO EN ZONA NO COBERTURADA', 'NO ESCUCHÓ OFERTA ', 'NO CONTACTO', 'OBJECIÓN DEFINITIVA', 'TELEFONO EQUIVOCADO (NO CONOCEN A CLIENTE)', 'CREDITO CONCRETADO', 'CLIENTE INTERESADO (VOLVER A LLAMAR)', 'NO DESEA PRODUCTO', 'CLIENTE VIVE / LABORA / DE VIAJE EN EXTRANJERO', 'TELEFONO/LINEA OPERATIVA', 'MENSAJES CON TERCEROS - HIJOS', 'ACEPTA CAMPANA', 'CLIENTE YA TIENE PRODUCTO', 'NO NECESITA / NO DESEA', 'TELEFONO APAGADO', 'NO EFECTIVO', 'INTERESADO', 'NUMERO EQUIVOCADO', 'ABANDONO', 'CONTESTO TERCERO', 'YA NO VIVE EN DOMICILIO (NO DAN MAS INFORMACION)', 'ESTA ENDEUDADO', 'TELEFONO FUERA DE SERVICIO', 'LLAMADA CORTADA', 'MENSAJES CON TERCEROS - ESPOSA', 'ACEPTO', 'SE DEJO ENCARGO EN OFICINA (VOLVER A LLAMAR)', 'DISCADOR (AUTO)', 'NO DISCADO', 'OTROS', 'CLIENTE VIVE / LABORA / DE VIAJE EN PROV
# ...

# %%
[
    'EFECTIVO',
 'CLIENTE ACEPTO OFERTA',
 'VOLVER A LLAMAR',
 'LO VA A PENSAR',
 'NO SE CONCRETO LLAMADA',
 'LINEA OPERATIVA',
 'LLAMADA INCONCLUSA',
 'NO ESCUCHÓ OFERTA ',
 'NO CONTACTO',
 'OBJECIÓN DEFINITIVA',
 'CREDITO CONCRETADO',
 'CLIENTE INTERESADO (VOLVER A LLAMAR)',
 'NO DESEA PRODUCTO',
 'CLIENTE VIVE / LABORA / DE VIAJE EN EXTRANJERO',
 'TELEFONO/LINEA OPERATIVA',
 'MENSAJES CON TERCEROS - HIJOS',
 'ACEPTA CAMPANA',
 'CLIENTE YA TIENE PRODUCTO',
 'NO NECESITA / NO DESEA',
 'TELEFONO APAGADO',
 'NO EFECTIVO',
 'INTERESADO',
 'ABANDONO',
 'CONTESTO TERCERO',
 'YA NO VIVE EN DOMICILIO (NO DAN MAS INFORMACION)',
 'ESTA ENDEUDADO',
 'TELEFONO FUERA DE SERVICIO',
 'LLAMADA CORTADA',
 'MENSAJES CON TERCEROS - ESPOSA',
 'ACEPTO',
 'SE DEJO ENCARGO EN OFICINA (VOLVER A LLAMAR)',
 'DISCADOR (AUTO)',
 'NO DISCADO',
 'OTROS',
 'CLIENTE VIVE / LABORA / DE VIAJE EN PROVINCIA',
 'NO CONTESTA ',
 'NO ACEPTA CAMPANA',
 'TITULAR NO CALIFICA- GIRO RESTRINGIDO9',
 'SIN CONTACTO',
 'CLIENTE RECHAZADO',
 'VERIFICACION',
 'OCUPADO',
 'NO GESTIONADO',
 'FUERA DE COBERTURA',
 'SE DEJO ENCARGO EN DOMICILIO (VOLVER A LLAMAR)',
 'MENSAJES CON TERCEROS - OTROS',
 'TELEFONO OCUPADO (NO CONTESTAN)',
 'CLIENTE NO DESEA',
 'CLIENTE FALLECIO',
 'FUERA DE SERVICIO',
 'SI QUIERE',
 'CLIENTE DE VIAJE',
 'AGENDAMIENTO',
 'NO DESEA',
 'CONFIRMAR CITA',
 'INTERESES ELEVADOS',
 'TITULAR NO CALIFICA - DESEMPLEO',
 'TONO OCUPADO',
 'SOLICITA SER RETIRADO',
 'NO CALIFICA',
 'CONTACTO CON TERCERO',
 'IVR - NO CONFIRMA',
 'VENTA',
 'DESEA MOTO',
 'NO ESCUCHO OFERTA',
 'NO CONTESTA',
 'DESEA MAS MONTO',
 'NO ESCUCHÓ OFERTA',
 'NO QUIERE',
 'PPD EN GESTIÓN',
 'PERSONA FALLECIDA',
 'PROBlEMAS CON LA TARJETA',
 'MAL SERVICIO',
 'TARJETA EN TRAMITE',
 'LINEA INOPERATIVA',
 'OBJECIÓN PERSONAL',
 None]

# %%
print(df_cet.columns)
# Out:
# ['NUMERO_DOCUMENTO', 'TELEFONO', 'TIPO_GESTION', 'GESTION', 'FECHA_ENVIO']

# %%
df_desembolso = df_desembolso.withColumn(
    "dif_meses",
    F.floor(
        F.months_between(
            F.to_date(F.lit('2026-07-01')),
            F.col("fecha_llamada")
        )
    )
)

df_desembolso=df_desembolso.withColumn('marca',when(F.col('dif_meses').isin(0,1),'INVENTARIO TARGET 0')
                                                .when(F.col('dif_meses').isin(2,3,4),'INVENTARIO TARGET 1')
                                                .otherwise(F.lit('INVENTARIO TARGET 2'))
)

df_gestion=df_gestion.filter(F.col('nivel_2').isin(nivel_2))
df_gestion=df_gestion.filter(F.col('nivel_1').isin('CONTACTO EFECTIVO CON TITULAR'))
df_gestion = df_gestion.withColumn(
    "dni_cliente",
    F.right(
        F.concat(F.lit("00000000"), F.col("dni_cliente")),
        F.lit(8)
    )

)

df_gestion=df_gestion.withColumn('marca',when(F.col('dif_meses').isin(0,1),'CET TARGET 0')
                                                .when(F.col('dif_meses').isin(2,3,4),'CET TARGET 1')
                                                .otherwise(F.lit('CET TARGET 2'))
)
# Out:
# {"ts": "2026-07-01 17:16:57.526", "level": "ERROR", "logger": "DataFrameQueryContextLogger", "msg": "[UNRESOLVED_COLUMN.WITH_SUGGESTION] A column, variable, or function parameter with name `fecha_llamada` cannot be resolved. Did you mean one of the following? [`cl_telf1_1`, `NUMERO_DOCUMENTO`]. SQLSTATE: 42703", "context": {"file": "line 6 in cell [41]", "line": "", "fragment": "col", "errorClass": "UNRESOLVED_COLUMN.WITH_SUGGESTION"}, "exception": {"class": "Py4JJavaError", "msg": "An error occurred while calling o2060.withColumn.\n: org.apache.spark.sql.AnalysisException: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column, variable, or function parameter with name `fecha_llamada` cannot be resolved. Did you mean one of the following? [`cl_telf1_1`, `NUMERO_DOCUMENTO`]. SQLSTATE: 42703;\n'Project [NUMERO_DOCUMENTO#2752, cl_telf1_1#2757, 'floor('months_between(to_date(2026-07-01, None, Some(America/Lima), true), 'fecha_llamada, true)) AS dif_meses#3684]\n+- Project [NUMERO_DOCUMENTO#2752, 
# ...

# %% [markdown]
# ## desembolso

# %%
query = f"""
    SELECT *
        FROM (
            select a.fecha as fecha_llamada,a.dni as NUMERO_DOCUMENTO,a.telefono,  1 as desembolso 
            from VALENTINA.dbo.alfcc_ventas a
            inner join cronox.dbo.ref_credicash_dni b
                on a.dni COLLATE Modern_Spanish_CI_AS=b.NUMERO_DOCUMENTO
            where a.estado in(4,13,0)
            and a.fecha<'2026-06-01'
            UNION ALL
            select a.fecha as fecha_llamada,a.dni as NUMERO_DOCUMENTO,a.telefono,  1 as desembolso 
            from VALENTINA.dbo.alfin_ventas a
            inner join cronox.dbo.ref_credicash_dni b
                on a.dni COLLATE Modern_Spanish_CI_AS=b.NUMERO_DOCUMENTO
            where a.estado in(4,13,0)
            and a.fecha<'2026-06-01'
        ) t
        """
df_desembolso=obtener_tabla_sql(spark,query,server_sa,user_sa,pwd_sa,db_sa)
window_spec = Window.partitionBy("NUMERO_DOCUMENTO").orderBy(F.col("fecha_llamada").desc())
df_desembolso = df_desembolso.withColumn("ref_01", row_number().over(window_spec))
df_desembolso = df_desembolso.filter(col("ref_01") == 1).drop('ref_01')

df_enriquecido=df_desembolso.select('NUMERO_DOCUMENTO', 'telefono')

# %%
print(df_desembolso.columns)
print(df_cet.columns)
print(df_base.columns)
# Out:
# ['fecha_llamada', 'NUMERO_DOCUMENTO', 'telefono', 'desembolso']
# ['NUMERO_DOCUMENTO', 'TELEFONO', 'TIPO_GESTION', 'GESTION', 'FECHA_ENVIO']
# ['NUMERO_DOCUMENTO', 'TIPO_DOCUMENTO', 'NOMBRE', 'PERFIL', 'OFERTA_CREDICASH', 'PLAZO_CREDICASH', 'TASA_CREDICASH', 'CME_CREDICASH', 'GRUPO_SEGMENTO', 'PROPENSION_CREDICASH', 'OFERTA_ELECTRO', 'PLAZO_ELECTRO', 'TASA_ELECTRO', 'CME_ELECTRO', 'PROPENSION_ELECTRO', 'Region', 'Tienda_IR', 'Semaforo', 'DEPARTAMENTO', 'PROVINCIA', 'DISTRITO', 'DIRECCION', 'FLG_AAHH', 'FLG_URB', 'TIPO_ZONA', 'MARCA_PD', 'PRODUCTO_EXTERNO', 'FLG_CRUCE_RECURRENTE', 'FRESCURA', 'RANGO_EDAD', 'RANGO_SUELDO', 'SITUACION_LABORAL', 'INTENSIDAD_MAX', 'SCORE_TELEFONO', 'cl_telf1', 'cl_telf2', 'CAMPANA', 'LOTE', 'cl_base', 'cl_carga', 'cl_estado', 'estado', 'FLG_PEARS']

# %%
df_desembolso=df_desembolso.select('NUMERO_DOCUMENTO','telefono')
df_cet=df_cet.select('NUMERO_DOCUMENTO','TELEFONO')
df_desembolso=df_desembolso.withColumnRenamed('telefono','cl_telf1_1')
df_cet=df_cet.withColumnRenamed('TELEFONO','cl_telf1_1')
df_cet=df_cet.unionByName(df_desembolso)
df_cet=df_cet.dropDuplicates(['NUMERO_DOCUMENTO'])

# %%
df_base=df_base.join(df_cet,['NUMERO_DOCUMENTO'],'left')

# %%
df_base=df_base.withColumn('cl_telf1',when(F.col('cl_telf1')==0,F.col('cl_telf1_1'))
                                    .when(F.col('cl_telf1').isNull(),F.col('cl_telf1_1'))
                                    .otherwise(F.col('cl_telf1'))).drop('cl_telf1_1')

# %%
# df_base.show(2)

# %%
append_table_SQL(spark,df_base,f'alfcc_clientes',server_sa,user_sa,pwd_sa,'VALENTINA')

# %%
df_list_filtrada = df_base.toPandas()
ruta_archivo = os.path.join(ruta_csv, 'PRUEBA_asu.xlsx')
df_list_filtrada.to_excel(ruta_archivo, index=False)

# %%
from pyspark.sql import functions as F

cols_int = [
    "PLAZO_CREDICASH",
    "PLAZO_ELECTRO",
    "PROPENSION_CREDICASH",
    "PROPENSION_ELECTRO",
    "FLG_AAHH",
    "FLG_URB",
    "FLG_CRUCE_RECURRENTE",
    "FRESCURA",
    "INTENSIDAD_MAX",
    "SCORE_TELEFONO",
    "cl_estado",
    "FLG_PEARS"
]

for c in cols_int:
    if c in df_base.columns:
        df_base = df_base.withColumn(
            c,
            F.when(
                F.lower(F.trim(F.col(c).cast("string"))).isin("nan", "", "null"),
                None
            ).otherwise(
                F.col(c).cast("double").cast("int")
            )
        )

cols_decimal = [
    "TASA_CREDICASH",
    "CME_CREDICASH",
    "TASA_ELECTRO",
    "CME_ELECTRO"
]

for c in cols_decimal:
    if c in df_base.columns:
        df_base = df_base.withColumn(
            c,
            F.when(
                F.lower(F.trim(F.col(c).cast("string"))).isin("nan", "", "null"),
                None
            ).otherwise(
                F.col(c).cast("double")
            )
        )
        
w = Window.orderBy(F.monotonically_increasing_id())
df_base = df_base.withColumn(
    "cl_id",
    F.row_number().over(w)
)

# %%
df_base_2=df_base.filter((F.col('cl_telf1')=='0')&(F.col('cl_telf2')=='0'))

# %%
df_base_2=df_base_2.join(df_enriquecido,['NUMERO_DOCUMENTO'],'left')
df_base_2=df_base_2.withColumn('cl_telf1',when(F.col('telefono')=='0',F.col('telefono'))).drop('telefono')

# %%
df=df_base_2.filter(F.col('cl_telf1')!='0').toPandas()

# %%
print(df_base.columns)[ 'TIPO_DOCUMENTO', 'NOMBRE', 'PERFIL', 'OFERTA_CREDICASH', 'PLAZO_CREDICASH', 'TASA_CREDICASH', 'CME_CREDICASH', 'GRUPO_SEGMENTO', 'PROPENSION_CREDICASH', 'OFERTA_ELECTRO', 'PLAZO_ELECTRO', 'TASA_ELECTRO', 'CME_ELECTRO', 'PROPENSION_ELECTRO', 'Region', 'Tienda_IR', 'Semaforo', 'DEPARTAMENTO', 'PROVINCIA', 'DISTRITO', 'DIRECCION', 'FLG_AAHH', 'FLG_URB', 'TIPO_ZONA', 'MARCA_PD', 'PRODUCTO_EXTERNO', 'FLG_CRUCE_RECURRENTE', 'FRESCURA', 'RANGO_EDAD', 'RANGO_SUELDO', 'SITUACION_LABORAL', 'INTENSIDAD_MAX', 'CAMPANA', 'LOTE', 'cl_base', 'cl_carga', 'cl_estado', 'estado', 'FLG_PEARS', 'SCORE_TELEFONO', 'cl_telf1', 'cl_telf2']
# Out:
# ['NUMERO_DOCUMENTO', 'TIPO_DOCUMENTO', 'NOMBRE', 'PERFIL', 'OFERTA_CREDICASH', 'PLAZO_CREDICASH', 'TASA_CREDICASH', 'CME_CREDICASH', 'GRUPO_SEGMENTO', 'PROPENSION_CREDICASH', 'OFERTA_ELECTRO', 'PLAZO_ELECTRO', 'TASA_ELECTRO', 'CME_ELECTRO', 'PROPENSION_ELECTRO', 'Region', 'Tienda_IR', 'Semaforo', 'DEPARTAMENTO', 'PROVINCIA', 'DISTRITO', 'DIRECCION', 'FLG_AAHH', 'FLG_URB', 'TIPO_ZONA', 'MARCA_PD', 'PRODUCTO_EXTERNO', 'FLG_CRUCE_RECURRENTE', 'FRESCURA', 'RANGO_EDAD', 'RANGO_SUELDO', 'SITUACION_LABORAL', 'INTENSIDAD_MAX', 'CAMPANA', 'LOTE', 'cl_base', 'cl_carga', 'cl_estado', 'estado', 'FLG_PEARS', 'SCORE_TELEFONO', 'cl_telf1', 'cl_telf2']

# %%
df_base=df_base.select('NUMERO_DOCUMENTO', 'RANGO_SUELDO','RANGO_EDAD')

# %%
from pyspark.sql import functions as F
from pyspark.sql.window import Window

w = Window.partitionBy("dni_cliente").orderBy(F.col("dias_antiguedad").asc())

df_ref01 = (
    df_ref01
    .withColumn("rn", F.row_number().over(w))
    .filter(F.col("rn") == 1)
    .drop("rn")
)

# %%
print([row['dni_cliente' ] for row in df_subir_.select('dni_cliente').distinct().collect()])
# Out:
# ['47026546', '23159729', '45580358', '46459987', '77492075', '77479646', '77100186', '46314514', '80387168', '42685274', '45961830', '42956447', '48109289', '09904001', '45254385', '70110149', '77092684', '22475673', '40243405', '80150485', '60135147', '00522417', '73963845', '48323333', '03886431', '44493264', '70057407', '16623834', '32905980', '46847612', '40905715', '73579067', '70112354', '70171806', '72863567', '06890176', '47219490', '76397319', '74452940', '19229896', '71240990', '71468442', '44748733', '40921472', '01082508', '10527277', '71974658', '08134525', '80445933', '28714645', '42433067', '32875997', '42141156', '46847048', '05631869', '21458436', '06757712', '48562902', '70887930', '03601996', '61521695', '40044649', '45027969', '08313745', '46877620', '17529940', '70497484', '44126357', '72392461', '21103047', '33432179', '71107576', '48287108', '46946074', '44772938', '47970897', '76007585', '43696457', '22088304', '46741408', '41259138', '40134927', '42510319', '
# ...

# %%
df_subir_.columns
# Out:
# ['dni_cliente', 'contacto']

# %%
df=df_subir_.toPandas()

# %%
from sqlalchemy import create_engine


engine = create_engine(
    f"mysql+pymysql://{user_valentina}:{pwd_valentina}@{server_valentina}:{port_mysql}/{db_valentina}"
)

# query = """
# SELECT cl_telf1,cl_telf2,NUMERO_DOCUMENTO FROM alfcc_clientes
# where cl_telf1 is not null or cl_telf2 is not null
# """

# df_historico = pd.read_sql(query, engine_mysql)
# print(df_formato.columns.tolist())

# %%
df.count()
# Out:
# dni_cliente        27076
# contacto           27076
# tipo_telf          27076
# dias_antiguedad    27076
# dtype: int64

# %%
df_base=df_base.join(df_cet.select('NUMERO_DOCUMENTO',F.col('TELEFONO').alias('cl_telf1')),['NUMERO_DOCUMENTO'],'inner')

# %%
['NUMERO_DOCUMENTO', 'TIPO_DOCUMENTO', 'NOMBRE', 'PERFIL', 'OFERTA_CREDICASH', 'PLAZO_CREDICASH', 'TASA_CREDICASH', 'CME_CREDICASH', 'GRUPO_SEGMENTO', 'PROPENSION_CREDICASH', 'OFERTA_ELECTRO', 'PLAZO_ELECTRO', 'TASA_ELECTRO', 'CME_ELECTRO', 'PROPENSION_ELECTRO', 'Region', 'Tienda_IR', 'Semaforo', 'DEPARTAMENTO', 'PROVINCIA', 'DISTRITO', 'DIRECCION', 'FLG_AAHH', 'FLG_URB', 'TIPO_ZONA', 'MARCA_PD', 'PRODUCTO_EXTERNO', 'FLG_CRUCE_RECURRENTE', 'FRESCURA', 'DEMANDA', 'RANGO_SUELDO', 'SITUACION_LABORAL', 'INTENSIDAD_MAX', 'CAMPANA', 'LOTE', 'cl_base', 'cl_carga', 'cl_estado', 'estado', 'FLG_PEARS', 'SCORE_TELEFONO', 'cl_telf2', 'cl_telf1']
# Out:
# ['NUMERO_DOCUMENTO', 'TIPO_DOCUMENTO', 'NOMBRE', 'PERFIL', 'OFERTA_CREDICASH', 'PLAZO_CREDICASH', 'TASA_CREDICASH', 'CME_CREDICASH', 'GRUPO_SEGMENTO', 'PROPENSION_CREDICASH', 'OFERTA_ELECTRO', 'PLAZO_ELECTRO', 'TASA_ELECTRO', 'CME_ELECTRO', 'PROPENSION_ELECTRO', 'Region', 'Tienda_IR', 'Semaforo', 'DEPARTAMENTO', 'PROVINCIA', 'DISTRITO', 'DIRECCION', 'FLG_AAHH', 'FLG_URB', 'TIPO_ZONA', 'MARCA_PD', 'PRODUCTO_EXTERNO', 'FLG_CRUCE_RECURRENTE', 'FRESCURA', 'DEMANDA', 'RANGO_SUELDO', 'SITUACION_LABORAL', 'INTENSIDAD_MAX', 'CAMPANA', 'LOTE', 'cl_base', 'cl_carga', 'cl_estado', 'estado', 'FLG_PEARS', 'SCORE_TELEFONO', 'cl_telf2', 'cl_telf1']

# %%
df_base.count()
# Out:
# 121587

# %%
df[df["PLAZO_ELECTRO"] == "nan"].shape
# Out:
# (0, 43)

# %%
df=df_base.toPandas()

# %%
from sqlalchemy import create_engine


engine = create_engine(
    f"mysql+pymysql://{user_valentina}:{pwd_valentina}@{server_valentina}:{port_mysql}/{db_valentina}"
)

# %%
df=df.drop(columns='DEMANDA')

# %%
import numpy as np

cols = [
    "PLAZO_ELECTRO",
    "TASA_ELECTRO",
    "CME_ELECTRO",
    "PLAZO_CREDICASH",
    "TASA_CREDICASH",
    "CME_CREDICASH"
]

df[cols] = (
    df[cols]
    .replace("nan", np.nan)
    .replace("", np.nan)
)

df = df.where(pd.notnull(df), None)

# %%
df.to_sql(
    name="tb_temporal",
    con=engine,
    if_exists="append",
    index=False,
    chunksize=1000
)

print(f"Se insertaron {len(df)} registros.")
# Out:
# Se insertaron 47480 registros.

# %%
from sqlalchemy import text

query = """
DELETE FROM crm_target.tb_temporal
"""

with engine.begin() as conn:
    result = conn.execute(text(query))
    print("Filas eliminadas:", result.rowcount)
# Out:
# Filas eliminadas: 27076

# %%
df = df.rename(columns={
    "dni_cliente": "col_01",
    "contacto": "col_02",
})

# %%
from sqlalchemy import create_engine


engine_mysql = create_engine(
    f"mysql+pymysql://{user_valentina}:{pwd_valentina}@{server_valentina}:{port_mysql}/{db_valentina}"
)

# %%
update a
set a.RANGO_EDAD=b.col_02
,b.RANGO_SUELDO=b.col_03
from crm_target.alfcc_clientes a
inner join crm_target.tb_temporal b
where a.cl_base='junio 2026'

# %%
# aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa
df[['col_01', 'col_02']].to_sql(
    name="tb_temporal",
    con=engine,
    if_exists="append",
    index=False,
    chunksize=1000
)
# Out:
# 327

# %%
from sqlalchemy import text

query = """
UPDATE crm_target.alfcc_clientes a
INNER JOIN crm_target.tb_temporal b
    ON a.NUMERO_DOCUMENTO = b.col_01 
SET 
    a.cl_telf1 = b.col_02
WHERE 
    a.cl_base = 'junio 2026'
"""

with engine.begin() as conn:
    result = conn.execute(text(query))
    print("Filas afectadas:", result.rowcount)
# Out:
# Filas afectadas: 28601

# %%
df=df.drop(columns='DEMANDA')
print(df.columns.tolist())
# Out:
# ['NUMERO_DOCUMENTO', 'TIPO_DOCUMENTO', 'NOMBRE', 'PERFIL', 'OFERTA_CREDICASH', 'PLAZO_CREDICASH', 'TASA_CREDICASH', 'CME_CREDICASH', 'GRUPO_SEGMENTO', 'PROPENSION_CREDICASH', 'OFERTA_ELECTRO', 'PLAZO_ELECTRO', 'TASA_ELECTRO', 'CME_ELECTRO', 'PROPENSION_ELECTRO', 'Region', 'Tienda_IR', 'Semaforo', 'DEPARTAMENTO', 'PROVINCIA', 'DISTRITO', 'DIRECCION', 'FLG_AAHH', 'FLG_URB', 'TIPO_ZONA', 'MARCA_PD', 'PRODUCTO_EXTERNO', 'FLG_CRUCE_RECURRENTE', 'FRESCURA', 'RANGO_SUELDO', 'SITUACION_LABORAL', 'INTENSIDAD_MAX', 'CAMPANA', 'LOTE', 'cl_base', 'cl_carga', 'cl_estado', 'estado', 'FLG_PEARS', 'SCORE_TELEFONO', 'cl_telf1', 'cl_telf2']

# %%
import numpy as np
import pandas as pd

df["PLAZO_ELECTRO"] = (
    pd.to_numeric(df["PLAZO_ELECTRO"].replace("nan", np.nan), errors="coerce")
    .fillna(0)
    .astype(int)
)

df["PLAZO_CREDICASH"] = (
    pd.to_numeric(df["PLAZO_CREDICASH"].replace("nan", np.nan), errors="coerce")
    .fillna(0)
    .astype(int)
)

# %%
df["PLAZO_ELECTRO"] = (
    df["PLAZO_ELECTRO"]
    .replace("nan", np.nan)
    .fillna(0)
    .astype(int)
)
df["PLAZO_CREDICASH"] = (
    df["PLAZO_CREDICASH"]
    .replace("nan", np.nan)
    .fillna(0)
    .astype(int)
)

# %%
['NUMERO_DOCUMENTO', 'TIPO_DOCUMENTO', 'NOMBRE', 'PERFIL', 'OFERTA_CREDICASH', 'PLAZO_CREDICASH', 'TASA_CREDICASH', 'CME_CREDICASH', 'GRUPO_SEGMENTO', 'PROPENSION_CREDICASH', 'OFERTA_ELECTRO', 'PLAZO_ELECTRO', 'TASA_ELECTRO', 'CME_ELECTRO', 'PROPENSION_ELECTRO', 'Region', 'Tienda_IR', 'Semaforo', 'DEPARTAMENTO', 'PROVINCIA', 'DISTRITO', 'DIRECCION', 'FLG_AAHH', 'FLG_URB', 'TIPO_ZONA', 'MARCA_PD', 'PRODUCTO_EXTERNO', 'FLG_CRUCE_RECURRENTE', 'FRESCURA', 'RANGO_SUELDO', 'SITUACION_LABORAL', 'INTENSIDAD_MAX', 'CAMPANA', 'LOTE', 'cl_base', 'cl_carga', 'cl_estado', 'estado', 'FLG_PEARS', 'SCORE_TELEFONO', 'cl_telf1', 'cl_telf2']

# %%
df_desembolso = df_desembolso.withColumn(
    "dif_meses",
    F.floor(
        F.months_between(
            F.to_date(F.lit('2026-06-01')),
            F.col("fecha_llamada")
        )
    )
)
df_desembolso = df_desembolso.withColumn(
    "dni_cliente",
    F.right(
        F.concat(F.lit("00000000"), F.col("dni_cliente")),
        F.lit(8)
    )

)
query = """
  SELECT distinct dni_cliente FROM cronox.dbo.borrar_alfin_01
    """
df_list = obtener_tabla_sql(spark,query,server_sa,user_sa,pwd_sa,db_sa)


df_list = df_list.withColumn(
    "dni_cliente",
    F.right(
        F.concat(F.lit("00000000"), F.col("dni_cliente")),
        F.lit(8)
    )

)
df_desembolso=df_desembolso.join(df_list,['dni_cliente'],'inner')
df_desembolso.count()

# %%
query = f"""
    SELECT DISTINCT dni_cliente,contacto,retiro4
        FROM (
            SELECT dni_cliente,celular as contacto,
            case
                when tipificacion in (4,5) then 'seguimiento -1'
                else 'no llamar -1'
            end as retiro4
            FROM valentina.dbo.alfin_gestion
            WHERE DNI_ejecutivo!='99999999' 
            and tipificacion in ('4','5','16','17')
            and CAST(fecha AS DATE) >= DATEADD(MONTH, -1, CAST('{fecha_mes_base}' AS DATE))
            AND CAST(fecha AS DATE) < DATEADD(MONTH, 0, CAST('{fecha_mes_base}' AS DATE))
            UNION ALL
            SELECT DISTINCT dni_cliente,CELULAR as contacto, 'excluir' as retiro4
            FROM valentina.dbo.Excluir_Gestion_TARGET where servicio in ('ALFIN','ALFCC')
        ) t
        """
df_retiro_dni_contacto=obtener_tabla_sql(spark,query,server_sa,user_sa,pwd_sa,db_sa)

# %%
import pandas as pd

df_formato_base['cl_telf1'] = df_formato_base['cl_telf1'].apply(
    lambda x: str(int(x)) if pd.notnull(x) else None
)

df_formato_base['cl_telf2'] = df_formato_base['cl_telf2'].apply(
    lambda x: str(int(x)) if pd.notnull(x) else None
)

df_formato_base['cl_telf2'] = df_formato_base['cl_telf2'].fillna(0)
df_formato_base['cl_telf1'] = df_formato_base['cl_telf1'].fillna(0)
ruta_archivo = os.path.join(ruta_csv, 'fc_alfin.csv')

df_formato_base.to_csv(
    ruta_archivo,
    index=False,
    sep=';'
)

# %%
df_base=df_base.select('CAMPANA','FLG_PEARS','FRESCURA','OFERTA_CREDICASH','OFERTA_ELECTRO','PROPENSION_CREDICASH','PROPENSION_ELECTRO','Region','Semaforo','TASA_CREDICASH','NUMERO_DOCUMENTO','PRODUCTO_EXTERNO')

# %%
print([row['Campana' ] for row in df_base.select('Campana').distinct().collect()])
print([row['FLG_PEARS' ] for row in df_base.select('FLG_PEARS').distinct().collect()])
print([row['FRESCURA' ] for row in df_base.select('FRESCURA').distinct().collect()])
print([row['OFERTA_CREDICASH' ] for row in df_base.select('OFERTA_CREDICASH').distinct().collect()])
print([row['PRODUCTO_EXTERNO' ] for row in df_base.select('PRODUCTO_EXTERNO').distinct().collect()])
print([row['PROPENSION_CREDICASH' ] for row in df_base.select('PROPENSION_CREDICASH').distinct().collect()])
print([row['PROPENSION_ELECTRO' ] for row in df_base.select('PROPENSION_ELECTRO').distinct().collect()])
print([row['Region' ] for row in df_base.select('Region').distinct().collect()])
print([row['Semaforo' ] for row in df_base.select('Semaforo').distinct().collect()])
print([row['TASA_CREDICASH' ] for row in df_base.select('TASA_CREDICASH').distinct().collect()])
# Out:
# ['202606']
# [1, 0]
# ['3', '0', '1', '4', '2']
# ...

# %%
df_base=df_base.withColumn('mes',F.lit(6))

# %%
query = f"""
    select CAMPANA,FLG_PEARS,FRESCURA,OFERTA_CREDICASH,OFERTA_ELECTRO,PROPENSION_CREDICASH,PROPENSION_ELECTRO,Region,Semaforo,TASA_CREDICASH,NUMERO_DOCUMENTO,PRODUCTO_EXTERNO,5 as mes from VALENTINA.dbo.alfcc_clientes 
    where cl_base='mayo 2026'
    and lote='BASE 2026-05-01'
    """
df_base_anterior=obtener_tabla_sql(spark,query,server_sa,user_sa,pwd_sa,db_sa)

# %%
print([row['Campana' ] for row in df_base_anterior.select('Campana').distinct().collect()])
print([row['FLG_PEARS' ] for row in df_base_anterior.select('FLG_PEARS').distinct().collect()])
print([row['FRESCURA' ] for row in df_base_anterior.select('FRESCURA').distinct().collect()])
print([row['OFERTA_CREDICASH' ] for row in df_base_anterior.select('OFERTA_CREDICASH').distinct().collect()])
print([row['PRODUCTO_EXTERNO' ] for row in df_base_anterior.select('PRODUCTO_EXTERNO').distinct().collect()])
print([row['PROPENSION_CREDICASH' ] for row in df_base_anterior.select('PROPENSION_CREDICASH').distinct().collect()])
print([row['PROPENSION_ELECTRO' ] for row in df_base_anterior.select('PROPENSION_ELECTRO').distinct().collect()])
print([row['Region' ] for row in df_base_anterior.select('Region').distinct().collect()])
print([row['Semaforo' ] for row in df_base_anterior.select('Semaforo').distinct().collect()])
print([row['TASA_CREDICASH' ] for row in df_base_anterior.select('TASA_CREDICASH').distinct().collect()])
# Out:
# ['202605']
# ['0', '1']
# [1, 3, 4, 2, 0]
# [5300, 9900, 4900, 11500, 3000, 11800, 4000, 6500, 13500, 5100, 1700, 2200, 7800, 8500, 6300, 4700, 9700, 4200, 10800, 3500, 7600, 6100, 12000, 10600, 3200, 5500, 7400, 13000, 8200, 14600, 5900, 10900, 2600, 5000, 7500, 12500, 14500, 3700, 8800, 13300, 6900, 11900, 10000, 8700, 6600, 14800, 6700, 9300, 13200, 11700, 13800, 1800, 10100, 11400, 14300, 13700, 10300, 13900, 12400, 1600, 5800, 10200, 4500, 3300, 3900, 6400, 5600, 8300, 12700, 12100, 5200, 12300, 3800, 14900, 14700, 5400, 2800, 8400, 7200, 10400, 6200, 7100, 3600, 11200, 9600, 4100, 11300, 15000, 10700, 7900, 13600, 9800, 4400, 7700, 6000, 9200, 2300, 2100, 12800, 11000, 8100, 14400, 8600, 4300, 9000, 7300, 12900, 2400, 3400, 14200, 4800, 3100, 14000, 2000, 5700, 12200, 9100, 6800, 11600, 9400, 13400, 8000, 10500, 9500, 2900, 11100, 2500, 12600, 8900, 4600, 1900, 2700, 7000, 14100, 13100]
# ...

# %%
df_tot=df_base.unionByName(df_base_anterior)

# %% [markdown]
# Aca empieza

# %%
from pyspark.sql import functions as F

cols_finales = [
    "CAMPANA",
    "FLG_PEARS",
    "FRESCURA",
    "OFERTA_CREDICASH",
    "OFERTA_ELECTRO",
    "PROPENSION_CREDICASH",
    "PROPENSION_ELECTRO",
    "Region",
    "Semaforo",
    "TASA_CREDICASH",
    "NUMERO_DOCUMENTO",
    "PRODUCTO_EXTERNO",
    "mes"
]

def limpiar_base(df):
    df = df.select(*cols_finales)

    cols_string = [
        "CAMPANA",
        "FLG_PEARS",
        "FRESCURA",
        "OFERTA_CREDICASH",
        "OFERTA_ELECTRO",
        "PROPENSION_CREDICASH",
        "PROPENSION_ELECTRO",
        "Region",
        "Semaforo",
        "TASA_CREDICASH",
        "NUMERO_DOCUMENTO",
        "PRODUCTO_EXTERNO"
    ]

    for c in cols_string:
        df = df.withColumn(
            c,
            F.when(
                F.col(c).isNull() |
                (F.trim(F.col(c).cast("string")) == "") |
                (F.lower(F.trim(F.col(c).cast("string"))) == "nan") |
                (F.lower(F.trim(F.col(c).cast("string"))) == "none") |
                (F.lower(F.trim(F.col(c).cast("string"))) == "null"),
                F.lit("no_aplica")
            ).otherwise(F.trim(F.col(c).cast("string")))
        )

    cols_quitar_decimal = [
        "FRESCURA",
        "OFERTA_CREDICASH",
        "OFERTA_ELECTRO",
        "PROPENSION_CREDICASH",
        "PROPENSION_ELECTRO",
        "TASA_CREDICASH"
    ]

    for c in cols_quitar_decimal:
        df = df.withColumn(
            c,
            F.when(F.col(c) == "no_aplica", F.col(c))
             .otherwise(F.regexp_replace(F.col(c), r"\.0$", ""))
        )

    df = df.withColumn("mes", F.col("mes").cast("int"))

    return df

df_mayo_limpio = limpiar_base(df_base)

# %%
df_mayo_limpio = limpiar_base(df_base)
df_junio_limpio = limpiar_base(df_base_anterior)

# %%
df_junio_limpio.printSchema()
df_mayo_limpio.printSchema()
# Out:
# root
#  |-- CAMPANA: string (nullable = true)
#  |-- FLG_PEARS: string (nullable = true)
#  |-- FRESCURA: string (nullable = true)
#  |-- OFERTA_CREDICASH: string (nullable = true)
#  |-- OFERTA_ELECTRO: string (nullable = true)
#  |-- PROPENSION_CREDICASH: string (nullable = true)
#  |-- PROPENSION_ELECTRO: string (nullable = true)
#  |-- Region: string (nullable = true)
#  |-- Semaforo: string (nullable = true)
#  |-- TASA_CREDICASH: string (nullable = true)
#  |-- NUMERO_DOCUMENTO: string (nullable = true)
#  |-- PRODUCTO_EXTERNO: string (nullable = true)
#  |-- mes: integer (nullable = true)
#
# root
#  |-- CAMPANA: string (nullable = false)
#  |-- FLG_PEARS: string (nullable = false)
#  |-- FRESCURA: string (nullable = true)
#  |-- OFERTA_CREDICASH: string (nullable = true)
#  |-- OFERTA_ELECTRO: string (nullable = true)
#  |-- PROPENSION_CREDICASH: string (nullable = true)
#  |-- PROPENSION_ELECTRO: string (nullable = true)
#  |-- Region: string (nullable = true)
# ...

# %%
df_tot = df_mayo_limpio.unionByName(df_junio_limpio)

# %%
df_tot.show()
# Out:
# +-------+---------+--------+----------------+--------------+--------------------+------------------+------+-----------------+--------------+----------------+--------------------+---+
# |CAMPANA|FLG_PEARS|FRESCURA|OFERTA_CREDICASH|OFERTA_ELECTRO|PROPENSION_CREDICASH|PROPENSION_ELECTRO|Region|         Semaforo|TASA_CREDICASH|NUMERO_DOCUMENTO|    PRODUCTO_EXTERNO|mes|
# +-------+---------+--------+----------------+--------------+--------------------+------------------+------+-----------------+--------------+----------------+--------------------+---+
# | 202606|        1|       2|            5600|     no_aplica|                   1|         no_aplica|    R5|      05 ESPECIAL|         67.50|        00003837|           CREDICASH|  6|
# | 202606|        1|       4|            4500|     no_aplica|                   4|         no_aplica|    R5|      05 ESPECIAL|         67.90|        00004795|           CREDICASH|  6|
# ...

# %%
from pyspark.sql import functions as F

df_general = (
    df_tot
    .groupBy()
    .agg(
        F.countDistinct(F.when(F.col("mes") == 5, F.col("NUMERO_DOCUMENTO"))).alias("Q_Mayo"),
        F.countDistinct(F.when(F.col("mes") == 6, F.col("NUMERO_DOCUMENTO"))).alias("Q_Junio")
    )
    .withColumn("Dif_Q", F.col("Q_Junio") - F.col("Q_Mayo"))
    .withColumn("VarPct_Q", F.round((F.col("Dif_Q") / F.col("Q_Mayo")) * 100, 2))
)

df_general.show()
# Out:
# +------+-------+------+--------+
# |Q_Mayo|Q_Junio| Dif_Q|VarPct_Q|
# +------+-------+------+--------+
# | 73716| 212158|138442|   187.8|
# +------+-------+------+--------+

# %%
def analizar_dimension(df, columna):
    return (
        df
        .groupBy(columna)
        .agg(
            F.countDistinct(F.when(F.col("mes") == 5, F.col("NUMERO_DOCUMENTO"))).alias("Q_Mayo"),
            F.countDistinct(F.when(F.col("mes") == 6, F.col("NUMERO_DOCUMENTO"))).alias("Q_Junio")
        )
        .withColumn("Dif_Q", F.col("Q_Junio") - F.col("Q_Mayo"))
        .withColumn(
            "VarPct_Q",
            F.when(
                F.col("Q_Mayo") != 0,
                F.round((F.col("Dif_Q") / F.col("Q_Mayo")) * 100, 2)
            ).otherwise(None)
        )
        .orderBy(F.col("Dif_Q").asc())
    )

# %%
df_producto = analizar_dimension(df_tot, "PRODUCTO_EXTERNO")
df_producto.show(100, truncate=False)
# Out:
# +-------------------------+------+-------+-----+--------+
# |PRODUCTO_EXTERNO         |Q_Mayo|Q_Junio|Dif_Q|VarPct_Q|
# +-------------------------+------+-------+-----+--------+
# |CREDICASH R / ELECTRO MSI|2162  |6974   |4812 |222.57  |
# |CREDICASH R              |2458  |7684   |5226 |212.61  |
# |CREDICASH R / ELECTRO    |9895  |32220  |22325|225.62  |
# |CREDICASH / ELECTRO MSI  |15661 |38937  |23276|148.62  |
# |CREDICASH                |18043 |54185  |36142|200.31  |
# |CREDICASH / ELECTRO      |25497 |72158  |46661|183.01  |
# +-------------------------+------+-------+-----+--------+

# %%
df_propension = analizar_dimension(df_tot, "PROPENSION_CREDICASH")
df_propension.show(100, truncate=False)
# Out:
# +--------------------+------+-------+------+--------+
# |PROPENSION_CREDICASH|Q_Mayo|Q_Junio|Dif_Q |VarPct_Q|
# +--------------------+------+-------+------+--------+
# |5                   |38594 |19041  |-19553|-50.66  |
# |4                   |7310  |22503  |15193 |207.84  |
# |3                   |7277  |29022  |21745 |298.82  |
# |2                   |8665  |34922  |26257 |303.02  |
# |6                   |0     |47356  |47356 |NULL    |
# |1                   |11870 |59314  |47444 |399.7   |
# +--------------------+------+-------+------+--------+

# %%
df_propension_electro = analizar_dimension(df_tot, "PROPENSION_ELECTRO")
df_propension_electro.show(100, truncate=False)
# Out:
# +------------------+------+-------+------+--------+
# |PROPENSION_ELECTRO|Q_Mayo|Q_Junio|Dif_Q |VarPct_Q|
# +------------------+------+-------+------+--------+
# |5                 |28151 |13981  |-14170|-50.34  |
# |4                 |5366  |16127  |10761 |200.54  |
# |3                 |5220  |20948  |15728 |301.3   |
# |2                 |6167  |24381  |18214 |295.35  |
# |1                 |8311  |40391  |32080 |385.99  |
# |6                 |0     |34461  |34461 |NULL    |
# |no_aplica         |20501 |61869  |41368 |201.79  |
# +------------------+------+-------+------+--------+

# %%
df_oferta = analizar_dimension(df_tot, "OFERTA_CREDICASH")
df_oferta.show(200, truncate=False)
# Out:
# +----------------+------+-------+-----+--------+
# |OFERTA_CREDICASH|Q_Mayo|Q_Junio|Dif_Q|VarPct_Q|
# +----------------+------+-------+-----+--------+
# |5800            |1192  |784    |-408 |-34.23  |
# |1900            |25    |75     |50   |200.0   |
# |14500           |26    |82     |56   |215.38  |
# |14400           |28    |86     |58   |207.14  |
# |14800           |36    |95     |59   |163.89  |
# |14900           |42    |103    |61   |145.24  |
# |14600           |32    |97     |65   |203.13  |
# |14700           |36    |107    |71   |197.22  |
# |13800           |45    |123    |78   |173.33  |
# |1700            |50    |140    |90   |180.0   |
# |14000           |56    |147    |91   |162.5   |
# |13600           |44    |136    |92   |209.09  |
# |14100           |44    |140    |96   |218.18  |
# |1800            |6     |102    |96   |1600.0  |
# |14300           |30    |130    |100  |333.33  |
# |9400            |84    |191    |107  |127.38  |
# ...

# %%
from pyspark.sql import functions as F

df_tot = df_tot.withColumn(
    "RANGO_OFERTA",
    F.when(F.col("OFERTA_CREDICASH") == "no_aplica", "Sin oferta")
    .when(F.col("OFERTA_CREDICASH").cast("int") < 3000, "0 - 2,999")
    .when(F.col("OFERTA_CREDICASH").cast("int") < 5000, "3,000 - 4,999")
    .when(F.col("OFERTA_CREDICASH").cast("int") < 7000, "5,000 - 6,999")
    .when(F.col("OFERTA_CREDICASH").cast("int") < 10000, "7,000 - 9,999")
    .when(F.col("OFERTA_CREDICASH").cast("int") < 13000, "10,000 - 12,999")
    .otherwise("13,000 - 15,000")
)

# %%
df_oferta = analizar_dimension(df_tot, "RANGO_OFERTA")

df_oferta.show(truncate=False)
# Out:
# +---------------+------+-------+-----+--------+
# |RANGO_OFERTA   |Q_Mayo|Q_Junio|Dif_Q|VarPct_Q|
# +---------------+------+-------+-----+--------+
# |13,000 - 15,000|5012  |14111  |9099 |181.54  |
# |0 - 2,999      |2916  |12856  |9940 |340.88  |
# |10,000 - 12,999|9454  |24478  |15024|158.92  |
# |3,000 - 4,999  |10851 |32735  |21884|201.68  |
# |5,000 - 6,999  |19095 |57406  |38311|200.63  |
# |7,000 - 9,999  |26388 |70572  |44184|167.44  |
# +---------------+------+-------+-----+--------+

# %%
df_oferta.filter(F.col("Dif_Q") < 0).orderBy(F.col("Dif_Q").asc()).show(30, truncate=False)
# Out:
# +------------+------+-------+-----+--------+
# |RANGO_OFERTA|Q_Mayo|Q_Junio|Dif_Q|VarPct_Q|
# +------------+------+-------+-----+--------+
# +------------+------+-------+-----+--------+

# %%
df_oferta.filter(F.col("Dif_Q") > 0).orderBy(F.col("Dif_Q").desc()).show(30, truncate=False)
# Out:
# +---------------+------+-------+-----+--------+
# |RANGO_OFERTA   |Q_Mayo|Q_Junio|Dif_Q|VarPct_Q|
# +---------------+------+-------+-----+--------+
# |7,000 - 9,999  |26388 |70572  |44184|167.44  |
# |5,000 - 6,999  |19095 |57406  |38311|200.63  |
# |3,000 - 4,999  |10851 |32735  |21884|201.68  |
# |10,000 - 12,999|9454  |24478  |15024|158.92  |
# |0 - 2,999      |2916  |12856  |9940 |340.88  |
# |13,000 - 15,000|5012  |14111  |9099 |181.54  |
# +---------------+------+-------+-----+--------+

# %%
df_tasa = analizar_dimension(df_tot, "TASA_CREDICASH")
df_tasa.show(200, truncate=False)
# Out:
# +--------------+------+-------+-----+--------+
# |TASA_CREDICASH|Q_Mayo|Q_Junio|Dif_Q|VarPct_Q|
# +--------------+------+-------+-----+--------+
# |48.0000       |9136  |0      |-9136|-100.0  |
# |40.7000       |8861  |0      |-8861|-100.0  |
# |29.9000       |5731  |0      |-5731|-100.0  |
# |51.0000       |4700  |0      |-4700|-100.0  |
# |86.7000       |3777  |0      |-3777|-100.0  |
# |56.8000       |3660  |0      |-3660|-100.0  |
# |67.9000       |3168  |0      |-3168|-100.0  |
# |67.5000       |2773  |0      |-2773|-100.0  |
# |58.9000       |2746  |0      |-2746|-100.0  |
# |45.2000       |2622  |0      |-2622|-100.0  |
# |75.7000       |2343  |0      |-2343|-100.0  |
# |68.4000       |2008  |0      |-2008|-100.0  |
# |35.2000       |1955  |0      |-1955|-100.0  |
# |40.8000       |1880  |0      |-1880|-100.0  |
# |33.6000       |1880  |0      |-1880|-100.0  |
# |56.2000       |1813  |0      |-1813|-100.0  |
# |51.3000       |1682  |0      |-1682|-100.0  |
# ...

# %%
df_tasa.filter(F.col("Dif_Q") < 0).orderBy(F.col("Dif_Q").asc()).show(30, truncate=False)
# Out:
# +--------------+------+-------+-----+--------+
# |TASA_CREDICASH|Q_Mayo|Q_Junio|Dif_Q|VarPct_Q|
# +--------------+------+-------+-----+--------+
# |48.0000       |9136  |0      |-9136|-100.0  |
# |40.7000       |8861  |0      |-8861|-100.0  |
# |29.9000       |5731  |0      |-5731|-100.0  |
# |51.0000       |4700  |0      |-4700|-100.0  |
# |86.7000       |3777  |0      |-3777|-100.0  |
# |56.8000       |3660  |0      |-3660|-100.0  |
# |67.9000       |3168  |0      |-3168|-100.0  |
# |67.5000       |2773  |0      |-2773|-100.0  |
# |58.9000       |2746  |0      |-2746|-100.0  |
# |45.2000       |2622  |0      |-2622|-100.0  |
# |75.7000       |2343  |0      |-2343|-100.0  |
# |68.4000       |2008  |0      |-2008|-100.0  |
# |35.2000       |1955  |0      |-1955|-100.0  |
# |40.8000       |1880  |0      |-1880|-100.0  |
# |33.6000       |1880  |0      |-1880|-100.0  |
# |56.2000       |1813  |0      |-1813|-100.0  |
# |51.3000       |1682  |0      |-1682|-100.0  |
# ...

# %%
from pyspark.sql import functions as F

df_tot = df_tot.withColumn(
    "RANGO_TEA",
    F.when(F.col("TASA_CREDICASH") == "no_aplica", "Sin tasa")
     .when(F.col("TASA_CREDICASH").cast("double") < 40, "0 - 39.99")
     .when(F.col("TASA_CREDICASH").cast("double") < 50, "40 - 49.99")
     .when(F.col("TASA_CREDICASH").cast("double") < 60, "50 - 59.99")
     .when(F.col("TASA_CREDICASH").cast("double") < 70, "60 - 69.99")
     .when(F.col("TASA_CREDICASH").cast("double") < 80, "70 - 79.99")
     .otherwise("80+")
)

df_tasa = analizar_dimension(df_tot, "RANGO_TEA")
df_tasa.show(truncate=False)
# Out:
# +----------+------+-------+-----+--------+
# |RANGO_TEA |Q_Mayo|Q_Junio|Dif_Q|VarPct_Q|
# +----------+------+-------+-----+--------+
# |80+       |3777  |8483   |4706 |124.6   |
# |70 - 79.99|2575  |10509  |7934 |308.12  |
# |60 - 69.99|9753  |31566  |21813|223.65  |
# |0 - 39.99 |12372 |37202  |24830|200.7   |
# |40 - 49.99|26998 |65717  |38719|143.41  |
# |50 - 59.99|18241 |58681  |40440|221.7   |
# +----------+------+-------+-----+--------+

# %%
df_resumen_final = None

for c in dimensiones:
    df_tmp = resumen_dimension(df_tot, c)

    if df_resumen_final is None:
        df_resumen_final = df_tmp
    else:
        df_resumen_final = df_resumen_final.unionByName(df_tmp)

# %%
df_frescura = analizar_dimension(df_tot, "FRESCURA")
df_frescura.show(100, truncate=False)

df_region = analizar_dimension(df_tot, "Region")
df_region.show(100, truncate=False)

df_semaforo = analizar_dimension(df_tot, "Semaforo")
df_semaforo.show(100, truncate=False)
# Out:
# +--------+------+-------+-----+--------+
# |FRESCURA|Q_Mayo|Q_Junio|Dif_Q|VarPct_Q|
# +--------+------+-------+-----+--------+
# |1       |14305 |18039  |3734 |26.1    |
# |0       |5102  |15012  |9910 |194.24  |
# |2       |13482 |40194  |26712|198.13  |
# |3       |17262 |45838  |28576|165.54  |
# |4       |23565 |93075  |69510|294.97  |
# +--------+------+-------+-----+--------+
#
# +---------+------+-------+-----+--------+
# |Region   |Q_Mayo|Q_Junio|Dif_Q|VarPct_Q|
# +---------+------+-------+-----+--------+
# |no_aplica|842   |11577  |10735|1274.94 |
# |R1       |6484  |18696  |12212|188.34  |
# |R2       |7100  |22113  |15013|211.45  |
# |R3       |8572  |24980  |16408|191.41  |
# |R6       |10722 |28388  |17666|164.76  |
# |R4       |12344 |32726  |20382|165.12  |
# |R7       |12510 |35443  |22933|183.32  |
# |R5       |15142 |38235  |23093|152.51  |
# +---------+------+-------+-----+--------+
#
# +-------------------+------+-------+-----+--------+
# ...

# %%
df_semaforo = analizar_dimension(df_tot, "Semaforo")
df_semaforo.show(100, truncate=False)
# Out:
# +-------------------+------+-------+-----+--------+
# |Semaforo           |Q_Mayo|Q_Junio|Dif_Q|VarPct_Q|
# +-------------------+------+-------+-----+--------+
# |04 EN RECUPERACIÓN |3096  |0      |-3096|-100.0  |
# |05 ESPECIAL        |1660  |5677   |4017 |241.99  |
# |no_aplica          |0     |4139   |4139 |NULL    |
# |04 EN RECUPERACIÃ“N|0     |4191   |4191 |NULL    |
# |03 NORMAL          |11055 |42270  |31215|282.36  |
# |02 FLEXIBLE        |33220 |73616  |40396|121.6   |
# |01 SUPER FLEXIBLE  |24685 |82265  |57580|233.26  |
# +-------------------+------+-------+-----+--------+

# %%
dimensiones = [
    "PRODUCTO_EXTERNO",
    "PROPENSION_CREDICASH",
    "PROPENSION_ELECTRO",
    "OFERTA_CREDICASH",
    "OFERTA_ELECTRO",
    "TASA_CREDICASH",
    "FRESCURA",
    "Region",
    "Semaforo",
    "FLG_PEARS"
]

df_resumen_final = None

for c in dimensiones:
    df_tmp = (
        analizar_dimension(df_tot, c)
        .withColumn("dimension", F.lit(c))
        .withColumnRenamed(c, "valor")
        .select("dimension", "valor", "Q_Mayo", "Q_Junio", "Dif_Q", "VarPct_Q")
    )

    df_resumen_final = df_tmp if df_resumen_final is None else df_resumen_final.unionByName(df_tmp)

df_resumen_final.show(300, truncate=False)
# Out:
# +--------------------+-------------------------+------+-------+------+---------+
# |dimension           |valor                    |Q_Mayo|Q_Junio|Dif_Q |VarPct_Q |
# +--------------------+-------------------------+------+-------+------+---------+
# |PRODUCTO_EXTERNO    |CREDICASH R / ELECTRO MSI|2162  |6974   |4812  |222.57   |
# |PRODUCTO_EXTERNO    |CREDICASH R              |2458  |7684   |5226  |212.61   |
# |PRODUCTO_EXTERNO    |CREDICASH R / ELECTRO    |9895  |32220  |22325 |225.62   |
# |PRODUCTO_EXTERNO    |CREDICASH / ELECTRO MSI  |15661 |38937  |23276 |148.62   |
# |PRODUCTO_EXTERNO    |CREDICASH                |18043 |54185  |36142 |200.31   |
# |PRODUCTO_EXTERNO    |CREDICASH / ELECTRO      |25497 |72158  |46661 |183.01   |
# |PROPENSION_CREDICASH|5                        |38594 |19041  |-19553|-50.66   |
# |PROPENSION_CREDICASH|4                        |7310  |22503  |15193 |207.84   |
# |PROPENSION_CREDICASH|3                        |7277  |29022  |21745 |298.82   |
# ...

# %%
df1=df_resumen_final.toPandas()

# %%
ruta_archivo = os.path.join(ruta_csv, 'resumen_credicash.xlsx')

df1.to_excel(ruta_archivo, index=False)

# %%
df_base.printSchema()
# Out:
# root
#  |-- CAMPANA: string (nullable = false)
#  |-- FLG_PEARS: integer (nullable = false)
#  |-- FRESCURA: string (nullable = true)
#  |-- OFERTA_CREDICASH: string (nullable = true)
#  |-- OFERTA_ELECTRO: string (nullable = true)
#  |-- PROPENSION_CREDICASH: string (nullable = true)
#  |-- PROPENSION_ELECTRO: string (nullable = true)
#  |-- Region: string (nullable = true)
#  |-- Semaforo: string (nullable = true)
#  |-- TASA_CREDICASH: string (nullable = true)
#  |-- NUMERO_DOCUMENTO: string (nullable = true)
#  |-- PRODUCTO_EXTERNO: string (nullable = true)
#  |-- mes: integer (nullable = false)
#  |-- SEGMENTO_PRODUCTO: string (nullable = false)

# %%
from pyspark.sql import functions as F

cols_texto = [
    "CAMPANA",
    "FRESCURA",
    "OFERTA_CREDICASH",
    "OFERTA_ELECTRO",
    "PROPENSION_CREDICASH",
    "PROPENSION_ELECTRO",
    "Region",
    "Semaforo",
    "TASA_CREDICASH",
    "NUMERO_DOCUMENTO",
    "PRODUCTO_EXTERNO"
]

for c in cols_texto:
    df_tot = df_tot.withColumn(
        c,
        F.when(
            F.col(c).isNull() |
            (F.lower(F.trim(F.col(c))) == "nan") |
            (F.lower(F.trim(F.col(c))) == "none") |
            (F.lower(F.trim(F.col(c))) == "null") |
            (F.trim(F.col(c)) == ""),
            F.lit("no_aplica")
        ).otherwise(F.trim(F.col(c)))
    )

df_tot.printSchema()
# Out:
# root
#  |-- CAMPANA: string (nullable = true)
#  |-- FLG_PEARS: long (nullable = true)
#  |-- FRESCURA: string (nullable = true)
#  |-- OFERTA_CREDICASH: string (nullable = true)
#  |-- OFERTA_ELECTRO: string (nullable = true)
#  |-- PROPENSION_CREDICASH: string (nullable = true)
#  |-- PROPENSION_ELECTRO: string (nullable = true)
#  |-- Region: string (nullable = true)
#  |-- Semaforo: string (nullable = true)
#  |-- TASA_CREDICASH: string (nullable = true)
#  |-- NUMERO_DOCUMENTO: string (nullable = true)
#  |-- PRODUCTO_EXTERNO: string (nullable = true)
#  |-- mes: integer (nullable = true)

# %%
print([row['Campana' ] for row in df_tot.select('Campana').distinct().collect()])
print([row['FLG_PEARS' ] for row in df_tot.select('FLG_PEARS').distinct().collect()])
print([row['FRESCURA' ] for row in df_tot.select('FRESCURA').distinct().collect()])
print([row['OFERTA_CREDICASH' ] for row in df_tot.select('OFERTA_CREDICASH').distinct().collect()])
print([row['PRODUCTO_EXTERNO' ] for row in df_tot.select('PRODUCTO_EXTERNO').distinct().collect()])
print([row['PROPENSION_CREDICASH' ] for row in df_tot.select('PROPENSION_CREDICASH').distinct().collect()])
print([row['PROPENSION_ELECTRO' ] for row in df_tot.select('PROPENSION_ELECTRO').distinct().collect()])
print([row['Region' ] for row in df_tot.select('Region').distinct().collect()])
print([row['Semaforo' ] for row in df_tot.select('Semaforo').distinct().collect()])
print([row['TASA_CREDICASH' ] for row in df_tot.select('TASA_CREDICASH').distinct().collect()])
# Out:
# ['202606', '202605']
# [0, 1]
# ['3', '0', '1', '4', '2']
# ...

# %%
df_resumen_final.orderBy("dimension", "valor").show(300, truncate=False)
# Out:
# {"ts": "2026-06-22 17:56:42.157", "level": "ERROR", "logger": "SQLQueryContextLogger", "msg": "[CAST_INVALID_INPUT] The value '5600.0' of the type \"STRING\" cannot be cast to \"BIGINT\" because it is malformed. Correct the value as per the syntax, or change its target type. Use `try_cast` to tolerate malformed input and return NULL instead. SQLSTATE: 22018", "context": {"errorClass": "CAST_INVALID_INPUT"}, "exception": {"class": "Py4JJavaError", "msg": "An error occurred while calling o7597.showString.\n: org.apache.spark.SparkNumberFormatException: [CAST_INVALID_INPUT] The value '5600.0' of the type \"STRING\" cannot be cast to \"BIGINT\" because it is malformed. Correct the value as per the syntax, or change its target type. Use `try_cast` to tolerate malformed input and return NULL instead. SQLSTATE: 22018\r\n\tat org.apache.spark.sql.errors.QueryExecutionErrors$.invalidInputInCastToNumberError(QueryExecutionErrors.scala:147)\r\n\tat org.apache.spark.sql.catalyst.util.UTF8StringU
# ...

# %%
from pyspark.sql import functions as F

df_resumen = (
    df_tot
    .groupBy("mes")
    .agg(F.countDistinct("NUMERO_DOCUMENTO").alias("registros"))
)

df_resumen.show()
# Out:
# +---+---------+
# |mes|registros|
# +---+---------+
# |  6|   212158|
# |  5|    73716|
# +---+---------+

# %%
df_comp_general = (
    df_resumen
    .groupBy()
    .agg(
        F.sum(F.when(F.col("mes") == 5, F.col("registros")).otherwise(0)).alias("mayo"),
        F.sum(F.when(F.col("mes") == 6, F.col("registros")).otherwise(0)).alias("junio")
    )
    .withColumn("diferencia", F.col("junio") - F.col("mayo"))
    .withColumn("variacion_pct", F.round((F.col("diferencia") / F.col("mayo")) * 100, 2))
)

df_comp_general.show()
# Out:
# +-----+------+----------+-------------+
# | mayo| junio|diferencia|variacion_pct|
# +-----+------+----------+-------------+
# |73716|212158|    138442|        187.8|
# +-----+------+----------+-------------+

# %%
from pyspark.sql import functions as F

def comparar_por_columna(df, columna):
    df_tmp = (
        df.groupBy(columna, "mes")
        .agg(F.countDistinct("NUMERO_DOCUMENTO").alias("registros"))
        .groupBy(columna)
        .pivot("mes", [5, 6])
        .agg(F.first("registros"))
        .fillna(0)
    )

    return (
        df_tmp
        .withColumnRenamed("5", "mayo")
        .withColumnRenamed("6", "junio")
        .withColumn("diferencia", F.col("junio") - F.col("mayo"))
        .withColumn(
            "variacion_pct",
            F.when(F.col("mayo") != 0, F.round((F.col("diferencia") / F.col("mayo")) * 100, 2))
             .otherwise(None)
        )
        .orderBy(F.col("diferencia").asc())
    )

# %%
(        df.groupBy('PROPENSION_CREDICASH', "mes")
        .agg(F.countDistinct("NUMERO_DOCUMENTO").alias("registros"))
        .groupBy('PROPENSION_CREDICASH')
        .pivot("mes", [5, 6])
        .agg(F.first("registros"))
        .fillna(0)
        .show())
# Out:
# {"ts": "2026-06-22 17:18:06.214", "level": "ERROR", "logger": "DataFrameQueryContextLogger", "msg": "[UNRESOLVED_COLUMN.WITH_SUGGESTION] A column, variable, or function parameter with name `mes` cannot be resolved. Did you mean one of the following? [`LOTE`, `estado`, `Region`, `Campana`, `NOMBRE`]. SQLSTATE: 42703", "context": {"file": "jdk.internal.reflect.GeneratedMethodAccessor25.invoke(Unknown Source)", "line": "", "fragment": "col", "errorClass": "UNRESOLVED_COLUMN.WITH_SUGGESTION"}, "exception": {"class": "Py4JJavaError", "msg": "An error occurred while calling o4885.agg.\n: org.apache.spark.sql.AnalysisException: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column, variable, or function parameter with name `mes` cannot be resolved. Did you mean one of the following? [`LOTE`, `estado`, `Region`, `Campana`, `NOMBRE`]. SQLSTATE: 42703;\n'Aggregate [PROPENSION_CREDICASH#26, 'mes], [PROPENSION_CREDICASH#26, 'mes, count(distinct NUMERO_DOCUMENTO#381) AS registros#4087L]\n+- Filter (isnotn
# ...

# %%
df_propension = comparar_por_columna(df_base, "PROPENSION_CREDICASH")
df_propension.show(100, truncate=False)
# Out:
# +--------------------+----+-----+----------+-------------+
# |PROPENSION_CREDICASH|mayo|junio|diferencia|variacion_pct|
# +--------------------+----+-----+----------+-------------+
# |5                   |0   |19041|19041     |NULL         |
# |4                   |0   |22503|22503     |NULL         |
# |3                   |0   |29022|29022     |NULL         |
# |2                   |0   |34922|34922     |NULL         |
# |6                   |0   |47356|47356     |NULL         |
# |1                   |0   |59314|59314     |NULL         |
# +--------------------+----+-----+----------+-------------+

# %%
df_propension_electro = comparar_por_columna(df_base, "PROPENSION_ELECTRO")
df_propension_electro.show(100, truncate=False)
# Out:
# +------------------+----+-----+----------+-------------+
# |PROPENSION_ELECTRO|mayo|junio|diferencia|variacion_pct|
# +------------------+----+-----+----------+-------------+
# |5.0               |0   |13981|13981     |NULL         |
# |4.0               |0   |16127|16127     |NULL         |
# |3.0               |0   |20948|20948     |NULL         |
# |2.0               |0   |24381|24381     |NULL         |
# |6.0               |0   |34461|34461     |NULL         |
# |1.0               |0   |40391|40391     |NULL         |
# |nan               |0   |61869|61869     |NULL         |
# +------------------+----+-----+----------+-------------+

# %%
df_oferta_credicash = comparar_por_columna(df_base, "OFERTA_CREDICASH")
df_oferta_credicash.show(100, truncate=False)
# Out:
# +----------------+----+-----+----------+-------------+
# |OFERTA_CREDICASH|mayo|junio|diferencia|variacion_pct|
# +----------------+----+-----+----------+-------------+
# |1900.0          |0   |75   |75        |NULL         |
# |14500.0         |0   |82   |82        |NULL         |
# |14400.0         |0   |86   |86        |NULL         |
# |14800.0         |0   |95   |95        |NULL         |
# |14600.0         |0   |97   |97        |NULL         |
# |1800.0          |0   |102  |102       |NULL         |
# |14900.0         |0   |103  |103       |NULL         |
# |14700.0         |0   |107  |107       |NULL         |
# |13800.0         |0   |123  |123       |NULL         |
# |14300.0         |0   |130  |130       |NULL         |
# |13600.0         |0   |136  |136       |NULL         |
# |1700.0          |0   |140  |140       |NULL         |
# |14100.0         |0   |140  |140       |NULL         |
# |14000.0         |0   |147  |147       |NULL         |
# ...

# %%
df_oferta_credicash = comparar_por_columna(df_base, "OFERTA_CREDICASH")
df_oferta_credicash.show(100, truncate=False)
# Out:
# +----------------+----+-----+----------+-------------+
# |OFERTA_CREDICASH|mayo|junio|diferencia|variacion_pct|
# +----------------+----+-----+----------+-------------+
# |1900.0          |0   |75   |75        |NULL         |
# |14500.0         |0   |82   |82        |NULL         |
# |14400.0         |0   |86   |86        |NULL         |
# |14800.0         |0   |95   |95        |NULL         |
# |14600.0         |0   |97   |97        |NULL         |
# |1800.0          |0   |102  |102       |NULL         |
# |14900.0         |0   |103  |103       |NULL         |
# |14700.0         |0   |107  |107       |NULL         |
# |13800.0         |0   |123  |123       |NULL         |
# |14300.0         |0   |130  |130       |NULL         |
# |13600.0         |0   |136  |136       |NULL         |
# |1700.0          |0   |140  |140       |NULL         |
# |14100.0         |0   |140  |140       |NULL         |
# |14000.0         |0   |147  |147       |NULL         |
# ...

# %%
df_tasa_credicash = comparar_por_columna(df_base, "TASA_CREDICASH")
df_tasa_credicash.show(100, truncate=False)
# Out:
# +--------------+----+-----+----------+-------------+
# |TASA_CREDICASH|mayo|junio|diferencia|variacion_pct|
# +--------------+----+-----+----------+-------------+
# |47.00         |0   |16   |16        |NULL         |
# |52.00         |0   |41   |41        |NULL         |
# |47.40         |0   |46   |46        |NULL         |
# |54.50         |0   |49   |49        |NULL         |
# |58.00         |0   |70   |70        |NULL         |
# |44.20         |0   |82   |82        |NULL         |
# |45.50         |0   |113  |113       |NULL         |
# |66.00         |0   |136  |136       |NULL         |
# |82.00         |0   |136  |136       |NULL         |
# |65.00         |0   |143  |143       |NULL         |
# |44.00         |0   |212  |212       |NULL         |
# |57.10         |0   |244  |244       |NULL         |
# |62.00         |0   |248  |248       |NULL         |
# |59.00         |0   |288  |288       |NULL         |
# |56.10         |0   |291  |291       |NULL         |
# ...

# %%
df_base = df_base.withColumn(
    "SEGMENTO_PRODUCTO",
    F.when(
        (F.col("OFERTA_CREDICASH").isNotNull()) & (F.col("OFERTA_ELECTRO").isNotNull()),
        "CREDICASH / ELECTRO"
    )
    .when(
        (F.col("OFERTA_CREDICASH").isNotNull()) & (F.col("OFERTA_ELECTRO").isNull()),
        "CREDICASH"
    )
    .when(
        (F.col("OFERTA_CREDICASH").isNull()) & (F.col("OFERTA_ELECTRO").isNotNull()),
        "ELECTRO"
    )
    .otherwise("SIN OFERTA")
)

# %%
df_segmento = comparar_por_columna(df_base, "SEGMENTO_PRODUCTO")
df_segmento.show(100, truncate=False)
# Out:
# +-------------------+----+------+----------+-------------+
# |SEGMENTO_PRODUCTO  |mayo|junio |diferencia|variacion_pct|
# +-------------------+----+------+----------+-------------+
# |CREDICASH / ELECTRO|0   |212158|212158    |NULL         |
# +-------------------+----+------+----------+-------------+

# %%
pd_general = df_comp_general.toPandas()
pd_segmento = df_segmento.toPandas()
pd_propension = df_propension.toPandas()
pd_oferta = df_oferta_credicash.toPandas()
pd_tasa = df_tasa_credicash.toPandas()

# %%
from pyspark.sql import functions as F

def comparar_por_columna(df, columna):
    return (
        df.groupBy(columna, "mes")
        .agg(F.countDistinct("NUMERO_DOCUMENTO").alias("registros"))
        .groupBy(columna)
        .agg(
            F.sum(F.when(F.col("mes") == 5, F.col("registros")).otherwise(0)).alias("mayo"),
            F.sum(F.when(F.col("mes") == 6, F.col("registros")).otherwise(0)).alias("junio")
        )
        .withColumn("diferencia", F.col("junio") - F.col("mayo"))
        .withColumn(
            "variacion_pct",
            F.when(F.col("mayo") != 0, F.round((F.col("diferencia") / F.col("mayo")) * 100, 2))
             .otherwise(None)
        )
        .orderBy(F.col("diferencia").asc())
    )

df_base = df_base.withColumn(
    "SEGMENTO_PRODUCTO",
    F.when(
        (F.col("OFERTA_CREDICASH").isNotNull()) & (F.col("OFERTA_ELECTRO").isNotNull()),
        "CREDICASH / ELECTRO"
    )
    .when(
        (F.col("OFERTA_CREDICASH").isNotNull()) & (F.col("OFERTA_ELECTRO").isNull()),
        "CREDICASH"
    )
    .when(
        (F.col("OFERTA_CREDICASH").isNull()) & (F.col("OFERTA_ELECTRO").isNotNull()),
        "ELECTRO"
    )
    .otherwise("SIN OFERTA")
)

df_general = (
    df_base.groupBy("mes")
    .agg(F.countDistinct("NUMERO_DOCUMENTO").alias("registros"))
)

df_comp_general = (
    df_general.groupBy()
    .agg(
        F.sum(F.when(F.col("mes") == 5, F.col("registros")).otherwise(0)).alias("mayo"),
        F.sum(F.when(F.col("mes") == 6, F.col("registros")).otherwise(0)).alias("junio")
    )
    .withColumn("diferencia", F.col("junio") - F.col("mayo"))
    .withColumn("variacion_pct", F.round((F.col("diferencia") / F.col("mayo")) * 100, 2))
)

df_segmento = comparar_por_columna(df_base, "SEGMENTO_PRODUCTO")
df_propension = comparar_por_columna(df_base, "PROPENSION_CREDICASH")
df_oferta = comparar_por_columna(df_base, "OFERTA_CREDICASH")
df_tasa = comparar_por_columna(df_base, "TASA_CREDICASH")
df_region = comparar_por_columna(df_base, "Region")
df_semaforo = comparar_por_columna(df_base, "Semaforo")
df_frescura = comparar_por_columna(df_base, "FRESCURA")

# %%
df_segmento.show()
# Out:
# +-------------------+----+------+----------+-------------+
# |  SEGMENTO_PRODUCTO|mayo| junio|diferencia|variacion_pct|
# +-------------------+----+------+----------+-------------+
# |CREDICASH / ELECTRO|   0|212158|    212158|         NULL|
# +-------------------+----+------+----------+-------------+

# %%
print(df_tot.columns)
# Out:
# ['CAMPANA', 'FLG_PEARS', 'FRESCURA', 'OFERTA_CREDICASH', 'OFERTA_ELECTRO', 'PROPENSION_CREDICASH', 'PROPENSION_ELECTRO', 'Region', 'Semaforo', 'TASA_CREDICASH', 'NUMERO_DOCUMENTO', 'PRODUCTO_EXTERNO', 'mes']

# %%
print(df_formato_base.shape)
print(df_formato_base_inventario.shape)
# Out:
# (73716, 42)
# (93326, 42)

# %%
from pyspark.sql import functions as F

df_resumen = (
    df_base
    .groupBy("mes")
    .agg(F.countDistinct("NUMERO_DOCUMENTO").alias("registros"))
)

df_resumen.show()

# %%
import pandas as pd

df_formato_base['cl_telf1'] = df_formato_base['cl_telf1'].apply(
    lambda x: str(int(x)) if pd.notnull(x) else None
)

df_formato_base['cl_telf2'] = df_formato_base['cl_telf2'].apply(
    lambda x: str(int(x)) if pd.notnull(x) else None
)

df_formato_base['cl_telf2'] = df_formato_base['cl_telf2'].fillna(0)
df_formato_base['cl_telf1'] = df_formato_base['cl_telf1'].fillna(0)

# %%
# ruta_archivo = os.path.join(ruta_csv, 'fc_credicash_inventario.xlsx')
# df_formato_base_inventario.to_excel(ruta_archivo, index=False)

# ruta_archivo = os.path.join(ruta_csv, 'fc_credicash.xlsx')
# df_formato_base.to_excel(ruta_archivo, index=False)

# %%
ruta_archivo = os.path.join(ruta_csv, 'fc_alfin.csv')

df_formato_base.to_csv(
    ruta_archivo,
    index=False,
    sep=';'
)

# %%
print(df_base.columns)
['NUMERO_DOCUMENTO', 'TIPO_DOCUMENTO', 'NOMBRE', 'PERFIL', 'OFERTA_CREDICASH', 'PLAZO_CREDICASH', 'TASA_CREDICASH', 'CME_CREDICASH', 'GRUPO_SEGMENTO', 'PROPENSION_CREDICASH', 'OFERTA_ELECTRO', 'PLAZO_ELECTRO', 'TASA_ELECTRO', 'CME_ELECTRO', 'PROPENSION_ELECTRO', 'Region', 'Tienda_IR', 'Semaforo', 'DEPARTAMENTO', 'PROVINCIA', 'DISTRITO', 'DIRECCION', 'FLG_AAHH', 'FLG_URB', 'TIPO_ZONA', 'MARCA_PD', 'FLG_PEARS', 'PRODUCTO_EXTERNO', 'FLG_CRUCE_RECURRENTE', 'FRESCURA', 'DEMANDA', 'RANGO_SUELDO', 'SITUACION_LABORAL', 'INTENSIDAD_MAX', 'DETALLE_OFERTA', 'DETALLE_TASA', 'SCORE_TELEFONO', 'cl_telf1', 'cl_telf2', 'Campana', 'LOTE', 'cl_base', 'cl_carga', 'cl_estado', 'estado']exter
# Out:
# ['NUMERO_DOCUMENTO', 'TIPO_DOCUMENTO', 'NOMBRE', 'PERFIL', 'OFERTA_CREDICASH', 'PLAZO_CREDICASH', 'TASA_CREDICASH', 'CME_CREDICASH', 'GRUPO_SEGMENTO', 'PROPENSION_CREDICASH', 'OFERTA_ELECTRO', 'PLAZO_ELECTRO', 'TASA_ELECTRO', 'CME_ELECTRO', 'PROPENSION_ELECTRO', 'Region', 'Tienda_IR', 'Semaforo', 'DEPARTAMENTO', 'PROVINCIA', 'DISTRITO', 'DIRECCION', 'FLG_AAHH', 'FLG_URB', 'TIPO_ZONA', 'MARCA_PD', 'FLG_PEARS', 'PRODUCTO_EXTERNO', 'FLG_CRUCE_RECURRENTE', 'FRESCURA', 'DEMANDA', 'RANGO_SUELDO', 'SITUACION_LABORAL', 'INTENSIDAD_MAX', 'DETALLE_OFERTA', 'DETALLE_TASA', 'SCORE_TELEFONO', 'cl_telf1', 'cl_telf2', 'Campana', 'LOTE', 'cl_base', 'cl_carga', 'cl_estado', 'estado']

# %% [markdown]
# subir

# %%
df_base.filter((F.col('cl_telf1').isNull()&F.col('cl_telf2').isNull())).count()
# Out:
# 198327

# %%
df_base.filter((F.col('cl_telf1').isNotNull()|F.col('cl_telf2').isNotNull())).count()
# Out:
# 13831

# %%
df_base.count()
# Out:
# 212158

# %%
df=df_base.filter((F.col('cl_telf1').isNotNull()|F.col('cl_telf2').isNotNull()))

# %%
df.groupBy('PRODUCTO_EXTERNO') \
    .count() \
    .orderBy('PRODUCTO_EXTERNO') \
    .show(30,truncate=False)
# Out:
# +-------------------------+-----+
# |PRODUCTO_EXTERNO         |count|
# +-------------------------+-----+
# |CREDICASH R              |2210 |
# |CREDICASH R / ELECTRO    |9799 |
# |CREDICASH R / ELECTRO MSI|1822 |
# +-------------------------+-----+

# %%
df_ref=df.toPandas()

# %%
df_ref.shape
# Out:
# (13831, 45)

# %%
print(198327+13831)
print(13831/212158)
# Out:
# 212158
# 0.06519197956240161

# %%
from sqlalchemy import create_engine


engine_mysql = create_engine(
    f"mysql+pymysql://{user_valentina}:{pwd_valentina}@{server_valentina}:{port_mysql}/{db_valentina}"
)

query = """
SELECT cl_telf1,cl_telf2,NUMERO_DOCUMENTO FROM alfcc_clientes
where cl_telf1 is not null or cl_telf2 is not null
"""

df_historico = pd.read_sql(query, engine_mysql)
print(df_formato.columns.tolist())
# Out:
# ['cl_id', 'TIPO_DOI', 'NUMERO_DOCUMENTO', 'NOMBRES', 'APELLIDO_PATERNO', 'APELLIDO_MATERNO', 'SUCURSAL', 'TIENDA', 'DEPARTAMENTO', 'PROVINCIA', 'DISTRITO', 'FEC_NACIMIENTO', 'OFERTA_MAX', 'OFERTA_REEN', 'Tipo_verificacion', 'GRUPO_RIESGO', 'PILOTO_PLAZAS', 'proveedor', 'lote', 'estado', 'Tasa_1', 'Tasa_2', 'Tasa_3', 'Tasa_4', 'Tasa_5', 'Tasa_6', 'Tasa_7', 'segmento', 'Campana', 'PLAZO', 'TEM', 'PROPENSION_IC', 'Desgravamen', 'CUOTA', 'Edad', 'Oferta_12M', 'Tasa_12M', 'Desgravamen_12M', 'CUOTA_12M', 'Oferta_18M', 'Tasa_18M', 'Desgravamen_18M', 'CUOTA_18M', 'Oferta_24M', 'Tasa_24M', 'Desgravamen_24M', 'CUOTA_24M', 'Oferta_36M', 'Tasa_36M', 'Desgravamen_36M', 'CUOTA_36M', 'Validador_Telefono', 'Prioridad', 'Nombre_prioridad', 'Deuda_1', 'Entidad_1', 'Deuda_2', 'Entidad_2', 'Deuda_3', 'Entidad_3', 'sucursal_comercial', 'Agencia_comercial', 'Region_comercial', 'Ubicacion', 'OfertaMaximaSinSeguro', 'color', 'color_final', 'PROPENSION', 'OFERTA_FINAL', 'GARANTIA', 'Oferta_Minima_Paperless',
# ...

# %%
filename='fc_alfin.csv'

filePath = os.path.join(ruta_csv, filename)

df_carga = pd.read_csv(filePath,sep=';')

df_carga["NUMERO_DOCUMENTO"] = (
    df_carga["NUMERO_DOCUMENTO"]
    .astype(str)
    .str.zfill(8)
)
print(df_carga.columns.tolist())
# Out:
# ['DEPARTAMENTO', 'FLG_AAHH', 'NOMBRES', 'Agencia_comercial', 'CAPACIDAD_MAX', 'SALDO_DIFERENCIAL_REENG', 'GRUPO_MONTO', 'RANGO_OFERTA', 'cl_carga', 'NUMERO_DOCUMENTO', 'PLAZO', 'APELLIDO_PATERNO', 'SCORE_TELEFONO', 'RANGO_EDAD', 'oferta_max', 'cl_base', 'TIPO_CLIENTE', 'cl_estado', 'TIENDA', 'color_final', 'GRUPO_TASA', 'lote', 'Tasa_6', 'Tasa_5', 'cl_telf2', 'cl_telf1', 'Tasa_3', 'Tasa_7', 'flag_deuda_v_oferta', 'campania', 'USER_V3', 'TIPO_BASE', 'PROVINCIA', 'RANGO_SUELDO', 'DISTRITO', 'Region_comercial', 'FRESCURA', 'tipo_cliente_riegos', 'PROPENSION', 'nombre_base', 'Tasa_2', 'Tasa_4', 'PILOTO_PLAZAS', 'INTENSIDAD_MAX', 'MGNEG', 'Campana', 'CUOTA', 'estado', 'Edad', 'PROPENSION_IC', 'APELLIDO_MATERNO', 'Tasa_1']

# %%
df_formato_base["NUMERO_DOCUMENTO"] = (
    df_formato_base["NUMERO_DOCUMENTO"]
    .astype(str)
    .str.zfill(8)
)

# %%
df_formato_base_inventario["NUMERO_DOCUMENTO"] = (
    df_formato_base_inventario["NUMERO_DOCUMENTO"]
    .astype(str)
    .str.zfill(8)
)

# %%
df_formato_base['FLG_PEARS'] = (
    df_formato_base['FLG_PEARS']
    .astype(str)
    .str.upper()
    .map({'FALSE': 0, 'TRUE': 1})
    .fillna(0)
    .astype(int)
)

df_formato_base_inventario['FLG_PEARS'] = (
    df_formato_base_inventario['FLG_PEARS']
    .astype(str)
    .str.upper()
    .map({'FALSE': 0, 'TRUE': 1})
    .fillna(0)
    .astype(int)
)

# %%
df_formato_base['FLG_PEARS'] = df_formato_base['FLG_PEARS'].astype(int)
df_formato_base_inventario['FLG_PEARS'] = df_formato_base_inventario['FLG_PEARS'].astype(int)

# %%
df_formato_base = df_formato_base.drop(columns=['DEMANDA'])
df_formato_base_inventario = df_formato_base_inventario.drop(columns=['DEMANDA'])

# %%
from sqlalchemy import create_engine

engine = create_engine(
    f"mysql+pymysql://{user_valentina}:{pwd_valentina}@{server_valentina}:{port_mysql}/{db_valentina}"
)

# %%
# df_ref = df_ref.drop(columns=['DEMANDA'])
# df_ref = df_ref.drop(columns=['DETALLE_OFERTA'])
# df_ref = df_ref.drop(columns=['DETALLE_TASA'])
df_ref = df_ref.drop(columns=['FLG_PEARS'])

# %%
df_ref['cl_telf2'] = (
    pd.to_numeric(df_ref['cl_telf2'], errors='coerce')
      .astype('Int64')
      .astype(str)
)

# %%
cols = ['cl_telf1', 'cl_telf2']

for c in cols:
    df_ref[c] = (
        pd.to_numeric(df_ref[c], errors='coerce')
        .astype('Int64')
        .astype(str)
        .replace('<NA>', '0')   # o None si prefieres
    )

# %%
df_ref['OFERTA_ELECTRO'] = df_ref['OFERTA_ELECTRO'].fillna(0)

# %%
print(df_ref["OFERTA_ELECTRO"].head())
print(df_ref["OFERTA_ELECTRO"].unique()[:20])
# Out:
# 0       nan
# 1    7000.0
# 2       nan
# 3    7000.0
# 4       nan
# Name: OFERTA_ELECTRO, dtype: object
# ['nan' '7000.0' '6000.0' '4320.0' '3510.0' '4770.0' '5580.0' '2430.0'
#  '1980.0' '5310.0' '2790.0' '6300.0' '5000.0' '3690.0' '5220.0' '3150.0'
#  '5940.0' '5760.0' '5040.0' '4500.0']

# %%
cols = [
    "OFERTA_ELECTRO",
    "PLAZO_ELECTRO",
    "TASA_ELECTRO",
    "CME_ELECTRO",
    "PROPENSION_ELECTRO"
]

for c in cols:
    df[c] = pd.to_numeric(df[c], errors="coerce")

# %%
df_ref[['cl_telf1','OFERTA_ELECTRO']].head()
# Out:
#     cl_telf1 OFERTA_ELECTRO
# 0  984771393              0
# 1  973784976           7000
# 2  961644603              0
# 3  940331848           7000
# 4  988285159              0

# %%
cols = ['OFERTA_ELECTRO', 'OFERTA_ELECTRO']

for c in cols:
    df_ref[c] = (
        pd.to_numeric(df_ref[c], errors='coerce')
        .astype('Int64')
        .astype(str)
        .replace('<NA>', '0')   # o None si prefieres
    )

# %%
import pandas as pd

df_ref['cl_telf1'] = df_ref['cl_telf1'].apply(
    lambda x: str(int(x)) if pd.notnull(x) else None
)

df_ref['cl_telf2'] = df_ref['cl_telf2'].apply(
    lambda x: str(int(x)) if pd.notnull(x) else None
)

df_ref['cl_telf2'] = df_ref['cl_telf2'].fillna(0)
df_ref['cl_telf1'] = df_ref['cl_telf1'].fillna(0)

# %%
df_ref.to_sql(
    name="alfcc_clientes",
    con=engine,
    if_exists="append",
    index=False,
    chunksize=1000
)
# Out:
# 13831

# %% [markdown]
# ## hasta aca

# %%
print(df_formato_base_inventario.columns.tolist())
# Out:
# ['NUMERO_DOCUMENTO', 'TIPO_DOCUMENTO', 'NOMBRE', 'PERFIL', 'OFERTA_CREDICASH', 'PLAZO_CREDICASH', 'TASA_CREDICASH', 'CME_CREDICASH', 'GRUPO_SEGMENTO', 'PROPENSION_CREDICASH', 'OFERTA_ELECTRO', 'PLAZO_ELECTRO', 'TASA_ELECTRO', 'CME_ELECTRO', 'PROPENSION_ELECTRO', 'Region', 'Tienda_IR', 'Semaforo', 'DEPARTAMENTO', 'PROVINCIA', 'DISTRITO', 'DIRECCION', 'FLG_AAHH', 'FLG_URB', 'TIPO_ZONA', 'MARCA_PD', 'FLG_PEARS', 'PRODUCTO_EXTERNO', 'FLG_CRUCE_RECURRENTE', 'FRESCURA', 'DEMANDA', 'SITUACION_LABORAL', 'INTENSIDAD_MAX', 'SCORE_TELEFONO', 'cl_telf1', 'cl_telf2', 'Campana', 'LOTE', 'cl_base', 'cl_carga', 'cl_estado']

# %%
df_ref[['FLG_PEARS']].head()
# Out:
#   FLG_PEARS
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False

# %%
['NUMERO_DOCUMENTO', 'TIPO_DOCUMENTO', 'NOMBRE', 'PERFIL', 'OFERTA_CREDICASH', 'PLAZO_CREDICASH', 'TASA_CREDICASH', 'CME_CREDICASH', 'GRUPO_SEGMENTO', 'PROPENSION_CREDICASH', 'OFERTA_ELECTRO', 'PLAZO_ELECTRO', 'TASA_ELECTRO', 'CME_ELECTRO', 'PROPENSION_ELECTRO', 'Region', 'Tienda_IR', 'Semaforo', 'DEPARTAMENTO', 'PROVINCIA', 'DISTRITO', 'DIRECCION', 'FLG_AAHH', 'FLG_URB', 'TIPO_ZONA', 'MARCA_PD', 'FLG_PEARS', 'PRODUCTO_EXTERNO', 'FLG_CRUCE_RECURRENTE', 'FRESCURA', 'DEMANDA', 'SITUACION_LABORAL', 'INTENSIDAD_MAX', 'SCORE_TELEFONO', 'cl_telf1', 'cl_telf2', 'Campana', 'LOTE', 'cl_base', 'cl_carga', 'cl_estado']

# %%
df_carga['len_campana'] = df_carga['Campana'].astype(str).str.len()

print(df_carga['len_campana'].max())

# %%
print(df_carga.columns.tolist())
# Out:
# ['DEPARTAMENTO', 'FLG_AAHH', 'NOMBRES', 'Agencia_comercial', 'CAPACIDAD_MAX', 'SALDO_DIFERENCIAL_REENG', 'GRUPO_MONTO', 'RANGO_OFERTA', 'cl_carga', 'NUMERO_DOCUMENTO', 'PLAZO', 'APELLIDO_PATERNO', 'SCORE_TELEFONO', 'RANGO_EDAD', 'oferta_max', 'cl_base', 'TIPO_CLIENTE', 'cl_estado', 'TIENDA', 'color_final', 'GRUPO_TASA', 'lote', 'Tasa_6', 'Tasa_5', 'cl_telf2', 'cl_telf1', 'Tasa_3', 'Tasa_7', 'flag_deuda_v_oferta', 'TIPO_BASE', 'USER_V3', 'PROVINCIA', 'RANGO_SUELDO', 'DISTRITO', 'Region_comercial', 'FRESCURA', 'tipo_cliente_riegos', 'Tasa_2', 'Tasa_4', 'nombre_base', 'PILOTO_PLAZAS', 'INTENSIDAD_MAX', 'MGNEG', 'Campana', 'CUOTA', 'estado', 'Edad', 'PROPENSION_IC', 'APELLIDO_MATERNO', 'Tasa_1']

# %%
# soverwrite_table_SQL(spark,df_prueba,f'ventas_dinners_rtiro_borrar____1',server_kishin,user_kishin,pwd_kishin,'DANTALION')

# %%
df_score = df_score.withColumn(
    "NUMERO_DOCUMENTO",
    F.right(
        F.concat(F.lit("00000000"), F.col("NUMERO_DOCUMENTO")),
        F.lit(8)
    )
)

df_prueba = df_prueba.withColumn(
    "NUMERO_DOCUMENTO",
    F.right(
        F.concat(F.lit("00000000"), F.col("NUMERO_DOCUMENTO")),
        F.lit(8)
    )
)

df_prueba=df_prueba.drop('SCORE_TELEFONO')
df_score=df_score.select('NUMERO_DOCUMENTO', 'cl_telf1', 'cl_telf2', 'SCORE_TELEFONO')
print(df_prueba.columns)

# %%
# Out:
# ['NUMERO_DOCUMENTO', 'PROPENSION_IC', 'USER_V3', 'APELLIDO_PATERNO', 'APELLIDO_MATERNO', 'NOMBRES', 'OFERTA_MAX', 'tasa_minima', 'PLAZO', 'CUOTA', 'CAPACIDAD_MAX', 'TIPO_GEST', 'TIPO_CLIENTE_COMERCIAL', 'campania', 'SALDO_DIFERENCIAL_REENG', 'TIPO_CLIENTE', 'color_final', 'PERFIL_RO', 'TIPO_BASE', 'DEPARTAMENTO', 'PROVINCIA', 'DISTRITO', 'SUCURSAL_COMERCIAL', 'Agencia_comercial', 'REGION_COMERCIAL', 'VARIACION_OFERTA_CAMPAÃ‘A_ANTERIOR', 'VARIACION_TASA_CAMPAÃ‘A_ANTERIOR', 'VAR_TASA_CREDITO_ANTERIOR', 'FLG_CET_6M', 'FLAG_DEUDA_V_OFERTA', 'GRUPO_TASA', 'GRUPO_MONTO', 'MGNEG', 'Tasa_1', 'Tasa_2', 'Tasa_3', 'Tasa_4', 'Tasa_5', 'Tasa_6', 'Tasa_7', 'Edad', 'RANGO_EDAD', 'RANGO_OFERTA', 'RANGO_SUELDO', 'BLOQUE', 'FRESCURA', 'FLG_AAHH', 'INTENSIDAD_MAX', 'PILOTO_PLAZAS', 'CAMP_BONO', 'CAMP_ADP', 'TIENDA', 'SUCURSAL', 'LOTE', 'cl_base', 'cl_carga', 'ESTADO', 'CAMPANA', 'nombre_base', 'cl_telf1', 'cl_telf2', 'SCORE_TELEFONO']

# %%
query = f"""
    select * from alfcc_clientes where cl_base="mayo 2026"');
    """
df_base=obtener_tabla_sql(spark,query,server_kishin,user_kishin,pwd_kishin,db_kishin)

# %%
from pyspark.sql import functions as F

cols_patron = [
    'NUMERO_DOCUMENTO', 'APELLIDO_PATERNO', 'APELLIDO_MATERNO', 'NOMBRES',
    'SUCURSAL', 'TIENDA', 'OFERTA_MAX', 'OFERTA_REEN', 'Tipo_verificacion',
    'Tasa_1', 'Tasa_2', 'Tasa_3', 'Tasa_4', 'Tasa_5', 'Tasa_6', 'Tasa_7',
    'PLAZO', 'campania', 'TEM', 'Desgravamen', 'CUOTA', 'Edad',
    'Oferta_12M', 'Tasa_12M', 'Desgravamen_12M', 'CUOTA_12M',
    'Oferta_18M', 'Tasa_18M', 'Desgravamen_18M', 'CUOTA_18M',
    'Oferta_24M', 'Tasa_24M', 'Desgravamen_24M', 'CUOTA_24M',
    'Oferta_36M', 'Tasa_36M', 'Desgravamen_36M', 'CUOTA_36M',
    'Validador_Telefono', 'Prioridad', 'Nombre_prioridad',
    'Deuda_1', 'Entidad_1', 'Deuda_2', 'Entidad_2', 'Deuda_3', 'Entidad_3',
    'DEPARTAMENTO', 'PROVINCIA', 'DISTRITO', 'sucursal_comercial',
    'Agencia_comercial', 'Region_comercial', 'RANGO_EDAD', 'RANGO_OFERTA',
    'RANGO_SUELDO', 'CAPACIDAD_MAX', 'PEER', 'TIPO_GEST', 'TIPO_CLIENTE',
    'CLIENTE_NUEVO', 'GRUPO_TASA', 'GRUPO_MONTO', 'TASA_VS_MONTO',
    'GRUPO_TASA_REENGANCHE', 'SALDO_DIFERENCIAL_REENG', 'FLAG_REENG',
    'color', 'color_final', 'PROPENSION', 'SEGMENTO_USER', 'USUARIO',
    'tipo_cliente_riegos', 'incremento_monto_riesgos', 'FLG_DEUDA_PLUS',
    'FRESCURA', 'LEAD_CALIDAD', 'USER_V3', 'TIPO_BASE',
    'flag_deuda_v_oferta', 'MGNEG', 'PROPENSION_IC', 'PERFIL_RO',
    'FLG_AAHH', 'SCORE_TELEFONO', 'NumEntidades', 'INTENSIDAD_MAX',
    'nombre_base', 'cl_telf1', 'cl_telf2', 'cl_telf3', 'cl_telf4',
    'cl_telf5', 'cl_telf6', 'cl_telf7', 'cl_telf8', 'cl_telf9',
    'cl_telf10', 'LOTE', 'ESTADO', 'CAMPANA', 'cl_base', 'tasa_minima',
    'cl_carga', 'MES_DURACION_BASE', 'ANIO_DURACION_BASE', 'PERFIL_GLOBAL'
]

# Crear columnas faltantes
for col in cols_patron:
    if col not in df_prueba.columns:
        df_prueba = df_prueba.withColumn(col, F.lit(None))

# Seleccionar exactamente en ese orden
df_prueba = df_prueba.select(cols_patron)

# %%
df_prueba.show()
# Out:
# +----------------+----------------+-------------------+-------------------+--------------------+--------------------+----------+-----------+-----------------+------+------+------+------+------+------+------+-----+--------+----+-----------+-------+----+----------+--------+---------------+---------+----------+--------+---------------+---------+----------+--------+---------------+---------+----------+--------+---------------+---------+------------------+---------+----------------+-------+---------+-------+---------+-------+---------+------------+-------------+--------------------+------------------+--------------------+----------------+----------+------------+------------+-------------+----+---------+-------------+-------------+-------------+---------------+-------------+---------------------+-----------------------+----------+-----+---------------+----------+-------------+-------+-------------------+------------------------+--------------+--------+------------+--------------------+----
# ...

# %%
df_dni = df_prueba.toPandas()
import os

ruta_archivo = os.path.join(ruta_csv, 'BASE_ALFIN_20260418.xlsx')

df_dni.to_excel(ruta_archivo, index=False)

# %%
df_prueba.show(5)
# Out:
# +----------------+-------------+--------+----------------+----------------+-----------------+----------+-----------+-----+------+-------------+---------+----------------------+--------+-----------------------+-------------+---------------+---------+----------------+------------+-------------+----------+------------------+-----------------+--------------------+---------------------------------+-------------------------------+-------------------------+----------+-------------------+-------------+---------------+-----+------+------+------+------+------+------+------+----+----------+------------+------------+------+--------+------------+--------------+-------------+------------+--------+-------------+-------------+----------+---------+----------+------+-------+-----------+---------+---------+--------------+
# ...

# %%
query = f"""
select *
    FROM valentina.dbo.alfin_clientes
    where cl_base='abril 2026'
    """
df_base_p=obtener_tabla_sql(spark,query,server_sa,user_sa,pwd_sa,db_sa)
df_base_p = df_base_p.toDF(*[c.lower() for c in df_base_p.columns])

# %%
df_base_p=df_base_p.select('numero_documento','cl_id','nombre')

# %%
# query = f"""
# select *
#     FROM valentina.dbo.alfin_clientes
#     where cl_base='abril 2026'
#     """
# df_base_p=obtener_tabla_sql(spark,query,server_sa,user_sa,pwd_sa,db_sa)
# df_base_p = df_base_p.toDF(*[c.lower() for c in df_base_p.columns])
# print(df_base_p.columns)
# Out:
# ['cl_id', 'tipo_doi', 'numero_documento', 'nombres', 'apellido_paterno', 'apellido_materno', 'sucursal', 'tienda', 'departamento', 'provincia', 'distrito', 'fec_nacimiento', 'oferta_max', 'oferta_reen', 'tipo_verificacion', 'grupo_riesgo', 'proveedor', 'lote', 'estado', 'tasa_1', 'tasa_2', 'tasa_3', 'tasa_4', 'tasa_5', 'tasa_6', 'tasa_7', 'segmento', 'campana', 'plazo', 'tem', 'propension_ic', 'desgravamen', 'cuota', 'edad', 'oferta_12m', 'tasa_12m', 'desgravamen_12m', 'cuota_12m', 'oferta_18m', 'tasa_18m', 'desgravamen_18m', 'cuota_18m', 'oferta_24m', 'tasa_24m', 'desgravamen_24m', 'cuota_24m', 'oferta_36m', 'tasa_36m', 'desgravamen_36m', 'cuota_36m', 'validador_telefono', 'prioridad', 'nombre_prioridad', 'deuda_1', 'entidad_1', 'deuda_2', 'entidad_2', 'deuda_3', 'entidad_3', 'sucursal_comercial', 'agencia_comercial', 'region_comercial', 'ubicacion', 'ofertamaximasinseguro', 'color', 'color_final', 'propension', 'oferta_final', 'garantia', 'oferta_minima_paperless', 'rango_oferta', 
# ...

# %%
['cl_id', 'tipo_doi', 'numero_documento', 'nombres', 'apellido_paterno', 'apellido_materno', 'sucursal', 'tienda', 'departamento', 'provincia', 'distrito', 'fec_nacimiento', 'oferta_max', 'oferta_reen', 'tipo_verificacion', 'grupo_riesgo', 'proveedor', 'lote', 'estado', 'tasa_1', 'tasa_2', 'tasa_3', 'tasa_4', 'tasa_5', 'tasa_6', 'tasa_7', 'segmento', 'campana', 'plazo', 'tem', 'propension_ic', 'desgravamen', 'cuota', 'edad', 'oferta_12m', 'tasa_12m', 'desgravamen_12m', 'cuota_12m', 'oferta_18m', 'tasa_18m', 'desgravamen_18m', 'cuota_18m', 'oferta_24m', 'tasa_24m', 'desgravamen_24m', 'cuota_24m', 'oferta_36m', 'tasa_36m', 'desgravamen_36m', 'cuota_36m', 'validador_telefono', 'prioridad', 'nombre_prioridad', 'deuda_1', 'entidad_1', 'deuda_2', 'entidad_2', 'deuda_3', 'entidad_3', 'sucursal_comercial', 'agencia_comercial', 'region_comercial', 'ubicacion', 'ofertamaximasinseguro', 'color', 'color_final', 'propension', 'oferta_final', 'garantia', 'oferta_minima_paperless', 'rango_oferta', 'rango_sueldo', 'capacidad_max', 'peer', 'prop_comer', 'tipo_gest', 'cliente_nuevo', 'grupo_tasa', 'nuevos_3m', 'nuevos_6m', 'nuevos_9m', 'nuevos_12m', 'nuevos_4m', 'grupo_monto', 'tasa_vs_monto', 'usuario', 'incremento_monto_riesgos', 'flg_deuda_plus', 'tipo_cliente_riegos', 'user_v3', 'lead_calidad', 'segmento_user', 'rango_edad', 'rango_oferta2', 'periodo', 'retiro_gest', 'mejor_tipificacion', 'status', 'fecha_sol', 'base', 'resultado', 'num_enriquecido', 'tipo_contacto', 'q_ventas', 'localidad', 'desembolsado', 'monto_desembolsado', 'sbi', 'cruce', 'prest_previo', 'id_cliente', 'rango_edad2', 'fecha_envio', 'tipo_bd', 'cod_bd', 'nomb_bd', 'mes_gestion', 'tipo_cliente', 'grupo_tasa_reenganche', 'saldo_diferencial_reeng', 'flag_reeng', 'retiro_desembolso', 'frescura', 'flag_deuda_v_oferta', 'mgneg', 'perfil_ro', 'tipo_base', 'cl_telf1', 'cl_telf2', 'cl_telf3', 'cl_telf4', 'cl_telf5', 'cl_telf6', 'cl_telf7', 'cl_telf8', 'cl_telf9', 'cl_telf10', 'cl_movil', 'cl_celular', 'cl_telefono', 'cl_turno', 'cl_gestor', 'cl_asesor', 'cl_accion', 'cl_gestion', 'cl_estado', 'cl_fecha_gestion', 'cl_hora_gestion', 'cl_hits', 'cl_fecha_llamar', 'cl_prioridad', 'cl_orden', 'cl_predictivo', 'cl_tiempo', 'cl_base', 'cl_mes', 'cl_carga', 'id_carga', 'cl_area', 'fecha_alimentacion', 'cl_base_ant', 'cl_accion_ant', 'cl_fecha_ant', 'campania', 'promocion', 'promocion2', 'nombre_base', 'numentidades', 'p_banco', 'perfil_global', 'flg_aahh', 'score_telefono', 'piloto_plazas', 'intensidad_max']tasa

# %%
df_base_p=df_base_p.select('numero_documento','cl_id', 'nombres', 'apellido_paterno')

# %%
from pyspark.sql.functions import lit

df1=df_prueba.select(
    'numero_documento',
    'TELEFONO',
    lit(12).alias('uno')
).join(
    df_base_p.select('cl_id','numero_documento','nombres', 'apellido_paterno'),
    ['numero_documento'],
    'inner'
)
# Out:
# {"ts": "2026-04-16 09:23:46.273", "level": "ERROR", "logger": "DataFrameQueryContextLogger", "msg": "[UNRESOLVED_COLUMN.WITH_SUGGESTION] A column, variable, or function parameter with name `TELEFONO` cannot be resolved. Did you mean one of the following? [`TASA_NUEVA`, `Dni_cliente`, `numero_documento`]. SQLSTATE: 42703", "context": {"file": "jdk.internal.reflect.GeneratedMethodAccessor35.invoke(Unknown Source)", "line": "", "fragment": "col", "errorClass": "UNRESOLVED_COLUMN.WITH_SUGGESTION"}, "exception": {"class": "Py4JJavaError", "msg": "An error occurred while calling o60.select.\n: org.apache.spark.sql.AnalysisException: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column, variable, or function parameter with name `TELEFONO` cannot be resolved. Did you mean one of the following? [`TASA_NUEVA`, `Dni_cliente`, `numero_documento`]. SQLSTATE: 42703;\n'Project [numero_documento#39, 'TELEFONO, 12 AS uno#1445]\n+- Project [Dni_cliente#36, TASA_NUEVA#37, right(concat(00000000, Dni_cliente#36)
# ...

# %%
filename='ultimo_base_crfc_alfinedi.csv'

df_prueba=cargar_archivo_csv(spark,filename,';',True)
# print(df_base_p.columns)
print(df_prueba.columns)
# Out:
# ['cel', 'DNI']

# %%
df_prueba = df_prueba.withColumn(
    "numero_documento",
    F.right(
        F.concat(F.lit("00000000"), F.col("DNI")),
        F.lit(8)
    )
)

# %%
# overwrite_table_SQL(spark,df_prueba,f'ventas_dinners_rtiro_borrar____1',server_sa,user_sa,pwd_sa,'ODIN')

# %%
print(df_base_p.columns)
print(df_prueba.columns)
# Out:
# ['numero_documento', 'cl_id', 'nombre']
# ['cel', 'DNI', 'numero_documento']

# %%
from pyspark.sql.functions import lit

df1=df_prueba.select(
    'numero_documento',
    'cel',
    lit(17).alias('uno')
).join(
    df_base_p.select('cl_id','numero_documento','nombre'),
    ['numero_documento'],
    'inner'
)

# %%
print(df1.columns)
# Out:
# ['numero_documento', 'cel', 'uno', 'cl_id', 'nombre']

# %%
df1=df1.select('cel', 'cl_id', 'uno', 'nombre')
df1 = df1.withColumn(
    "col_final",
    F.concat_ws(",", "cel", "cl_id", "uno", "nombre")
)

df1 = df1.withColumn(
    "col_final",
    F.concat_ws("", "col_final", lit(","))
)
df1=df1.select('col_final')

# %%
import os
df_carga=df1.toPandas()

ruta_archivo = os.path.join(ruta_csv, 'va_01_base2.csv')
df_carga.to_csv(ruta_archivo, index=False, sep=",",header=False)
# df_dni.to_excel(ruta_archivo, index=False)

# %%
filename='fugas_dni.csv'

df_prueba=cargar_archivo_csv(spark,filename,';',True)
print(df_prueba.columns)
# Out:
# ['dni']

# %%
['ID PROVEEDOR', 'NOMBRES', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'TIPO DE DOCUMENTO', 'NUMERO_DOCUMENTO', 'TASA(TEA)', 'TEA_DF', 'TELEFONO_CASA1', 'TELEFONO_CASA2', 'TELEFONO_CASA3', 'TELEFONO_CASA4', 'TELEFONO_CASA5', 'TELEFONO_CASA6', 'TELEFONO_CASA7', 'TELEFONO_CASA8', 'TELEFONO_CASA9', 'TELEFONO_CASA10', 'NUEVO_GRUPO03', 'PROB_CONTACTO', 'DINERS_NRO1', 'DINERS_NRO2', 'DINERS_NRO3', 'DINERS_NRO4', 'DINERS_NRO5', 'OSIPTEL_NRO1_ENCRIP', 'OSIPTEL_NRO2_ENCRIP', 'OSIPTEL_NRO3_ENCRIP', 'OSIPTEL_NRO4_ENCRIP', 'OSIPTEL_NRO5_ENCRIP', 'DCP01', 'DCP02', 'DCP03', 'DCP04', 'DCP05', 'CELULAR01', 'CELULAR02', 'CELULAR03', 'CELULAR04', 'CELULAR05', 'CELULAR06', 'CELULAR07', 'CELULAR08', 'CELULAR09', 'CELULAR10', 'RECENCIA', 'PERFIL', 'PRODUCTO', 'LINEA_DIN', 'ID RESULTADO GESTION', 'TCEA_NEW', 'TCEA_CUOTAS_DF', 'LIMACALLAO', 'FECHA_NACIMIENTO', 'PROVINCIA', 'L_BCP', 'L_BBVA', 'L_IBK', 'L_SCO', 'L_BIF', 'L_CITI', 'L_FIN', 'L_RIP', 'L_CMR', 'L_CRESCO', 'L_CEN', 'L_AZT', 'L_UNO', 'L_GNB', 'L_EFE', 'L_COM', 'L_NAC', 'EX_SOCIO', 'LINEA_ANT_EX_SOCIO', 'ULT_TASA_EX_SOCIO', 'PRIORIDAD', 'BENCH', 'FUENTE', 'SEGMENTACION']

# %%
df_prueba=df_prueba.select('NUMERO_DOCUMENTO','SEGMENTACION')

# %%
df_prueba = df_prueba.withColumn(
    "numero_documento",
    F.right(
        F.concat(F.lit("00000000"), F.col("dni")),
        F.lit(8)
    )
)

# %%
df_prueba=df_prueba.select('numero_documento')

# %%
overwrite_table_SQL(spark,df_prueba,f'ventas_dinners_rtiro_borrar____1',server_sa,user_sa,pwd_sa,'ODIN')
overwrite_table_SQL(spark,df_prueba,f'ventas_dinners_rtiro_borrar____1',server_kishin,user_kishin,pwd_kishin,'DANTALION')
overwrite_table_SQL(spark,df_prueba,f'ventas_dinners_rtiro_borrar____1',server_zeus,user_zeus,pwd_zeus,'ODIN')

# %%
overwrite_table_SQL(spark,df_prueba,f'ventas_dinners_segmentacion',server_sa,user_sa,pwd_sa,'ODIN')
overwrite_table_SQL(spark,df_prueba,f'ventas_dinners_segmentacion',server_kishin,user_kishin,pwd_kishin,'DANTALION')
overwrite_table_SQL(spark,df_prueba,f'ventas_dinners_segmentacion',server_zeus,user_zeus,pwd_zeus,'ODIN')

# %%
fecha_mes_base='2026-04-01'
query = f"""
    SELECT 
    a.NUMERO_DOCUMENTO as dni_cliente,
    t.contacto,
    t.tipo_telf,
    a.cl_carga
    FROM VALENTINA.dbo.alfin_clientes a
    CROSS APPLY (
    VALUES
        (a.cl_telf1, 'cel01'),
        (a.cl_telf2, 'cel02'),
        (a.cl_telf3, 'cel03'),
        (a.cl_telf4, 'cel04'),
        (a.cl_telf5, 'cel05'),
        (a.cl_telf6, 'cel06'),
        (a.cl_telf7, 'cel07'),
        (a.cl_telf8, 'cel08'),
        (a.cl_telf9, 'cel09'),
        (a.cl_telf10, 'cel10')
    ) t(contacto, tipo_telf)
    WHERE 
    t.contacto IS NOT NULL
    AND t.contacto <> ''
    AND LEN(t.contacto) = 9
    AND t.contacto LIKE '9%'
    AND CAST(a.cl_carga AS DATE) >= CAST('{fecha_mes_base}' AS DATE)
    AND CAST(a.cl_carga AS DATE) < DATEADD(MONTH, 1, CAST('{fecha_mes_base}' AS DATE))
    """

df_tnumero=obtener_tabla_sql(spark,query,server_sa,user_sa,pwd_sa,db_sa)

# %%
query = """
  SELECT * FROM cronox.dbo.borrar_df_cencosud_tc_01
    """
df_list_cencosud = obtener_tabla_sql(spark,query,server_sa,user_sa,pwd_sa,db_sa)

# df_list_cencosud = df_list_cencosud.withColumn(
#     'linea_sae',
#     col('linea_sae').cast('int')
# )
# df_list_cencosud = df_list_cencosud.withColumn(
#     'q_intentos_telef',
#     col('q_intentos_telef').cast('int')
# )
# df_list_cencosud = df_list_cencosud.withColumn(
#     'tea',
#     col('tea').cast('double')
# )


print(df_list_cencosud.columns)
print(df_list_cencosud.count())
# Out:
# ['vendor_lead_code', 'phone_number', 'phone_number_02', 'first_name', 'last_name', 'address1', 'address2', 'address3', 'city', 'province', 'email', 'security_phrase', 'comments', 'mejor_CODIGO_cli_dia', 'mejor15_CODIGO_telf', 'mejor15_CODIGO_cli', 'mejor_CODIGO_cli', 'indice_num', 'tipo_telf', 'cod_attempt', 'q_intentos_telef', 'indice_tpo_telf', 'min_numero', 'phone_number_04', 'indice', 'segmento', 'tipdoc', 'regimen_laboral', 'quintil', 'linea_cencosud', 'rng_edad', 'propension_efectivo', 'tipo_tarjeta_cenco', 'num_tc', 'mejora_oferta', 'seg_contact', 'fecha_envio', 'antiguedad', 'retiro', 'seg_edad', 'flg_ex_cliente', 'region', 'flg_frescura', 'flg_cliente_nuevo', 'mes_prioridad', 'retiro_01', 'numero_campana', 'nombre_campana', 'fecha_hora_llamada', 'duracion', 'call_result', 'list_name', 'fecha_agenda', 'comentarios', 'fecha_llamada', 'tramo', 'dni_ejecutivo', 'ejecutivo', 'ult_call_result', 'dni_unico', 'mejor_estado_tipi_cli', 'mejor_descripcion_cli', 'mejor_sub_descripcion',
# ...

# %%
df_list_cencosud.dropDuplicates(['vendor_lead_code']) \
    .groupBy("quintil") \
    .count() \
    .orderBy("quintil") \
    .show()
# Out:
# +-------+-----+
# |quintil|count|
# +-------+-----+
# |      1| 7706|
# |      2| 7305|
# |      3| 7784|
# |      4| 7560|
# |      5| 7927|
# +-------+-----+

# %%
['vendor_lead_code', 'phone_number', 'phone_number_02', 'first_name', 'last_name', 'address1', 'address2', 'address3', 'city', 'province', 'email', 'security_phrase', 'comments', 'mejor_CODIGO_cli_dia', 'mejor15_CODIGO_telf', 'mejor15_CODIGO_cli', 'mejor_CODIGO_cli', 'indice_num', 'tipo_telf', 'cod_attempt', 'q_intentos_telef', 'indice_tpo_telf', 'min_numero', 'phone_number_04', 'indice', 'segmento', 'tipdoc', 'regimen_laboral', 'quintil', 'linea_cencosud', 'rng_edad', 'propension_efectivo', 'tipo_tarjeta_cenco', 'num_tc', 'mejora_oferta', 'seg_contact', 'fecha_envio', 'antiguedad', 'retiro', 'seg_edad', 'flg_ex_cliente', 'region', 'flg_frescura', 'flg_cliente_nuevo', 'mes_prioridad', 'retiro_01', 'numero_campana', 'nombre_campana', 'fecha_hora_llamada', 'duracion', 'call_result', 'list_name', 'fecha_agenda', 'comentarios', 'fecha_llamada', 'tramo', 'dni_ejecutivo', 'ejecutivo', 'ult_call_result', 'dni_unico', 'mejor_estado_tipi_cli', 'mejor_descripcion_cli', 'mejor_sub_descripcion', 'mejor_peso_cli', 'mejor15_estado_tipi_cli', 'mejor15_descripcion_cli', 'mejor15_sub_descripcion_cli', 'mejor15_peso_cli', 'mejor15_estado_tipi_telf', 'mejor15_descripcion_telf', 'mejor15_sub_descripcion_telf', 'mejor15_peso_telf', 'mejor_estado_tipi_cli_dia', 'mejor_descripcion_cli_dia', 'mejor_sub_descripcion_cli_dia', 'mejor_peso_cli_dia']esta

# %%
df_list_cencosud.dropDuplicates(['vendor_lead_code']).count()
# Out:
# 38282

# %%
df_list_cencosud.dropDuplicates(['vendor_lead_code']).count()
# Out:
# 38282

# %%
print([row['mejor15_descripcion_telf' ] for row in df_list_cencosud.select('mejor15_descripcion_telf').distinct().collect()])
# Out:
# ['LLAMADA ELIMINADA POR ERROR EN RED (AUTO)', 'VOLVER A LLAMAR', 'CLIENTE CUELGA ANTES DE ESCUCHAR OFERTA', 'NO UTILIZA (TARJETAS - PRESTAMOS)', 'AUTODIAL NO RESPONDE (AUTO)', 'OFERTA DE TASA MUY ALTA', 'OFERTA DE LINEA MUY BAJA', 'NO DESEA PAGAR MEMBRESIA', 'NO SE CONCRETO LLAMADA (CASILLA DE VOZ - APAGADO)', 'VOLVER A LLAMAR (TERCERO RELACIONADO)', 'ZONA FUERA DE COBERTURA', 'NO VOLVER A LLAMAR NUNCA MAS', 'VOLVER A LLAMAR - call', 'TELEFONO OCUPADO / NO CONTESTAN', 'OCUPADO (AUTO)', 'NO DESEA –NO ESPECIFICA MOTIVO', 'TELEFONO EQUIVOCADO', 'GESTION EN PROCESO (AUTO)', 'MENSAJE EN CASILLA DE VOZ (AUTO)', 'CLIENTE FALLECIO', 'CLIENTE ACEPTA PRODUCTO', 'TELEFONO FUERA DE SERVICIO / NO EXISTE', 'DESEA IR A AGENCIA', 'CLIENTE DESEA OTRO PRODUCTO', 'AGENTE NO DISPONIBLE (AUTO)', None]

# %%
flg_ex_cliente=['EX-CLIENTE', 'NUEVO']
tipo_telf=['BBDD CEL01']
segmento=['TC2', 'TC1', 'TC3']
first_name=['SEGMENTO SIN BONUS', 'SEGMENTO BONUS', 'SEGMENTO EXCLUSIVO']
regimen_laboral=['INDEP', 'DEP', 'INFOR']
tipo_tarjeta_cenco=['BLACK', 'PREMIUM', 'CLASICA']
quintil=[ '1', '2']
propension_efectivo=['1. TOMA EFECTIVO MAS TARJETA', '2. TOMA SOLO EFECTIVO', '3. TOMA SOLO TC']
mejor15_descripcion_telf=['LLAMADA ELIMINADA POR ERROR EN RED (AUTO)',
 'CLIENTE CUELGA ANTES DE ESCUCHAR OFERTA',
 'NO UTILIZA (TARJETAS - PRESTAMOS)',
 'AUTODIAL NO RESPONDE (AUTO)',
 'OFERTA DE TASA MUY ALTA',
 'NO DESEA PAGAR MEMBRESIA',
 'OFERTA DE LINEA MUY BAJA',
 'NO SE CONCRETO LLAMADA (CASILLA DE VOZ - APAGADO)',
 'VOLVER A LLAMAR (TERCERO RELACIONADO)',
 'TELEFONO OCUPADO / NO CONTESTAN',
 'OCUPADO (AUTO)',
 'NO SE ASIGNO RESULTADO A LA LLAMADA (AUTO)',
 'NO DESEA –NO ESPECIFICA MOTIVO',
 'GESTION EN PROCESO (AUTO)',
 'NUMERO DESCONECTADO (AUTO)',
 'MENSAJE EN CASILLA DE VOZ (AUTO)',
 'DESEA IR A AGENCIA',
 'CLIENTE DESEA OTRO PRODUCTO',
 'AGENTE NO DISPONIBLE (AUTO)']

# %%
flg_ex_cliente=[ 'NUEVO']
tipo_telf=['bbdd cel01']
segmento=['TC2', 'TC1']
first_name=['SEGMENTO SIN BONUS', 'SEGMENTO BONUS', 'SEGMENTO EXCLUSIVO']
regimen_laboral=['', 'DEP', 'INFOR']
tipo_tarjeta_cenco=['BLACK', 'PREMIUM', 'CLASICA']
quintil=[ '1','2','3']
propension_efectivo=['1. TOMA EFECTIVO MAS TARJETA',  '3. TOMA SOLO TC']
mejor15_descripcion_telf=[
'LLAMADA ELIMINADA POR ERROR EN RED (AUTO)',
 'CLIENTE CUELGA ANTES DE ESCUCHAR OFERTA',
 'NO UTILIZA (TARJETAS - PRESTAMOS)',
 'AUTODIAL NO RESPONDE (AUTO)',
 'OFERTA DE TASA MUY ALTA',
 'OFERTA DE LINEA MUY BAJA',
 'NO DESEA PAGAR MEMBRESIA',
 'NO SE CONCRETO LLAMADA (CASILLA DE VOZ - APAGADO)',
 'VOLVER A LLAMAR (TERCERO RELACIONADO)',
 'TELEFONO OCUPADO / NO CONTESTAN',
 'OCUPADO (AUTO)',
 'NO DESEA –NO ESPECIFICA MOTIVO',
 'GESTION EN PROCESO (AUTO)',
 'MENSAJE EN CASILLA DE VOZ (AUTO)',
 'DESEA IR A AGENCIA',
 'CLIENTE DESEA OTRO PRODUCTO',
 'AGENTE NO DISPONIBLE (AUTO)'
 ]

# %%
# mejor_tipi=['VOLVER A LLAMAR','VOLVER A LLAMAR - call']

df_filtrado = df_list_cencosud.filter(
    # ((F.col('mejor_estado_tipi_cli').isin('CONTACTO EFECTIVO','NO GESTIONADO')) | (F.col('mejor_estado_tipi_cli').isNull())) &
    ((F.col('mejor_descripcion_cli').isin(mejor15_descripcion_telf)) | (F.col('mejor_descripcion_cli').isNull())) &
    ((F.col('mejor15_descripcion_telf').isin(mejor15_descripcion_telf)) | (F.col('mejor15_descripcion_telf').isNull())) &
    ((F.col('fecha_llamada')<'2026-04-07') | (F.col('fecha_llamada').isNull())) &
    (F.col('quintil').isin(quintil))&
    (F.col('q_intentos_telef')<4)

    
).orderBy(col('linea_cencosud').desc())


print(df_filtrado.count())
print(df_filtrado.columns)
# Out:
# 1015
# ...

# %%
tipificaicon_telf="mejor15_descripcion_telf"
df_filtrado = df_filtrado.select(
    'vendor_lead_code', 'phone_number', 'phone_number_02', 'first_name',
    'last_name', 'address1', 'address2', 'address3',
    'city', 'province', 'email', 'security_phrase', 'comments','mejor15_descripcion_telf'
)

# %%
df_dni = df_filtrado.toPandas()

import os

ruta_archivo = os.path.join(ruta_csv, 'tc_cenco_202604080941.xlsx')

df_dni.to_excel(ruta_archivo, index=False)

# %%
df_dni = df_filtrado.toPandas()
pareto_mejor_descripcion(df_dni,tipificaicon_telf)

# %%
exportar_lista(df_filtrado,'tc_cenco_202603301418.xlsx','linea_cencosud')

# %%
cantidad_leads=df_filtrado.count()

# %%
info_list=f"""
Se tienen {cantidad_leads} leads
Prioridad : {quintil}
maximo de intentos por num telef: {q_intentos_telef}
flg_ex_cliente :{flg_ex_cliente}
{segmento}
{first_name}

"""

print(info_list)
# Out:
# Se tienen 2814 leads
# Prioridad : ['1', '2']
# maximo de intentos por num telef: 40
# flg_ex_cliente :['NUEVO']
# ['TC2', 'TC1']
# ['SEGMENTO BONUS', 'SEGMENTO EXCLUSIVO']

# %%
exportar_lista(df_filtrado,'tc_cencor_202603310847.xlsx','linea_cencosud')

# %%
# Out:
# ['LLAMADA ELIMINADA POR ERROR EN RED (AUTO)', 'VOLVER A LLAMAR', 'CLIENTE CUELGA ANTES DE ESCUCHAR OFERTA', 'NO UTILIZA (TARJETAS - PRESTAMOS)', 'AUTODIAL NO RESPONDE (AUTO)', 'OFERTA DE TASA MUY ALTA', 'OFERTA DE LINEA MUY BAJA', 'NO DESEA PAGAR MEMBRESIA', 'NO SE CONCRETO LLAMADA (CASILLA DE VOZ - APAGADO)', 'VOLVER A LLAMAR (TERCERO RELACIONADO)', 'ZONA FUERA DE COBERTURA', 'NO VOLVER A LLAMAR NUNCA MAS', 'VOLVER A LLAMAR - call', 'TELEFONO OCUPADO / NO CONTESTAN', 'OCUPADO (AUTO)', 'NO SE ASIGNO RESULTADO A LA LLAMADA (AUTO)', 'NO DESEA –NO ESPECIFICA MOTIVO', 'TELEFONO EQUIVOCADO', 'NUMERO DESCONECTADO (AUTO)', 'MENSAJE EN CASILLA DE VOZ (AUTO)', 'CLIENTE FALLECIO', 'CLIENTE ACEPTA PRODUCTO', 'TELEFONO FUERA DE SERVICIO / NO EXISTE', 'DESEA IR A AGENCIA', 'CLIENTE DESEA OTRO PRODUCTO', 'AGENTE NO DISPONIBLE (AUTO)', None]

# %%
import os

ruta_archivo = os.path.join(ruta_csv, 'ivr_202603271706.xlsx')

df_dni.to_excel(ruta_archivo, index=False)

# %%
df_dni = df_filtrado.toPandas()

# %%
los pu pm los qu epodemos usar
# Out:
#   Cell In[73], line 1
#     los pu pm los qu epodemos usar
#         ^
# SyntaxError: invalid syntax

# %%
nombre_archivo_xlsx='SAE_202603251722.xlsx'
columna_ref='linea_sae'
exportar_lista(df_filtrado,nombre_archivo_xlsx,columna_ref)

# %%
fecha_mes_base='2026-03-01'
t_maestra='Base_Maestra_Cencosud_PPFF'
t_name_vigente='Base_Maestra_Cencosud_PPFF_vigente'
t_mumeros='tNumeroCenco_Sae'
cols_drop=[ 'FRESCURA_TARGET', 'REP1', 'REP2', 'REP3','FLAT2']

# %%
df_filtrado = df_filtrado.select(
    'vendor_lead_code', 'phone_number', 'first_name',
    'last_name', 'address1', 'address2', 'address3',
    'city', 'province', 'email', 'security_phrase', 'comments'
)
df_dni = df_filtrado.toPandas()

# %%
import matplotlib.pyplot as plt

df_dni['email'].value_counts().plot(kind='bar')

plt.title('Top departamentos (email)')
plt.xlabel('Departamento')
plt.ylabel('Cantidad')
plt.xticks(rotation=45)
plt.show()

# %%
df_list.select('retiro_01').filter(col('retiro_01')==0).count()
# Out:
# 2266

# %%
# print([row['first_name'] for row in df_list.select('first_name').distinct().collect()])
# print([row['title'] for row in df_list.select('title').distinct().collect()])
# print([row['tip_prioridad'] for row in df_list.select('tip_prioridad').distinct().collect()])
# print([row['email'] for row in df_list.select('email').distinct().collect()])
# print([row['prioridada'] for row in df_list.select('prioridada').distinct().collect()])
print([row['mejor15_descripcion_telf' ] for row in df_list.select('mejor15_descripcion_telf').distinct().collect()])
# print(df_list.columns)
# Out:
# ['PERSONA FALLECIDA', 'VOLVER A LLAMAR', 'LO VA A PENSAR', 'DESEA ELECTRO', 'NEGOCIO EN ZONA NO COBERTURADA', 'TITULAR CONTAGIADO CON COVID - 19', 'CREDITO CONCRETADO', 'MENSAJES CON TERCEROS - HIJOS', 'NO DESEA SER CONTACTADO / MANIFIESTA SU RECHAZO', 'NO NECESITA / NO DESEA', 'TELEFONO APAGADO', 'NUMERO EQUIVOCADO', 'ESTA ENDEUDADO', 'MENSAJES CON TERCEROS - ESPOSA', 'OTROS', 'NO CONTESTA ', 'TITULAR NO CALIFICA- GIRO RESTRINGIDO9', 'CLIENTE RECHAZADO', 'MENSAJES CON TERCEROS - OTROS', 'NO BRINDA CONSENTIMIENTO', 'CASA EN ZONA NO COBERTURADA', 'SI QUIERE', 'CLIENTE DE VIAJE', 'TELEFONO FUERA DE SERVICIO/SUSPENDIDO', 'CONFIRMAR CITA', 'INTERESES ELEVADOS', 'NUMERO NO EXISTE', 'TITULAR NO CALIFICA - DESEMPLEO', 'MENSAJES DE TEXTO', 'TONO OCUPADO', 'SOLICITA SER RETIRADO', 'IVR - NO CONFIRMA', 'MALA EXPERIENCIA (TDA/FNC)', 'DESEA MAS MONTO', 'NO QUIERE', None]
