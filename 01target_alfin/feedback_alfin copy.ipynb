# %% [markdown]
# lista
#
#
#
#
#
# feedback
#
#
# envio formulario
# correo

# %%
import sys 
sys.path.append('C:/Users/DATA/Documents/datos/01_script/inicio/funciones')
from funciones import *
from funciones_spark import *
from variables_inicio import *
from utils_sql import *

spark = SparkSession.builder \
    .appName("SparkExample") \
    .master("local[*]") \
    .config('spark.driver.extraClassPath', 'C:/spark/jars/mssql-jdbc-13.2.1.jre11.jar') \
    .config('spark.executor.extraClassPath', 'C:/spark/jars/mssql-jdbc-13.2.1.jre11.jar') \
    .config('spark.executor.memory', '8g') \
    .config('spark.driver.memory', '8g') \
    .getOrCreate()

# %%
query = """
select 
a.Dni as DNI,
FORMAT(a.Fecha_Llamada, 'yyyy-MM-dd') AS fecha_llamada,
CONVERT(VARCHAR(8), a.Fecha_Hora_Llamada, 108) AS Hora,
a.PHONE_NUMBER as TELEFONO,
case 
    WHEN a.DNI_Ejecutivo = 'VDAD' THEN '27' 
    WHEN a.DNI_Ejecutivo = 'XFER' THEN '27' 
    WHEN a.DNI_Ejecutivo = 'DCMX' THEN '27' 
    WHEN a.Codigo_paleta = 'DISPO' THEN '27' 
    WHEN a.Codigo_paleta = 'DCMX' THEN '27' 
    WHEN a.Codigo_paleta = 'XFER' THEN '27' 
    WHEN a.Codigo_paleta = 'INCALL' THEN '27' 
    WHEN a.Codigo_paleta = 'DONEM' THEN '27' 
    WHEN a.Codigo_paleta = '32' THEN '24' 
    else a.Codigo_paleta 
end as Tipificacion,
'1111' as Id_personal,
'12' as Servicio,
'8' as Id_Supervisor,
'julio 2026' as Campaña,
'1' as Intentos,
segundos as TMO,
'1' as T_espera,
'VALENTINA' as id_record
from THOTH.dbo.Tmp_LLamadas_Alfin a
inner join ODIN.dbo.Base_Maestra_Alfin_bk_Vigente b
on a.Dni=b.NUMERO_DOCUMENTO
where b.NUMERO_DOCUMENTO<>'10492705'
and a.DNI_Ejecutivo<>'VDAD'
    """
df_formato=obtener_tabla_sql(spark,query,server_zeus,user_zeus,pwd_zeus,db_zeus)
print(df_formato.columns)
# Out:
# ['DNI', 'fecha_llamada', 'Hora', 'TELEFONO', 'Tipificacion', 'Id_personal', 'Servicio', 'Id_Supervisor', 'Campaña', 'Intentos', 'TMO', 'T_espera', 'id_record']

# %%
append_table_SQL(spark,df_formato,f'alfin_gestion',server_sa,user_sa,pwd_sa,'VALENTINA')
# Out:
# Error al insertar JDBC: [COLUMN_NOT_DEFINED_IN_TABLE] "STRING" column `DNI` is not defined in table `alfin_gestion`, defined table columns are: `DNI`, `Fecha`, `Hora`, `TELEFONO`, `Tipificacion`, `Id_personal`, `Servicio`, `Id_Supervisor`, `Campaña`, `Intentos`, `TMO`, `T_espera`, `id_record`. SQLSTATE: 42703

# %%
Dni_cliente, Fecha, Hora, Celular, Tipificacion, Id_personal, Servicio, Id_Supervisor, Campaña, Intentos, TMO, T_espera, id_record

# %%
df_formato.select('FECHA_GESTION').orderBy(F.col('FECHA_GESTION').desc()).show()
# Out:
# +-------------+
# |FECHA_GESTION|
# +-------------+
# |     20260729|
# |     20260729|
# |     20260729|
# |     20260729|
# |     20260729|
# |     20260729|
# |     20260729|
# |     20260729|
# |     20260729|
# |     20260729|
# |     20260729|
# |     20260729|
# |     20260729|
# |     20260729|
# |     20260729|
# |     20260729|
# |     20260729|
# |     20260729|
# |     20260729|
# |     20260729|
# +-------------+
# only showing top 20 rows

# %%
filename='RetiroDefinitivo_BlackList.csv'
ruta_archivo = os.path.join(ruta_alfin, filename)
df_def_blacklist = pd.read_csv(ruta_archivo,sep='|')
filename='RetiroDeGestion_BlackList.csv'
ruta_archivo = os.path.join(ruta_alfin, filename)
df_blacklist = pd.read_csv(ruta_archivo,sep='|')
filename='RetiroDeGestion_Telefonos.csv'
ruta_archivo = os.path.join(ruta_alfin, filename)
df_telf = pd.read_csv(ruta_archivo,sep='|')
filename='retiro_correo_alfin.csv'
ruta_archivo = os.path.join(ruta_alfin, filename)
df_retiro_correo = pd.read_csv(ruta_archivo,sep=';')

df_def_blacklist = df_def_blacklist.rename(columns={'DNI': 'dni_cliente'})
df_blacklist = df_blacklist.rename(columns={'DNI': 'dni_cliente'})
df_telf= df_telf.rename(columns={'TELEFONO': 'celular'})
df_retiro_correo= df_retiro_correo.rename(columns={'DNI': 'dni_cliente'})


# Blacklists de DNI
df1 = df_def_blacklist.copy()
df1["celular"] = None
df1 = df1[["dni_cliente", "celular"]]

df2 = df_blacklist.copy()
df2["celular"] = None
df2 = df2[["dni_cliente", "celular"]]

# Blacklist de teléfonos
df3 = df_telf.copy()
df3["dni_cliente"] = None
df3 = df3[["dni_cliente", "celular"]]

# Archivo con DNI y celular
df4 = df_retiro_correo[["dni_cliente", "celular"]].copy()

# Unir todo
df_retiros = pd.concat(
    [df1, df2, df3, df4],
    ignore_index=True
)

# dni_retiro = set(df_retiros['dni_cliente'].dropna())
# cel_retiro = set(df_retiros['celular'].dropna())

# df_seguimiento_1['retiro'] = (
#     df_seguimiento_1['dni_cliente'].isin(dni_retiro) |
#     df_seguimiento_1['celular'].isin(cel_retiro)
# ).astype(int)
# Out:
# C:\Users\DATA\AppData\Local\Temp\ipykernel_3228\2298311491.py:38: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_retiros = pd.concat(

# %%
df_retiros.head()
# Out:
#   dni_cliente  celular
# 0    00000711      NaN
# 1    00002032      NaN
# 2    00002073      NaN
# 3    00002194      NaN
# 4    00002780      NaN

# %%
df_formato.columns
# Out:
# ['Dni_cliente',
#  'Fecha',
#  'Hora',
#  'Celular',
#  'Tipificacion',
#  'Id_personal',
#  'Servicio',
#  'Id_Supervisor',
#  'Campaña',
#  'Intentos',
#  'TMO',
#  'T_espera',
#  'id_record']

# %%
import os
import pandas as pd

# Convertir el DataFrame de PySpark a Pandas
df_feedback_pd = df_formato.toPandas()
# df_feedback_pd.head()

# %%
df_feedback_pd.shape
# Out:
# (151554, 13)

# %%
# (380782, 13)

# %%
# df_validar = df_postulante[
#     ~df_postulante['id_postulante'].isin(df_retiros['dni_cliente'])
# ].copy()

# df_embudo['numero_de_documento'] = (
#     df_embudo['numero_de_documento']
#     .astype(str)
#     .str.replace(r'\D', '', regex=True)      # deja solo números
#     .replace('', pd.NA)                      # vacío -> NA
#     .mask(lambda s: s.str.len() > 8, pd.NA)  # >8 dígitos -> NA
#     .str.zfill(8)                            # <8 dígitos -> completa con ceros
# )

dni_retiro = set(df_retiros['dni_cliente'].dropna())
cel_retiro = set(df_retiros['celular'].dropna())

mask = (
    df_feedback_pd['DNI'].isin(dni_retiro) |
    df_feedback_pd['TELEFONO'].isin(cel_retiro)
)

df_feedback_pd = df_feedback_pd[~mask]

df_feedback_pd.count()
# Out:
# DNI              151545
# fecha_llamada    151545
# Hora             151545
# TELEFONO         151545
# Tipificacion     151545
# Id_personal      151545
# Servicio         151545
# Id_Supervisor    151545
# Campaña          151545
# Intentos         151545
# TMO              151545
# T_espera         151545
# id_record        151545
# dtype: int64

# %%
df_feedback_pd=df_feedback_pd[df_feedback_pd['fecha_llamada']=='2026-07-28']
df_feedback_pd.head()
# Out:
# Empty DataFrame
# Columns: [COD_CANAL, CANAL, DNI, FECHA_ENVIO, FECHA_GESTION, HORA_GESTION, TELEFONO, ORIGEN_TELEFONO, COD_CAMPANA, COD_TIPO, OFERTA, DNI_ASESOR, fecha_llamada]
# Index: []

# %%
df_feedback_pd.columns
# Out:
# Index(['DNI', 'Fecha_Llamada', 'Hora', 'TELEFONO', 'Tipificacion',
#        'Id_personal', 'Servicio', 'Id_Supervisor', 'Campaña', 'Intentos',
#        'TMO', 'T_espera', 'id_record'],
#       dtype='object')

# %%
df_feedback_pd.shape
# Out:
# (0, 13)

# %%
print(dni_retiro)fecha_llamada
# Out:
# {'45013474', 6815749, 15728648, 48234510, '15859154', '45756975', 15728656, 46137364, 3670045, 20971551, '08097023', '43291041', 1048614, 80216112, '41113500', 28311601, 48234550, '41521319', 21495865, 45613113, 21495869, 28311617, '30414082', 15728710, 25690185, 72351820, 44040269, '48273724', 47186000, 7864402, '47374288', 7864408, '40739553', 9437272, 9961565, '44525729', '70027318', 42467427, 9437286, '73826467', 2621547, 6815859, 25690230, 40370297, '76978248', '41210253', 10485888, '43450544', '08601519', 7864458, 45088906, 7864461, 40370320, '76445465', 21495955, '06751648', 7864468, 40894613, 71303326, '43495125', 9437357, 3670197, '80145930', 3670207, 74973378, 9961669, 42467527, 7864521, 44564689, 15728855, '72943909', 45613271, 45613274, 7864539, 25690331, 45088989, 7340256, 9961703, 40370409, 6815978, 29360368, '00448398', 80216308, 19923190, 7864571, 19923196, '73939756', 3670271, '19898526', 21496065, 41419010, '20102945', 7864588, 46137614, 40894745, 3670297, 40370457, 45089050, 8388894, 47710495, '44273010', '72316258', 21496101, 9961769, '44418559', 15728937, 6291756, 28311851, '16718281', '05225507', '46747044', 6816050, 48234804, '71668110', 7864645, 326, '47501074', '41282256', 21496152, '10750313', 7340385, '08992017', 29360482, 2621801, 374, '47155814', 2621822, 44040581, 45089165, '71512682', '71720340', '44595253', 40370583, 6816152, 40894880, 29360546, 42467750, 21496232, '06417065', '06638437', 41943474, 29360565, 40370616, '45890895', '07891039', 45089217, 29360578, '06202506', 21496263, 47186376, 6816201, 47186375, '72650565', '77217561', 15729125, 25690601, 8389103, '46771771', 15729147, 45613566, 6291967, 7864833, '72630360', '46549870', 27263492, '47045212', 7864848, '76242987', 6816277, 10486293, 7864861, '07254295', 15729187, 9437734, 7864873, '46567137', 7340591, 18874927, 29360690, '46429934', 72352307, 15729212, '21858836', 47186496, 40370754, 45613639, 9962057, '41863890', '02683392', 40895054, '10732536', 598, 40370775, 9962083, 25690723, 44565091, '72743937', 7340649, 44565096, '09528338', '06196873', 9962097, 40370803, 10486391, '48728984', '72548185', '72430273', '45489123', '07577396', '40065911', 7340687, 9437845, 9437847, 72352412, '46089768', 72352418, '43366270', '23807629', 15729321, 6292138, 9962155, 18875052, '19544379', 3670704, '70904510', 5243574, 6816442, 5243582, '42000503', 6816451, 40895181, 10486478, 6292176, 7340753, '44386854', 25690836, 7340757, '41870722', 3670742, 47186643, 9437913, '76506932', 72215119, 9962219, 10486508, '23392140', '42698287', 47710961, '31607124', 72876790, '43063392', 40370943, '44669048', 8913664, '74802257', 40370948, '70478382', '44383556', 30409478, 41943816, 43516681, 9437965, '74862243', '43132255', '00409492', '45582395', '07508440', '18199118', '73147826', 9437979, '09985570', 9962271, 19923743, 17826593, 40895264, 43516704, '44817685', 7865126, 8389416, 3670826, '45148994', '48715522', '25766045', 47186742, '40797665', '45662748', '47659621', 25690943, 10486595, '09380759', 47186755, '07872485', 25690964, 47186773, 7865179, '22757758', 40371049, 44565358, '76208772', 5243779, '42167278', 6816647, 70779793, 29361042, '70047561', 2622356, '25684190', 9962395, 15729564, '45139291', '45250417', 6816669, '31141753', 7865251, 25691044, '16690239', 7340976, '80382395', 9438141, 9962429, 6816704, '76297864', '26611545', '32922746', 5243861, '17537713', 9962455, 9962459, 9962465, '02779357', 8389606, 40371179, 72352755, '10170436', 10486779, 8389629, 9438212, 17826822, '46847131', 19923981, '47723679', 41419795, 42468373, '06095554', 3671066, '10322413', 7865374, 16778271, '25538157', 15729701, 46662694, '42006142', '71409463', 6816810, 40895532, 70255661, 46662705, 15729714, 72352819, '43678586', '48661338', 40371265, 40371267, '21865122', 40371275, '73747348', 7865420, 72352846, 3671123, 9438292, 28312661, '17870971', 42992729, '40632638', 9962594, 43517025, 25691238, '15353598', 19924072, 7865457, 80217202, 25691251, 7865466, '74557202', '70 ...

# %%
# Convertir la columna de fecha
df_feedback_pd["FECHA_INICIO_GESTION_ref"] = pd.to_datetime(
    df_feedback_pd["fecha_llamada"],
    errors="coerce"
)

# Crear una columna auxiliar solo con la fecha
df_feedback_pd["fecha_archivo"] = (
    df_feedback_pd["FECHA_INICIO_GESTION_ref"].dt.date
)

# Eliminar registros cuya fecha no pudo convertirse
df_feedback_pd = df_feedback_pd[
    df_feedback_pd["fecha_archivo"].notna()
]

# Crear la carpeta si no existe
os.makedirs(ruta_csv, exist_ok=True)

# Generar un archivo CSV por cada fecha
for fecha, df_dia in df_feedback_pd.groupby("fecha_archivo"):
    nombre_fecha = fecha.strftime("%Y%m%d")
    nombre_archivo = f"FEEDBACK_TARGET_{nombre_fecha}.csv"
    # nombre_fecha = fecha.strftime("%d_%m_%Y")
    # nombre_archivo = f"FEEDBACK_TARGET_{nombre_fecha}.csv"

    ruta_archivo = os.path.join(
        ruta_csv,
        nombre_archivo
    )

    # Quitar columnas auxiliares antes de exportar
    df_exportar = df_dia.drop(
        columns=[
            "FECHA_INICIO_GESTION_ref",
            "fecha_archivo",
            'fecha_llamada'
        ]
    )

    # Exportar CSV separado por |
    df_exportar.to_csv(
        ruta_archivo,
        sep="|",
        index=False,
        encoding="utf-8-sig",
        lineterminator="\n"
    )

    print(
        f"Archivo generado: {ruta_archivo} "
        f"| filas: {len(df_exportar)}"
    )
# Out:
# Archivo generado: C:\Users\DATA\Documents\datos\05_subir_csv\FEEDBACK_TARGET_20260801.csv | filas: 9942
# Archivo generado: C:\Users\DATA\Documents\datos\05_subir_csv\FEEDBACK_TARGET_20260802.csv | filas: 4350
# Archivo generado: C:\Users\DATA\Documents\datos\05_subir_csv\FEEDBACK_TARGET_20260803.csv | filas: 11224
# Archivo generado: C:\Users\DATA\Documents\datos\05_subir_csv\FEEDBACK_TARGET_20260804.csv | filas: 10975
# Archivo generado: C:\Users\DATA\Documents\datos\05_subir_csv\FEEDBACK_TARGET_20260805.csv | filas: 16656
# Archivo generado: C:\Users\DATA\Documents\datos\05_subir_csv\FEEDBACK_TARGET_20260806.csv | filas: 14508
# Archivo generado: C:\Users\DATA\Documents\datos\05_subir_csv\FEEDBACK_TARGET_20260807.csv | filas: 16722
# Archivo generado: C:\Users\DATA\Documents\datos\05_subir_csv\FEEDBACK_TARGET_20260808.csv | filas: 18954
# Archivo generado: C:\Users\DATA\Documents\datos\05_subir_csv\FEEDBACK_TARGET_20260810.csv | filas: 14592
# Archivo generado: C:\Users\DATA\Documents\datos\05_subir_csv\FEEDBACK_TARGET_20260811.csv | filas: 301
# Archivo generado: C:\Users\DATA\Documents\datos\05_subir_csv\FEEDBACK_TARGET_20260812.csv | filas: 10777
# Archivo generado: C:\Users\DATA\Documents\datos\05_subir_csv\FEEDBACK_TARGET_20260813.csv | filas: 11683
# Archivo generado: C:\Users\DATA\Documents\datos\05_subir_csv\FEEDBACK_TARGET_20260814.csv | filas: 10452
# Archivo generado: C:\Users\DATA\Documents\datos\05_subir_csv\FEEDBACK_TARGET_20260815.csv | filas: 409

# %%
FEEDBACK_TARGET_20260702

# %%
df_formato.show()
# Out:
# +---------+------+--------+-----------+-------------+------------+---------+---------------+-----------+--------+------+----------+-------------+
# |COD_CANAL| CANAL|     DNI|FECHA_ENVIO|FECHA_GESTION|HORA_GESTION| TELEFONO|ORIGEN_TELEFONO|COD_CAMPANA|COD_TIPO|OFERTA|DNI_ASESOR|fecha_llamada|
# +---------+------+--------+-----------+-------------+------------+---------+---------------+-----------+--------+------+----------+-------------+
# |   TAG202|TARGET|00219827|   20260701|     20260704|    04:33:06|976149271|             T1|    SOLODNI|      27| 18000|          |   2026-07-04|
# |   TAG202|TARGET|02837980|   20260701|     20260701|    09:18:55|968913228|             T1|      MUJER|      27|  2200|          |   2026-07-01|
# |   TAG202|TARGET|02838590|   20260701|     20260701|    05:42:49|966575545|             T1|    SOLODNI|      27|  1900|          |   2026-07-01|
# |   TAG202|TARGET|06555251|   20260701|     20260704|    11:16:49|993904077|             T1|      SD PE|      27|  6200|          |   2026-07-04|
# |   TAG202|TARGET|02849351|   20260701|     20260710|    06:06:32|975591063|             T1|    SOLODNI|      27| 13200|          |   2026-07-10|
# |   TAG202|TARGET|00227389|   20260701|     20260706|    15:42:06|912015816|             T1|      MUJER|      27|  7000|          |   2026-07-06|
# |   TAG202|TARGET|06555993|   20260701|     20260710|    08:19:23|952987346|             T1|    SOLODNI|      27|  4000|          |   2026-07-10|
# |   TAG202|TARGET|00218443|   20260701|     20260702|    10:36:08|996760401|             T1|    SOLODNI|      34|  3300|          |   2026-07-02|
# |   TAG202|TARGET|06556164|   20260701|     20260706|    15:55:37|975663461|             T1|    SOLODNI|      27| 23000|          |   2026-07-06|
# |   TAG202|TARGET|06557002|   20260701|     20260709|    15:15:47|941482284|             T1|   SDFCP100|      27| 10800|          |   2026-07-09|
# |   TAG202|TARGET|02839950|   20260701|     20260709|    15:11:28|904866097|             T1|    SOLODNI|      27|  6000|          |   2026-07-09|
# |   TAG202|TARGET|06559527|   20260701|     20260703|    10:27:11|971978719|             T1|    SOLODNI|      34|  8000|          |   2026-07-03|
# |   TAG202|TARGET|00219032|   20260701|     20260706|    07:56:45|959928246|             T1|      MUJER|      27| 23600|          |   2026-07-06|
# |   TAG202|TARGET|00235339|   20260701|     20260703|    11:47:58|989256029|             T1|    SOLODNI|      27|  5000|          |   2026-07-03|
# |   TAG202|TARGET|02715891|   20260701|     20260702|    09:35:54|969574368|             T1|    SOLODNI|      27|  5000|          |   2026-07-02|
# |   TAG202|TARGET|05374911|   20260701|     20260708|    15:16:27|927109822|             T1|    SOLODNI|      27|  7600|          |   2026-07-08|
# |   TAG202|TARGET|02723573|   20260701|     20260701|    08:16:27|933235585|             T1|    SOLODNI|      27|  2000|          |   2026-07-01|
# |   TAG202|TARGET|02849591|   20260701|     20260708|    12:43:47|934906816|             T1|    SOLODNI|      27|  9900|          |   2026-07-08|
# |   TAG202|TARGET|03692685|   20260701|     20260706|    07:32:21|922475261|             T1|      MUJER|      27|  7000|          |   2026-07-06|
# |   TAG202|TARGET|02856821|   20260701|     20260703|    07:15:35|968183577|             T1|    SOLODNI|      27|  3700|          |   2026-07-03|
# +---------+------+--------+-----------+-------------+------------+---------+---------------+-----------+--------+------+----------+-------------+
# only showing top 20 rows

# %%
df = df.withColumn(
    "hora",
    F.date_format(F.col("fecha_hora_llamada"), "HH:mm:ss")
)

# %%
df_formato.show()
# Out:
# +--------+--------------+-----------------+-------------+------------------+-------------------+--------+-------------+----------+-------+----------+--------------------+----------------+----------------+------------+------------+-----------+-------------+-------------------+-------------------+--------+--------+--------------------+--------------------+-----+------------------+----------+------------+---+-------+--------------+---------------+----+
# |     Dni|Numero_Campana|   Nombre_Campana|DNI_Ejecutivo|         Ejecutivo| Fecha_Hora_Llamada|segundos|Fecha_Llamada|Trama_Hora|Estados|Sub_estado|         Descripcion|list_description|       list_name|PHONE_NUMBER|Fecha_Agenda|Comentarios|Codigo_Paleta|             Inicio|                Fin| lead_id| Estado_|         Sub_Estado_|        Descripcion_|Pesos|            Enlace|Fecha_Llam|Hora_Llamada| RH|COD_BCO|Mejor_Telefono|Mejor_Resultado|RHFC|
# +--------+--------------+-----------------+-------------+------------------+-------------------+--------+-------------+----------+-------+----------+--------------------+----------------+----------------+------------+------------+-----------+-------------+-------------------+-------------------+--------+--------+--------------------+--------------------+-----+------------------+----------+------------+---+-------+--------------+---------------+----+
# |00407577|           401|2026-07 BCO ALFIN|         VDAD|Outbound Auto Dial|2026-07-03 04:22:01|       0|   2026-07-03|         4|       |          |                NULL|     provicional|     provicional|   920540009|        NULL|       NULL|           AB|2026-07-03 04:22:01|2026-07-03 04:22:01|    NULL|DISCADOR|NO SE CONCRETO LL...|TELEFONO FUERA DE...|   56|00407577 920540009|2026-07-03|           4|  1|   NULL|             1|              1|   1|
# |00465327|           401|        BOT_ALFIN|         VDAD|Outbound Auto Dial|2026-07-10 10:33:47|       0|   2026-07-10|        10|       |          |                NULL|     provicional|     provicional|   949295591|        NULL|       NULL|           NA|2026-07-10 10:33:47|2026-07-10 10:33:47|    NULL|DISCADOR|NO SE CONCRETO LL...|TELEFONO OCUPADO ...|   86|00465327 949295591|2026-07-10|          10|  1|   NULL|             1|              1| 123|
# |00373932|           401|        BOT_ALFIN|         VDAD|Outbound Auto Dial|2026-07-06 15:52:53|       0|   2026-07-06|        15|       |          |Outbound Pre-Rout...| Base_Prueba_Bot| Base_Prueba_Bot|   938176645|        NULL|       NULL|        PDROP|2026-07-06 15:52:53|2026-07-06 15:52:53|20902655|DISCADOR|REGISTRO SIN GESTION|REGISTRO NO GESTI...|   76|00373932 938176645|2026-07-06|          15|  3|   NULL|             2|              1| 123|
# |00400424|           401|        BOT_ALFIN|         VDAD|Outbound Auto Dial|2026-07-04 09:36:38|       0|   2026-07-04|         9|       |          |Outbound Pre-Rout...|Prueba_bot_alfin|Prueba_bot_alfin|   996408007|        NULL|       NULL|        PDROP|2026-07-04 09:36:38|2026-07-04 09:36:38|20807915|DISCADOR|REGISTRO SIN GESTION|REGISTRO NO GESTI...|   76|00400424 996408007|2026-07-04|           9|  1|   NULL|             2|              1|  13|
# |00400669|           401|2026-07 BCO ALFIN|         VDAD|Outbound Auto Dial|2026-07-09 09:18:24|       0|   2026-07-09|         9|       |          |           Busy Auto|  lista_01_alfin|  lista_01_alfin|   970760141|            |           |           AB|2026-07-09 09:18:24|2026-07-09 09:18:24|25149703|DISCADOR|NO SE CONCRETO LL...|TELEFONO FUERA DE...|   56|00400669 970760141|2026-07-09|           9|  1|   NULL|             1|              1|   1|
# |00402583|           401|        BOT_ALFIN|         VDAD|Outbound Auto Dial|2026-07-04 10:30:12|       0|   2026-07-04|        10|       |          |Outbound Pre-Rout...|Prueba_bot_alfin|Prueba_bot_alfin|   962393044|        NULL|       NULL|        PDROP|2026-07-04 10:30:12|2026-07-04 10:30:12|20802677|DISCADOR|REGISTRO SIN GESTION|REGISTRO NO GESTI...|   76|00402583 962393044|2026-07-04|          10|  1|   NULL|             1|              1|  13|
# |00403959|           401|2026-07 BCO ALFIN|         VDAD|Outbound Auto Dial|2026-07-08 16:10:06|       0|   2026-07-08|        16|       |          |Answering Machine...|  lista_01_alfin|  lista_01_alfin|   995101811|            |           |           AA|2026-07-08 16:10:06|2026-07-08 16:10:06|25067329|DISCADOR|NO SE CONCRETO LL...|TELEFONO OCUPADO ...|   54|00403959 995101811|2026-07-08|          16|  3|   NULL|             1|              1|  23|
# |00404631|           401|2026-07 BCO ALFIN|       PEC139|  Agente BCO Alfin|2026-07-04 12:15:37|      70|   2026-07-04|        12|       |          |                NULL|     provicional|     provicional|   952657726|        NULL|       NULL|           34|2026-07-04 12:15:37|2026-07-04 12:16:47|    NULL|    NULL|                NULL|                NULL| NULL|00404631 952657726|2026-07-04|          12|  2|   NULL|             1|              1|   2|
# |00405033|           401|        BOT_ALFIN|         VDAD|Outbound Auto Dial|2026-07-03 07:29:14|       0|   2026-07-03|         7|       |          |                NULL|     provicional|     provicional|   982225856|        NULL|       NULL|           AB|2026-07-03 07:29:14|2026-07-03 07:29:14|    NULL|DISCADOR|NO SE CONCRETO LL...|TELEFONO FUERA DE...|   56|00405033 982225856|2026-07-03|           7|  1|   NULL|             1|              1|   1|
# |00405164|           401|        BOT_ALFIN|         VDAD|Outbound Auto Dial|2026-07-07 04:33:31|       0|   2026-07-07|         4|       |          |                NULL|     provicional|     provicional|   954630051|        NULL|       NULL|        PDROP|2026-07-07 04:33:31|2026-07-07 04:33:31|    NULL|DISCADOR|REGISTRO SIN GESTION|REGISTRO NO GESTI...|   76|00405164 954630051|2026-07-07|           4|  1|   NULL|             1|              1|   1|
# |00405170|           401|        BOT_ALFIN|         VDAD|Outbound Auto Dial|2026-07-01 05:55:11|       0|   2026-07-01|         5|       |          |                NULL|     provicional|     provicional|   952686282|        NULL|       NULL|        PDROP|2026-07-01 05:55:11|2026-07-01 05:55:11|    NULL|DISCADOR|REGISTRO SIN GESTION|REGISTRO NO GESTI...|   76|00405170 952686282|2026-07-01|           5|  1|   NULL|             1|              1|   1|
# |00405191|           401|        BOT_ALFIN|         VDAD|Outbound Auto Dial|2026-07-09 14:30:53|       0|   2026-07-09|        14|       |          |           Busy Auto|  Base_Alfin_Bot|  Base_Alfin_Bot|   998753692|        NULL|       NULL|           AB|2026-07-09 14:30:53|2026-07-09 14:30:53|20955380|DISCADOR|NO SE CONCRETO LL...|TELEFONO FUERA DE...|   56|00405191 998753692|2026-07-09|          14|  2|   NULL|             2|              1|  23|
# |00405470|           401|        BOT_ALFIN|         VDAD|Outbound Auto Dial|2026-07-10 11:04:50|       0|   2026-07-10|        11|       |          |                NULL|     provicional|     provicional|   949146884|        NULL|       NULL|           AB|2026-07-10 11:04:50|2026-07-10 11:04:50|    NULL|DISCADOR|NO SE CONCRETO LL...|TELEFONO FUERA DE...|   56|00405470 949146884|2026-07-10|          11|  1|   NULL|             1|              1|   1|
# |00405570|           401|        BOT_ALFIN|     49587612|     Bot Bco Alfin|2026-07-09 14:41:18|      12|   2026-07-09|        14|       |          |                NULL|  Base_Alfin_Bot|  Base_Alfin_Bot|   985083173|        NULL|       NULL|           16|2026-07-09 14:41:18|2026-07-09 14:42:02|20952980|    NULL|                NULL|                NULL| NULL|00405570 985083173|2026-07-09|          14|  2|   NULL|             1|              1|   2|
# |00405628|           401|        BOT_ALFIN|         VDAD|Outbound Auto Dial|2026-07-01 08:49:23|       0|   2026-07-01|         8|       |          |                NULL|     provicional|     provicional|   949401141|        NULL|       NULL|           AB|2026-07-01 08:49:23|2026-07-01 08:49:23|    NULL|DISCADOR|NO SE CONCRETO LL...|TELEFONO FUERA DE...|   56|00405628 949401141|2026-07-01|           8|  1|   NULL|             1|              1|   1|
# |00405767|           401|        BOT_ALFIN|         VDAD|Outbound Auto Dial|2026-07-06 15:31:22|       0|   2026-07-06|        15|       |          |Outbound Pre-Rout...| Base_Prueba_Bot| Base_Prueba_Bot|   994294957|        NULL|       NULL|        PDROP|2026-07-06 15:31:22|2026-07-06 15:31:22|20902659|DISCADOR|REGISTRO SIN GESTION|REGISTRO NO GESTI...|   76|00405767 994294957|2026-07-06|          15|  3|   NULL|             2|              1|  13|
# |00405804|           401|        BOT_ALFIN|         VDAD|Outbound Auto Dial|2026-07-03 11:27:56|       0|   2026-07-03|        11|       |          |           Busy Auto|Prueba_bot_alfin|Prueba_bot_alfin|   949869524|        NULL|       NULL|           AB|2026-07-03 11:27:56|2026-07-03 11:27:56|20800801|DISCADOR|NO SE CONCRETO LL...|TELEFONO FUERA DE...|   56|00405804 949869524|2026-07-03|          11|  1|   NULL|             2|              1|   1|
# |00405839|           401|        BOT_ALFIN|         VDAD|Outbound Auto Dial|2026-07-01 05:24:15|       0|   2026-07-01|         5|       |          |                NULL|     provicional|     provicional|   952250911|        NULL|       NULL|           AB|2026-07-01 05:24:15|2026-07-01 05:24:15|    NULL|DISCADOR|NO SE CONCRETO LL...|TELEFONO FUERA DE...|   56|00405839 952250911|2026-07-01|           5|  1|   NULL|             2|              1|   1|
# |00405895|           401|        BOT_ALFIN|         VDAD|Outbound Auto Dial|2026-07-08 07:15:53|       0|   2026-07-08|         7|       |          |                NULL|     provicional|     provicional|   965998777|        NULL|       NULL|           AB|2026-07-08 07:15:53|2026-07-08 07:15:53|    NULL|DISCADOR|NO SE CONCRETO LL...|TELEFONO FUERA DE...|   56|00405895 965998777|2026-07-08|           7|  1|   NULL|             1|              1|   1|
# |00406088|           401|        BOT_ALFIN|         VDAD|Outbound Auto Dial|2026-07-08 08:10:45|       0|   2026-07-08|         8|       |          |                NULL|     provicional|     provicional|   952509892|        NULL|       NULL|        PDROP|2026-07-08 08:10:45|2026-07-08 08:10:45|    NULL|DISCADOR|REGISTRO SIN GESTION|REGISTRO NO GESTI...|   76|00406088 952509892|2026-07-08|           8|  1|   NULL|             2|              1|   1|
# +--------+--------------+-----------------+-------------+------------------+-------------------+--------+-------------+----------+-------+----------+--------------------+----------------+----------------+------------+------------+-----------+-------------+-------------------+-------------------+--------+--------+--------------------+--------------------+-----+------------------+----------+------------+---+-------+--------------+---------------+----+
# only showing top 20 rows

# %%
['Dni', 'Numero_Campana', 'Nombre_Campana', 'DNI_Ejecutivo', 'Ejecutivo', 'Fecha_Hora_Llamada', 'segundos', 'Fecha_Llamada', 'Trama_Hora', 'Estados', 'Sub_estado', 'Descripcion', 'list_description', 'list_name', 'PHONE_NUMBER', 'Fecha_Agenda', 'Comentarios', 'Codigo_Paleta', 'Inicio', 'Fin', 'lead_id', 'Estado_', 'Sub_Estado_', 'Descripcion_', 'Pesos', 'Enlace', 'Fecha_Llam', 'Hora_Llamada', 'RH', 'COD_BCO', 'Mejor_Telefono', 'Mejor_Resultado', 'RHFC']celular

# %%
'
SELECT 
    RTRIM(LTRIM(d.vendor_lead_code)) AS dni_cliente,
    DATE(a.call_date) AS fecha,
    TIME(a.call_date) AS hora,
    a.PHONE_NUMBER AS celular,
    CASE 
        WHEN DNI_Ejecutivo = ''VDAD'' THEN 27 
        ELSE a.status 
    END AS tipificacion,
    ''17'' AS servicio,
    ''30'' AS id_supervisor,
    '''' AS campana,
    ''1'' AS intentos,
    a.length_in_sec AS TMO,
    ''0'' AS T_espera,
    ''TARGET'' AS ID_RECORD,
    CASE 
        WHEN a.user = ''VDAD'' THEN ''99999999'' 
        ELSE ''00000001'' 
    END AS edni,
    CASE 
        WHEN a.user <> ''VDAD'' THEN ''00000001'' 
        ELSE a.user 
    END AS eid
FROM asterisk.vicidial_log a 
LEFT JOIN asterisk.vicidial_list d 
    ON a.lead_id = d.lead_id
LEFT JOIN asterisk.vicidial_campaigns e 
    ON a.campaign_id = e.campaign_id
LEFT JOIN asterisk.vicidial_lists f 
    ON a.list_id = f.list_id
LEFT JOIN asterisk.vicidial_statuses b 
    ON a.status = b.status
LEFT JOIN asterisk.vicidial_users c 
    ON a.user = c.user
WHERE DATE(a.call_date) = ''2026-07-01''
  AND a.campaign_id = ''401''
'

# %%
import sys 
sys.path.append('C:/Users/DATA/Documents/datos/01_script/inicio/funciones')
from funciones import *
from funciones_spark import *
from variables_inicio import *
from utils_sql import *

spark = SparkSession.builder \
    .appName("SparkExample") \
    .master("local[*]") \
    .config('spark.driver.extraClassPath', 'C:/spark/jars/mssql-jdbc-13.2.1.jre11.jar') \
    .config('spark.executor.extraClassPath', 'C:/spark/jars/mssql-jdbc-13.2.1.jre11.jar') \
    .config('spark.executor.memory', '8g') \
    .config('spark.driver.memory', '8g') \
    .getOrCreate()

# %% [markdown]
# ## lista seguimiento

# %%
ruta_archivo = os.path.join(ruta_csv, 'ULTIMO_.csv')
df_seguimiento=cargar_archivo_csv(spark,ruta_archivo,';',True)
print(df_seguimiento.columns)


query = """
    select NUMERO_DOCUMENTO as DNI2
    from DANTALION.dbo.Base_Maestra_ALFIN_BK_Vigente
    """
df_formato=obtener_tabla_sql(spark,query,server_kishin,user_kishin,pwd_kishin,db_kishin)
print(df_formato.columns)
# Out:
# ['DNI0', 'D', 'DNI2', 'NOMBRE', 'CELULAR', 'COD', 'AGENCIA', '_c7', 'MONTO']
# ['DNI2']

# %%
df_seguimiento = df_seguimiento.withColumn(
    "DNI2",
    F.right(
        F.concat(F.lit("00000000"), F.col("DNI2")),
        F.lit(8)
    )
)
df_formato = df_formato.withColumn(
    "DNI2",
    F.right(
        F.concat(F.lit("00000000"), F.col("DNI2")),
        F.lit(8)
    )
)

# %%
append_table_SQL(spark,df_formato,f'ventas_alfin_a',server_zeus,user_zeus,pwd_zeus,'odin')

# %%
df_formato=df_formato.join(df_seguimiento,['DNI2'],'inner')

# %%
df_formato.show()
# Out:
# +--------+--------+----------------+--------------+----------------+-------------------+--------+---------------+------------+--------------+------------+--------------+----------+-----------+-----------------+------------+---------+----------+------+------+------+------+------+------+------+------+--------+-------+-----+----+-------------+-----------+------+----+----------+--------+---------------+---------+----------+--------+---------------+---------+----------+--------+---------------+---------+----------+--------+---------------+---------+------------------+---------+----------------+-------+---------+-------+---------+-------+---------+------------------+-----------------+--------------------+---------+---------------------+-----+---------------+----------+------------+--------+-----------------------+------------+------------+-------------+----+----------+---------+-------------+-------------+---------+---------+---------+----------+---------+---------------+-------------+-------+------------------------+--------------+-------------------+--------------------+------------+-------------+----------+-------------+-------+-----------+------------------+------+---------+----+---------+---------------+-------------+--------+---------+------------+------------------+----+-----+------------+----------+-----------+-----------+-------+------+-------+-----------+-------------+---------------------+-----------------------+----------+-----------------+--------+-------------------+-----+---------+----------------+---------+---------+--------+--------+--------+--------+--------+--------+--------+---------+--------+----------+-----------+--------+---------+---------+---------+----------+--------+----------------+---------------+-------+---------------+------------+--------+-------------+---------+----------+------+----------+--------+-------+------------------+-----------+-------------+------------+--------------------+---------+----------+-----------+------------+-------+-------------+------------+--------------+-------------+--------------+--------------------+------+------+-----------------+-----------------+-----+----+----+--------+------+--------------------+---------+------------------+---------------+-----+-----+
# |    DNI2|TIPO_DOI|NUMERO_DOCUMENTO|       NOMBRES|APELLIDO_PATERNO|   APELLIDO_MATERNO|SUCURSAL|         TIENDA|DEPARTAMENTO|     PROVINCIA|    DISTRITO|FEC_NACIMIENTO|OFERTA_MAX|OFERTA_REEN|Tipo_verificacion|GRUPO_RIESGO|proveedor|      lote|RETIRO|Tasa_1|Tasa_2|Tasa_3|Tasa_4|Tasa_5|Tasa_6|Tasa_7|segmento|Campana|PLAZO| TEM|PROPENSION_IC|Desgravamen| CUOTA|Edad|Oferta_12M|Tasa_12M|Desgravamen_12M|CUOTA_12M|Oferta_18M|Tasa_18M|Desgravamen_18M|CUOTA_18M|Oferta_24M|Tasa_24M|Desgravamen_24M|CUOTA_24M|Oferta_36M|Tasa_36M|Desgravamen_36M|CUOTA_36M|Validador_Telefono|Prioridad|Nombre_prioridad|Deuda_1|Entidad_1|Deuda_2|Entidad_2|Deuda_3|Entidad_3|sucursal_comercial|Agencia_comercial|    Region_comercial|Ubicacion|OfertaMaximaSinSeguro|color|    color_final|PROPENSION|OFERTA_FINAL|GARANTIA|Oferta_Minima_Paperless|RANGO_OFERTA|RANGO_SUELDO|CAPACIDAD_MAX|PEER|PROP_COMER|TIPO_GEST|CLIENTE_NUEVO|   GRUPO_TASA|NUEVOS_3M|NUEVOS_6M|NUEVOS_9M|NUEVOS_12M|NUEVOS_4M|    GRUPO_MONTO|TASA_VS_MONTO|USUARIO|incremento_monto_riesgos|FLG_DEUDA_PLUS|tipo_cliente_riegos|             USER_V3|LEAD_CALIDAD|SEGMENTO_USER|RANGO_EDAD|RANGO_OFERTA2|PERIODO|RETIRO_GEST|MEJOR_TIPIFICACION|STATUS|FECHA_SOL|BASE|RESULTADO|NUM_ENRIQUECIDO|TIPO_CONTACTO|Q_VENTAS|LOCALIDAD|DESEMBOLSADO|MONTO_DESEMBOLSADO| SBI|CRUCE|PREST_PREVIO|ID_CLIENTE|RANGO_EDAD2|Fecha_Envio|TIPO_BD|COD_BD|NOMB_BD|MES_GESTION| TIPO_CLIENTE|GRUPO_TASA_REENGANCHE|SALDO_DIFERENCIAL_REENG|FLAG_REENG|RETIRO_DESEMBOLSO|FRESCURA|flag_deuda_v_oferta|MGNEG|PERFIL_RO|       TIPO_BASE| cl_telf1| cl_telf2|cl_telf3|cl_telf4|cl_telf5|cl_telf6|cl_telf7|cl_telf8|cl_telf9|cl_telf10|cl_movil|cl_celular|cl_telefono|cl_turno|cl_gestor|cl_asesor|cl_accion|cl_gestion|SERVICIO|cl_fecha_gestion|cl_hora_gestion|cl_hits|cl_fecha_llamar|cl_prioridad|cl_orden|cl_predictivo|cl_tiempo|   cl_base|cl_mes|  cl_carga|id_carga|cl_area|fecha_alimentacion|cl_base_ant|cl_accion_ant|cl_fecha_ant|            campania|PROMOCION|PROMOCION2|nombre_base|NumEntidades|p_banco|PERFIL_GLOBAL|    FLG_AAHH|SCORE_TELEFONO|PILOTO_PLAZAS|INTENSIDAD_MAX|              marca1|marca2|marca3|AÑO_DURACION_BASE|MES_DURACION_BASE|FLAT2|REP1|REP2|    DNI0|     D|              NOMBRE|  CELULAR|               COD|        AGENCIA|  _c7|MONTO|
# +--------+--------+----------------+--------------+----------------+-------------------+--------+---------------+------------+--------------+------------+--------------+----------+-----------+-----------------+------------+---------+----------+------+------+------+------+------+------+------+------+--------+-------+-----+----+-------------+-----------+------+----+----------+--------+---------------+---------+----------+--------+---------------+---------+----------+--------+---------------+---------+----------+--------+---------------+---------+------------------+---------+----------------+-------+---------+-------+---------+-------+---------+------------------+-----------------+--------------------+---------+---------------------+-----+---------------+----------+------------+--------+-----------------------+------------+------------+-------------+----+----------+---------+-------------+-------------+---------+---------+---------+----------+---------+---------------+-------------+-------+------------------------+--------------+-------------------+--------------------+------------+-------------+----------+-------------+-------+-----------+------------------+------+---------+----+---------+---------------+-------------+--------+---------+------------+------------------+----+-----+------------+----------+-----------+-----------+-------+------+-------+-----------+-------------+---------------------+-----------------------+----------+-----------------+--------+-------------------+-----+---------+----------------+---------+---------+--------+--------+--------+--------+--------+--------+--------+---------+--------+----------+-----------+--------+---------+---------+---------+----------+--------+----------------+---------------+-------+---------------+------------+--------+-------------+---------+----------+------+----------+--------+-------+------------------+-----------+-------------+------------+--------------------+---------+----------+-----------+------------+-------+-------------+------------+--------------+-------------+--------------+--------------------+------+------+-----------------+-----------------+-----+----+----+--------+------+--------------------+---------+------------------+---------------+-----+-----+
# |06526273|    NULL|        06526273|        SALOME|          SEGURA|             ACUÃ‘A|    NULL|TRUJILLO CENTRO| LA LIBERTAD|      TRUJILLO|    TRUJILLO|          NULL|      5200|       NULL|             NULL|        NULL|     NULL|NO CLIENTE|ACTIVO|  69.0|  67.0|  NULL|  NULL|  NULL|  NULL|  NULL|    NULL| 202607|   36|NULL|            2|       NULL|302.35|  68|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|              NULL|     NULL|            NULL|   NULL|     NULL|   NULL|     NULL|   NULL|     NULL|              NULL|  TRUJILLO CENTRO|        REGION NORTE|     NULL|                 NULL| NULL|AMARILLO OSCURO|      NULL|        NULL|    NULL|                   NULL|   5000-6999|   2000-2500|      358.477|NULL|      NULL|     NULL|         NULL|Mantiene tasa|     NULL|     NULL|     NULL|      NULL|     NULL|Disminuye Monto|         NULL|   NULL|                    NULL|          NULL|       3.NO CLIENTE|   8. Tarjetero Cash|        NULL|         NULL|  60 A MAS|         NULL|   NULL|       NULL|              NULL|  NULL|     NULL|NULL|     NULL|           NULL|         NULL|    NULL|     NULL|        NULL|              NULL|NULL| NULL|        NULL|      NULL|       NULL| 2026-07-01|   NULL|  NULL|   NULL|       NULL|  DEPENDIENTE|                 NULL|                      0|      NULL|             NULL|       4|                  0|    1|     NULL|         Regular|949181320|981713196|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|    NULL|      NULL|       NULL|    NULL|     NULL|     NULL|     NULL|      NULL|      12|            NULL|           NULL|   NULL|           NULL|        NULL|    NULL|         NULL|     NULL|Julio 2026|  NULL|2026-07-01|    NULL|   NULL|              NULL|       NULL|         NULL|        NULL|             SOLODNI|     NULL|      NULL| 2026-07-01|        NULL|   NULL|         NULL|NO EMERGENTE|             2|            0|             8|734265 - TRUJ CENTRO|  NULL|  NULL|             2026|               07|    1|NULL|NULL|00000001|TARGET|SEGURA ACUÃ‘A SALOME|949181320|   TRUJILLO CENTRO|         CENTRO|46209| 5200|
# |06526273|    NULL|        06526273|        SALOME|          SEGURA|             ACUÃ‘A|    NULL|TRUJILLO CENTRO| LA LIBERTAD|      TRUJILLO|    TRUJILLO|          NULL|      5200|       NULL|             NULL|        NULL|     NULL|NO CLIENTE|ACTIVO|  69.0|  67.0|  NULL|  NULL|  NULL|  NULL|  NULL|    NULL| 202607|   36|NULL|            2|       NULL|302.35|  68|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|              NULL|     NULL|            NULL|   NULL|     NULL|   NULL|     NULL|   NULL|     NULL|              NULL|  TRUJILLO CENTRO|        REGION NORTE|     NULL|                 NULL| NULL|AMARILLO OSCURO|      NULL|        NULL|    NULL|                   NULL|   5000-6999|   2000-2500|      358.477|NULL|      NULL|     NULL|         NULL|Mantiene tasa|     NULL|     NULL|     NULL|      NULL|     NULL|Disminuye Monto|         NULL|   NULL|                    NULL|          NULL|       3.NO CLIENTE|   8. Tarjetero Cash|        NULL|         NULL|  60 A MAS|         NULL|   NULL|       NULL|              NULL|  NULL|     NULL|NULL|     NULL|           NULL|         NULL|    NULL|     NULL|        NULL|              NULL|NULL| NULL|        NULL|      NULL|       NULL| 2026-07-01|   NULL|  NULL|   NULL|       NULL|  DEPENDIENTE|                 NULL|                      0|      NULL|             NULL|       4|                  0|    1|     NULL|         Regular|949181320|981713196|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|    NULL|      NULL|       NULL|    NULL|     NULL|     NULL|     NULL|      NULL|      12|            NULL|           NULL|   NULL|           NULL|        NULL|    NULL|         NULL|     NULL|Julio 2026|  NULL|2026-07-01|    NULL|   NULL|              NULL|       NULL|         NULL|        NULL|             SOLODNI|     NULL|      NULL| 2026-07-01|        NULL|   NULL|         NULL|NO EMERGENTE|             2|            0|             8|734265 - TRUJ CENTRO|  NULL|  NULL|             2026|               07|    1|NULL|NULL|77091562|TARGET|SEGURA ACUÃ‘A SALOME|949181320|   TRUJILLO CENTRO|TRUJILLO CENTRO|46205| 5200|
# |02629949|    NULL|        02629949|MARCELO ERADIO|        SERNAQUE|            CABRERA|    NULL|        SULLANA|       PIURA|       SULLANA|MIGUEL CHECA|          NULL|     18000|       NULL|             NULL|        NULL|     NULL|NO CLIENTE|ACTIVO|  68.0|  67.0|  66.0|  61.0|  59.0|  52.0|  NULL|    NULL| 202607|   36|NULL|            2|       NULL|927.25|  76|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|              NULL|     NULL|            NULL|   NULL|     NULL|   NULL|     NULL|   NULL|     NULL|              NULL|          SULLANA|        REGION NORTE|     NULL|                 NULL| NULL| AMARILLO CLARO|      NULL|        NULL|    NULL|                   NULL| 15000-19999|   4000-5000|      1477.55|NULL|      NULL|     NULL|         NULL|   Menor tasa|     NULL|     NULL|     NULL|      NULL|     NULL|   Mejora Monto|         NULL|   NULL|                    NULL|          NULL|       3.NO CLIENTE|1. sunedu & sunarp A|        NULL|         NULL|  60 A MAS|         NULL|   NULL|       NULL|              NULL|  NULL|     NULL|NULL|     NULL|           NULL|         NULL|    NULL|     NULL|        NULL|              NULL|NULL| NULL|        NULL|      NULL|       NULL| 2026-07-01|   NULL|  NULL|   NULL|       NULL|  DEPENDIENTE|                 NULL|                      0|      NULL|             NULL|       4|                  1|    3|     NULL|         Regular|953993651|978851073|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|    NULL|      NULL|       NULL|    NULL|     NULL|     NULL|     NULL|      NULL|      12|            NULL|           NULL|   NULL|           NULL|        NULL|    NULL|         NULL|     NULL|Julio 2026|  NULL|2026-07-01|    NULL|   NULL|              NULL|       NULL|         NULL|        NULL|             SOLODNI|     NULL|      NULL| 2026-07-01|        NULL|   NULL|         NULL|NO EMERGENTE|             1|            0|             8|    734270 - SULLANA|  NULL|  NULL|             2026|               07|    1|NULL|NULL|75976391|TARGET|SERNAQUE CABRERA ...|969452111|  734270 - SULLANA|        SULLANA|46214|18000|
# |02629949|    NULL|        02629949|MARCELO ERADIO|        SERNAQUE|            CABRERA|    NULL|        SULLANA|       PIURA|       SULLANA|MIGUEL CHECA|          NULL|     18000|       NULL|             NULL|        NULL|     NULL|NO CLIENTE|ACTIVO|  68.0|  67.0|  66.0|  61.0|  59.0|  52.0|  NULL|    NULL| 202607|   36|NULL|            2|       NULL|927.25|  76|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|              NULL|     NULL|            NULL|   NULL|     NULL|   NULL|     NULL|   NULL|     NULL|              NULL|          SULLANA|        REGION NORTE|     NULL|                 NULL| NULL| AMARILLO CLARO|      NULL|        NULL|    NULL|                   NULL| 15000-19999|   4000-5000|      1477.55|NULL|      NULL|     NULL|         NULL|   Menor tasa|     NULL|     NULL|     NULL|      NULL|     NULL|   Mejora Monto|         NULL|   NULL|                    NULL|          NULL|       3.NO CLIENTE|1. sunedu & sunarp A|        NULL|         NULL|  60 A MAS|         NULL|   NULL|       NULL|              NULL|  NULL|     NULL|NULL|     NULL|           NULL|         NULL|    NULL|     NULL|        NULL|              NULL|NULL| NULL|        NULL|      NULL|       NULL| 2026-07-01|   NULL|  NULL|   NULL|       NULL|  DEPENDIENTE|                 NULL|                      0|      NULL|             NULL|       4|                  1|    3|     NULL|         Regular|953993651|978851073|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|    NULL|      NULL|       NULL|    NULL|     NULL|     NULL|     NULL|      NULL|      12|            NULL|           NULL|   NULL|           NULL|        NULL|    NULL|         NULL|     NULL|Julio 2026|  NULL|2026-07-01|    NULL|   NULL|              NULL|       NULL|         NULL|        NULL|             SOLODNI|     NULL|      NULL| 2026-07-01|        NULL|   NULL|         NULL|NO EMERGENTE|             1|            0|             8|    734270 - SULLANA|  NULL|  NULL|             2026|               07|    1|NULL|NULL|00000001|TARGET|SERNAQUE CABRERA ...|969452111|           SULLANA|       #¡VALOR!|46208|18000|
# |02629949|    NULL|        02629949|MARCELO ERADIO|        SERNAQUE|            CABRERA|    NULL|        SULLANA|       PIURA|       SULLANA|MIGUEL CHECA|          NULL|     18000|       NULL|             NULL|        NULL|     NULL|NO CLIENTE|ACTIVO|  68.0|  67.0|  66.0|  61.0|  59.0|  52.0|  NULL|    NULL| 202607|   36|NULL|            2|       NULL|927.25|  76|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|              NULL|     NULL|            NULL|   NULL|     NULL|   NULL|     NULL|   NULL|     NULL|              NULL|          SULLANA|        REGION NORTE|     NULL|                 NULL| NULL| AMARILLO CLARO|      NULL|        NULL|    NULL|                   NULL| 15000-19999|   4000-5000|      1477.55|NULL|      NULL|     NULL|         NULL|   Menor tasa|     NULL|     NULL|     NULL|      NULL|     NULL|   Mejora Monto|         NULL|   NULL|                    NULL|          NULL|       3.NO CLIENTE|1. sunedu & sunarp A|        NULL|         NULL|  60 A MAS|         NULL|   NULL|       NULL|              NULL|  NULL|     NULL|NULL|     NULL|           NULL|         NULL|    NULL|     NULL|        NULL|              NULL|NULL| NULL|        NULL|      NULL|       NULL| 2026-07-01|   NULL|  NULL|   NULL|       NULL|  DEPENDIENTE|                 NULL|                      0|      NULL|             NULL|       4|                  1|    3|     NULL|         Regular|953993651|978851073|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|    NULL|      NULL|       NULL|    NULL|     NULL|     NULL|     NULL|      NULL|      12|            NULL|           NULL|   NULL|           NULL|        NULL|    NULL|         NULL|     NULL|Julio 2026|  NULL|2026-07-01|    NULL|   NULL|              NULL|       NULL|         NULL|        NULL|             SOLODNI|     NULL|      NULL| 2026-07-01|        NULL|   NULL|         NULL|NO EMERGENTE|             1|            0|             8|    734270 - SULLANA|  NULL|  NULL|             2026|               07|    1|NULL|NULL|71408476|TARGET|SERNAQUE CABRERA ...|969452111|           SULLANA|        SULLANA|46204|18000|
# |01820516|    NULL|        01820516|        RAFAEL|        UCHARICO|             VARGAS|    NULL|           NULL|        PUNO|       YUNGUYO|     YUNGUYO|          NULL|      8800|       NULL|             NULL|        NULL|     NULL|NO CLIENTE|ACTIVO|  75.0|  74.0|  72.0|  66.0|  NULL|  NULL|  NULL|    NULL| 202607|   36|NULL|            1|       NULL|507.83|  71|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|              NULL|     NULL|            NULL|   NULL|     NULL|   NULL|     NULL|   NULL|     NULL|              NULL|             NULL|                NULL|     NULL|                 NULL| NULL| AMARILLO CLARO|      NULL|        NULL|    NULL|                   NULL|   7000-9999|   1500-2000|      584.271|NULL|      NULL|     NULL|         NULL|         NULL|     NULL|     NULL|     NULL|      NULL|     NULL|           NULL|         NULL|   NULL|                    NULL|          NULL|       3.NO CLIENTE|2. sunedu & sunarp B|        NULL|         NULL|  60 A MAS|         NULL|   NULL|       NULL|              NULL|  NULL|     NULL|NULL|     NULL|           NULL|         NULL|    NULL|     NULL|        NULL|              NULL|NULL| NULL|        NULL|      NULL|       NULL| 2026-07-01|   NULL|  NULL|   NULL|       NULL|  DEPENDIENTE|                 NULL|                      0|      NULL|             NULL|       2|                  1|    2|     NULL|         Regular|958717364|904674086|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|    NULL|      NULL|       NULL|    NULL|     NULL|     NULL|     NULL|      NULL|      12|            NULL|           NULL|   NULL|           NULL|        NULL|    NULL|         NULL|     NULL|Julio 2026|  NULL|2026-07-01|    NULL|   NULL|              NULL|       NULL|         NULL|        NULL|SOLO CON DNI - ZO...|     NULL|      NULL| 2026-07-01|        NULL|   NULL|         NULL|NO EMERGENTE|             1|            0|             8|                NULL|  NULL|  NULL|             2026|               07|    1|NULL|NULL|00000001|TARGET|RAFAEL  UCHARICO ...|958717364|735986 - JULIACA 2|      JULIACA 2|46211| 8800|
# |05360580|    NULL|        05360580|       MARLENE|          PINEDO|             SHUÃ‘A|    NULL|          COMAS|        LIMA|          LIMA|  CARABAYLLO|          NULL|      9900|       NULL|             NULL|        NULL|     NULL|NO CLIENTE|ACTIVO|  63.0|  61.0|  59.0|  57.0|  NULL|  NULL|  NULL|    NULL| 202607|   36|NULL|            1|       NULL|532.04|  50|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|              NULL|     NULL|            NULL|   NULL|     NULL|   NULL|     NULL|   NULL|     NULL|              NULL|            COMAS|   REGION LIMA NORTE|     NULL|                 NULL| NULL|   VERDE OSCURO|      NULL|        NULL|    NULL|                   NULL|   7000-9999|   1500-2000|      610.035|NULL|      NULL|     NULL|         NULL|   Menor tasa|     NULL|     NULL|     NULL|      NULL|     NULL|   Mejora Monto|         NULL|   NULL|                    NULL|          NULL|       3.NO CLIENTE|            7. Peers|        NULL|         NULL|     50-59|         NULL|   NULL|       NULL|              NULL|  NULL|     NULL|NULL|     NULL|           NULL|         NULL|    NULL|     NULL|        NULL|              NULL|NULL| NULL|        NULL|      NULL|       NULL| 2026-07-01|   NULL|  NULL|   NULL|       NULL|INDEPENDIENTE|                 NULL|                      0|      NULL|             NULL|       2|                  0|    1|     NULL|SALDO COMPETIDOR|926595459|986087459|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|    NULL|      NULL|       NULL|    NULL|     NULL|     NULL|     NULL|      NULL|      12|            NULL|           NULL|   NULL|           NULL|        NULL|    NULL|         NULL|     NULL|Julio 2026|  NULL|2026-07-01|    NULL|   NULL|              NULL|       NULL|         NULL|        NULL|               MUJER|     NULL|      NULL| 2026-07-01|        NULL|   NULL|         NULL|NO EMERGENTE|             1|            0|             7|      737883 - COMAS|  NULL|  NULL|             2026|               07|    1|NULL|NULL|00000001|TARGET|PINEDO SHUÃ‘A MAR...|926595459|             COMAS|       #¡VALOR!|46209| 9900|
# |05360580|    NULL|        05360580|       MARLENE|          PINEDO|             SHUÃ‘A|    NULL|          COMAS|        LIMA|          LIMA|  CARABAYLLO|          NULL|      9900|       NULL|             NULL|        NULL|     NULL|NO CLIENTE|ACTIVO|  63.0|  61.0|  59.0|  57.0|  NULL|  NULL|  NULL|    NULL| 202607|   36|NULL|            1|       NULL|532.04|  50|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|              NULL|     NULL|            NULL|   NULL|     NULL|   NULL|     NULL|   NULL|     NULL|              NULL|            COMAS|   REGION LIMA NORTE|     NULL|                 NULL| NULL|   VERDE OSCURO|      NULL|        NULL|    NULL|                   NULL|   7000-9999|   1500-2000|      610.035|NULL|      NULL|     NULL|         NULL|   Menor tasa|     NULL|     NULL|     NULL|      NULL|     NULL|   Mejora Monto|         NULL|   NULL|                    NULL|          NULL|       3.NO CLIENTE|            7. Peers|        NULL|         NULL|     50-59|         NULL|   NULL|       NULL|              NULL|  NULL|     NULL|NULL|     NULL|           NULL|         NULL|    NULL|     NULL|        NULL|              NULL|NULL| NULL|        NULL|      NULL|       NULL| 2026-07-01|   NULL|  NULL|   NULL|       NULL|INDEPENDIENTE|                 NULL|                      0|      NULL|             NULL|       2|                  0|    1|     NULL|SALDO COMPETIDOR|926595459|986087459|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|    NULL|      NULL|       NULL|    NULL|     NULL|     NULL|     NULL|      NULL|      12|            NULL|           NULL|   NULL|           NULL|        NULL|    NULL|         NULL|     NULL|Julio 2026|  NULL|2026-07-01|    NULL|   NULL|              NULL|       NULL|         NULL|        NULL|               MUJER|     NULL|      NULL| 2026-07-01|        NULL|   NULL|         NULL|NO EMERGENTE|             1|            0|             7|      737883 - COMAS|  NULL|  NULL|             2026|               07|    1|NULL|NULL|75416659|TARGET|PINEDO SHUÃ‘A MAR...|926595459|             COMAS|          COMAS|46205| 9900|
# |02678467|    NULL|        02678467|        JAVIER|        IPANAQUE|            AREVALO|    NULL|       CASTILLA|       PIURA|         PIURA|    CASTILLA|          NULL|      8000|       NULL|             NULL|        NULL|     NULL|NO CLIENTE|ACTIVO|  75.0|  73.0|  71.0|  NULL|  NULL|  NULL|  NULL|    NULL| 202607|   36|NULL|            1|       NULL|479.07|  77|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|              NULL|     NULL|            NULL|   NULL|     NULL|   NULL|     NULL|   NULL|     NULL|              NULL|         CASTILLA|        REGION NORTE|     NULL|                 NULL| NULL|   VERDE OSCURO|      NULL|        NULL|    NULL|                   NULL|   7000-9999|   4000-5000|        739.5|NULL|      NULL|     NULL|         NULL|         NULL|     NULL|     NULL|     NULL|      NULL|     NULL|           NULL|         NULL|   NULL|                    NULL|          NULL|       3.NO CLIENTE|  3. MES + PLD Peers|        NULL|         NULL|  60 A MAS|         NULL|   NULL|       NULL|              NULL|  NULL|     NULL|NULL|     NULL|           NULL|         NULL|    NULL|     NULL|        NULL|              NULL|NULL| NULL|        NULL|      NULL|       NULL| 2026-07-01|   NULL|  NULL|   NULL|       NULL|INDEPENDIENTE|                 NULL|                      0|      NULL|             NULL|       0|                  0|    1|     NULL|SALDO COMPETIDOR|969676863|954845022|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|    NULL|      NULL|       NULL|    NULL|     NULL|     NULL|     NULL|      NULL|      12|            NULL|           NULL|   NULL|           NULL|        NULL|    NULL|         NULL|     NULL|Julio 2026|  NULL|2026-07-01|    NULL|   NULL|              NULL|       NULL|         NULL|        NULL|            SDFCP100|     NULL|      NULL| 2026-07-01|        NULL|   NULL|         NULL|NO EMERGENTE|             2|            0|             7|   737490 - CASTILLA|  NULL|  NULL|             2026|               07|    1|NULL|NULL|00000001|TARGET|IPANAQUE AREVALO ...|955555555| 737490 - CASTILLA|       CASTILLA|46211| 8000|
# |01332047|    NULL|        01332047|         NORMA|           APAZA|             AVILES|    NULL|      JULIACA 2|        PUNO|          PUNO|        PUNO|          NULL|     20000|       NULL|             NULL|        NULL|     NULL|NO CLIENTE|ACTIVO|  56.0|  55.0|  54.0|  52.0|  50.0|  46.0|  NULL|    NULL| 202607|   36|NULL|            2|       NULL|976.38|  54|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|              NULL|     NULL|            NULL|   NULL|     NULL|   NULL|     NULL|   NULL|     NULL|              NULL|        JULIACA 2|          REGION SUR|     NULL|                 NULL| NULL|   VERDE OSCURO|      NULL|        NULL|    NULL|                   NULL| 20000-24999|   2500-3000|      1426.02|NULL|      NULL|     NULL|         NULL|   Mayor tasa|     NULL|     NULL|     NULL|      NULL|     NULL| Mantiene Monto|         NULL|   NULL|                    NULL|          NULL|       3.NO CLIENTE|   9. Dependiente BN|        NULL|         NULL|     50-59|         NULL|   NULL|       NULL|              NULL|  NULL|     NULL|NULL|     NULL|           NULL|         NULL|    NULL|     NULL|        NULL|              NULL|NULL| NULL|        NULL|      NULL|       NULL| 2026-07-01|   NULL|  NULL|   NULL|       NULL|  DEPENDIENTE|                 NULL|                      0|      NULL|             NULL|       4|                  1|    3|     NULL|         Regular|913399759|948837063|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|    NULL|      NULL|       NULL|    NULL|     NULL|     NULL|     NULL|      NULL|      12|            NULL|           NULL|   NULL|           NULL|        NULL|    NULL|         NULL|     NULL|Julio 2026|  NULL|2026-07-01|    NULL|   NULL|              NULL|       NULL|         NULL|        NULL|               MUJER|     NULL|      NULL| 2026-07-01|        NULL|   NULL|         NULL|NO EMERGENTE|             1|            0|             8|  735986 - JULIACA 2|  NULL|  NULL|             2026|               07|    1|NULL|NULL|00000001|TARGET|  APAZA AVILES NORMA|913399759|         JULIACA 2|           NULL|46208|20000|
# |01332047|    NULL|        01332047|         NORMA|           APAZA|             AVILES|    NULL|      JULIACA 2|        PUNO|          PUNO|        PUNO|          NULL|     20000|       NULL|             NULL|        NULL|     NULL|NO CLIENTE|ACTIVO|  56.0|  55.0|  54.0|  52.0|  50.0|  46.0|  NULL|    NULL| 202607|   36|NULL|            2|       NULL|976.38|  54|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|              NULL|     NULL|            NULL|   NULL|     NULL|   NULL|     NULL|   NULL|     NULL|              NULL|        JULIACA 2|          REGION SUR|     NULL|                 NULL| NULL|   VERDE OSCURO|      NULL|        NULL|    NULL|                   NULL| 20000-24999|   2500-3000|      1426.02|NULL|      NULL|     NULL|         NULL|   Mayor tasa|     NULL|     NULL|     NULL|      NULL|     NULL| Mantiene Monto|         NULL|   NULL|                    NULL|          NULL|       3.NO CLIENTE|   9. Dependiente BN|        NULL|         NULL|     50-59|         NULL|   NULL|       NULL|              NULL|  NULL|     NULL|NULL|     NULL|           NULL|         NULL|    NULL|     NULL|        NULL|              NULL|NULL| NULL|        NULL|      NULL|       NULL| 2026-07-01|   NULL|  NULL|   NULL|       NULL|  DEPENDIENTE|                 NULL|                      0|      NULL|             NULL|       4|                  1|    3|     NULL|         Regular|913399759|948837063|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|    NULL|      NULL|       NULL|    NULL|     NULL|     NULL|     NULL|      NULL|      12|            NULL|           NULL|   NULL|           NULL|        NULL|    NULL|         NULL|     NULL|Julio 2026|  NULL|2026-07-01|    NULL|   NULL|              NULL|       NULL|         NULL|        NULL|               MUJER|     NULL|      NULL| 2026-07-01|        NULL|   NULL|         NULL|NO EMERGENTE|             1|            0|             8|  735986 - JULIACA 2|  NULL|  NULL|             2026|               07|    1|NULL|NULL|75283477|TARGET|  APAZA AVILES NORMA|913399759|         JULIACA 2|      JULIACA 2|46204|20000|
# |02869844|    NULL|        02869844|        FAUSTO|          YOVERA|              ELIAS|    NULL|       CASTILLA|       PIURA|         PIURA|TAMBO GRANDE|          NULL|      8000|       NULL|             NULL|        NULL|     NULL|NO CLIENTE|ACTIVO|  95.0|  95.0|  89.0|  NULL|  NULL|  NULL|  NULL|    NULL| 202607|   36|NULL|            1|       NULL|540.44|  51|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|              NULL|     NULL|            NULL|   NULL|     NULL|   NULL|     NULL|   NULL|     NULL|              NULL|         CASTILLA|        REGION NORTE|     NULL|                 NULL| NULL| NARANJA OSCURO|      NULL|        NULL|    NULL|                   NULL|   7000-9999|   2500-3000|      680.901|NULL|      NULL|     NULL|         NULL|   Menor tasa|     NULL|     NULL|     NULL|      NULL|     NULL|   Mejora Monto|         NULL|   NULL|                    NULL|          NULL|       3.NO CLIENTE|  3. MES + PLD Peers|        NULL|         NULL|     50-59|         NULL|   NULL|       NULL|              NULL|  NULL|     NULL|NULL|     NULL|           NULL|         NULL|    NULL|     NULL|        NULL|              NULL|NULL| NULL|        NULL|      NULL|       NULL| 2026-07-01|   NULL|  NULL|   NULL|       NULL|     INFORMAL|                 NULL|                      0|      NULL|             NULL|       4|                  1|    0|     NULL|         Regular|968155298|968155568|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|    NULL|      NULL|       NULL|    NULL|     NULL|     NULL|     NULL|      NULL|      12|            NULL|           NULL|   NULL|           NULL|        NULL|    NULL|         NULL|     NULL|Julio 2026|  NULL|2026-07-01|    NULL|   NULL|              NULL|       NULL|         NULL|        NULL|             SOLODNI|     NULL|      NULL| 2026-07-01|        NULL|   NULL|         NULL|   EMERGENTE|             1|            0|             8|   737490 - CASTILLA|  NULL|  NULL|             2026|               07|    1|NULL|NULL|80963564|TARGET| FAUSTO YOVERA ELIAS|968155298| 737490 - CASTILLA|       CASTILLA|46212| 8000|
# |05374911|    NULL|        05374911|      NAPOLEON|       FERNANDEZ|              ALVAN|    NULL|        IQUITOS|      LORETO|        MAYNAS|     IQUITOS|          NULL|      7600|       NULL|             NULL|        NULL|     NULL|NO CLIENTE|ACTIVO|  73.0|  72.0|  68.0|  NULL|  NULL|  NULL|  NULL|    NULL| 202607|   36|NULL|            1|       NULL|445.21|  53|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|              NULL|     NULL|            NULL|   NULL|     NULL|   NULL|     NULL|   NULL|     NULL|              NULL|          IQUITOS|REGION LIMA SUR O...|     NULL|                 NULL| NULL| AMARILLO CLARO|      NULL|        NULL|    NULL|                   NULL|   7000-9999|   2000-2500|      1568.46|NULL|      NULL|     NULL|         NULL|   Mayor tasa|     NULL|     NULL|     NULL|      NULL|     NULL| Mantiene Monto|         NULL|   NULL|                    NULL|          NULL|       3.NO CLIENTE|  3. MES + PLD Peers|        NULL|         NULL|     50-59|         NULL|   NULL|       NULL|              NULL|  NULL|     NULL|NULL|     NULL|           NULL|         NULL|    NULL|     NULL|        NULL|              NULL|NULL| NULL|        NULL|      NULL|       NULL| 2026-07-01|   NULL|  NULL|   NULL|       NULL|INDEPENDIENTE|                 NULL|                      0|      NULL|             NULL|       4|                  1|    1|     NULL|SALDO COMPETIDOR|927109822|994460180|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|    NULL|      NULL|       NULL|    NULL|     NULL|     NULL|     NULL|      NULL|      12|            NULL|           NULL|   NULL|           NULL|        NULL|    NULL|         NULL|     NULL|Julio 2026|  NULL|2026-07-01|    NULL|   NULL|              NULL|       NULL|         NULL|        NULL|             SOLODNI|     NULL|      NULL| 2026-07-01|        NULL|   NULL|         NULL|   EMERGENTE|             1|            0|             7|    733825 - IQUITOS|  NULL|  NULL|             2026|               07|    1|NULL|NULL|00000001|TARGET|  NAPOLEON FERNANDEZ|927109822|  733825 - IQUITOS|        IQUITOS|46212| 7600|
# |03678356|    NULL|        03678356|        BERTHA|        PALACIOS|CARREÃ‘O DE JIMENEZ|    NULL|        SULLANA|       PIURA|       SULLANA|  BELLAVISTA|          NULL|     10900|       NULL|             NULL|        NULL|     NULL|NO CLIENTE|ACTIVO|  67.0|  65.0|  63.0|  61.0|  NULL|  NULL|  NULL|    NULL| 202607|   36|NULL|            1|       NULL|605.08|  63|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|              NULL|     NULL|            NULL|   NULL|     NULL|   NULL|     NULL|   NULL|     NULL|              NULL|          SULLANA|        REGION NORTE|     NULL|                 NULL| NULL|   VERDE OSCURO|      NULL|        NULL|    NULL|                   NULL| 10000-14999|   3000-3500|       678.56|NULL|      NULL|     NULL|         NULL|   Menor tasa|     NULL|     NULL|     NULL|      NULL|     NULL|   Mejora Monto|         NULL|   NULL|                    NULL|          NULL|       3.NO CLIENTE|  3. MES + PLD Peers|        NULL|         NULL|  60 A MAS|         NULL|   NULL|       NULL|              NULL|  NULL|     NULL|NULL|     NULL|           NULL|         NULL|    NULL|     NULL|        NULL|              NULL|NULL| NULL|        NULL|      NULL|       NULL| 2026-07-01|   NULL|  NULL|   NULL|       NULL|     INFORMAL|                 NULL|                      0|      NULL|             NULL|       2|                  0|    3|     NULL|SALDO COMPETIDOR|954965673|954965139|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|    NULL|      NULL|       NULL|    NULL|     NULL|     NULL|     NULL|      NULL|      12|            NULL|           NULL|   NULL|           NULL|        NULL|    NULL|         NULL|     NULL|Julio 2026|  NULL|2026-07-01|    NULL|   NULL|              NULL|       NULL|         NULL|        NULL|               MUJER|     NULL|      NULL| 2026-07-01|        NULL|   NULL|         NULL|NO EMERGENTE|             3|            0|            10|    734270 - SULLANA|  NULL|  NULL|             2026|               07|    1|NULL|NULL|00000001|TARGET|PALACIOS CARREÑO ...|932594389|  734270 - SULLANA|        SULLANA|46211|10900|
# |03830283|    NULL|        03830283|         JESUS|          ZAPATA|         DE LA CRUZ|    NULL|       CASTILLA|       PIURA|        TALARA|    PARIÃ‘AS|          NULL|      6000|       NULL|             NULL|        NULL|     NULL|NO CLIENTE|ACTIVO|  81.0|  77.0|  NULL|  NULL|  NULL|  NULL|  NULL|    NULL| 202607|   36|NULL|            1|       NULL|374.82|  69|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|              NULL|     NULL|            NULL|   NULL|     NULL|   NULL|     NULL|   NULL|     NULL|              NULL|         CASTILLA|        REGION NORTE|     NULL|                 NULL| NULL| NARANJA OSCURO|      NULL|        NULL|    NULL|                   NULL|   5000-6999|   4000-5000|       699.37|NULL|      NULL|     NULL|         NULL|   Mayor tasa|     NULL|     NULL|     NULL|      NULL|     NULL|Disminuye Monto|         NULL|   NULL|                    NULL|          NULL|       3.NO CLIENTE|   8. Tarjetero Cash|        NULL|         NULL|  60 A MAS|         NULL|   NULL|       NULL|              NULL|  NULL|     NULL|NULL|     NULL|           NULL|         NULL|    NULL|     NULL|        NULL|              NULL|NULL| NULL|        NULL|      NULL|       NULL| 2026-07-01|   NULL|  NULL|   NULL|       NULL|     INFORMAL|                 NULL|                      0|      NULL|             NULL|       4|                  0|    0|     NULL|         Regular|941931526|969927172|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|    NULL|      NULL|       NULL|    NULL|     NULL|     NULL|     NULL|      NULL|      12|            NULL|           NULL|   NULL|           NULL|        NULL|    NULL|         NULL|     NULL|Julio 2026|  NULL|2026-07-01|    NULL|   NULL|              NULL|       NULL|         NULL|        NULL|               SD PE|     NULL|      NULL| 2026-07-01|        NULL|   NULL|         NULL|NO EMERGENTE|             1|            0|             8|   737490 - CASTILLA|  NULL|  NULL|             2026|               07|    1|NULL|NULL|00000001|TARGET|ZAPATA DE LA CRUZ...|969927172|          CASTILLA|       #¡VALOR!|46210| 6000|
# |03830283|    NULL|        03830283|         JESUS|          ZAPATA|         DE LA CRUZ|    NULL|       CASTILLA|       PIURA|        TALARA|    PARIÃ‘AS|          NULL|      6000|       NULL|             NULL|        NULL|     NULL|NO CLIENTE|ACTIVO|  81.0|  77.0|  NULL|  NULL|  NULL|  NULL|  NULL|    NULL| 202607|   36|NULL|            1|       NULL|374.82|  69|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|              NULL|     NULL|            NULL|   NULL|     NULL|   NULL|     NULL|   NULL|     NULL|              NULL|         CASTILLA|        REGION NORTE|     NULL|                 NULL| NULL| NARANJA OSCURO|      NULL|        NULL|    NULL|                   NULL|   5000-6999|   4000-5000|       699.37|NULL|      NULL|     NULL|         NULL|   Mayor tasa|     NULL|     NULL|     NULL|      NULL|     NULL|Disminuye Monto|         NULL|   NULL|                    NULL|          NULL|       3.NO CLIENTE|   8. Tarjetero Cash|        NULL|         NULL|  60 A MAS|         NULL|   NULL|       NULL|              NULL|  NULL|     NULL|NULL|     NULL|           NULL|         NULL|    NULL|     NULL|        NULL|              NULL|NULL| NULL|        NULL|      NULL|       NULL| 2026-07-01|   NULL|  NULL|   NULL|       NULL|     INFORMAL|                 NULL|                      0|      NULL|             NULL|       4|                  0|    0|     NULL|         Regular|941931526|969927172|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|    NULL|      NULL|       NULL|    NULL|     NULL|     NULL|     NULL|      NULL|      12|            NULL|           NULL|   NULL|           NULL|        NULL|    NULL|         NULL|     NULL|Julio 2026|  NULL|2026-07-01|    NULL|   NULL|              NULL|       NULL|         NULL|        NULL|               SD PE|     NULL|      NULL| 2026-07-01|        NULL|   NULL|         NULL|NO EMERGENTE|             1|            0|             8|   737490 - CASTILLA|  NULL|  NULL|             2026|               07|    1|NULL|NULL|74879594|TARGET|ZAPATA DE LA CRUZ...|969927172|          CASTILLA|       CASTILLA|46206| 6000|
# |05411983|    NULL|        05411983|   VICTOR HUGO|          LOZANO|           GONZALES|    NULL|       PC TACNA|    MOQUEGUA|MARISCAL NIETO|    MOQUEGUA|          NULL|      7100|       NULL|             NULL|        NULL|     NULL|NO CLIENTE|ACTIVO|  57.0|  55.0|  53.0|  NULL|  NULL|  NULL|  NULL|    NULL| 202607|   36|NULL|            1|       NULL|368.92|  49|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|              NULL|     NULL|            NULL|   NULL|     NULL|   NULL|     NULL|   NULL|     NULL|              NULL|         PC TACNA|          REGION SUR|     NULL|                 NULL| NULL|    VERDE CLARO|      NULL|        NULL|    NULL|                   NULL|   7000-9999|   2000-2500|      432.943|NULL|      NULL|     NULL|         NULL|Mantiene tasa|     NULL|     NULL|     NULL|      NULL|     NULL|   Mejora Monto|         NULL|   NULL|                    NULL|          NULL|       3.NO CLIENTE|  3. MES + PLD Peers|        NULL|         NULL|     40-49|         NULL|   NULL|       NULL|              NULL|  NULL|     NULL|NULL|     NULL|           NULL|         NULL|    NULL|     NULL|        NULL|              NULL|NULL| NULL|        NULL|      NULL|       NULL| 2026-07-01|   NULL|  NULL|   NULL|       NULL|  DEPENDIENTE|                 NULL|                      0|      NULL|             NULL|       4|                  0|    1|     NULL|         Regular|965874121|951182606|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|    NULL|      NULL|       NULL|    NULL|     NULL|     NULL|     NULL|      NULL|      12|            NULL|           NULL|   NULL|           NULL|        NULL|    NULL|         NULL|     NULL|Julio 2026|  NULL|2026-07-01|    NULL|   NULL|              NULL|       NULL|         NULL|        NULL|               SD PE|     NULL|      NULL| 2026-07-01|        NULL|   NULL|         NULL|NO EMERGENTE|             2|            0|             8|   738013 - PC TACNA|  NULL|  NULL|             2026|               07|    1|NULL|NULL|00000001|TARGET|LOZANO GONZALES V...|972768771|          PC TACNA|       #¡VALOR!|46208| 7100|
# |05411983|    NULL|        05411983|   VICTOR HUGO|          LOZANO|           GONZALES|    NULL|       PC TACNA|    MOQUEGUA|MARISCAL NIETO|    MOQUEGUA|          NULL|      7100|       NULL|             NULL|        NULL|     NULL|NO CLIENTE|ACTIVO|  57.0|  55.0|  53.0|  NULL|  NULL|  NULL|  NULL|    NULL| 202607|   36|NULL|            1|       NULL|368.92|  49|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|              NULL|     NULL|            NULL|   NULL|     NULL|   NULL|     NULL|   NULL|     NULL|              NULL|         PC TACNA|          REGION SUR|     NULL|                 NULL| NULL|    VERDE CLARO|      NULL|        NULL|    NULL|                   NULL|   7000-9999|   2000-2500|      432.943|NULL|      NULL|     NULL|         NULL|Mantiene tasa|     NULL|     NULL|     NULL|      NULL|     NULL|   Mejora Monto|         NULL|   NULL|                    NULL|          NULL|       3.NO CLIENTE|  3. MES + PLD Peers|        NULL|         NULL|     40-49|         NULL|   NULL|       NULL|              NULL|  NULL|     NULL|NULL|     NULL|           NULL|         NULL|    NULL|     NULL|        NULL|              NULL|NULL| NULL|        NULL|      NULL|       NULL| 2026-07-01|   NULL|  NULL|   NULL|       NULL|  DEPENDIENTE|                 NULL|                      0|      NULL|             NULL|       4|                  0|    1|     NULL|         Regular|965874121|951182606|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|    NULL|      NULL|       NULL|    NULL|     NULL|     NULL|     NULL|      NULL|      12|            NULL|           NULL|   NULL|           NULL|        NULL|    NULL|         NULL|     NULL|Julio 2026|  NULL|2026-07-01|    NULL|   NULL|              NULL|       NULL|         NULL|        NULL|               SD PE|     NULL|      NULL| 2026-07-01|        NULL|   NULL|         NULL|NO EMERGENTE|             2|            0|             8|   738013 - PC TACNA|  NULL|  NULL|             2026|               07|    1|NULL|NULL|77091562|TARGET|LOZANO GONZALES V...|972768771|          PC TACNA|       PC TACNA|46204| 7100|
# |05617443|    NULL|        05617443|   OLGA ISABEL|         TRIGOSO|            VASQUEZ|    NULL|     SAN MIGUEL|        LIMA|          LIMA|  SAN MIGUEL|          NULL|     16000|       NULL|             NULL|        NULL|     NULL|NO CLIENTE|ACTIVO|  73.0|  72.0|  71.0|  64.0|  63.0|  56.0|  NULL|    NULL| 202607|   36|NULL|            2|       NULL|852.76|  52|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|              NULL|     NULL|            NULL|   NULL|     NULL|   NULL|     NULL|   NULL|     NULL|              NULL|       SAN MIGUEL|  REGION LIMA CENTRO|     NULL|                 NULL| NULL|AMARILLO OSCURO|      NULL|        NULL|    NULL|                   NULL| 15000-19999|   3000-3500|       1159.4|NULL|      NULL|     NULL|         NULL|   Mayor tasa|     NULL|     NULL|     NULL|      NULL|     NULL| Mantiene Monto|         NULL|   NULL|                    NULL|          NULL|       3.NO CLIENTE|11. Dependiente B...|        NULL|         NULL|     50-59|         NULL|   NULL|       NULL|              NULL|  NULL|     NULL|NULL|     NULL|           NULL|         NULL|    NULL|     NULL|        NULL|              NULL|NULL| NULL|        NULL|      NULL|       NULL| 2026-07-01|   NULL|  NULL|   NULL|       NULL|  DEPENDIENTE|                 NULL|                      0|      NULL|             NULL|       4|                  1|    4|     NULL|         Regular|956819749|973822456|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|    NULL|      NULL|       NULL|    NULL|     NULL|     NULL|     NULL|      NULL|      12|            NULL|           NULL|   NULL|           NULL|        NULL|    NULL|         NULL|     NULL|Julio 2026|  NULL|2026-07-01|    NULL|   NULL|              NULL|       NULL|         NULL|        NULL|             SOLODNI|     NULL|      NULL| 2026-07-01|        NULL|   NULL|         NULL|NO EMERGENTE|             1|            0|             5| 739483 - SAN MIGUEL|  NULL|  NULL|             2026|               07|    1|NULL|NULL|00000001|TARGET|TRIGOSO VASQUEZ O...|956819749|        SAN MIGUEL|              L|46210|16000|
# |05617443|    NULL|        05617443|   OLGA ISABEL|         TRIGOSO|            VASQUEZ|    NULL|     SAN MIGUEL|        LIMA|          LIMA|  SAN MIGUEL|          NULL|     16000|       NULL|             NULL|        NULL|     NULL|NO CLIENTE|ACTIVO|  73.0|  72.0|  71.0|  64.0|  63.0|  56.0|  NULL|    NULL| 202607|   36|NULL|            2|       NULL|852.76|  52|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|              NULL|     NULL|            NULL|   NULL|     NULL|   NULL|     NULL|   NULL|     NULL|              NULL|       SAN MIGUEL|  REGION LIMA CENTRO|     NULL|                 NULL| NULL|AMARILLO OSCURO|      NULL|        NULL|    NULL|                   NULL| 15000-19999|   3000-3500|       1159.4|NULL|      NULL|     NULL|         NULL|   Mayor tasa|     NULL|     NULL|     NULL|      NULL|     NULL| Mantiene Monto|         NULL|   NULL|                    NULL|          NULL|       3.NO CLIENTE|11. Dependiente B...|        NULL|         NULL|     50-59|         NULL|   NULL|       NULL|              NULL|  NULL|     NULL|NULL|     NULL|           NULL|         NULL|    NULL|     NULL|        NULL|              NULL|NULL| NULL|        NULL|      NULL|       NULL| 2026-07-01|   NULL|  NULL|   NULL|       NULL|  DEPENDIENTE|                 NULL|                      0|      NULL|             NULL|       4|                  1|    4|     NULL|         Regular|956819749|973822456|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|    NULL|      NULL|       NULL|    NULL|     NULL|     NULL|     NULL|      NULL|      12|            NULL|           NULL|   NULL|           NULL|        NULL|    NULL|         NULL|     NULL|Julio 2026|  NULL|2026-07-01|    NULL|   NULL|              NULL|       NULL|         NULL|        NULL|             SOLODNI|     NULL|      NULL| 2026-07-01|        NULL|   NULL|         NULL|NO EMERGENTE|             1|            0|             5| 739483 - SAN MIGUEL|  NULL|  NULL|             2026|               07|    1|NULL|NULL|75416659|TARGET|TRIGOSO VASQUEZ O...|956819749|        SAN MIGUEL|     SAN MIGUEL|46206|16000|
# +--------+--------+----------------+--------------+----------------+-------------------+--------+---------------+------------+--------------+------------+--------------+----------+-----------+-----------------+------------+---------+----------+------+------+------+------+------+------+------+------+--------+-------+-----+----+-------------+-----------+------+----+----------+--------+---------------+---------+----------+--------+---------------+---------+----------+--------+---------------+---------+----------+--------+---------------+---------+------------------+---------+----------------+-------+---------+-------+---------+-------+---------+------------------+-----------------+--------------------+---------+---------------------+-----+---------------+----------+------------+--------+-----------------------+------------+------------+-------------+----+----------+---------+-------------+-------------+---------+---------+---------+----------+---------+---------------+-------------+-------+------------------------+--------------+-------------------+--------------------+------------+-------------+----------+-------------+-------+-----------+------------------+------+---------+----+---------+---------------+-------------+--------+---------+------------+------------------+----+-----+------------+----------+-----------+-----------+-------+------+-------+-----------+-------------+---------------------+-----------------------+----------+-----------------+--------+-------------------+-----+---------+----------------+---------+---------+--------+--------+--------+--------+--------+--------+--------+---------+--------+----------+-----------+--------+---------+---------+---------+----------+--------+----------------+---------------+-------+---------------+------------+--------+-------------+---------+----------+------+----------+--------+-------+------------------+-----------+-------------+------------+--------------------+---------+----------+-----------+------------+-------+-------------+------------+--------------+-------------+--------------+--------------------+------+------+-----------------+-----------------+-----+----+----+--------+------+--------------------+---------+------------------+---------------+-----+-----+
# only showing top 20 rows

# %%
# df_seguimiento = df_seguimiento.withColumn(
#     "DNI",
#     F.date_format(
#         F.to_date(F.col("DNI"), "d/MM/yyyy"),
#         "yyyy-MM-dd"
#     )
# )
df_seguimiento = df_seguimiento.withColumn(
    "DNI",
    F.right(
        F.concat(F.lit("00000000"), F.col("DNI")),
        F.lit(8)
    )
)
df_seguimiento=df_seguimiento.join(df_formato,['DNI'],'left')

df_seguimiento=df_seguimiento.withColumn('CLIENTE',when(F.col('CLIENTE').isNull(),F.col('NOMBRES')).otherwise(F.col('CLIENTE')))
df_seguimiento=df_seguimiento.withColumnRenamed('DNI','vendor_lead_code')
df_seguimiento=df_seguimiento.withColumnRenamed('CLIENTE','address1')
df_seguimiento=df_seguimiento.withColumnRenamed('TELEFONO','phone_number')
df_seguimiento=df_seguimiento.withColumnRenamed('PLAZA','email')
df_seguimiento=df_seguimiento.withColumnRenamed('MONTO','comments')
df_seguimiento=df_seguimiento.select('vendor_lead_code','address1','phone_number','email','comments')

df_list_filtrada = df_seguimiento.toPandas()
ruta_archivo = os.path.join(ruta_csv, 'alfin_seguimiento.xlsx')
df_list_filtrada.to_excel(ruta_archivo, index=False)

# %% [markdown]
# ## lista BOT

# %%
import sys 
sys.path.append('C:/Users/DATA/Documents/datos/01_script/inicio/funciones')
from funciones import *
from funciones_spark import *
from variables_inicio import *
from utils_sql import *

spark = SparkSession.builder \
    .appName("SparkExample") \
    .master("local[*]") \
    .config('spark.driver.extraClassPath', 'C:/spark/jars/mssql-jdbc-13.2.1.jre11.jar') \
    .config('spark.executor.extraClassPath', 'C:/spark/jars/mssql-jdbc-13.2.1.jre11.jar') \
    .config('spark.executor.memory', '8g') \
    .config('spark.driver.memory', '8g') \
    .getOrCreate()

# %%
# filename='BASE_TARGET_20260701_alfin.csv'
# df_base=cargar_archivo_csv(spark,filename,';',True)

filename='ULTIMO.csv'
agendas_01=cargar_archivo_csv(spark,filename,';',True)
agendas_01.columns  
filename='lista_01.csv'
df_validar_01=cargar_archivo_csv(spark,filename,';',True)
filename='lista_02.csv'
df_validar_02=cargar_archivo_csv(spark,filename,';',True)
# filename='LISTA_ALFIN_1.csv'
# df_validar_03=cargar_archivo_csv(spark,filename,';',True)
# filename='LISTA_ALFIN_2.csv'
# df_validar_04=cargar_archivo_csv(spark,filename,';',True)

df_validar=df_validar_01.unionByName(df_validar_02)

print(agendas_01.columns)
print(df_validar.columns)
# Out:
# ['DNI', 'NOMBRES', 'CELULAR', 'COD', 'AGENCIA', 'FECHA', 'MONTO']
# ['DNI', 'COLOR_FINAL', 'COD_USER_V3', 'USER_V3', 'PERFIL_RO', 'campaña', 'OFERTA_MAX', 'PLAZO', 'CAPACIDAD_MAX', 'FRESCURA', 'rango_deuda', 'numentidades', 'TOTAL_A_LIQUIDAR', 'TASA_CREDITO_ANTERIOR', 'TASA_1', 'TASA_2', 'TASA_3', 'TASA_4', 'TASA_5', 'TASA_6', 'TASA_7', 'MGNEG', 'MARCA_PD', 'AUTORIZACION_DATOS', 'FLAG_DEUDA_V_OFERTA', 'GRUPO_TASA', 'TIPO_BASE', 'PROPENSION_DISTRIBUCION', 'OFERTA_SS', 'TASA_1_SS', 'TASA_2_SS', 'TASA_3_SS', 'TASA_4_SS', 'TASA_5_SS', 'TASA_6_SS', 'TASA_7_SS', 'ALERTA_MAQUETA', 'FEN', 'PERFIL_ESPECIAL']

# %%
agendas_01=agendas_01.join(df_validar,['DNI'],'inner')

# %%
agendas_01.join(df_validar,['DNI'],'inner').count()
# Out:
# 2469

# %%
# agendas_01=agendas_01.filter(F.col('PROPENSION_DISTRIBUCION').isin('1','2'))
agendas_01.groupBy('PROPENSION_DISTRIBUCION') \
    .count() \
    .orderBy('PROPENSION_DISTRIBUCION') \
    .show(30)
# Out:
# +-----------------------+-----+
# |PROPENSION_DISTRIBUCION|count|
# +-----------------------+-----+
# |                      1| 1135|
# |                      2| 1046|
# |                      3|   55|
# |                      4|   50|
# |                      5|   70|
# |                      6|  113|
# +-----------------------+-----+

# %%
agendas_01=agendas_01.filter(F.col('PROPENSION_DISTRIBUCION').isin('1'))

# %%
agendas_01 = agendas_01.withColumn(
    "rango_OFERTA",   
    F.when(F.col("OFERTA_MAX").cast("int").isNull(), "SIN DATO")
     .when(F.col("OFERTA_MAX").cast("int") < 2500,  "00.[0 - 2,500)")
     .when(F.col("OFERTA_MAX").cast("int") < 5000,  "01.[2,500 - 5,000)")
     .when(F.col("OFERTA_MAX").cast("int") < 7500,  "02.[5,000 - 7,500)")
     .when(F.col("OFERTA_MAX").cast("int") < 10000, "03.[7,500 - 10,000)")
     .when(F.col("OFERTA_MAX").cast("int") < 12500, "04.[10,000 - 12,500)")
     .when(F.col("OFERTA_MAX").cast("int") < 15000, "05.[12,500 - 15,000)")
     .when(F.col("OFERTA_MAX").cast("int") < 17500, "06.[15,000 - 17,500)")
     .when(F.col("OFERTA_MAX").cast("int") < 20000, "07.[17,500 - 20,000)")
     .when(F.col("OFERTA_MAX").cast("int") < 22500, "08.[20,000 - 22,500)")
     .when(F.col("OFERTA_MAX").cast("int") < 25000, "09.[22,500 - 25,000)")
     .when(F.col("OFERTA_MAX").cast("int") < 27500, "10.[25,000 - 27,500)")
     .otherwise("11.[27,500 A MÁS]")
)

# %%
agendas_01=agendas_01.filter(F.col('OFERTA_MAX')>5000)
agendas_01.groupBy('RANGO_OFERTA') \
    .count() \
    .orderBy('RANGO_OFERTA') \
    .show(30)
# Out:
# +--------------------+-----+
# |        RANGO_OFERTA|count|
# +--------------------+-----+
# |  02.[5,000 - 7,500)|  158|
# | 03.[7,500 - 10,000)|   92|
# |04.[10,000 - 12,500)|  103|
# |05.[12,500 - 15,000)|   73|
# |06.[15,000 - 17,500)|   43|
# |07.[17,500 - 20,000)|   30|
# |08.[20,000 - 22,500)|   21|
# |09.[22,500 - 25,000)|   10|
# |10.[25,000 - 27,500)|    3|
# +--------------------+-----+

# %%
agendas_01=agendas_01.filter(F.col('FRESCURA').isin('1','4'))

# %%
# query = """
#     select *
#     from DANTALION.dbo.Base_Maestra_ALFIN_BK_Vigente
#     where (cl_telf1 is not null and cl_telf1<>0) 
#     and cl_base='julio 2026'
#     and OFERTA_MAX>=5000
#     """
# df_formato=obtener_tabla_sql(spark,query,server_kishin,user_kishin,pwd_kishin,db_kishin)


query = """
    select NUMERO_DOCUMENTO,cl_telf1 as [PHONE NUMBER],NOMBRES,APELLIDO_PATERNO,APELLIDO_MATERNO
    from DANTALION.dbo.Base_Maestra_ALFIN_BK_Vigente
    where (cl_telf1 is not null and cl_telf1<>0) 
    and cl_base='julio 2026'
    and OFERTA_MAX>=5000
    """
df_dni_telf=obtener_tabla_sql(spark,query,server_kishin,user_kishin,pwd_kishin,db_kishin)
query = """
    select *
    from maeba.[ADM_OBJ_TG].[tGestionMesAlfin]
    """
df_maestra=obtener_tabla_sql(spark,query,server_zeus,user_zeus,pwd_zeus,db_zeus)

df_formato=df_maestra.join(df_dni_telf,['NUMERO_DOCUMENTO'],'inner')

# %%
df_formato=df_formato.withColumnRenamed('NUMERO_DOCUMENTO','VENDOR LEAD CODE')
# df_formato=df_formato.withColumnRenamed('cl_telf1','PHONE NUMBER')
df_formato=df_formato.withColumnRenamed('Agencia_comercial','TIENDA_CERCANA_LIMPIA')
df_formato=df_formato.withColumn('campana',F.lit('401'))
df_formato=df_formato.withColumnRenamed('COLOR_FINAL','TIENDA_2_DIRECCION')
df_formato=df_formato.withColumnRenamed('OFERTA_MAX','OFERTA_MAX_TEXTO')
df_formato=df_formato.withColumnRenamed('MARCA1','AGENCIA')
df_formato = df_formato.withColumn(
    "ADDRESS1",
    F.concat_ws(
        " ",
        F.col("NOMBRES"),
        F.col("APELLIDO_PATERNO"),
        F.col("APELLIDO_MATERNO")
    )
)
print(df_formato.columns)
# print(agendas_01.columns)
# Out:
# ['VENDOR LEAD CODE', 'NRG', 'Dni', 'TIPO_GESTION', 'GESTION', 'SUBGESTION', 'TIPO_GESTION_hum', 'GESTION_hum', 'SUBGESTION_hum', 'TIPO_GESTION_bot', 'GESTION_bot', 'SUBGESTION_bot', 'TIPO', 'RECORRIDO', 'RECORRIDO_hum', 'RECORRIDO_bot', 'CET', 'CET_hum', 'CET_bot', 'CONT_GEN', 'CONT_GEN_hum', 'CONT_GEN_bot', 'Hora_Llamada', 'Mejor_Telefono', 'TELEFONO', 'FECHA_LLAMADA', 'DIA', 'Ejecutivo', 'RHFC', 'SUPERVISOR', 'segundos', 'AGENDADOS', 'AGENDADOS_hum', 'AGENDADOS_bot', 'SOLO FH1', 'SOLO FH2', 'SOLO FH3', 'DOBLE FH', 'TRIPLE FH', 'NUMXDNI', 'Estado', 'CntEstado', 'MntOferta', 'CNTVTAS', 'NUM_DIA_HABIL', 'Semana_Mes', 'tMontoDesem', 'tMontoDesemFugas', 'CNT_LLAMADAS', 'CNT_LLAMADAS_hum', 'CNT_LLAMADAS_bot', 'AÑO_DURACION_BASE', 'MES_DURACION_BASE', 'FECHA_ENVIO', 'SERVICIO', 'RETIRO', 'REP1', 'REP2', 'FLG_SIN_ENR', 'tMesGestion', 'DESCRIPCION', 'DESCRIPCION2', 'llave', 'DEPARTAMENTO', 'DISTRITO', 'PROPENSION_IC', 'CUOTA', 'TIENDA_CERCANA_LIMPIA', 'Region_comercial', 'TIENDA_2_DIRECCION', 'GRUPO_TASA', 'GRUPO_MONTO', 'tipo_cliente_riegos', 'USER_V3', 'TIPO_CLIENTE', 'FRESCURA', 'TIPO_BASE', 'campania', 'FLG_AAHH', 'INTENSIDAD_MAX', 'lote', 'REGION', 'RANGO_EDAD', 'RANGO_OFERTA', 'RANGO_TASA', 'TIPO_LOTE', 'TIPO_TELF', 'PHONE NUMBER', 'NOMBRES', 'APELLIDO_PATERNO', 'APELLIDO_MATERNO', 'campana', 'ADDRESS1']

# %%
START TRANSACTION;

-- =========================================================================
-- PASO 1: ALIMENTAR VICIDIAL_LIST (Mapeo Nativo de 14 Campos Operativos)
-- =========================================================================
INSERT INTO asterisk.vicidial_list 
    (
        phone_number, vendor_lead_code, list_id, status, gmt_offset_now, 
        title, first_name, last_name, address1, address2, address3, 
        city, province, email, security_phrase, comments, entry_date, called_since_last_reset
    )
SELECT 
    phone_num, vendor_code, list_id, 'NEW', '0.00', 
    title, first_name, last_name, add1, add2, add3, 
    city, prov, email, sec_phrase, comms, NOW(), 'N'
FROM asterisk.tmp_carga_manual_bot
WHERE procesado = 'N';

-- =========================================================================
-- PASO 2: ALIMENTAR COLLABORIX_LEADS (Cruce Relacional Automatizado)
-- =========================================================================
INSERT INTO asterisk.collaborix_leads 
    (
        lead_id, dni, nombre, nombre_corto, campana, 
        oferta_max_texto, direccion_limpia, tienda_cercana_limpia, 
        tienda_2_nombre, tienda_2_direccion, tienda_3_nombre, tienda_3_direccion, 
        tratamiento, fecha_carga, codAgencia, perfil
    )
SELECT 
    v.lead_id, 
    t.vendor_code, 
    t.add1, -- Contiene el Nombre Completo original
    -- Extrae la primera palabra antes del primer espacio de forma limpia
    SUBSTRING_INDEX(t.add1, ' ', 1),
    '401', -- ID de Campaña por defecto para el Flujo Bot
    t.oferta_max, 
    t.dir_limpia, 
    t.tienda_cercana, 
    t.tienda_2_nom, 
    t.tienda_2_dir, 
    t.tienda_3_nom, 
    t.tienda_3_dir, 
    t.tratamiento, 
    NOW(), 
    t.agencia, 
    'NUEVO'
FROM asterisk.vicidial_list v
INNER JOIN asterisk.tmp_carga_manual_bot t 
    ON v.vendor_lead_code = t.vendor_code AND v.list_id = t.list_id
WHERE t.procesado = 'N'
ON DUPLICATE KEY UPDATE dni = VALUES(dni);

-- =========================================================================
-- PASO 3: CIERRE DE COLA MANUAL
-- =========================================================================
UPDATE asterisk.tmp_carga_manual_bot 
SET procesado = 'Y' 
WHERE procesado = 'N';

COMMIT;

# %%
['VENDOR LEAD CODE', 'NRG', 'Dni', 'TIPO_GESTION', 'GESTION', 'SUBGESTION', 'TIPO_GESTION_hum', 'GESTION_hum', 'SUBGESTION_hum', 'TIPO_GESTION_bot', 'GESTION_bot', 'SUBGESTION_bot', 'TIPO', 'RECORRIDO', 'RECORRIDO_hum', 'RECORRIDO_bot', 'CET', 'CET_hum', 'CET_bot', 'CONT_GEN', 'CONT_GEN_hum', 'CONT_GEN_bot', 'Hora_Llamada', 'Mejor_Telefono', 'TELEFONO', 'FECHA_LLAMADA', 'DIA', 'Ejecutivo', 'RHFC', 'SUPERVISOR', 'segundos', 'AGENDADOS', 'AGENDADOS_hum', 'AGENDADOS_bot', 'SOLO FH1', 'SOLO FH2', 'SOLO FH3', 'DOBLE FH', 'TRIPLE FH', 'NUMXDNI', 'Estado', 'CntEstado', 'MntOferta', 'CNTVTAS', 'NUM_DIA_HABIL', 'Semana_Mes', 'tMontoDesem', 'tMontoDesemFugas', 'CNT_LLAMADAS', 'CNT_LLAMADAS_hum', 'CNT_LLAMADAS_bot', 'AÑO_DURACION_BASE', 'MES_DURACION_BASE', 'FECHA_ENVIO', 'SERVICIO', 'RETIRO', 'REP1', 'REP2', 'FLG_SIN_ENR', 'tMesGestion', 'DESCRIPCION', 'DESCRIPCION2', 'llave', 'DEPARTAMENTO', 'DISTRITO', 'PROPENSION_IC', 'CUOTA', 'TIENDA_CERCANA_LIMPIA', 'Region_comercial', 'TIENDA_2_DIRECCION', 'GRUPO_TASA', 'GRUPO_MONTO', 'tipo_cliente_riegos', 'USER_V3', 'TIPO_CLIENTE', 'FRESCURA', 'TIPO_BASE', 'campania', 'FLG_AAHH', 'INTENSIDAD_MAX', 'lote', 'REGION', 'RANGO_EDAD', 'RANGO_OFERTA', 'RANGO_TASA', 'TIPO_LOTE', 'TIPO_TELF', 'PHONE NUMBER', 'NOMBRES', 'APELLIDO_PATERNO', 'APELLIDO_MATERNO', 'campana', 'ADDRESS1']per

# %%
# grupo_tasa=['None', '', '', '', '', ]
# agencia_comercial=[ 'SAN MIGUEL', 'MIRAFLORES']

df_filtrado = df_formato.filter(
    # (F.col('propension_ic').isin('1','2','3'))&
    # (F.col('proveedor').isin(['INVENTARIO TARGET 2', 'CET TARGET 2', 'CET TARGET 0', 'INVENTARIO TARGET 1', 'INVENTARIO TARGET 0', ]))&
    # (F.col('user_v3').isin(user_v3))&

    (F.col('RECORRIDO').isin('0'))&
    # (
    (F.col('PROPENSION_IC').isin('1','2'))&
    (F.col('frescura').isin('4'))&
    # )
    (F.col('USER_V3').isin('7. Peers','4. MES + PLD No Peers','3. MES + PLD Peers'))&
    (F.col('TIPO_CLIENTE').isin('INDEPENDIENTE'))&
    (F.col('RETIRO')=='ACTIVO')  # retiro

)



print(df_filtrado.count())
print(df_filtrado.columns)
# Out:
# 9722
# ['VENDOR LEAD CODE', 'NRG', 'Dni', 'TIPO_GESTION', 'GESTION', 'SUBGESTION', 'TIPO_GESTION_hum', 'GESTION_hum', 'SUBGESTION_hum', 'TIPO_GESTION_bot', 'GESTION_bot', 'SUBGESTION_bot', 'TIPO', 'RECORRIDO', 'RECORRIDO_hum', 'RECORRIDO_bot', 'CET', 'CET_hum', 'CET_bot', 'CONT_GEN', 'CONT_GEN_hum', 'CONT_GEN_bot', 'Hora_Llamada', 'Mejor_Telefono', 'TELEFONO', 'FECHA_LLAMADA', 'DIA', 'Ejecutivo', 'RHFC', 'SUPERVISOR', 'segundos', 'AGENDADOS', 'AGENDADOS_hum', 'AGENDADOS_bot', 'SOLO FH1', 'SOLO FH2', 'SOLO FH3', 'DOBLE FH', 'TRIPLE FH', 'NUMXDNI', 'Estado', 'CntEstado', 'MntOferta', 'CNTVTAS', 'NUM_DIA_HABIL', 'Semana_Mes', 'tMontoDesem', 'tMontoDesemFugas', 'CNT_LLAMADAS', 'CNT_LLAMADAS_hum', 'CNT_LLAMADAS_bot', 'AÑO_DURACION_BASE', 'MES_DURACION_BASE', 'FECHA_ENVIO', 'SERVICIO', 'RETIRO', 'REP1', 'REP2', 'FLG_SIN_ENR', 'tMesGestion', 'DESCRIPCION', 'DESCRIPCION2', 'llave', 'DEPARTAMENTO', 'DISTRITO', 'PROPENSION_IC', 'CUOTA', 'TIENDA_CERCANA_LIMPIA', 'Region_comercial', 'TIENDA_2_DIRECCION', 'GRUPO_TASA', 'GRUPO_MONTO', 'tipo_cliente_riegos', 'USER_V3', 'TIPO_CLIENTE', 'FRESCURA', 'TIPO_BASE', 'campania', 'FLG_AAHH', 'INTENSIDAD_MAX', 'lote', 'REGION', 'RANGO_EDAD', 'RANGO_OFERTA', 'RANGO_TASA', 'TIPO_LOTE', 'TIPO_TELF', 'PHONE NUMBER', 'NOMBRES', 'APELLIDO_PATERNO', 'APELLIDO_MATERNO', 'campana', 'ADDRESS1']

# %%
['VENDOR LEAD CODE', 'NRG', 'Dni', 'TIPO_GESTION', 'GESTION', 'SUBGESTION', 'TIPO_GESTION_hum', 'GESTION_hum', 'SUBGESTION_hum', 'TIPO_GESTION_bot', 'GESTION_bot', 'SUBGESTION_bot', 'TIPO', 'RECORRIDO', 'RECORRIDO_hum', 'RECORRIDO_bot', 'CET', 'CET_hum', 'CET_bot', 'CONT_GEN', 'CONT_GEN_hum', 'CONT_GEN_bot', 'Hora_Llamada', 'Mejor_Telefono', 'TELEFONO', 'FECHA_LLAMADA', 'DIA', 'Ejecutivo', 'RHFC', 'SUPERVISOR', 'segundos', 'AGENDADOS', 'AGENDADOS_hum', 'AGENDADOS_bot', 'SOLO FH1', 'SOLO FH2', 'SOLO FH3', 'DOBLE FH', 'TRIPLE FH', 'NUMXDNI', 'Estado', 'CntEstado', 'MntOferta', 'CNTVTAS', 'NUM_DIA_HABIL', 'Semana_Mes', 'tMontoDesem', 'tMontoDesemFugas', 'CNT_LLAMADAS', 'CNT_LLAMADAS_hum', 'CNT_LLAMADAS_bot', 'AÑO_DURACION_BASE', 'MES_DURACION_BASE', 'FECHA_ENVIO', 'SERVICIO', 'RETIRO', 'REP1', 'REP2', 'FLG_SIN_ENR', 'tMesGestion', 'DESCRIPCION', 'DESCRIPCION2', 'llave', 'DEPARTAMENTO', 'DISTRITO', 'PROPENSION_IC', 'CUOTA', 'TIENDA_CERCANA_LIMPIA', 'Region_comercial', 'TIENDA_2_DIRECCION', 'GRUPO_TASA', 'GRUPO_MONTO', 'tipo_cliente_riegos', 'USER_V3', 'TIPO_CLIENTE', 'FRESCURA', 'TIPO_BASE', 'campania', 'FLG_AAHH', 'INTENSIDAD_MAX', 'lote', 'REGION', 'RANGO_EDAD', 'RANGO_OFERTA', 'RANGO_TASA', 'TIPO_LOTE', 'TIPO_TELF', 'PHONE NUMBER', 'NOMBRES', 'APELLIDO_PATERNO', 'APELLIDO_MATERNO', 'campana', 'ADDRESS1']recorri

# %%
df_formato.groupBy('region_comercial','DETALLE_TASA') \
    .count() \
    .orderBy('region_comercial','DETALLE_TASA') \
    .show(30)

# %%
engine_mysql = create_engine(
    f"mysql+pymysql://{user_envio}:{pwd_envio}@{server_envio}:{port_mysql}/{db_envio}"
)
query = f"""
	select * from Alice.agencias_alfin
"""
df_agencia = pd.read_sql(query, engine_mysql)
df_agencia.head()
# Out:
#         agencia_Formulario    agencia_base   agencia_base2  agencia_correo  \
# 0       738363 - CAJAMARCA       CAJAMARCA       CAJAMARCA       CAJAMARCA
# 1        737490 - CASTILLA        CASTILLA        CASTILLA        CASTILLA
# 2  734281 - CHICLAYO BALTA  CHICLAYO BALTA  CHICLAYO BALTA  CHICLAYO BALTA
# 3        734272 - CHIMBOTE        CHIMBOTE        CHIMBOTE        CHIMBOTE
# 4     738360 - MOSHOQUEQUE     MOSHOQUEQUE     MOSHOQUEQUE     MOSHOQUEQUE
#
#                          correos
# 0  claudia.cantera@alfinbanco.pe
# 1    randy.carrion@alfinbanco.pe
# 2      karina.ruiz@alfinbanco.pe
# 3   junior.sanchez@alfinbanco.pe
# 4      juan.arbulu@alfinbanco.pe

# %%
df_formato.show(5)
# Out:
# +----------------+---+--------+------------+--------------------+--------------------+----------------+--------------------+--------------------+----------------+--------------------+--------------------+---------+---------+-------------+-------------+---+-------+-------+--------+------------+------------+------------+--------------+---------+-------------+---+------------------+----+-----------+--------+---------+-------------+-------------+--------+--------+--------+--------+---------+-------+------+---------+---------+-------+-------------+----------+-----------+----------------+------------+----------------+----------------+-----------------+-----------------+-----------+--------+------+-----+-----+-----------+-----------+--------------------+------------------+-------------------+------------+-----------+-------------+-------+---------------------+--------------------+------------------+-------------+---------------+-------------------+--------------------+-------------+--------+----------------+--------+------------+--------------+----------+---------------+------------+--------------------+------------+------------+---------+------------+--------------+----------------+------------------+-------+--------------------+
# |VENDOR LEAD CODE|NRG|     Dni|TIPO_GESTION|             GESTION|          SUBGESTION|TIPO_GESTION_hum|         GESTION_hum|      SUBGESTION_hum|TIPO_GESTION_bot|         GESTION_bot|      SUBGESTION_bot|     TIPO|RECORRIDO|RECORRIDO_hum|RECORRIDO_bot|CET|CET_hum|CET_bot|CONT_GEN|CONT_GEN_hum|CONT_GEN_bot|Hora_Llamada|Mejor_Telefono| TELEFONO|FECHA_LLAMADA|DIA|         Ejecutivo|RHFC| SUPERVISOR|segundos|AGENDADOS|AGENDADOS_hum|AGENDADOS_bot|SOLO FH1|SOLO FH2|SOLO FH3|DOBLE FH|TRIPLE FH|NUMXDNI|Estado|CntEstado|MntOferta|CNTVTAS|NUM_DIA_HABIL|Semana_Mes|tMontoDesem|tMontoDesemFugas|CNT_LLAMADAS|CNT_LLAMADAS_hum|CNT_LLAMADAS_bot|AÑO_DURACION_BASE|MES_DURACION_BASE|FECHA_ENVIO|SERVICIO|RETIRO| REP1| REP2|FLG_SIN_ENR|tMesGestion|         DESCRIPCION|      DESCRIPCION2|              llave|DEPARTAMENTO|   DISTRITO|PROPENSION_IC|  CUOTA|TIENDA_CERCANA_LIMPIA|    Region_comercial|TIENDA_2_DIRECCION|   GRUPO_TASA|    GRUPO_MONTO|tipo_cliente_riegos|             USER_V3| TIPO_CLIENTE|FRESCURA|       TIPO_BASE|campania|    FLG_AAHH|INTENSIDAD_MAX|      lote|         REGION|  RANGO_EDAD|        RANGO_OFERTA|  RANGO_TASA|   TIPO_LOTE|TIPO_TELF|PHONE NUMBER|       NOMBRES|APELLIDO_PATERNO|  APELLIDO_MATERNO|campana|            ADDRESS1|
# +----------------+---+--------+------------+--------------------+--------------------+----------------+--------------------+--------------------+----------------+--------------------+--------------------+---------+---------+-------------+-------------+---+-------+-------+--------+------------+------------+------------+--------------+---------+-------------+---+------------------+----+-----------+--------+---------+-------------+-------------+--------+--------+--------+--------+---------+-------+------+---------+---------+-------+-------------+----------+-----------+----------------+------------+----------------+----------------+-----------------+-----------------+-----------+--------+------+-----+-----+-----------+-----------+--------------------+------------------+-------------------+------------+-----------+-------------+-------+---------------------+--------------------+------------------+-------------+---------------+-------------------+--------------------+-------------+--------+----------------+--------+------------+--------------+----------+---------------+------------+--------------------+------------+------------+---------+------------+--------------+----------------+------------------+-------+--------------------+
# |        00006227|  1|00006227|    DISCADOR|NO SE CONCRETO LL...|TELEFONO OCUPADO ...|        DISCADOR|NO SE CONCRETO LL...|TELEFONO OCUPADO ...|      NO DISCADO|          NO DISCADO|          NO DISCADO|GEST+DISC|        1|            1|            0|  0|      0|      0|       0|           0|           0|          15|             1|971487730|   2026-07-08| 08|Outbound Auto Dial|   3|Sin_Asignar|       0|        0|            0|            0|       0|       0|       0|       0|        0|      2|  NULL|     NULL|     NULL|   NULL|            7|  Semana 2|       NULL|            NULL|         1.0|             1.0|            NULL|             2026|               07| 2026-07-01|      12|ACTIVO|NUEVO|NUEVO|       NULL|      Julio|REGISTROS ENTREGADOS|REGISTROS CARGADOS|00006227 2026-07-01|     UCAYALI|   CALLERIA|            2|1042.43|             PUCALLPA|REGION LIMA SUR O...|       VERDE CLARO|   Mayor tasa|Disminuye Monto|       3.NO CLIENTE|            7. Peers|  DEPENDIENTE|       4|SALDO COMPETIDOR| SOLODNI|   EMERGENTE|             7|NO CLIENTE|Leads Provincia|10.[75 - 79]|09.[22,500 - 25,000)|01.[50 - 55)|BASE REGULAR|    TIENE|   971487730|PELAYO ROSALES|          OSORES|              INGA|    401|PELAYO ROSALES OS...|
# |        00006521|  1|00006521|    DISCADOR|REGISTRO SIN GESTION|REGISTRO NO GESTI...|      NO DISCADO|          NO DISCADO|          NO DISCADO|        DISCADOR|REGISTRO SIN GESTION|REGISTRO NO GESTI...|GEST+DISC|        1|            0|            1|  0|      0|      0|       0|           0|           0|           5|             1|958632458|   2026-07-02| 02|Outbound Auto Dial|   1|Sin_Asignar|       0|        0|            0|            0|       0|       0|       0|       0|        0|      5|  NULL|     NULL|     NULL|   NULL|            2|  Semana 1|       NULL|            NULL|         1.0|            NULL|             1.0|             2026|               07| 2026-07-01|      12|ACTIVO|NUEVO|NUEVO|       NULL|      Julio|REGISTROS ENTREGADOS|REGISTROS CARGADOS|00006521 2026-07-01|        LIMA|     HUACHO|            6| 420.58|               HUACHO|   REGION LIMA NORTE|       VERDE CLARO|   Mayor tasa|   Mejora Monto|       3.NO CLIENTE|14. Otros Bancari...|  DEPENDIENTE|       4|         Regular|   MUJER|NO EMERGENTE|             6|       BOT|Leads Provincia|10.[75 - 79]| 03.[7,500 - 10,000)|01.[50 - 55)|    BASE BOT|    TIENE|   958632458|          OLGA|         ABENSUR|           ALVAREZ|    401|OLGA ABENSUR ALVAREZ|
# |        00007374|  1|00007374|    DISCADOR|REGISTRO SIN GESTION|REGISTRO NO GESTI...|      NO DISCADO|          NO DISCADO|          NO DISCADO|        DISCADOR|REGISTRO SIN GESTION|REGISTRO NO GESTI...|GEST+DISC|        1|            0|            1|  0|      0|      0|       0|           0|           0|          10|             1|944408041|   2026-07-04| 04|Outbound Auto Dial|  13|Sin_Asignar|       0|        0|            0|            0|       0|       0|       0|       0|        0|      2|  NULL|     NULL|     NULL|   NULL|            4|  Semana 1|       NULL|            NULL|         3.0|            NULL|             3.0|             2026|               07| 2026-07-01|      12|ACTIVO|NUEVO|NUEVO|       NULL|      Julio|REGISTROS ENTREGADOS|REGISTROS CARGADOS|00007374 2026-07-01|     UCAYALI|   CALLERIA|            3| 505.86|             PUCALLPA|REGION LIMA SUR O...|    NARANJA OSCURO|Mantiene tasa| Mantiene Monto|       3.NO CLIENTE|14. Otros Bancari...|INDEPENDIENTE|       4|         Regular| SOLODNI|NO EMERGENTE|             6|       BOT|Leads Provincia|07.[60 - 64]| 03.[7,500 - 10,000)|07.[80 - 85)|    BASE BOT|    TIENE|   944408041|        NORITA|            MERA|TENAZOA DE GONGORA|    401|NORITA MERA TENAZ...|
# |        00008085|  1|00008085|    DISCADOR|REGISTRO SIN GESTION|REGISTRO NO GESTI...|      NO DISCADO|          NO DISCADO|          NO DISCADO|        DISCADOR|REGISTRO SIN GESTION|REGISTRO NO GESTI...|GEST+DISC|        1|            0|            1|  0|      0|      0|       0|           0|           0|           9|             2|921634074|   2026-07-04| 04|Outbound Auto Dial|  13|Sin_Asignar|       0|        0|            0|            0|       0|       0|       0|       0|        0|      2|  NULL|     NULL|     NULL|   NULL|            4|  Semana 1|       NULL|            NULL|         3.0|            NULL|             3.0|             2026|               07| 2026-07-01|      12|ACTIVO|NUEVO|NUEVO|       NULL|      Julio|REGISTROS ENTREGADOS|REGISTROS CARGADOS|00008085 2026-07-01|     UCAYALI|   CALLERIA|            3| 349.63|             PUCALLPA|REGION LIMA SUR O...|   AMARILLO OSCURO|   Menor tasa|   Mejora Monto|       3.NO CLIENTE|14. Otros Bancari...|  DEPENDIENTE|       4|         Regular| SOLODNI|NO EMERGENTE|             6|       BOT|Leads Provincia|07.[60 - 64]|  02.[5,000 - 7,500)|04.[65 - 70)|    BASE BOT|    TIENE|   921634074|       JUANITA|      MONTENEGRO|            DE CHU|    401|JUANITA MONTENEGR...|
# |        00008091|  1|00008091|    DISCADOR|NO SE CONCRETO LL...|TELEFONO OCUPADO ...|        DISCADOR|NO SE CONCRETO LL...|TELEFONO OCUPADO ...|      NO DISCADO|          NO DISCADO|          NO DISCADO|GEST+DISC|        1|            1|            0|  0|      0|      0|       0|           0|           0|          15|             1|961076862|   2026-07-08| 08|Outbound Auto Dial|   3|Sin_Asignar|       0|        0|            0|            0|       0|       0|       0|       0|        0|      5|  NULL|     NULL|     NULL|   NULL|            7|  Semana 2|       NULL|            NULL|         1.0|             1.0|            NULL|             2026|               07| 2026-07-01|      12|ACTIVO|NUEVO|NUEVO|       NULL|      Julio|REGISTROS ENTREGADOS|REGISTROS CARGADOS|00008091 2026-07-01|     UCAYALI|YARINACOCHA|            4|1164.21|             PUCALLPA|REGION LIMA SUR O...|       VERDE CLARO|Mantiene tasa| Mantiene Monto|       3.NO CLIENTE|2. sunedu & sunarp B|INDEPENDIENTE|       4|         Regular|   MUJER|   EMERGENTE|             7|NO CLIENTE|Leads Provincia|07.[60 - 64]|09.[22,500 - 25,000)|03.[60 - 65)|BASE REGULAR|    TIENE|   961076862|    ANA ESTHER|          TINOCO| SILVA DE REATEGUI|    401|ANA ESTHER TINOCO...|
# +----------------+---+--------+------------+--------------------+--------------------+----------------+--------------------+--------------------+----------------+--------------------+--------------------+---------+---------+-------------+-------------+---+-------+-------+--------+------------+------------+------------+--------------+---------+-------------+---+------------------+----+-----------+--------+---------+-------------+-------------+--------+--------+--------+--------+---------+-------+------+---------+---------+-------+-------------+----------+-----------+----------------+------------+----------------+----------------+-----------------+-----------------+-----------+--------+------+-----+-----+-----------+-----------+--------------------+------------------+-------------------+------------+-----------+-------------+-------+---------------------+--------------------+------------------+-------------+---------------+-------------------+--------------------+-------------+--------+----------------+--------+------------+--------------+----------+---------------+------------+--------------------+------------+------------+---------+------------+--------------+----------------+------------------+-------+--------------------+
# only showing top 5 rows

# %%
    user_bot = "kishin"
pwd_bot = ")k9t-NT5UcMM5iPn"
server_bot = "192.168.3.7"
db_bot = "asterisk"

# %%
df_filtrado_1=df_filtrado.select('VENDOR LEAD CODE','PHONE NUMBER','TIENDA_CERCANA_LIMPIA','AGENCIA','TIENDA_2_DIRECCION','OFERTA_MAX_TEXTO','ADDRESS1','campana')
df_filtrado_1.show()
# Out:
# {"ts": "2026-07-10 12:18:33.437", "level": "ERROR", "logger": "DataFrameQueryContextLogger", "msg": "[UNRESOLVED_COLUMN.WITH_SUGGESTION] A column, variable, or function parameter with name `AGENCIA` cannot be resolved. Did you mean one of the following? [`CET`, `DIA`, `GESTION`, `NRG`, `REP1`]. SQLSTATE: 42703", "context": {"file": "jdk.internal.reflect.GeneratedMethodAccessor21.invoke(Unknown Source)", "line": "", "fragment": "col", "errorClass": "UNRESOLVED_COLUMN.WITH_SUGGESTION"}, "exception": {"class": "Py4JJavaError", "msg": "An error occurred while calling o308.select.\n: org.apache.spark.sql.AnalysisException: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column, variable, or function parameter with name `AGENCIA` cannot be resolved. Did you mean one of the following? [`CET`, `DIA`, `GESTION`, `NRG`, `REP1`]. SQLSTATE: 42703;\n'Project [VENDOR LEAD CODE#564, PHONE NUMBER#473, TIENDA_CERCANA_LIMPIA#565, 'AGENCIA, TIENDA_2_DIRECCION#567, 'OFERTA_MAX_TEXTO, ADDRESS1#568, campana#566]\n+- Filter ((((PROPENSION_IC#542 IN (1,2) AND frescura#552 IN (4)) AND USER_V3#550 IN (7. Peers,4. MES + PLD No Peers,3. MES + PLD Peers)) AND TIPO_CLIENTE#551 IN (INDEPENDIENTE)) AND (RETIRO#532 = ACTIVO))\n   +- Project [VENDOR LEAD CODE#564, NRG#478, Dni#479, TIPO_GESTION#480, GESTION#481, SUBGESTION#482, TIPO_GESTION_hum#483, GESTION_hum#484, SUBGESTION_hum#485, TIPO_GESTION_bot#486, GESTION_bot#487, SUBGESTION_bot#488, TIPO#489, RECORRIDO#490, RECORRIDO_hum#491, RECORRIDO_bot#492, CET#493, CET_hum#494, CET_bot#495, CONT_GEN#496, CONT_GEN_hum#497, CONT_GEN_bot#498, Hora_Llamada#499, Mejor_Telefono#500L, TELEFONO#501, ... 68 more fields]\n      +- Project [VENDOR LEAD CODE#564, NRG#478, Dni#479, TIPO_GESTION#480, GESTION#481, SUBGESTION#482, TIPO_GESTION_hum#483, GESTION_hum#484, SUBGESTION_hum#485, TIPO_GESTION_bot#486, GESTION_bot#487, SUBGESTION_bot#488, TIPO#489, RECORRIDO#490, RECORRIDO_hum#491, RECORRIDO_bot#492, CET#493, CET_hum#494, CET_bot#495, CONT_GEN#496, CONT_GEN_hum#497, CONT_GEN_bot#498, Hora_Llamada#499, Mejor_Telefono#500L, TELEFONO#501, ... 67 more fields]\n         +- Project [VENDOR LEAD CODE#564, NRG#478, Dni#479, TIPO_GESTION#480, GESTION#481, SUBGESTION#482, TIPO_GESTION_hum#483, GESTION_hum#484, SUBGESTION_hum#485, TIPO_GESTION_bot#486, GESTION_bot#487, SUBGESTION_bot#488, TIPO#489, RECORRIDO#490, RECORRIDO_hum#491, RECORRIDO_bot#492, CET#493, CET_hum#494, CET_bot#495, CONT_GEN#496, CONT_GEN_hum#497, CONT_GEN_bot#498, Hora_Llamada#499, Mejor_Telefono#500L, TELEFONO#501, ... 67 more fields]\n            +- Project [VENDOR LEAD CODE#564, NRG#478, Dni#479, TIPO_GESTION#480, GESTION#481, SUBGESTION#482, TIPO_GESTION_hum#483, GESTION_hum#484, SUBGESTION_hum#485, TIPO_GESTION_bot#486, GESTION_bot#487, SUBGESTION_bot#488, TIPO#489, RECORRIDO#490, RECORRIDO_hum#491, RECORRIDO_bot#492, CET#493, CET_hum#494, CET_bot#495, CONT_GEN#496, CONT_GEN_hum#497, CONT_GEN_bot#498, Hora_Llamada#499, Mejor_Telefono#500L, TELEFONO#501, ... 67 more fields]\n               +- Project [VENDOR LEAD CODE#564, NRG#478, Dni#479, TIPO_GESTION#480, GESTION#481, SUBGESTION#482, TIPO_GESTION_hum#483, GESTION_hum#484, SUBGESTION_hum#485, TIPO_GESTION_bot#486, GESTION_bot#487, SUBGESTION_bot#488, TIPO#489, RECORRIDO#490, RECORRIDO_hum#491, RECORRIDO_bot#492, CET#493, CET_hum#494, CET_bot#495, CONT_GEN#496, CONT_GEN_hum#497, CONT_GEN_bot#498, Hora_Llamada#499, Mejor_Telefono#500L, TELEFONO#501, ... 67 more fields]\n                  +- Project [VENDOR LEAD CODE#564, NRG#478, Dni#479, TIPO_GESTION#480, GESTION#481, SUBGESTION#482, TIPO_GESTION_hum#483, GESTION_hum#484, SUBGESTION_hum#485, TIPO_GESTION_bot#486, GESTION_bot#487, SUBGESTION_bot#488, TIPO#489, RECORRIDO#490, RECORRIDO_hum#491, RECORRIDO_bot#492, CET#493, CET_hum#494, CET_bot#495, CONT_GEN#496, CONT_GEN_hum#497, CONT_GEN_bot#498, Hora_Llamada#499, Mejor_Telefono#500L, TELEFONO#501, ... 66 more fields]\n                     +- Project [NUMERO_DOCUMENTO#477 AS VENDOR LEAD CODE#564, NRG#478, Dni#479, TI ...
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df_filtrado_1=df_filtrado.select('VENDOR LEAD CODE','PHONE NUMBER','TIENDA_CERCANA_LIMPIA','AGENCIA','TIENDA_2_DIRECCION','OFERTA_MAX_TEXTO','ADDRESS1','campana')
#       2 df_filtrado_1.show()
#
# File c:\Users\DATA\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyspark\sql\classic\dataframe.py:1015, in DataFrame.select(self, *cols)
#    1014 def select(self, *cols: "ColumnOrName") -> ParentDataFrame:  # type: ignore[misc]
# -> 1015     jdf = self._jdf.select(self._jcols(*cols))
#    1016     return DataFrame(jdf, self.sparkSession)
#
# File c:\Users\DATA\AppData\Local\Programs\Python\Python311\Lib\site-packages\py4j\java_gateway.py:1362, in JavaMember.__call__(self, *args)
#    1356 command = proto.CALL_COMMAND_NAME +\
#    1357     self.command_header +\
#    1358     args_command +\
#    1359     proto.END_COMMAND_PART
#    1361 answer = self.gateway_client.send_command(command)
# -> 1362 return_value = get_return_value(
#    1363     answer, self.gateway_client, self.target_id, self.name)
#    1365 for temp_arg in temp_args:
#    1366     if hasattr(temp_arg, "_detach"):
#
# File c:\Users\DATA\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyspark\errors\exceptions\captured.py:269, in capture_sql_exception.<locals>.deco(*a, **kw)
#     265 converted = convert_exception(e.java_exception)
#     266 if not isinstance(converted, UnknownException):
#     267     # Hide where the exception came from that shows a non-Pythonic
#     268     # JVM exception message.
# --> 269     raise converted from None
#     270 else:
#     271     raise
#
# AnalysisException: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column, variable, or function parameter with name `AGENCIA` cannot be resolved. Did you mean one of the following? [`CET`, `DIA`, `GESTION`, `NRG`, `REP1`]. SQLSTATE: 42703;
# 'Project [VENDOR LEAD CODE#564, PHONE NUMBER#473, TIENDA_CERCANA_LIMPIA#565, 'AGENCIA, TIENDA_2_DIRECCION#567, 'OFERTA_MAX_TEXTO, ADDRESS1#568, campana#566]
# +- Filter ((((PROPENSION_IC#542 IN (1,2) AND frescura#552 IN (4)) AND USER_V3#550 IN (7. Peers,4. MES + PLD No Peers,3. MES + PLD Peers)) AND TIPO_CLIENTE#551 IN (INDEPENDIENTE)) AND (RETIRO#532 = ACTIVO))
#    +- Project [VENDOR LEAD CODE#564, NRG#478, Dni#479, TIPO_GESTION#480, GESTION#481, SUBGESTION#482, TIPO_GESTION_hum#483, GESTION_hum#484, SUBGESTION_hum#485, TIPO_GESTION_bot#486, GESTION_bot#487, SUBGESTION_bot#488, TIPO#489, RECORRIDO#490, RECORRIDO_hum#491, RECORRIDO_bot#492, CET#493, CET_hum#494, CET_bot#495, CONT_GEN#496, CONT_GEN_hum#497, CONT_GEN_bot#498, Hora_Llamada#499, Mejor_Telefono#500L, TELEFONO#501, ... 68 more fields]
#       +- Project [VENDOR LEAD CODE#564, NRG#478, Dni#479, TIPO_GESTION#480, GESTION#481, SUBGESTION#482, TIPO_GESTION_hum#483, GESTION_hum#484, SUBGESTION_hum#485, TIPO_GESTION_bot#486, GESTION_bot#487, SUBGESTION_bot#488, TIPO#489, RECORRIDO#490, RECORRIDO_hum#491, RECORRIDO_bot#492, CET#493, CET_hum#494, CET_bot#495, CONT_GEN#496, CONT_GEN_hum#497, CONT_GEN_bot#498, Hora_Llamada#499, Mejor_Telefono#500L, TELEFONO#501, ... 67 more fields]
#          +- Project [VENDOR LEAD CODE#564, NRG#478, Dni#479, TIPO_GESTION#480, GESTION#481, SUBGESTION#482, TIPO_GESTION_hum#483, GESTION_hum#484, SUBGESTION_hum#485, TIPO_GESTION_bot#486, GESTION_bot#487, SUBGESTION_bot#488, TIPO#489, RECORRIDO#490, RECORRIDO_hum#491, RECORRIDO_bot#492, CET#493, CET_hum#494, CET_bot#495, CONT_GEN#496, CONT_GEN_hum#497, CONT_GEN_bot#498, Hora_Llamada#499, Mejor_Telefono#500L, TELEFONO#501, ... 67 more fields]
#             +- Project [VENDOR LEAD CODE#564, NRG#478, Dni#479, TIPO_GESTION#480, GESTION#481, SUBGESTION#482, TIPO_GESTION_hum#483, GESTION_hum#484, SUBGESTION_hum#485, TIPO_GESTION_bot#486, GESTION_bot#487, SUBGESTION_bot#488, TIPO#489, RECORRIDO#490, RECORRIDO_hum#491, RECORRIDO_bot#492, CET#493, CET_hum#494, CET_bot#495, CONT_GEN#496, CONT_GEN_hum#497, CONT_GEN_bot#498, Hora_Llamada#499, Mejor_Telefono#500L, TELEFONO#501, ... 67 more fields]
#                +- Project [VENDOR LEAD CODE#564, NRG#478, Dni#479, TIPO_GESTION#480, GESTION#481, SUBGESTION#482, TIPO_GESTION_hum#483, GESTION_hum#484, SUBGESTION_hum#485, TIPO_GESTION_bot#486, GESTION_bot#487, SUBGESTION_bot#488, TIPO#489, RECORRIDO#490, RECORRIDO_hum#491, RECORRIDO_bot#492, CET#493, CET_hum#494, CET_bot#495, CONT_GEN#496, CONT_GEN_hum#497, CONT_GEN_bot#498, Hora_Llamada#499, Mejor_Telefono#500L, TELEFONO#501, ... 67 more fields]
#                   +- Project [VENDOR LEAD CODE#564, NRG#478, Dni#479, TIPO_GESTION#480, GESTION#481, SUBGESTION#482, TIPO_GESTION_hum#483, GESTION_hum#484, SUBGESTION_hum#485, TIPO_GESTION_bot#486, GESTION_bot#487, SUBGESTION_bot#488, TIPO#489, RECORRIDO#490, RECORRIDO_hum#491, RECORRIDO_bot#492, CET#493, CET_hum#494, CET_bot#495, CONT_GEN#496, CONT_GEN_hum#497, CONT_GEN_bot#498, Hora_Llamada#499, Mejor_Telefono#500L, TELEFONO#501, ... 66 more fields]
#                      +- Project [NUMERO_DOCUMENTO#477 AS VENDOR LEAD CODE#564, NRG#478, Dni#479, TIPO_GESTION#480, GESTION#481, SUBGESTION#482, TIPO_GESTION_hum#483, GESTION_hum#484, SUBGESTION_hum#485, TIPO_GESTION_bot#486, GESTION_bot#487, SUBGESTION_bot#488, TIPO#489, RECORRIDO#490, RECORRIDO_hum#491, RECORRIDO_bot#492, CET#493, CET_hum#494, CET_bot#495, CONT_GEN#496, CONT_GEN_hum#497, CONT_GEN_bot#498, Hora_Llamada#499, Mejor_Telefono#500L, TELEFONO#501, ... 66 more fields]
#                         +- Project [NUMERO_DOCUMENTO#477, NRG#478, Dni#479, TIPO_GESTION#480, GESTION#481, SUBGESTION#482, TIPO_GESTION_hum#483, GESTION_hum#484, SUBGESTION_hum#485, TIPO_GESTION_bot#486, GESTION_bot#487, SUBGESTION_bot#488, TIPO#489, RECORRIDO#490, RECORRIDO_hum#491, RECORRIDO_bot#492, CET#493, CET_hum#494, CET_bot#495, CONT_GEN#496, CONT_GEN_hum#497, CONT_GEN_bot#498, Hora_Llamada#499, Mejor_Telefono#500L, TELEFONO#501, ... 66 more fields]
#                            +- Join Inner, (NUMERO_DOCUMENTO#477 = NUMERO_DOCUMENTO#472)
#                               :- Relation [NUMERO_DOCUMENTO#477,NRG#478,Dni#479,TIPO_GESTION#480,GESTION#481,SUBGESTION#482,TIPO_GESTION_hum#483,GESTION_hum#484,SUBGESTION_hum#485,TIPO_GESTION_bot#486,GESTION_bot#487,SUBGESTION_bot#488,TIPO#489,RECORRIDO#490,RECORRIDO_hum#491,RECORRIDO_bot#492,CET#493,CET_hum#494,CET_bot#495,CONT_GEN#496,CONT_GEN_hum#497,CONT_GEN_bot#498,Hora_Llamada#499,Mejor_Telefono#500L,TELEFONO#501,... 62 more fields] JDBCRelation((
#     select *
#     from maeba.[ADM_OBJ_TG].[tGestionMesAlfin]
#     ) AS tmp) [numPartitions=1]
#                               +- Relation [NUMERO_DOCUMENTO#472,PHONE NUMBER#473,NOMBRES#474,APELLIDO_PATERNO#475,APELLIDO_MATERNO#476] JDBCRelation((
#     select NUMERO_DOCUMENTO,cl_telf1 as [PHONE NUMBER],NOMBRES,APELLIDO_PATERNO,APELLIDO_MATERNO
#     from DANTALION.dbo.Base_Maestra_ALFIN_BK_Vigente
#     where (cl_telf1 is not null and cl_telf1<>0)
#     and cl_base='julio 2026'
#     and OFERTA_MAX>=5000
#     ) AS tmp) [numPartitions=1]

# %%
['DNI', 'NOMBRE', 'CELCULAR', '#¡VALOR!', 'MONTO', 'COLOR_FINAL', 'COD_USER_V3', 'USER_V3', 'PERFIL_RO', 'campaña', 'OFERTA_MAX', 'PLAZO', 'CAPACIDAD_MAX', 'FRESCURA', 'rango_deuda', 'numentidades', 'TOTAL_A_LIQUIDAR', 'TASA_CREDITO_ANTERIOR', 'TASA_1', 'TASA_2', 'TASA_3', 'TASA_4', 'TASA_5', 'TASA_6', 'TASA_7', 'MGNEG', 'MARCA_PD', 'AUTORIZACION_DATOS', 'FLAG_DEUDA_V_OFERTA', 'GRUPO_TASA', 'TIPO_BASE', 'PROPENSION_DISTRIBUCION', 'OFERTA_SS', 'TASA_1_SS', 'TASA_2_SS', 'TASA_3_SS', 'TASA_4_SS', 'TASA_5_SS', 'TASA_6_SS', 'TASA_7_SS', 'ALERTA_MAQUETA', 'FEN', 'PERFIL_ESPECIAL', 'rango_OFERTA']CO
# Out:
# ['DNI', 'NOMBRE', 'CELCULAR', '#¡VALOR!', 'MONTO', 'COLOR_FINAL', 'COD_USER_V3', 'USER_V3', 'PERFIL_RO', 'campaña', 'OFERTA_MAX', 'PLAZO', 'CAPACIDAD_MAX', 'FRESCURA', 'rango_deuda', 'numentidades', 'TOTAL_A_LIQUIDAR', 'TASA_CREDITO_ANTERIOR', 'TASA_1', 'TASA_2', 'TASA_3', 'TASA_4', 'TASA_5', 'TASA_6', 'TASA_7', 'MGNEG', 'MARCA_PD', 'AUTORIZACION_DATOS', 'FLAG_DEUDA_V_OFERTA', 'GRUPO_TASA', 'TIPO_BASE', 'PROPENSION_DISTRIBUCION', 'OFERTA_SS', 'TASA_1_SS', 'TASA_2_SS', 'TASA_3_SS', 'TASA_4_SS', 'TASA_5_SS', 'TASA_6_SS', 'TASA_7_SS', 'ALERTA_MAQUETA', 'FEN', 'PERFIL_ESPECIAL', 'rango_OFERTA']

# %%
agendas_01.show()
# Out:
# +----------------+--------------------+------------+---------------------+-----+------------------+-----------+--------------------+-------------+-----------+----------+-----+-------------+--------+-----------+------------+----------------+---------------------+------+------+------+------+------+------+------+-----+--------+------------------+-------------------+-------------+----------------+-----------------------+---------+---------+---------+---------+---------+---------+---------+---------+--------------+----+---------------+--------------------+-------+
# |VENDOR LEAD CODE|            ADDRESS1|PHONE NUMBER|TIENDA_CERCANA_LIMPIA|MONTO|TIENDA_2_DIRECCION|COD_USER_V3|             USER_V3|    PERFIL_RO|    campaña|OFERTA_MAX|PLAZO|CAPACIDAD_MAX|FRESCURA|rango_deuda|numentidades|TOTAL_A_LIQUIDAR|TASA_CREDITO_ANTERIOR|TASA_1|TASA_2|TASA_3|TASA_4|TASA_5|TASA_6|TASA_7|MGNEG|MARCA_PD|AUTORIZACION_DATOS|FLAG_DEUDA_V_OFERTA|   GRUPO_TASA|       TIPO_BASE|PROPENSION_DISTRIBUCION|OFERTA_SS|TASA_1_SS|TASA_2_SS|TASA_3_SS|TASA_4_SS|TASA_5_SS|TASA_6_SS|TASA_7_SS|ALERTA_MAQUETA| FEN|PERFIL_ESPECIAL|        rango_OFERTA|campana|
# +----------------+--------------------+------------+---------------------+-----+------------------+-----------+--------------------+-------------+-----------+----------+-----+-------------+--------+-----------+------------+----------------+---------------------+------+------+------+------+------+------+------+-----+--------+------------------+-------------------+-------------+----------------+-----------------------+---------+---------+---------+---------+---------+---------+---------+---------+--------------+----+---------------+--------------------+-------+
# |        10000920|HUMALA ESPINOZA Y...|   986208139|           MIRAFLORES| 6400|   AMARILLO OSCURO|          7|            7. Peers|Resistente II|    SOLODNI|      6400|   36|      801.447|       4|          3|           4|            NULL|                 NULL|    71|    70|    65|  NULL|  NULL|  NULL|  NULL|    1|      A1|              NULL|                  0|   Mayor tasa|SALDO COMPETIDOR|                      1|     6400|      110|      107|       91|       91|       91|       91|       91|          NULL|NULL|           NULL|  02.[5,000 - 7,500)|    401|
# |        10016923|   MARIA LUISA ARIAS|   988249076| SAN JUAN DE MIRAF...| 6500|      VERDE OSCURO|          3|  3. MES + PLD Peers| Resistente I|      MUJER|      6400|   36|      423.122|       4|          2|           3|            NULL|                 NULL|    65|    64|    62|  NULL|  NULL|  NULL|  NULL|    1|      A3|              NULL|                  0|   Mayor tasa|SALDO COMPETIDOR|                      1|     5600|      110|      106|      106|      106|      106|      106|      106|          NULL|NULL|           NULL|  02.[5,000 - 7,500)|    401|
# |        10022338|    JOSE LLANTIRHUAY|   997377946| SAN JUAN DE MIRAF...|14000|   AMARILLO OSCURO|          7|            7. Peers|  Dispuesto I|    SOLODNI|     14000|   36|      853.902|       4|          1|           1|            NULL|                 NULL|    71|    70|    68|    62|    57|  NULL|  NULL|    4|      A1|              NULL|                  1|   Mayor tasa|         Regular|                      1|    13300|      110|      107|       94|       85|       80|       80|       80|          NULL|NULL|           NULL|05.[12,500 - 15,000)|    401|
# |        10022845|ORTIZ ROLDAN CARM...|   953051482|        VILLA MARIA 2|16000|       VERDE CLARO|          6|            6. MES B| Aceptante II|      MUJER|     16400|   36|      939.906|       4|          1|           2|            NULL|                 NULL|  59.5|  58.5|  58.5|  54.5|  53.5|  49.5|  NULL|    0|      A3|              NULL|                  -|   Mayor tasa|         Regular|                      2|    16100|      110|       92|       82|       74|       71|       67|       67|          NULL|NULL|           NULL|06.[15,000 - 17,500)|    401|
# |        10024222|JARA MAGALLANES M...|   947193062| SAN JUAN DE MIRAF...|12900|    AMARILLO CLARO|          2|2. sunedu & sunarp B|  Dispuesto I|      MUJER|     20000|   36|      1788.22|       4|          2|           4|            NULL|                 NULL|    68|    67|    66|    60|    59|    53|  NULL|    4|      A2|              NULL|                  1|   Mayor tasa|         Regular|                      2|    20000|      110|      103|       93|       83|       81|       73|       73|          NULL|NULL|           NULL|08.[20,000 - 22,500)|    401|
# |        10069510|ESMERALDA ANTONIE...|   922584249|        PUENTE PIEDRA|25000|    NARANJA OSCURO|          7|            7. Peers|  Dispuesto I|    SOLODNI|      6400|   36|      467.788|       4|          6|           3|            NULL|                 NULL|    82|    81|    76|  NULL|  NULL|  NULL|  NULL|    0|      A1|              NULL|                  0|   Mayor tasa|SALDO COMPETIDOR|                      1|     6200|      110|      110|      105|      105|      105|      105|      105|          NULL|NULL|           NULL|  02.[5,000 - 7,500)|    401|
# |        10071737|       PABLO LLONTOP|   989783480|           AREQ CAYMA|18000|       VERDE CLARO|          7|            7. Peers| Aceptante II|    SOLODNI|     23000|   36|      1453.25|       4|          1|           1|            NULL|                 NULL|  50.5|  49.5|  48.5|  46.5|  45.5|  40.5|  NULL|    2|      A1|              NULL|                  1|   Mayor tasa|         Regular|                      2|    23000|      110|       80|       70|       65|       62|       56|       56|             3|NULL|           NULL|09.[22,500 - 25,000)|    401|
# |        10077508|MARUJA DAMIANA VI...|   981096426|        VILLA MARIA 2|22000|       VERDE CLARO|          3|  3. MES + PLD Peers| Aceptante II|RECONQUISTA|     22000|   48|      2232.99|       4|          6|           4|               0|                   39|    47|    43|    43|    42|    42|    40|  NULL|    3|      A3|                 S|                  0|   Menor tasa|SALDO COMPETIDOR|                      2|    22000|      107|       69|       61|       57|       55|       52|       52|          NULL|NULL|           NULL|08.[20,000 - 22,500)|    401|
# |        10080010|RUTH CERAFINA URQ...|   991973384|        VILLA MARIA 2| 6900|     NARANJA CLARO|          7|            7. Peers|Dispuesto III|    SOLODNI|      7200|   36|      505.737|       4|          2|           3|            NULL|                 NULL|    78|    77|    71|  NULL|  NULL|  NULL|  NULL|    2|      A1|              NULL|                  0|Mantiene tasa|SALDO COMPETIDOR|                      1|     7200|      110|      110|       94|       94|       94|       94|       94|          NULL|NULL|           NULL|  02.[5,000 - 7,500)|    401|
# |        10081223|BLANCA FLOR BECER...|   948194383|        VILLA MARIA 2|18600|      VERDE OSCURO|          7|            7. Peers| Dispuesto II|      MUJER|     19800|   36|      1085.26|       4|          3|           2|            NULL|                 NULL|    56|    55|    54|    52|    51|    46|  NULL|    3|      A1|                 S|                  0|   Mayor tasa|SALDO COMPETIDOR|                      1|    18900|      110|       94|       82|       74|       72|       65|       65|          NULL|NULL|           NULL|07.[17,500 - 20,000)|    401|
# |        10085416|LUCIO SALAZAR HUA...|   965378124|           MIRAFLORES|16800|      VERDE OSCURO|         14|14. Otros Bancari...| Dispuesto II|    SOLODNI|     18000|   36|      1100.17|       4|          1|           5|            NULL|                 NULL|    58|    57|    56|    53|    53|    47|  NULL|    3|      A1|              NULL|                  -|   Mayor tasa|         Regular|                      2|    18000|      110|       96|       84|       76|       73|       68|       68|          NULL|NULL|           NULL|07.[17,500 - 20,000)|    401|
# |        10087326|HUGO SANDOVAL GUE...|   996740392| SAN JUAN DE MIRAF...|18900|    AMARILLO CLARO|         14|14. Otros Bancari...|  Aceptante I|      REENG|     16000|   48|      1651.24|       4|          1|           2|        12633.21|                   42|    53|    47|    47|    46|    46|    46|  NULL|    3|      A2|                 S|                  1|Mantiene tasa|         Regular|                      2|    16000|      108|       71|       65|       61|       59|       57|       57|          NULL|NULL|           NULL|06.[15,000 - 17,500)|    401|
# |        10088217|ALBERTO FELIX POS...|   999004117|           MIRAFLORES|13600|      VERDE OSCURO|          7|            7. Peers| Dispuesto II|    SOLODNI|     18000|   36|      996.726|       4|          1|           2|            NULL|                 NULL|    58|    57|    56|    53|    53|    47|  NULL|    2|      A1|              NULL|                  1|   Menor tasa|SALDO COMPETIDOR|                      1|    17000|      110|       96|       84|       76|       73|       68|       68|          NULL|NULL|           NULL|07.[17,500 - 20,000)|    401|
# |        10006326|     Juan Luis Alba |   912174433|           MIRAFLORES|18000|      VERDE OSCURO|          8|   8. Tarjetero Cash| Aceptante II|    SOLODNI|     18000|   36|      1140.94|       4|          2|           5|            NULL|                 NULL|    60|    59|    58|    56|    54|    48|  NULL|    3|      A2|              NULL|                  1|   Mayor tasa|         Regular|                      2|    18000|      110|       93|       85|       77|       74|       67|       67|             2|NULL|           NULL|07.[17,500 - 20,000)|    401|
# |        10009610|RODRIGUEZ GAYOSO ...|   998416978|  VILLA EL SALVADOR 2| 6000|    AMARILLO CLARO|          6|            6. MES B| Resistente I|      MUJER|     18500|   36|      1132.39|       4|          0|           2|            NULL|                 NULL|    75|    73|    71|    68|    67|    59|  NULL|    5|      A3|                 S|                  -|   Mayor tasa|         Regular|                      2|    18200|      110|      110|       98|       88|       85|       76|       76|          NULL|NULL|           NULL|07.[17,500 - 20,000)|    401|
# |        10011619|HERNANDEZ DIAZ MA...|   971150612| SAN JUAN DE MIRAF...| 6000|       VERDE CLARO|          2|2. sunedu & sunarp B|  Aceptante I|      MUJER|     18100|   36|      1305.71|       4|          1|           5|            NULL|                 NULL|  50.5|  49.5|  48.5|  46.5|  45.5|  40.5|  NULL|    2|      A1|              NULL|                  -|   Mayor tasa|         Regular|                      2|    18100|      110|       80|       70|       65|       62|       56|       56|          NULL|NULL|           NULL|07.[17,500 - 20,000)|    401|
# |        10013623|   VICTOR HUGO VILCA|   982114285| SAN JUAN DE MIRAF...|14000|    NARANJA OSCURO|          7|            7. Peers| Resistente I|    SOLODNI|      8000|   36|      582.217|       4|          1|           3|            NULL|                 NULL|    82|    81|    76|  NULL|  NULL|  NULL|  NULL|    0|      A1|              NULL|                  1|   Mayor tasa|         Regular|                      1|     7800|      110|      110|      105|      105|      105|      105|      105|          NULL|NULL|           NULL| 03.[7,500 - 10,000)|    401|
# |        10014143|Edgar Torres Hilario|   992180070|          SANTA ANITA|18000|      VERDE OSCURO|          7|            7. Peers| Dispuesto II|    SOLODNI|     18000|   36|       1482.6|       4|          1|           4|            NULL|                 NULL|    56|    55|    54|    52|    51|    46|  NULL|    3|      A1|              NULL|                  -|   Mayor tasa|         Regular|                      2|    18000|      110|       94|       82|       74|       72|       65|       65|             2|NULL|           NULL|07.[17,500 - 20,000)|    401|
# |        10177516|MARTHA CECILIA SILVA|   941460715|          ATE VITARTE|17400|       VERDE CLARO|          7|            7. Peers|  Aceptante I|      MUJER|     15800|   36|      829.793|       4|          5|           2|            NULL|                 NULL|  50.5|  49.5|  48.5|  46.5|  45.5|  40.5|  NULL|    2|      A1|              NULL|                  0|   Mayor tasa|SALDO COMPETIDOR|                      1|    15500|      110|       80|       70|       65|       62|       56|       56|          NULL|NULL|           NULL|06.[15,000 - 17,500)|    401|
# |        10183609|MILAGROS ELENA RI...|   947626518|          SANTA ANITA|20000|    AMARILLO CLARO|          1|1. sunedu & sunarp A|Dispuesto III|      MUJER|     18500|   36|       1133.5|       4|          6|           5|            NULL|                 NULL|    75|    73|    71|    68|    67|    59|  NULL|    2|      A3|              NULL|                  1|   Mayor tasa|SALDO COMPETIDOR|                      1|    18200|      110|      110|       98|       88|       85|       76|       76|          NULL|NULL|           NULL|07.[17,500 - 20,000)|    401|
# +----------------+--------------------+------------+---------------------+-----+------------------+-----------+--------------------+-------------+-----------+----------+-----+-------------+--------+-----------+------------+----------------+---------------------+------+------+------+------+------+------+------+-----+--------+------------------+-------------------+-------------+----------------+-----------------------+---------+---------+---------+---------+---------+---------+---------+---------+--------------+----+---------------+--------------------+-------+
# only showing top 20 rows

# %%
print(agendas_01.columns)
print(df_filtrado_1.columns)
# Out:
# ['DNI', 'NOMBRE', 'CELCULAR', '#¡VALOR!', 'MONTO', 'COLOR_FINAL', 'COD_USER_V3', 'USER_V3', 'PERFIL_RO', 'campaña', 'OFERTA_MAX', 'PLAZO', 'CAPACIDAD_MAX', 'FRESCURA', 'rango_deuda', 'numentidades', 'TOTAL_A_LIQUIDAR', 'TASA_CREDITO_ANTERIOR', 'TASA_1', 'TASA_2', 'TASA_3', 'TASA_4', 'TASA_5', 'TASA_6', 'TASA_7', 'MGNEG', 'MARCA_PD', 'AUTORIZACION_DATOS', 'FLAG_DEUDA_V_OFERTA', 'GRUPO_TASA', 'TIPO_BASE', 'PROPENSION_DISTRIBUCION', 'OFERTA_SS', 'TASA_1_SS', 'TASA_2_SS', 'TASA_3_SS', 'TASA_4_SS', 'TASA_5_SS', 'TASA_6_SS', 'TASA_7_SS', 'ALERTA_MAQUETA', 'FEN', 'PERFIL_ESPECIAL', 'rango_OFERTA']
# ['VENDOR LEAD CODE', 'PHONE NUMBER', 'TIENDA_CERCANA_LIMPIA', 'AGENCIA', 'TIENDA_2_DIRECCION', 'OFERTA_MAX_TEXTO', 'ADDRESS1', 'campana']

# %%
agendas_01=agendas_01.select('VENDOR LEAD CODE','PHONE NUMBER','TIENDA_CERCANA_LIMPIA','AGENCIA','TIENDA_2_DIRECCION','OFERTA_MAX_TEXTO','ADDRESS1','campana')

# %%
agendas_01=agendas_01.withColumn('campana',F.lit('401'))
agendas_01=agendas_01.withColumnRenamed('DNI','VENDOR LEAD CODE')
agendas_01=agendas_01.withColumnRenamed('NOMBRE','ADDRESS1')
agendas_01=agendas_01.withColumnRenamed('COLOR_FINAL','TIENDA_2_DIRECCION')

agendas_01=agendas_01.withColumnRenamed('CELCULAR','PHONE NUMBER')
agendas_01=agendas_01.withColumnRenamed('MONTO','OFERTA_MAX_TEXTO')
agendas_01 = agendas_01.withColumnRenamed("#¡VALOR!", "TIENDA_CERCANA_LIMPIA")

# %%
agendas_01=agendas_01.withColumn('AGENCIA',F.lit(' '))

# %%
df_filtrado_2=df_filtrado_1.unionByName(agendas_01)

# %%
df_list_filtrada = agendas_01.toPandas()
ruta_archivo = os.path.join(ruta_csv, 'ssssssss.xlsx')
df_list_filtrada.to_excel(ruta_archivo, index=False)

# %%
query = """
    select *
    from DANTALION.dbo.Base_Maestra_ALFIN_BK_Vigente
    where (cl_telf1 is not null and cl_telf1<>0) 
    and cl_base='julio 2026'
    and OFERTA_MAX>=5000
    """
df_formato=obtener_tabla_sql(spark,query,server_kishin,user_kishin,pwd_kishin,db_kishin)
print(df_formato.columns)
# Out:
# ['TIPO_DOI', 'NUMERO_DOCUMENTO', 'NOMBRES', 'APELLIDO_PATERNO', 'APELLIDO_MATERNO', 'SUCURSAL', 'TIENDA', 'DEPARTAMENTO', 'PROVINCIA', 'DISTRITO', 'FEC_NACIMIENTO', 'OFERTA_MAX', 'OFERTA_REEN', 'Tipo_verificacion', 'GRUPO_RIESGO', 'proveedor', 'lote', 'estado', 'Tasa_1', 'Tasa_2', 'Tasa_3', 'Tasa_4', 'Tasa_5', 'Tasa_6', 'Tasa_7', 'segmento', 'Campana', 'PLAZO', 'TEM', 'PROPENSION_IC', 'Desgravamen', 'CUOTA', 'Edad', 'Oferta_12M', 'Tasa_12M', 'Desgravamen_12M', 'CUOTA_12M', 'Oferta_18M', 'Tasa_18M', 'Desgravamen_18M', 'CUOTA_18M', 'Oferta_24M', 'Tasa_24M', 'Desgravamen_24M', 'CUOTA_24M', 'Oferta_36M', 'Tasa_36M', 'Desgravamen_36M', 'CUOTA_36M', 'Validador_Telefono', 'Prioridad', 'Nombre_prioridad', 'Deuda_1', 'Entidad_1', 'Deuda_2', 'Entidad_2', 'Deuda_3', 'Entidad_3', 'sucursal_comercial', 'Agencia_comercial', 'Region_comercial', 'Ubicacion', 'OfertaMaximaSinSeguro', 'color', 'color_final', 'PROPENSION', 'OFERTA_FINAL', 'GARANTIA', 'Oferta_Minima_Paperless', 'RANGO_OFERTA', 'RANGO_SUELDO', 'CAPACIDAD_MAX', 'PEER', 'PROP_COMER', 'TIPO_GEST', 'CLIENTE_NUEVO', 'GRUPO_TASA', 'NUEVOS_3M', 'NUEVOS_6M', 'NUEVOS_9M', 'NUEVOS_12M', 'NUEVOS_4M', 'GRUPO_MONTO', 'TASA_VS_MONTO', 'USUARIO', 'incremento_monto_riesgos', 'FLG_DEUDA_PLUS', 'tipo_cliente_riegos', 'USER_V3', 'LEAD_CALIDAD', 'SEGMENTO_USER', 'RANGO_EDAD', 'RANGO_OFERTA2', 'PERIODO', 'RETIRO_GEST', 'MEJOR_TIPIFICACION', 'STATUS', 'FECHA_SOL', 'BASE', 'RESULTADO', 'NUM_ENRIQUECIDO', 'TIPO_CONTACTO', 'Q_VENTAS', 'LOCALIDAD', 'DESEMBOLSADO', 'MONTO_DESEMBOLSADO', 'SBI', 'CRUCE', 'PREST_PREVIO', 'ID_CLIENTE', 'RANGO_EDAD2', 'Fecha_Envio', 'TIPO_BD', 'COD_BD', 'NOMB_BD', 'MES_GESTION', 'TIPO_CLIENTE', 'GRUPO_TASA_REENGANCHE', 'SALDO_DIFERENCIAL_REENG', 'FLAG_REENG', 'RETIRO_DESEMBOLSO', 'FRESCURA', 'flag_deuda_v_oferta', 'MGNEG', 'PERFIL_RO', 'TIPO_BASE', 'cl_telf1', 'cl_telf2', 'cl_telf3', 'cl_telf4', 'cl_telf5', 'cl_telf6', 'cl_telf7', 'cl_telf8', 'cl_telf9', 'cl_telf10', 'cl_movil', 'cl_celular', 'cl_telefono', 'cl_turno', 'cl_gestor', 'cl_asesor', 'cl_accion', 'cl_gestion', 'cl_estado', 'cl_fecha_gestion', 'cl_hora_gestion', 'cl_hits', 'cl_fecha_llamar', 'cl_prioridad', 'cl_orden', 'cl_predictivo', 'cl_tiempo', 'cl_base', 'cl_mes', 'cl_carga', 'id_carga', 'cl_area', 'fecha_alimentacion', 'cl_base_ant', 'cl_accion_ant', 'cl_fecha_ant', 'campania', 'PROMOCION', 'PROMOCION2', 'nombre_base', 'NumEntidades', 'p_banco', 'PERFIL_GLOBAL', 'FLG_AAHH', 'SCORE_TELEFONO', 'PILOTO_PLAZAS', 'INTENSIDAD_MAX', 'marca1', 'marca2', 'marca3', 'AÑO_DURACION_BASE', 'MES_DURACION_BASE']

# %%
['TIPO_DOI', 'NUMERO_DOCUMENTO', 'NOMBRES', 'APELLIDO_PATERNO', 'APELLIDO_MATERNO', 'SUCURSAL', 'TIENDA', 'DEPARTAMENTO', 'PROVINCIA', 'DISTRITO', 'FEC_NACIMIENTO', 'OFERTA_MAX', 'OFERTA_REEN', 'Tipo_verificacion', 'GRUPO_RIESGO', 'proveedor', 'lote', 'estado', 'Tasa_1', 'Tasa_2', 'Tasa_3', 'Tasa_4', 'Tasa_5', 'Tasa_6', 'Tasa_7', 'segmento', 'Campana', 'PLAZO', 'TEM', 'PROPENSION_IC', 'Desgravamen', 'CUOTA', 'Edad', 'Oferta_12M', 'Tasa_12M', 'Desgravamen_12M', 'CUOTA_12M', 'Oferta_18M', 'Tasa_18M', 'Desgravamen_18M', 'CUOTA_18M', 'Oferta_24M', 'Tasa_24M', 'Desgravamen_24M', 'CUOTA_24M', 'Oferta_36M', 'Tasa_36M', 'Desgravamen_36M', 'CUOTA_36M', 'Validador_Telefono', 'Prioridad', 'Nombre_prioridad', 'Deuda_1', 'Entidad_1', 'Deuda_2', 'Entidad_2', 'Deuda_3', 'Entidad_3', 'sucursal_comercial', 'Agencia_comercial', 'Region_comercial', 'Ubicacion', 'OfertaMaximaSinSeguro', 'color', 'color_final', 'PROPENSION', 'OFERTA_FINAL', 'GARANTIA', 'Oferta_Minima_Paperless', 'RANGO_OFERTA', 'RANGO_SUELDO', 'CAPACIDAD_MAX', 'PEER', 'PROP_COMER', 'TIPO_GEST', 'CLIENTE_NUEVO', 'GRUPO_TASA', 'NUEVOS_3M', 'NUEVOS_6M', 'NUEVOS_9M', 'NUEVOS_12M', 'NUEVOS_4M', 'GRUPO_MONTO', 'TASA_VS_MONTO', 'USUARIO', 'incremento_monto_riesgos', 'FLG_DEUDA_PLUS', 'tipo_cliente_riegos', 'USER_V3', 'LEAD_CALIDAD', 'SEGMENTO_USER', 'RANGO_EDAD', 'RANGO_OFERTA2', 'PERIODO', 'RETIRO_GEST', 'MEJOR_TIPIFICACION', 'STATUS', 'FECHA_SOL', 'BASE', 'RESULTADO', 'NUM_ENRIQUECIDO', 'TIPO_CONTACTO', 'Q_VENTAS', 'LOCALIDAD', 'DESEMBOLSADO', 'MONTO_DESEMBOLSADO', 'SBI', 'CRUCE', 'PREST_PREVIO', 'ID_CLIENTE', 'RANGO_EDAD2', 'Fecha_Envio', 'TIPO_BD', 'COD_BD', 'NOMB_BD', 'MES_GESTION', 'TIPO_CLIENTE', 'GRUPO_TASA_REENGANCHE', 'SALDO_DIFERENCIAL_REENG', 'FLAG_REENG', 'RETIRO_DESEMBOLSO', 'FRESCURA', 'flag_deuda_v_oferta', 'MGNEG', 'PERFIL_RO', 'TIPO_BASE', 'cl_telf1', 'cl_telf2', 'cl_telf3', 'cl_telf4', 'cl_telf5', 'cl_telf6', 'cl_telf7', 'cl_telf8', 'cl_telf9', 'cl_telf10', 'cl_movil', 'cl_celular', 'cl_telefono', 'cl_turno', 'cl_gestor', 'cl_asesor', 'cl_accion', 'cl_gestion', 'cl_estado', 'cl_fecha_gestion', 'cl_hora_gestion', 'cl_hits', 'cl_fecha_llamar', 'cl_prioridad', 'cl_orden', 'cl_predictivo', 'cl_tiempo', 'cl_base', 'cl_mes', 'cl_carga', 'id_carga', 'cl_area', 'fecha_alimentacion', 'cl_base_ant', 'cl_accion_ant', 'cl_fecha_ant', 'campania', 'PROMOCION', 'PROMOCION2', 'nombre_base', 'NumEntidades', 'p_banco', 'PERFIL_GLOBAL', 'FLG_AAHH', 'SCORE_TELEFONO', 'PILOTO_PLAZAS', 'INTENSIDAD_MAX', 'marca1', 'marca2', 'marca3', 'AÑO_DURACION_BASE', 'MES_DURACION_BASE']

# %%
df_filtrado_2.columns
# Out:
# ['VENDOR LEAD CODE',
#  'PHONE NUMBER',
#  'TIENDA_CERCANA_LIMPIA',
#  'AGENCIA',
#  'TIENDA_2_DIRECCION',
#  'OFERTA_MAX_TEXTO',
#  'ADDRESS1',
#  'campana']

# %%
df_filtrado_2.columns
# Out:
# ['VENDOR LEAD CODE',
#  'PHONE NUMBER',
#  'TIENDA_CERCANA_LIMPIA',
#  'AGENCIA',
#  'TIENDA_2_DIRECCION',
#  'OFERTA_MAX_TEXTO',
#  'ADDRESS1',
#  'campana']

# %%
query = """
SELECT agencia_Formulario as AGENCIA1 ,agencia_correo as TIENDA_CERCANA_LIMPIA
FROM OPENQUERY([192.168.2.100], '
    select * from Alice.agencias_alfin
')
    """
df_Age=obtener_tabla_sql(spark,query,server_zeus,user_zeus,pwd_zeus,db_zeus)

# %%
df_filtrado_2=df_filtrado_2.join(df_Age,['TIENDA_CERCANA_LIMPIA'],'left')

# %%
df_filtrado_2=df_filtrado_2.withColumn('AGENCIA',when(F.col('AGENCIA').isNull(),F.col('AGENCIA1')).otherwise(F.col('AGENCIA')))
df_filtrado_2=df_filtrado_2.withColumn('AGENCIA',when(F.col('AGENCIA')=='',F.col('AGENCIA1')).otherwise(F.col('AGENCIA')))

# %%
df_filtrado_2=df_filtrado_2.drop('AGENCIA1')

# %%
df_filtrado_2 = df_filtrado_2.withColumn(
    "AGENCIA",
    F.regexp_extract(F.col("AGENCIA"), r"^(\d+)", 1)
)

# %%
df_filtrado_2.show()
# Out:
# +---------------------+----------------+------------+-------+------------------+----------------+--------------------+-------+
# |TIENDA_CERCANA_LIMPIA|VENDOR LEAD CODE|PHONE NUMBER|AGENCIA|TIENDA_2_DIRECCION|OFERTA_MAX_TEXTO|            ADDRESS1|campana|
# +---------------------+----------------+------------+-------+------------------+----------------+--------------------+-------+
# |               CAÑETE|        02848126|   967948335| 732243|    NARANJA OSCURO|            5200|PROFETA PEÃ‘A BERMEO|    401|
# |              SULLANA|        02838605|   943747319| 734270|      VERDE OSCURO|           11100| EMERITA NIÃ‘O NIÃ‘O|    401|
# |               HUACHO|        02839950|   904866097| 739467|      VERDE OSCURO|            6000|JAVIER EDUARDO PO...|    401|
# |             CASTILLA|        02840567|   939146665| 737490|      VERDE OSCURO|           18000|WILFREDO ABDUL CA...|    401|
# |             CASTILLA|        02707992|   920598982| 737490|      VERDE OSCURO|           11600|     JOSE MEJIA RUIZ|    401|
# |           SAN MIGUEL|        02695252|   981206106| 739483|       VERDE CLARO|            7000|EDUARDO DAVID GUZ...|    401|
# |             CASTILLA|        02697348|   949408627| 737490|   AMARILLO OSCURO|            5200|MARIA LAURA ADANA...|    401|
# |             PC TACNA|        01339178|   969998384| 738013|   AMARILLO OSCURO|            6200|JULIA EULALIA CAM...|    401|
# |             PC TACNA|        00496494|   931570927| 738013|       VERDE CLARO|           15600|VERONICA KARIN ME...|    401|
# |             PC TACNA|        00497964|   930099201| 738013|      VERDE OSCURO|           12100|MARA OLIMPIA VERA...|    401|
# |        PUENTE PIEDRA|        06544047|   959326876| 738369|      VERDE OSCURO|           18000|CESAR GREGORIO RA...|    401|
# |        PUENTE PIEDRA|        06546085|   929249351| 738369|      VERDE OSCURO|           20000|DORIS ESTELISTA H...|    401|
# |             CASTILLA|        02638170|   939590411| 737490|       VERDE CLARO|           18000|MARTHA MERCEDES C...|    401|
# |             PC TACNA|        01805901|   979906800| 738013|   AMARILLO OSCURO|            6200|  LUISA CHOQUE ALAVE|    401|
# |            JULIACA 2|        01307136|   950863843| 735986|    AMARILLO CLARO|           10800|  EDIT CALSIN CALSIN|    401|
# |             CASTILLA|        02636144|   958649587| 737490|       VERDE CLARO|           14000|CONNIE CRISTINA C...|    401|
# |             PC TACNA|        01307867|   944483795| 738013|       VERDE CLARO|           15300|SEVERINO APOLINAR...|    401|
# |              SULLANA|        02797544|   969713716| 734270|      VERDE OSCURO|           18000|BETY JUAREZ NIMA ...|    401|
# |             CASTILLA|        02778601|   969641290| 737490|      VERDE OSCURO|           18000|MANUEL EDUARDO VE...|    401|
# |             CASTILLA|        02805314|   950904756| 737490|    AMARILLO CLARO|           15200|REYNALDA ANGELA R...|    401|
# +---------------------+----------------+------------+-------+------------------+----------------+--------------------+-------+
# only showing top 20 rows

# %%
from pyspark.sql import functions as F
from pyspark.sql.window import Window

w = Window.partitionBy('TIENDA_CERCANA_LIMPIA','OFERTA_MAX_TEXTO').orderBy(F.rand())

df_split = df_filtrado_2.withColumn("grupo_split", F.ntile(3).over(w))

df_parte_1 = df_split.filter(F.col("grupo_split") == 1).drop("grupo_split")
df_parte_2 = df_split.filter(F.col("grupo_split") == 2).drop("grupo_split")
df_parte_3 = df_split.filter(F.col("grupo_split") == 3).drop("grupo_split")
# df_parte_3 = df_split.filter(F.col("grupo_split") == 3).drop("grupo_split")
# df_parte_4 = df_split.filter(F.col("grupo_split") == 4).drop("grupo_split")
# df_parte_5 = df_split.filter(F.col("grupo_split") == 5).drop("grupo_split")
# df_parte_6 = df_split.filter(F.col("grupo_split") == 6).drop("grupo_split")
# df_parte_7 = df_split.filter(F.col("grupo_split") == 7).drop("grupo_split")

print(
    df_parte_1.count(),
    df_parte_2.count(),
    df_parte_3.count()
    # df_parte_4.count(),
    # df_parte_5.count(),
    # df_parte_6.count(),
    # df_parte_7.count()
)
# Out:
# 9993 6895 5130

# %%
df_list_filtrada = df_parte_1.toPandas()
ruta_archivo = os.path.join(ruta_csv, 'alfin1.xlsx')
df_list_filtrada.to_excel(ruta_archivo, index=False)
df_list_filtrada = df_parte_2.toPandas()
ruta_archivo = os.path.join(ruta_csv, 'alfin2.xlsx')
df_list_filtrada.to_excel(ruta_archivo, index=False)
df_list_filtrada = df_parte_3.toPandas()
ruta_archivo = os.path.join(ruta_csv, 'alfin3.xlsx')
df_list_filtrada.to_excel(ruta_archivo, index=False)

# %%
df_parte_3.show()
# Out:
# +---------------------+----------------+------------+-------+------------------+----------------+--------------------+-------+
# |TIENDA_CERCANA_LIMPIA|VENDOR LEAD CODE|PHONE NUMBER|AGENCIA|TIENDA_2_DIRECCION|OFERTA_MAX_TEXTO|            ADDRESS1|campana|
# +---------------------+----------------+------------+-------+------------------+----------------+--------------------+-------+
# |           AREQ CAYMA|        29659831|   977319165|       |      VERDE OSCURO|           13600|FLOR LUZ VILLEGAS...|    401|
# |           AREQ CAYMA|        45640479|   959155400|       |    AMARILLO CLARO|           16000|Alexander pinto p...|    401|
# |           AREQ CAYMA|        29647727|   934562868|       |      VERDE OSCURO|           16000|SEBASTIANA CRISTI...|    401|
# |           AREQ CAYMA|        46725183|   915384977|       |      VERDE OSCURO|           16000|ANACAREN JULIANA ...|    401|
# |           AREQ CAYMA|        29472104|   949483947|       |      VERDE OSCURO|           20000|JULIA CONDORI ARCANA|    401|
# |           AREQ CAYMA|        45008214|   987898499|       |      VERDE OSCURO|           20000|YESHIRA SALLY MED...|    401|
# |           AREQ CAYMA|        40192536|   941466495|       |       VERDE CLARO|           20000|CLAUDIA CECILIA P...|    401|
# |           AREQ CAYMA|        41953439|   959753741|       |     NARANJA CLARO|           20000|DAJHANA AYLINN FU...|    401|
# |           AREQ CAYMA|        45529873|   921831026|       |      VERDE OSCURO|           20000|  Ana Huarachi Vilca|    401|
# |           AREQ CAYMA|        42816694|   982734994|       |       VERDE CLARO|           20000|NEVADO PALACO DEB...|    401|
# |           AREQ CAYMA|        43515649|   966359965|       |      VERDE OSCURO|           20000|KATERINE VANESSA ...|    401|
# |           AREQ CAYMA|        29251778|   958640176|       |      VERDE OSCURO|           20000|ROXANA LILIANA FE...|    401|
# |        AREQ PAMPILLA|        43648718|   992124030|       |   AMARILLO OSCURO|            8000|CHURA CONDORI SOF...|    401|
# |        AREQ PAMPILLA|        29539458|   902376677|       |   AMARILLO OSCURO|            9300|LUIS EDMUNDO FERN...|    401|
# |        AREQ PAMPILLA|        20659550|   985203843|       |   AMARILLO OSCURO|            9800|ABDEL ERIBERTO FE...|    401|
# |        AREQ PAMPILLA|        40494549|   904769489|       |      VERDE OSCURO|           10300|     ANGELA BEDREGAL|    401|
# |        AREQ PAMPILLA|        30578079|   987891644|       |      VERDE OSCURO|           11000|BAUTISTA ISAAC VA...|    401|
# |        AREQ PAMPILLA|        29500746|   959740175|       |       VERDE CLARO|           12900|EXEQUIEL MOISES M...|    401|
# |        AREQ PAMPILLA|        29429722|   964575371|       |      VERDE OSCURO|           14000|GUTIERREZ GUTIERR...|    401|
# |        AREQ PAMPILLA|        44031846|   964649535|       |    AMARILLO CLARO|           14000|SONCCO CANAZA MEL...|    401|
# +---------------------+----------------+------------+-------+------------------+----------------+--------------------+-------+
# only showing top 20 rows

# %%
# append_table_SQL(spark,df_lista,f'suuuuuuubirborrddar',server_kishin,user_kishin,pwd_kishin,'DANTALION')
#

# %%
query = """
    select *
    from DANTALION.dbo.Base_Maestra_ALFIN_BK_Vigente
    where (cl_telf1 is not null and cl_telf1<>0) 
    and cl_base='julio 2026'
    and OFERTA_MAX>=5000
    """
df_formato=obtener_tabla_sql(spark,query,server_kishin,user_kishin,pwd_kishin,db_kishin)

# df_formato=df_formato.withColumnRenamed('NUMERO_DOCUMENTO','VENDOR LEAD CODE')
# df_formato=df_formato.withColumnRenamed('cl_telf1','PHONE NUMBER')
# df_formato=df_formato.withColumnRenamed('Agencia_comercial','TIENDA_CERCANA_LIMPIA')
# df_formato=df_formato.withColumn('campana',F.lit('401'))
# df_formato=df_formato.withColumnRenamed('COLOR_FINAL','TIENDA_2_DIRECCION')
# df_formato=df_formato.withColumnRenamed('OFERTA_MAX','OFERTA_MAX_TEXTO')
# df_formato=df_formato.withColumnRenamed('MARCA1','AGENCIA')
# df_formato = df_formato.withColumn(
#     "ADDRESS1",
#     F.concat_ws(
#         " ",
#         F.col("NOMBRES"),
#         F.col("APELLIDO_PATERNO"),
#         F.col("APELLIDO_MATERNO")
#     )
# )

# %%
|TIPO_DOI|VENDOR LEAD CODE|         NOMBRES|APELLIDO_PATERNO|  APELLIDO_MATERNO|SUCURSAL|  TIENDA|DEPARTAMENTO|       PROVINCIA|   DISTRITO|FEC_NACIMIENTO|OFERTA_MAX_TEXTO|OFERTA_REEN|Tipo_verificacion|GRUPO_RIESGO|proveedor|          lote|estado|Tasa_1|Tasa_2|Tasa_3|Tasa_4|Tasa_5|Tasa_6|Tasa_7|segmento|campana|PLAZO| TEM|PROPENSION_IC|Desgravamen|  CUOTA|Edad|Oferta_12M|Tasa_12M|Desgravamen_12M|CUOTA_12M|Oferta_18M|Tasa_18M|Desgravamen_18M|CUOTA_18M|Oferta_24M|Tasa_24M|Desgravamen_24M|CUOTA_24M|Oferta_36M|Tasa_36M|Desgravamen_36M|CUOTA_36M|Validador_Telefono|Prioridad|Nombre_prioridad|Deuda_1|Entidad_1|Deuda_2|Entidad_2|Deuda_3|Entidad_3|sucursal_comercial|TIENDA_CERCANA_LIMPIA|    Region_comercial|Ubicacion|OfertaMaximaSinSeguro|color|TIENDA_2_DIRECCION|PROPENSION|OFERTA_FINAL|GARANTIA|Oferta_Minima_Paperless|RANGO_OFERTA|RANGO_SUELDO|CAPACIDAD_MAX|PEER|PROP_COMER|TIPO_GEST|CLIENTE_NUEVO|   GRUPO_TASA|NUEVOS_3M|NUEVOS_6M|NUEVOS_9M|NUEVOS_12M|NUEVOS_4M|    GRUPO_MONTO|TASA_VS_MONTO|USUARIO|incremento_monto_riesgos|FLG_DEUDA_PLUS|tipo_cliente_riegos|             USER_V3|LEAD_CALIDAD|SEGMENTO_USER|RANGO_EDAD|RANGO_OFERTA2|PERIODO|RETIRO_GEST|MEJOR_TIPIFICACION|STATUS|FECHA_SOL|BASE|RESULTADO|NUM_ENRIQUECIDO|TIPO_CONTACTO|Q_VENTAS|LOCALIDAD|DESEMBOLSADO|MONTO_DESEMBOLSADO| SBI|CRUCE|PREST_PREVIO|ID_CLIENTE|RANGO_EDAD2|Fecha_Envio|TIPO_BD|COD_BD|NOMB_BD|MES_GESTION| TIPO_CLIENTE|GRUPO_TASA_REENGANCHE|SALDO_DIFERENCIAL_REENG|FLAG_REENG|RETIRO_DESEMBOLSO|FRESCURA|flag_deuda_v_oferta|MGNEG|PERFIL_RO|       TIPO_BASE|PHONE NUMBER| cl_telf2|cl_telf3|cl_telf4|cl_telf5|cl_telf6|cl_telf7|cl_telf8|cl_telf9|cl_telf10|cl_movil|cl_celular|cl_telefono|cl_turno|cl_gestor|cl_asesor|cl_accion|cl_gestion|cl_estado|cl_fecha_gestion|cl_hora_gestion|cl_hits|cl_fecha_llamar|cl_prioridad|cl_orden|cl_predictivo|cl_tiempo|   cl_base|cl_mes|  cl_carga|id_carga|cl_area|fecha_alimentacion|cl_base_ant|cl_accion_ant|cl_fecha_ant|            campania|PROMOCION|PROMOCION2|nombre_base|NumEntidades|p_banco|PERFIL_GLOBAL|    FLG_AAHH|SCORE_TELEFONO|PILOTO_PLAZAS|INTENSIDAD_MAX|          AGENCIA|marca2|marca3|AÑO_DURACION_BASE|MES_DURACION_BASE|            ADDRESS1|

# %%
df_formato.show()
# Out:
# +--------+----------------+----------------+----------------+------------------+--------+--------+------------+----------------+-----------+--------------+----------+-----------+-----------------+------------+---------+--------------+------+------+------+------+------+------+------+------+--------+-------+-----+----+-------------+-----------+-------+----+----------+--------+---------------+---------+----------+--------+---------------+---------+----------+--------+---------------+---------+----------+--------+---------------+---------+------------------+---------+----------------+-------+---------+-------+---------+-------+---------+------------------+-----------------+--------------------+---------+---------------------+-----+---------------+----------+------------+--------+-----------------------+------------+------------+-------------+----+----------+---------+-------------+-------------+---------+---------+---------+----------+---------+---------------+-------------+-------+------------------------+--------------+-------------------+--------------------+------------+-------------+----------+-------------+-------+-----------+------------------+------+---------+----+---------+---------------+-------------+--------+---------+------------+------------------+----+-----+------------+----------+-----------+-----------+-------+------+-------+-----------+-------------+---------------------+-----------------------+----------+-----------------+--------+-------------------+-----+---------+----------------+---------+---------+--------+--------+--------+--------+--------+--------+--------+---------+--------+----------+-----------+--------+---------+---------+---------+----------+---------+----------------+---------------+-------+---------------+------------+--------+-------------+---------+----------+------+----------+--------+-------+------------------+-----------+-------------+------------+--------------------+---------+----------+-----------+------------+-------+-------------+------------+--------------+-------------+--------------+-----------------+------+------+-----------------+-----------------+
# |TIPO_DOI|NUMERO_DOCUMENTO|         NOMBRES|APELLIDO_PATERNO|  APELLIDO_MATERNO|SUCURSAL|  TIENDA|DEPARTAMENTO|       PROVINCIA|   DISTRITO|FEC_NACIMIENTO|OFERTA_MAX|OFERTA_REEN|Tipo_verificacion|GRUPO_RIESGO|proveedor|          lote|estado|Tasa_1|Tasa_2|Tasa_3|Tasa_4|Tasa_5|Tasa_6|Tasa_7|segmento|Campana|PLAZO| TEM|PROPENSION_IC|Desgravamen|  CUOTA|Edad|Oferta_12M|Tasa_12M|Desgravamen_12M|CUOTA_12M|Oferta_18M|Tasa_18M|Desgravamen_18M|CUOTA_18M|Oferta_24M|Tasa_24M|Desgravamen_24M|CUOTA_24M|Oferta_36M|Tasa_36M|Desgravamen_36M|CUOTA_36M|Validador_Telefono|Prioridad|Nombre_prioridad|Deuda_1|Entidad_1|Deuda_2|Entidad_2|Deuda_3|Entidad_3|sucursal_comercial|Agencia_comercial|    Region_comercial|Ubicacion|OfertaMaximaSinSeguro|color|    color_final|PROPENSION|OFERTA_FINAL|GARANTIA|Oferta_Minima_Paperless|RANGO_OFERTA|RANGO_SUELDO|CAPACIDAD_MAX|PEER|PROP_COMER|TIPO_GEST|CLIENTE_NUEVO|   GRUPO_TASA|NUEVOS_3M|NUEVOS_6M|NUEVOS_9M|NUEVOS_12M|NUEVOS_4M|    GRUPO_MONTO|TASA_VS_MONTO|USUARIO|incremento_monto_riesgos|FLG_DEUDA_PLUS|tipo_cliente_riegos|             USER_V3|LEAD_CALIDAD|SEGMENTO_USER|RANGO_EDAD|RANGO_OFERTA2|PERIODO|RETIRO_GEST|MEJOR_TIPIFICACION|STATUS|FECHA_SOL|BASE|RESULTADO|NUM_ENRIQUECIDO|TIPO_CONTACTO|Q_VENTAS|LOCALIDAD|DESEMBOLSADO|MONTO_DESEMBOLSADO| SBI|CRUCE|PREST_PREVIO|ID_CLIENTE|RANGO_EDAD2|Fecha_Envio|TIPO_BD|COD_BD|NOMB_BD|MES_GESTION| TIPO_CLIENTE|GRUPO_TASA_REENGANCHE|SALDO_DIFERENCIAL_REENG|FLAG_REENG|RETIRO_DESEMBOLSO|FRESCURA|flag_deuda_v_oferta|MGNEG|PERFIL_RO|       TIPO_BASE| cl_telf1| cl_telf2|cl_telf3|cl_telf4|cl_telf5|cl_telf6|cl_telf7|cl_telf8|cl_telf9|cl_telf10|cl_movil|cl_celular|cl_telefono|cl_turno|cl_gestor|cl_asesor|cl_accion|cl_gestion|cl_estado|cl_fecha_gestion|cl_hora_gestion|cl_hits|cl_fecha_llamar|cl_prioridad|cl_orden|cl_predictivo|cl_tiempo|   cl_base|cl_mes|  cl_carga|id_carga|cl_area|fecha_alimentacion|cl_base_ant|cl_accion_ant|cl_fecha_ant|            campania|PROMOCION|PROMOCION2|nombre_base|NumEntidades|p_banco|PERFIL_GLOBAL|    FLG_AAHH|SCORE_TELEFONO|PILOTO_PLAZAS|INTENSIDAD_MAX|           marca1|marca2|marca3|AÑO_DURACION_BASE|MES_DURACION_BASE|
# +--------+----------------+----------------+----------------+------------------+--------+--------+------------+----------------+-----------+--------------+----------+-----------+-----------------+------------+---------+--------------+------+------+------+------+------+------+------+------+--------+-------+-----+----+-------------+-----------+-------+----+----------+--------+---------------+---------+----------+--------+---------------+---------+----------+--------+---------------+---------+----------+--------+---------------+---------+------------------+---------+----------------+-------+---------+-------+---------+-------+---------+------------------+-----------------+--------------------+---------+---------------------+-----+---------------+----------+------------+--------+-----------------------+------------+------------+-------------+----+----------+---------+-------------+-------------+---------+---------+---------+----------+---------+---------------+-------------+-------+------------------------+--------------+-------------------+--------------------+------------+-------------+----------+-------------+-------+-----------+------------------+------+---------+----+---------+---------------+-------------+--------+---------+------------+------------------+----+-----+------------+----------+-----------+-----------+-------+------+-------+-----------+-------------+---------------------+-----------------------+----------+-----------------+--------+-------------------+-----+---------+----------------+---------+---------+--------+--------+--------+--------+--------+--------+--------+---------+--------+----------+-----------+--------+---------+---------+---------+----------+---------+----------------+---------------+-------+---------------+------------+--------+-------------+---------+----------+------+----------+--------+-------+------------------+-----------+-------------+------------+--------------------+---------+----------+-----------+------------+-------+-------------+------------+--------------+-------------+--------------+-----------------+------+------+-----------------+-----------------+
# |    NULL|        00006227|  PELAYO ROSALES|          OSORES|              INGA|    NULL|PUCALLPA|     UCAYALI|CORONEL PORTILLO|   CALLERIA|          NULL|     22500|       NULL|             NULL|        NULL|     NULL|    NO CLIENTE|ACTIVO|  50.5|  49.5|  48.5|  46.5|  45.5|  40.5|  NULL|    NULL| 202607|   36|NULL|            2|       NULL|1042.43|  77|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|              NULL|     NULL|            NULL|   NULL|     NULL|   NULL|     NULL|   NULL|     NULL|              NULL|         PUCALLPA|REGION LIMA SUR O...|     NULL|                 NULL| NULL|    VERDE CLARO|      NULL|        NULL|    NULL|                   NULL| 20000-24999|   3500-4000|      1144.87|NULL|      NULL|     NULL|         NULL|   Mayor tasa|     NULL|     NULL|     NULL|      NULL|     NULL|Disminuye Monto|         NULL|   NULL|                    NULL|          NULL|       3.NO CLIENTE|            7. Peers|        NULL|         NULL|  60 A MAS|         NULL|   NULL|       NULL|              NULL|  NULL|     NULL|NULL|     NULL|           NULL|         NULL|    NULL|     NULL|        NULL|              NULL|NULL| NULL|        NULL|      NULL|       NULL|       NULL|   NULL|  NULL|   NULL|       NULL|  DEPENDIENTE|                 NULL|                      0|      NULL|             NULL|       4|                  0|    2|     NULL|SALDO COMPETIDOR|971487730|963816399|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|    NULL|      NULL|       NULL|    NULL|     NULL|     NULL|     NULL|      NULL|        1|            NULL|           NULL|   NULL|           NULL|        NULL|    NULL|         NULL|     NULL|Julio 2026|  NULL|2026-07-01|    NULL|   NULL|              NULL|       NULL|         NULL|        NULL|             SOLODNI|     NULL|      NULL| 2026-07-01|        NULL|   NULL|         NULL|   EMERGENTE|             2|            0|             7|738334 - PUCALLPA|  NULL|  NULL|             2026|               07|
# |    NULL|        00005798|       AURISTELA|          CHAVEZ|   VIDALON DE MORI|    NULL|PUCALLPA|     UCAYALI|CORONEL PORTILLO|   CALLERIA|          NULL|     25000|       NULL|             NULL|        NULL|     NULL|           BOT|ACTIVO|  55.0|  53.0|  51.0|  49.0|  47.0|  45.0|  43.0|    NULL| 202607|   36|NULL|            2|       NULL|1186.59|  62|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|              NULL|     NULL|            NULL|   NULL|     NULL|   NULL|     NULL|   NULL|     NULL|              NULL|         PUCALLPA|REGION LIMA SUR O...|     NULL|                 NULL| NULL|    VERDE CLARO|      NULL|        NULL|    NULL|                   NULL| 25000-29999|   5000-7000|      2619.11|NULL|      NULL|     NULL|         NULL|Mantiene tasa|     NULL|     NULL|     NULL|      NULL|     NULL| Mantiene Monto|         NULL|   NULL|                    NULL|          NULL|       3.NO CLIENTE|1. sunedu & sunarp A|        NULL|         NULL|  60 A MAS|         NULL|   NULL|       NULL|              NULL|  NULL|     NULL|NULL|     NULL|           NULL|         NULL|    NULL|     NULL|        NULL|              NULL|NULL| NULL|        NULL|      NULL|       NULL|       NULL|   NULL|  NULL|   NULL|       NULL|  DEPENDIENTE|                 NULL|                      0|      NULL|             NULL|       4|                  0|    3|     NULL|         Regular|964376735|967679447|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|    NULL|      NULL|       NULL|    NULL|     NULL|     NULL|     NULL|      NULL|        1|            NULL|           NULL|   NULL|           NULL|        NULL|    NULL|         NULL|     NULL|Julio 2026|  NULL|2026-07-01|    NULL|   NULL|              NULL|       NULL|         NULL|        NULL|               MUJER|     NULL|      NULL| 2026-07-01|        NULL|   NULL|         NULL|   EMERGENTE|             3|            0|             6|738334 - PUCALLPA|  NULL|  NULL|             2026|               07|
# |    NULL|        00006521|            OLGA|         ABENSUR|           ALVAREZ|    NULL|  HUACHO|        LIMA|          HUAURA|     HUACHO|          NULL|      8200|       NULL|             NULL|        NULL|     NULL|           BOT|ACTIVO|  54.5|  53.5|  51.5|  NULL|  NULL|  NULL|  NULL|    NULL| 202607|   36|NULL|            6|       NULL| 420.58|  75|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|              NULL|     NULL|            NULL|   NULL|     NULL|   NULL|     NULL|   NULL|     NULL|              NULL|           HUACHO|   REGION LIMA NORTE|     NULL|                 NULL| NULL|    VERDE CLARO|      NULL|        NULL|    NULL|                   NULL|   7000-9999|   1500-2000|      1104.63|NULL|      NULL|     NULL|         NULL|   Mayor tasa|     NULL|     NULL|     NULL|      NULL|     NULL|   Mejora Monto|         NULL|   NULL|                    NULL|          NULL|       3.NO CLIENTE|14. Otros Bancari...|        NULL|         NULL|  60 A MAS|         NULL|   NULL|       NULL|              NULL|  NULL|     NULL|NULL|     NULL|           NULL|         NULL|    NULL|     NULL|        NULL|              NULL|NULL| NULL|        NULL|      NULL|       NULL|       NULL|   NULL|  NULL|   NULL|       NULL|  DEPENDIENTE|                 NULL|                      0|      NULL|             NULL|       4|                  -|    3|     NULL|         Regular|958632458|990755443|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|    NULL|      NULL|       NULL|    NULL|     NULL|     NULL|     NULL|      NULL|        1|            NULL|           NULL|   NULL|           NULL|        NULL|    NULL|         NULL|     NULL|Julio 2026|  NULL|2026-07-01|    NULL|   NULL|              NULL|       NULL|         NULL|        NULL|               MUJER|     NULL|      NULL| 2026-07-01|        NULL|   NULL|         NULL|NO EMERGENTE|             3|            0|             6|  739467 - HUACHO|  NULL|  NULL|             2026|               07|
# |    NULL|        00007374|          NORITA|            MERA|TENAZOA DE GONGORA|    NULL|PUCALLPA|     UCAYALI|CORONEL PORTILLO|   CALLERIA|          NULL|      8700|       NULL|             NULL|        NULL|     NULL|           BOT|ACTIVO|  83.0|  83.0|  81.0|  67.0|  NULL|  NULL|  NULL|    NULL| 202607|   36|NULL|            3|       NULL| 505.86|  63|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|              NULL|     NULL|            NULL|   NULL|     NULL|   NULL|     NULL|   NULL|     NULL|              NULL|         PUCALLPA|REGION LIMA SUR O...|     NULL|                 NULL| NULL| NARANJA OSCURO|      NULL|        NULL|    NULL|                   NULL|   7000-9999|   3000-3500|      767.412|NULL|      NULL|     NULL|         NULL|Mantiene tasa|     NULL|     NULL|     NULL|      NULL|     NULL| Mantiene Monto|         NULL|   NULL|                    NULL|          NULL|       3.NO CLIENTE|14. Otros Bancari...|        NULL|         NULL|  60 A MAS|         NULL|   NULL|       NULL|              NULL|  NULL|     NULL|NULL|     NULL|           NULL|         NULL|    NULL|     NULL|        NULL|              NULL|NULL| NULL|        NULL|      NULL|       NULL|       NULL|   NULL|  NULL|   NULL|       NULL|INDEPENDIENTE|                 NULL|                      0|      NULL|             NULL|       4|                  0|    4|     NULL|         Regular|944408041|980310607|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|    NULL|      NULL|       NULL|    NULL|     NULL|     NULL|     NULL|      NULL|        1|            NULL|           NULL|   NULL|           NULL|        NULL|    NULL|         NULL|     NULL|Julio 2026|  NULL|2026-07-01|    NULL|   NULL|              NULL|       NULL|         NULL|        NULL|             SOLODNI|     NULL|      NULL| 2026-07-01|        NULL|   NULL|         NULL|NO EMERGENTE|             2|            0|             6|738334 - PUCALLPA|  NULL|  NULL|             2026|               07|
# |    NULL|        00005667|         GHEGNIS|          TORRES|        DEL AGUILA|    NULL|PUCALLPA|     UCAYALI|CORONEL PORTILLO|   CALLERIA|          NULL|      5300|       NULL|             NULL|        NULL|     NULL|    NO CLIENTE|ACTIVO|  72.0|  70.0|  NULL|  NULL|  NULL|  NULL|  NULL|    NULL| 202607|   36|NULL|            3|       NULL| 315.09|  60|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|              NULL|     NULL|            NULL|   NULL|     NULL|   NULL|     NULL|   NULL|     NULL|              NULL|         PUCALLPA|REGION LIMA SUR O...|     NULL|                 NULL| NULL| AMARILLO CLARO|      NULL|        NULL|    NULL|                   NULL|   5000-6999|   3500-4000|      719.673|NULL|      NULL|     NULL|         NULL|Mantiene tasa|     NULL|     NULL|     NULL|      NULL|     NULL|   Mejora Monto|         NULL|   NULL|                    NULL|          NULL|       3.NO CLIENTE|   9. Dependiente BN|        NULL|         NULL|  60 A MAS|         NULL|   NULL|       NULL|              NULL|  NULL|     NULL|NULL|     NULL|           NULL|         NULL|    NULL|     NULL|        NULL|              NULL|NULL| NULL|        NULL|      NULL|       NULL|       NULL|   NULL|  NULL|   NULL|       NULL|  DEPENDIENTE|                 NULL|                      0|      NULL|             NULL|       3|                  0|    1|     NULL|         Regular|998661915|998661249|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|    NULL|      NULL|       NULL|    NULL|     NULL|     NULL|     NULL|      NULL|        1|            NULL|           NULL|   NULL|           NULL|        NULL|    NULL|         NULL|     NULL|Julio 2026|  NULL|2026-07-01|    NULL|   NULL|              NULL|       NULL|         NULL|        NULL|               MUJER|     NULL|      NULL| 2026-07-01|        NULL|   NULL|         NULL|NO EMERGENTE|             3|            0|            10|738334 - PUCALLPA|  NULL|  NULL|             2026|               07|
# |    NULL|        00005700|   BLANCA NIEVES|          CAUPER|            CAUPER|    NULL|PUCALLPA|     UCAYALI|CORONEL PORTILLO|   CALLERIA|          NULL|     17800|       NULL|             NULL|        NULL|     NULL|    NO CLIENTE|ACTIVO|  65.0|  64.0|  63.0|  61.0|  57.0|  52.0|  NULL|    NULL| 202607|   36|NULL|            2|       NULL| 916.94|  70|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|              NULL|     NULL|            NULL|   NULL|     NULL|   NULL|     NULL|   NULL|     NULL|              NULL|         PUCALLPA|REGION LIMA SUR O...|     NULL|                 NULL| NULL| AMARILLO CLARO|      NULL|        NULL|    NULL|                   NULL| 15000-19999|   2000-2500|      1163.19|NULL|      NULL|     NULL|         NULL|   Mayor tasa|     NULL|     NULL|     NULL|      NULL|     NULL| Mantiene Monto|         NULL|   NULL|                    NULL|          NULL|       3.NO CLIENTE|            7. Peers|        NULL|         NULL|  60 A MAS|         NULL|   NULL|       NULL|              NULL|  NULL|     NULL|NULL|     NULL|           NULL|         NULL|    NULL|     NULL|        NULL|              NULL|NULL| NULL|        NULL|      NULL|       NULL|       NULL|   NULL|  NULL|   NULL|       NULL|     INFORMAL|                 NULL|                      0|      NULL|             NULL|       4|                  1|    3|     NULL|SALDO COMPETIDOR|979496298|962576923|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|    NULL|      NULL|       NULL|    NULL|     NULL|     NULL|     NULL|      NULL|        1|            NULL|           NULL|   NULL|           NULL|        NULL|    NULL|         NULL|     NULL|Julio 2026|  NULL|2026-07-01|    NULL|   NULL|              NULL|       NULL|         NULL|        NULL|               MUJER|     NULL|      NULL| 2026-07-01|        NULL|   NULL|         NULL|NO EMERGENTE|             1|            0|             7|738334 - PUCALLPA|  NULL|  NULL|             2026|               07|
# |    NULL|        00008085|         JUANITA|      MONTENEGRO|            DE CHU|    NULL|PUCALLPA|     UCAYALI|CORONEL PORTILLO|   CALLERIA|          NULL|      6200|       NULL|             NULL|        NULL|     NULL|           BOT|ACTIVO|  67.0|  65.0|  63.0|  NULL|  NULL|  NULL|  NULL|    NULL| 202607|   36|NULL|            3|       NULL| 349.63|  64|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|              NULL|     NULL|            NULL|   NULL|     NULL|   NULL|     NULL|   NULL|     NULL|              NULL|         PUCALLPA|REGION LIMA SUR O...|     NULL|                 NULL| NULL|AMARILLO OSCURO|      NULL|        NULL|    NULL|                   NULL|   5000-6999|   1500-2000|      1057.24|NULL|      NULL|     NULL|         NULL|   Menor tasa|     NULL|     NULL|     NULL|      NULL|     NULL|   Mejora Monto|         NULL|   NULL|                    NULL|          NULL|       3.NO CLIENTE|14. Otros Bancari...|        NULL|         NULL|  60 A MAS|         NULL|   NULL|       NULL|              NULL|  NULL|     NULL|NULL|     NULL|           NULL|         NULL|    NULL|     NULL|        NULL|              NULL|NULL| NULL|        NULL|      NULL|       NULL|       NULL|   NULL|  NULL|   NULL|       NULL|  DEPENDIENTE|                 NULL|                      0|      NULL|             NULL|       4|                  -|    1|     NULL|         Regular|921634074|942920506|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|    NULL|      NULL|       NULL|    NULL|     NULL|     NULL|     NULL|      NULL|        1|            NULL|           NULL|   NULL|           NULL|        NULL|    NULL|         NULL|     NULL|Julio 2026|  NULL|2026-07-01|    NULL|   NULL|              NULL|       NULL|         NULL|        NULL|             SOLODNI|     NULL|      NULL| 2026-07-01|        NULL|   NULL|         NULL|NO EMERGENTE|             2|            0|             6|738334 - PUCALLPA|  NULL|  NULL|             2026|               07|
# |    NULL|        00008091|      ANA ESTHER|          TINOCO| SILVA DE REATEGUI|    NULL|PUCALLPA|     UCAYALI|CORONEL PORTILLO|YARINACOCHA|          NULL|     23000|       NULL|             NULL|        NULL|     NULL|    NO CLIENTE|ACTIVO|  60.0|  58.0|  56.0|  54.0|  52.0|  50.0|  NULL|    NULL| 202607|   36|NULL|            4|       NULL|1164.21|  64|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|              NULL|     NULL|            NULL|   NULL|     NULL|   NULL|     NULL|   NULL|     NULL|              NULL|         PUCALLPA|REGION LIMA SUR O...|     NULL|                 NULL| NULL|    VERDE CLARO|      NULL|        NULL|    NULL|                   NULL| 20000-24999|  7000-10000|      6185.46|NULL|      NULL|     NULL|         NULL|Mantiene tasa|     NULL|     NULL|     NULL|      NULL|     NULL| Mantiene Monto|         NULL|   NULL|                    NULL|          NULL|       3.NO CLIENTE|2. sunedu & sunarp B|        NULL|         NULL|  60 A MAS|         NULL|   NULL|       NULL|              NULL|  NULL|     NULL|NULL|     NULL|           NULL|         NULL|    NULL|     NULL|        NULL|              NULL|NULL| NULL|        NULL|      NULL|       NULL|       NULL|   NULL|  NULL|   NULL|       NULL|INDEPENDIENTE|                 NULL|                      0|      NULL|             NULL|       4|                  -|    4|     NULL|         Regular|961076862|961076868|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|    NULL|      NULL|       NULL|    NULL|     NULL|     NULL|     NULL|      NULL|        1|            NULL|           NULL|   NULL|           NULL|        NULL|    NULL|         NULL|     NULL|Julio 2026|  NULL|2026-07-01|    NULL|   NULL|              NULL|       NULL|         NULL|        NULL|               MUJER|     NULL|      NULL| 2026-07-01|        NULL|   NULL|         NULL|   EMERGENTE|             1|            0|             7|738334 - PUCALLPA|  NULL|  NULL|             2026|               07|
# |    NULL|        00014115|            GERI|          GARCIA|              LUNA|    NULL|PUCALLPA|     UCAYALI|CORONEL PORTILLO|   MANANTAY|          NULL|     16000|       NULL|             NULL|        NULL|     NULL|NO CLIENTE CET|ACTIVO|  56.0|  55.0|  54.0|  52.0|  50.0|  46.0|  NULL|    NULL| 202607|   36|NULL|            1|       NULL|  781.1|  65|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|              NULL|     NULL|            NULL|   NULL|     NULL|   NULL|     NULL|   NULL|     NULL|              NULL|         PUCALLPA|REGION LIMA SUR O...|     NULL|                 NULL| NULL|   VERDE OSCURO|      NULL|        NULL|    NULL|                   NULL| 15000-19999|   1500-2000|      888.923|NULL|      NULL|     NULL|         NULL|   Mayor tasa|     NULL|     NULL|     NULL|      NULL|     NULL|   Mejora Monto|         NULL|   NULL|                    NULL|          NULL|       3.NO CLIENTE|            7. Peers|        NULL|         NULL|  60 A MAS|         NULL|   NULL|       NULL|              NULL|  NULL|     NULL|NULL|     NULL|           NULL|         NULL|    NULL|     NULL|        NULL|              NULL|NULL| NULL|        NULL|      NULL|       NULL|       NULL|   NULL|  NULL|   NULL|       NULL|  DEPENDIENTE|                 NULL|                      0|      NULL|             NULL|       4|                  1|    3|     NULL|SALDO COMPETIDOR|994238964|996759358|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|    NULL|      NULL|       NULL|    NULL|     NULL|     NULL|     NULL|      NULL|        1|            NULL|           NULL|   NULL|           NULL|        NULL|    NULL|         NULL|     NULL|Julio 2026|  NULL|2026-07-01|    NULL|   NULL|              NULL|       NULL|         NULL|        NULL|             SOLODNI|     NULL|      NULL| 2026-07-01|        NULL|   NULL|         NULL|   EMERGENTE|             3|            0|            10|738334 - PUCALLPA|  NULL|  NULL|             2026|               07|
# |    NULL|        00015057|     MARIA ELENA|            ISLA|             HOYOS|    NULL|PUCALLPA|     UCAYALI|CORONEL PORTILLO|   CALLERIA|          NULL|     18000|       NULL|             NULL|        NULL|     NULL|           BOT|ACTIVO|  53.0|  51.0|  49.0|  47.0|  45.0|  43.0|  NULL|    NULL| 202607|   36|NULL|            5|       NULL| 854.34|  70|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|              NULL|     NULL|            NULL|   NULL|     NULL|   NULL|     NULL|   NULL|     NULL|              NULL|         PUCALLPA|REGION LIMA SUR O...|     NULL|                 NULL| NULL|    VERDE CLARO|      NULL|        NULL|    NULL|                   NULL| 15000-19999|   2000-2500|      1167.27|NULL|      NULL|     NULL|         NULL|   Menor tasa|     NULL|     NULL|     NULL|      NULL|     NULL| Mantiene Monto|         NULL|   NULL|                    NULL|          NULL|       3.NO CLIENTE|14. Otros Bancari...|        NULL|         NULL|  60 A MAS|         NULL|   NULL|       NULL|              NULL|  NULL|     NULL|NULL|     NULL|           NULL|         NULL|    NULL|     NULL|        NULL|              NULL|NULL| NULL|        NULL|      NULL|       NULL|       NULL|   NULL|  NULL|   NULL|       NULL|  DEPENDIENTE|                 NULL|                      0|      NULL|             NULL|       4|                  -|    6|     NULL|         Regular|961622680|973100541|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|    NULL|      NULL|       NULL|    NULL|     NULL|     NULL|     NULL|      NULL|        1|            NULL|           NULL|   NULL|           NULL|        NULL|    NULL|         NULL|     NULL|Julio 2026|  NULL|2026-07-01|    NULL|   NULL|              NULL|       NULL|         NULL|        NULL|               MUJER|     NULL|      NULL| 2026-07-01|        NULL|   NULL|         NULL|NO EMERGENTE|             1|            0|             6|738334 - PUCALLPA|  NULL|  NULL|             2026|               07|
# |    NULL|        00015085|    ANA VIRGINIA|       RODRIGUEZ|SANCHEZ DE DELGADO|    NULL| SULLANA|       PIURA|          TALARA|    LOBITOS|          NULL|     16600|       NULL|             NULL|        NULL|     NULL|    NO CLIENTE|ACTIVO|  59.0|  57.0|  55.0|  53.0|  51.0|  49.0|  NULL|    NULL| 202607|   36|NULL|            2|       NULL| 832.81|  65|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|              NULL|     NULL|            NULL|   NULL|     NULL|   NULL|     NULL|   NULL|     NULL|              NULL|          SULLANA|        REGION NORTE|     NULL|                 NULL| NULL|   VERDE OSCURO|      NULL|        NULL|    NULL|                   NULL| 15000-19999|   2000-2500|      948.665|NULL|      NULL|     NULL|         NULL|Mantiene tasa|     NULL|     NULL|     NULL|      NULL|     NULL|   Mejora Monto|         NULL|   NULL|                    NULL|          NULL|       3.NO CLIENTE|            7. Peers|        NULL|         NULL|  60 A MAS|         NULL|   NULL|       NULL|              NULL|  NULL|     NULL|NULL|     NULL|           NULL|         NULL|    NULL|     NULL|        NULL|              NULL|NULL| NULL|        NULL|      NULL|       NULL|       NULL|   NULL|  NULL|   NULL|       NULL|INDEPENDIENTE|                 NULL|                      0|      NULL|             NULL|       4|                  -|    3|     NULL|         Regular|928368023|928652434|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|    NULL|      NULL|       NULL|    NULL|     NULL|     NULL|     NULL|      NULL|        1|            NULL|           NULL|   NULL|           NULL|        NULL|    NULL|         NULL|     NULL|Julio 2026|  NULL|2026-07-01|    NULL|   NULL|              NULL|       NULL|         NULL|        NULL|               MUJER|     NULL|      NULL| 2026-07-01|        NULL|   NULL|         NULL|NO EMERGENTE|             3|            0|             7| 734270 - SULLANA|  NULL|  NULL|             2026|               07|
# |    NULL|        00015617|         BARBARA|          CHAVEZ|            GUERRA|    NULL|PUCALLPA|     UCAYALI|CORONEL PORTILLO|   CALLERIA|          NULL|      5000|       NULL|             NULL|        NULL|     NULL|           BOT|ACTIVO|  68.0|  64.0|  NULL|  NULL|  NULL|  NULL|  NULL|    NULL| 202607|   36|NULL|            5|       NULL| 284.16|  60|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|              NULL|     NULL|            NULL|   NULL|     NULL|   NULL|     NULL|   NULL|     NULL|              NULL|         PUCALLPA|REGION LIMA SUR O...|     NULL|                 NULL| NULL| AMARILLO CLARO|      NULL|        NULL|    NULL|                   NULL|   5000-6999|   2000-2500|       1402.9|NULL|      NULL|     NULL|         NULL|   Mayor tasa|     NULL|     NULL|     NULL|      NULL|     NULL| Mantiene Monto|         NULL|   NULL|                    NULL|          NULL|       3.NO CLIENTE|14. Otros Bancari...|        NULL|         NULL|  60 A MAS|         NULL|   NULL|       NULL|              NULL|  NULL|     NULL|NULL|     NULL|           NULL|         NULL|    NULL|     NULL|        NULL|              NULL|NULL| NULL|        NULL|      NULL|       NULL|       NULL|   NULL|  NULL|   NULL|       NULL|INDEPENDIENTE|                 NULL|                      0|      NULL|             NULL|       4|                  -|    1|     NULL|         Regular|954433868|952088958|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|    NULL|      NULL|       NULL|    NULL|     NULL|     NULL|     NULL|      NULL|        1|            NULL|           NULL|   NULL|           NULL|        NULL|    NULL|         NULL|     NULL|Julio 2026|  NULL|2026-07-01|    NULL|   NULL|              NULL|       NULL|         NULL|        NULL|SOLO CON DNI - RE...|     NULL|      NULL| 2026-07-01|        NULL|   NULL|         NULL|NO EMERGENTE|             3|            0|             6|738334 - PUCALLPA|  NULL|  NULL|             2026|               07|
# |    NULL|        00015698|   MARCO ANTONIO|            DIAZ|              APAC|    NULL|PUCALLPA|     UCAYALI|CORONEL PORTILLO|   MANANTAY|          NULL|     13600|       NULL|             NULL|        NULL|     NULL|    NO CLIENTE|ACTIVO|  57.0|  55.0|  53.0|  51.0|  49.0|  NULL|  NULL|    NULL| 202607|   36|NULL|            1|       NULL|  682.3|  60|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|              NULL|     NULL|            NULL|   NULL|     NULL|   NULL|     NULL|   NULL|     NULL|              NULL|         PUCALLPA|REGION LIMA SUR O...|     NULL|                 NULL| NULL|   VERDE OSCURO|      NULL|        NULL|    NULL|                   NULL| 10000-14999|   3500-4000|      917.715|NULL|      NULL|     NULL|         NULL|   Menor tasa|     NULL|     NULL|     NULL|      NULL|     NULL|   Mejora Monto|         NULL|   NULL|                    NULL|          NULL|       3.NO CLIENTE|            7. Peers|        NULL|         NULL|  60 A MAS|         NULL|   NULL|       NULL|              NULL|  NULL|     NULL|NULL|     NULL|           NULL|         NULL|    NULL|     NULL|        NULL|              NULL|NULL| NULL|        NULL|      NULL|       NULL|       NULL|   NULL|  NULL|   NULL|       NULL|  DEPENDIENTE|                 NULL|                      0|      NULL|             NULL|       4|                  0|    3|     NULL|SALDO COMPETIDOR|943262635|959001902|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|    NULL|      NULL|       NULL|    NULL|     NULL|     NULL|     NULL|      NULL|        1|            NULL|           NULL|   NULL|           NULL|        NULL|    NULL|         NULL|     NULL|Julio 2026|  NULL|2026-07-01|    NULL|   NULL|              NULL|       NULL|         NULL|        NULL|             SOLODNI|     NULL|      NULL| 2026-07-01|        NULL|   NULL|         NULL|NO EMERGENTE|             1|            0|             7|738334 - PUCALLPA|  NULL|  NULL|             2026|               07|
# |    NULL|        00016324|            RUBI|          CULQUI|             GOMEZ|    NULL|PUCALLPA|     UCAYALI|CORONEL PORTILLO|   CALLERIA|          NULL|     23000|       NULL|             NULL|        NULL|     NULL|    NO CLIENTE|ACTIVO|  50.5|  49.5|  48.5|  46.5|  45.5|  40.5|  NULL|    NULL| 202607|   36|NULL|            3|       NULL| 1065.6|  60|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|              NULL|     NULL|            NULL|   NULL|     NULL|   NULL|     NULL|   NULL|     NULL|              NULL|         PUCALLPA|REGION LIMA SUR O...|     NULL|                 NULL| NULL|    VERDE CLARO|      NULL|        NULL|    NULL|                   NULL| 20000-24999|   2000-2500|       1348.7|NULL|      NULL|     NULL|         NULL|   Mayor tasa|     NULL|     NULL|     NULL|      NULL|     NULL|Disminuye Monto|         NULL|   NULL|                    NULL|          NULL|       3.NO CLIENTE|2. sunedu & sunarp B|        NULL|         NULL|  60 A MAS|         NULL|   NULL|       NULL|              NULL|  NULL|     NULL|NULL|     NULL|           NULL|         NULL|    NULL|     NULL|        NULL|              NULL|NULL| NULL|        NULL|      NULL|       NULL|       NULL|   NULL|  NULL|   NULL|       NULL|  DEPENDIENTE|                 NULL|                      0|      NULL|             NULL|       4|                  1|    2|     NULL|SALDO COMPETIDOR|947321685|908608358|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|    NULL|      NULL|       NULL|    NULL|     NULL|     NULL|     NULL|      NULL|        1|            NULL|           NULL|   NULL|           NULL|        NULL|    NULL|         NULL|     NULL|Julio 2026|  NULL|2026-07-01|    NULL|   NULL|              NULL|       NULL|         NULL|        NULL|               MUJER|     NULL|      NULL| 2026-07-01|        NULL|   NULL|         NULL|   EMERGENTE|             1|            0|             7|738334 - PUCALLPA|  NULL|  NULL|             2026|               07|
# |    NULL|        00016909|    LUZ ANGELICA|         SALCEDO|            TORRES|    NULL|PUCALLPA|     UCAYALI|CORONEL PORTILLO|   CALLERIA|          NULL|      7000|       NULL|             NULL|        NULL|     NULL|           BOT|ACTIVO|  54.5|  53.5|  51.5|  NULL|  NULL|  NULL|  NULL|    NULL| 202607|   36|NULL|            4|       NULL| 359.03|  76|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|              NULL|     NULL|            NULL|   NULL|     NULL|   NULL|     NULL|   NULL|     NULL|              NULL|         PUCALLPA|REGION LIMA SUR O...|     NULL|                 NULL| NULL|    VERDE CLARO|      NULL|        NULL|    NULL|                   NULL|   7000-9999|   2000-2500|      1430.59|NULL|      NULL|     NULL|         NULL|   Mayor tasa|     NULL|     NULL|     NULL|      NULL|     NULL| Mantiene Monto|         NULL|   NULL|                    NULL|          NULL|       3.NO CLIENTE|2. sunedu & sunarp B|        NULL|         NULL|  60 A MAS|         NULL|   NULL|       NULL|              NULL|  NULL|     NULL|NULL|     NULL|           NULL|         NULL|    NULL|     NULL|        NULL|              NULL|NULL| NULL|        NULL|      NULL|       NULL|       NULL|   NULL|  NULL|   NULL|       NULL|  DEPENDIENTE|                 NULL|                      0|      NULL|             NULL|       4|                  -|    1|     NULL|         Regular|961585299|973707352|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|    NULL|      NULL|       NULL|    NULL|     NULL|     NULL|     NULL|      NULL|        1|            NULL|           NULL|   NULL|           NULL|        NULL|    NULL|         NULL|     NULL|Julio 2026|  NULL|2026-07-01|    NULL|   NULL|              NULL|       NULL|         NULL|        NULL|               MUJER|     NULL|      NULL| 2026-07-01|        NULL|   NULL|         NULL|NO EMERGENTE|             2|            0|             6|738334 - PUCALLPA|  NULL|  NULL|             2026|               07|
# |    NULL|        00017295|    FIDEL CARLOS|           MALCA|         HERNANDEZ|    NULL|PUCALLPA|     UCAYALI|CORONEL PORTILLO|   MANANTAY|          NULL|      5000|       NULL|             NULL|        NULL|     NULL|           BOT|ACTIVO|  65.0|  63.0|  NULL|  NULL|  NULL|  NULL|  NULL|    NULL| 202607|   36|NULL|            6|       NULL| 281.96|  66|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|              NULL|     NULL|            NULL|   NULL|     NULL|   NULL|     NULL|   NULL|     NULL|              NULL|         PUCALLPA|REGION LIMA SUR O...|     NULL|                 NULL| NULL| AMARILLO CLARO|      NULL|        NULL|    NULL|                   NULL|   5000-6999|   3000-3500|      2048.97|NULL|      NULL|     NULL|         NULL|Mantiene tasa|     NULL|     NULL|     NULL|      NULL|     NULL| Mantiene Monto|         NULL|   NULL|                    NULL|          NULL|       3.NO CLIENTE|2. sunedu & sunarp B|        NULL|         NULL|  60 A MAS|         NULL|   NULL|       NULL|              NULL|  NULL|     NULL|NULL|     NULL|           NULL|         NULL|    NULL|     NULL|        NULL|              NULL|NULL| NULL|        NULL|      NULL|       NULL|       NULL|   NULL|  NULL|   NULL|       NULL|  DEPENDIENTE|                 NULL|                      0|      NULL|             NULL|       3|                  -|    1|     NULL|         Regular|948288505|961079099|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|    NULL|      NULL|       NULL|    NULL|     NULL|     NULL|     NULL|      NULL|        1|            NULL|           NULL|   NULL|           NULL|        NULL|    NULL|         NULL|     NULL|Julio 2026|  NULL|2026-07-01|    NULL|   NULL|              NULL|       NULL|         NULL|        NULL|             SOLODNI|     NULL|      NULL| 2026-07-01|        NULL|   NULL|         NULL|NO EMERGENTE|             3|            0|             6|738334 - PUCALLPA|  NULL|  NULL|             2026|               07|
# |    NULL|        00017321|MARIA DEL CARMEN|         VASQUEZ|             PEÃ‘A|    NULL|PUCALLPA|     UCAYALI|CORONEL PORTILLO|   CALLERIA|          NULL|      9600|       NULL|             NULL|        NULL|     NULL|    NO CLIENTE|ACTIVO|  56.0|  55.0|  54.0|  50.0|  NULL|  NULL|  NULL|    NULL| 202607|   36|NULL|            2|       NULL| 485.93|  66|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|              NULL|     NULL|            NULL|   NULL|     NULL|   NULL|     NULL|   NULL|     NULL|              NULL|         PUCALLPA|REGION LIMA SUR O...|     NULL|                 NULL| NULL|   VERDE OSCURO|      NULL|        NULL|    NULL|                   NULL|   7000-9999|   1500-2000|      558.031|NULL|      NULL|     NULL|         NULL|   Menor tasa|     NULL|     NULL|     NULL|      NULL|     NULL|   Mejora Monto|         NULL|   NULL|                    NULL|          NULL|       3.NO CLIENTE|            7. Peers|        NULL|         NULL|  60 A MAS|         NULL|   NULL|       NULL|              NULL|  NULL|     NULL|NULL|     NULL|           NULL|         NULL|    NULL|     NULL|        NULL|              NULL|NULL| NULL|        NULL|      NULL|       NULL|       NULL|   NULL|  NULL|   NULL|       NULL|  DEPENDIENTE|                 NULL|                      0|      NULL|             NULL|       4|                  0|    1|     NULL|SALDO COMPETIDOR|936270463|947803161|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|    NULL|      NULL|       NULL|    NULL|     NULL|     NULL|     NULL|      NULL|        1|            NULL|           NULL|   NULL|           NULL|        NULL|    NULL|         NULL|     NULL|Julio 2026|  NULL|2026-07-01|    NULL|   NULL|              NULL|       NULL|         NULL|        NULL|               MUJER|     NULL|      NULL| 2026-07-01|        NULL|   NULL|         NULL|NO EMERGENTE|             1|            0|             7|738334 - PUCALLPA|  NULL|  NULL|             2026|               07|
# |    NULL|        00017668|  JUAN EDILBERTO|         ARRIAGA|          CAMPRUBI|    NULL|PUCALLPA|     UCAYALI|CORONEL PORTILLO|   CALLERIA|          NULL|     19100|       NULL|             NULL|        NULL|     NULL|    NO CLIENTE|ACTIVO|  51.0|  49.0|  47.0|  45.0|  43.0|  41.0|  NULL|    NULL| 202607|   36|NULL|            2|       NULL| 889.24|  69|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|              NULL|     NULL|            NULL|   NULL|     NULL|   NULL|     NULL|   NULL|     NULL|              NULL|         PUCALLPA|REGION LIMA SUR O...|     NULL|                 NULL| NULL|    VERDE CLARO|      NULL|        NULL|    NULL|                   NULL| 15000-19999|   2500-3000|      994.739|NULL|      NULL|     NULL|         NULL|Mantiene tasa|     NULL|     NULL|     NULL|      NULL|     NULL|Disminuye Monto|         NULL|   NULL|                    NULL|          NULL|       3.NO CLIENTE|            7. Peers|        NULL|         NULL|  60 A MAS|         NULL|   NULL|       NULL|              NULL|  NULL|     NULL|NULL|     NULL|           NULL|         NULL|    NULL|     NULL|        NULL|              NULL|NULL| NULL|        NULL|      NULL|       NULL|       NULL|   NULL|  NULL|   NULL|       NULL|  DEPENDIENTE|                 NULL|                      0|      NULL|             NULL|       4|                  0|    0|     NULL|         Regular|960530417|966338677|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|    NULL|      NULL|       NULL|    NULL|     NULL|     NULL|     NULL|      NULL|        1|            NULL|           NULL|   NULL|           NULL|        NULL|    NULL|         NULL|     NULL|Julio 2026|  NULL|2026-07-01|    NULL|   NULL|              NULL|       NULL|         NULL|        NULL|             SOLODNI|     NULL|      NULL| 2026-07-01|        NULL|   NULL|         NULL|NO EMERGENTE|             3|            0|             7|738334 - PUCALLPA|  NULL|  NULL|             2026|               07|
# |    NULL|        00024183|     PEDRO PABLO|          RIVERO|         FERNANDEZ|    NULL|PUCALLPA|     UCAYALI|CORONEL PORTILLO| CAMPOVERDE|          NULL|      5100|       NULL|             NULL|        NULL|     NULL|NO CLIENTE CET|ACTIVO|  59.0|  57.0|  NULL|  NULL|  NULL|  NULL|  NULL|    NULL| 202607|   36|NULL|            1|       NULL| 274.08|  74|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|              NULL|     NULL|            NULL|   NULL|     NULL|   NULL|     NULL|   NULL|     NULL|              NULL|         PUCALLPA|REGION LIMA SUR O...|     NULL|                 NULL| NULL|   VERDE OSCURO|      NULL|        NULL|    NULL|                   NULL|   5000-6999|    930-1500|      324.803|NULL|      NULL|     NULL|         NULL|   Menor tasa|     NULL|     NULL|     NULL|      NULL|     NULL|   Mejora Monto|         NULL|   NULL|                    NULL|          NULL|       3.NO CLIENTE|            7. Peers|        NULL|         NULL|  60 A MAS|         NULL|   NULL|       NULL|              NULL|  NULL|     NULL|NULL|     NULL|           NULL|         NULL|    NULL|     NULL|        NULL|              NULL|NULL| NULL|        NULL|      NULL|       NULL|       NULL|   NULL|  NULL|   NULL|       NULL|     INFORMAL|                 NULL|                      0|      NULL|             NULL|       4|                  0|    1|     NULL|SALDO COMPETIDOR|921460362|921460477|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|    NULL|      NULL|       NULL|    NULL|     NULL|     NULL|     NULL|      NULL|        1|            NULL|           NULL|   NULL|           NULL|        NULL|    NULL|         NULL|     NULL|Julio 2026|  NULL|2026-07-01|    NULL|   NULL|              NULL|       NULL|         NULL|        NULL|             SOLODNI|     NULL|      NULL| 2026-07-01|        NULL|   NULL|         NULL|NO EMERGENTE|             1|            0|             8|738334 - PUCALLPA|  NULL|  NULL|             2026|               07|
# |    NULL|        00026430|            JUAN|        REATEGUI|            MAYNAS|    NULL|PUCALLPA|     UCAYALI|CORONEL PORTILLO|YARINACOCHA|          NULL|     20000|       NULL|             NULL|        NULL|     NULL|    NO CLIENTE|ACTIVO|  51.0|  50.0|  49.0|  47.0|  46.0|  41.0|  NULL|    NULL| 202607|   36|NULL|            2|       NULL| 931.15|  69|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|      NULL|    NULL|           NULL|     NULL|              NULL|     NULL|            NULL|   NULL|     NULL|   NULL|     NULL|   NULL|     NULL|              NULL|         PUCALLPA|REGION LIMA SUR O...|     NULL|                 NULL| NULL|    VERDE CLARO|      NULL|        NULL|    NULL|                   NULL| 20000-24999|   1500-2000|      1193.16|NULL|      NULL|     NULL|         NULL|   Mayor tasa|     NULL|     NULL|     NULL|      NULL|     NULL| Mantiene Monto|         NULL|   NULL|                    NULL|          NULL|       3.NO CLIENTE|            7. Peers|        NULL|         NULL|  60 A MAS|         NULL|   NULL|       NULL|              NULL|  NULL|     NULL|NULL|     NULL|           NULL|         NULL|    NULL|     NULL|        NULL|              NULL|NULL| NULL|        NULL|      NULL|       NULL|       NULL|   NULL|  NULL|   NULL|       NULL|INDEPENDIENTE|                 NULL|                      0|      NULL|             NULL|       4|                  1|    4|     NULL|SALDO COMPETIDOR|978509387|932749339|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|    NULL|      NULL|       NULL|    NULL|     NULL|     NULL|     NULL|      NULL|        1|            NULL|           NULL|   NULL|           NULL|        NULL|    NULL|         NULL|     NULL|Julio 2026|  NULL|2026-07-01|    NULL|   NULL|              NULL|       NULL|         NULL|        NULL|             SOLODNI|     NULL|      NULL| 2026-07-01|        NULL|   NULL|         NULL|   EMERGENTE|             1|            0|             7|738334 - PUCALLPA|  NULL|  NULL|             2026|               07|
# +--------+----------------+----------------+----------------+------------------+--------+--------+------------+----------------+-----------+--------------+----------+-----------+-----------------+------------+---------+--------------+------+------+------+------+------+------+------+------+--------+-------+-----+----+-------------+-----------+-------+----+----------+--------+---------------+---------+----------+--------+---------------+---------+----------+--------+---------------+---------+----------+--------+---------------+---------+------------------+---------+----------------+-------+---------+-------+---------+-------+---------+------------------+-----------------+--------------------+---------+---------------------+-----+---------------+----------+------------+--------+-----------------------+------------+------------+-------------+----+----------+---------+-------------+-------------+---------+---------+---------+----------+---------+---------------+-------------+-------+------------------------+--------------+-------------------+--------------------+------------+-------------+----------+-------------+-------+-----------+------------------+------+---------+----+---------+---------------+-------------+--------+---------+------------+------------------+----+-----+------------+----------+-----------+-----------+-------+------+-------+-----------+-------------+---------------------+-----------------------+----------+-----------------+--------+-------------------+-----+---------+----------------+---------+---------+--------+--------+--------+--------+--------+--------+--------+---------+--------+----------+-----------+--------+---------+---------+---------+----------+---------+----------------+---------------+-------+---------------+------------+--------+-------------+---------+----------+------+----------+--------+-------+------------------+-----------+-------------+------------+--------------------+---------+----------+-----------+------------+-------+-------------+------------+--------------+-------------+--------------+-----------------+------+------+-----------------+-----------------+
# only showing top 20 rows

# %%
df_prueba_1 = df_prueba_1.withColumn(
    "RANGO_OFERTA",   
    F.when(F.col("OFERTA").cast("int").isNull(), "SIN DATO")
     .when(F.col("OFERTA").cast("int") < 2500,  "00.[0 - 2,500)")
     .when(F.col("OFERTA").cast("int") < 5000,  "01.[2,500 - 5,000)")
     .when(F.col("OFERTA").cast("int") < 7500,  "02.[5,000 - 7,500)")
     .when(F.col("OFERTA").cast("int") < 10000, "03.[7,500 - 10,000)")
     .when(F.col("OFERTA").cast("int") < 12500, "04.[10,000 - 12,500)")
     .when(F.col("OFERTA").cast("int") < 15000, "05.[12,500 - 15,000)")
     .when(F.col("OFERTA").cast("int") < 17500, "06.[15,000 - 17,500)")
     .when(F.col("OFERTA").cast("int") < 20000, "07.[17,500 - 20,000)")
     .when(F.col("OFERTA").cast("int") < 22500, "08.[20,000 - 22,500)")
     .when(F.col("OFERTA").cast("int") < 25000, "09.[22,500 - 25,000)")
     .when(F.col("OFERTA").cast("int") < 27500, "10.[25,000 - 27,500)")
     .otherwise("11.[27,500 A MÁS]")
)

# %%
USER_V3=['3. MES + PLD Peers', '1. sunedu & sunarp A', '12. Independiente A', '8. Tarjetero Cash', '5. MES A', '2. sunedu & sunarp B', '7. Peers', '13. No dependiente + Convenios', '6. MES B', '11. Dependiente Banca', '10. Dependiente + Convenios', '4. MES + PLD No Peers', '9. Dependiente BN', '14. Otros Bancarizados']
campania=['MUJER', 'BANTRAD', 'SDFCP100', 'SOLO CON DNI - RECUPERO', 'SD PE', 'SD FCP', 'SOLO CON DNI - ZONA COBERTURA', 'SOLODNI']
TIPO_BASE=['Blacklist', 'Regular', 'SALDO COMPETIDOR']
PROPENSION_IC=['3', '5', '6', '1', '4', '2']
Edad=[31, 65, 53, 78, 34, 28, 76, 44, 47, 52, 40, 57, 54, 48, 64, 41, 43, 37, 61, 72, 35, 59, 55, 39, 49, 51, 69, 63, 77, 50, 45, 38, 73, 70, 62, 29, 60, 32, 75, 56, 58, 33, 71, 68, 42, 79, 30, 66, 67, 46, 74, 36]
GRUPO_TASA=['Mantiene tasa', 'Mayor tasa', 'Menor tasa', None]
GRUPO_MONTO=['Mantiene Monto', 'Disminuye Monto', 'Mejora Monto', None]
color_final=['NARANJA CLARO', 'AMARILLO CLARO', 'NARANJA OSCURO', 'AMARILLO OSCURO', 'VERDE OSCURO', 'VERDE CLARO']
Region_comercial=['REGION SUR', 'REGION LIMA CENTRO', 'REGION LIMA SUR ORIENTE', 'REGION LIMA NORTE', 'REGION NORTE', None]
[74.5, 67.0, 70.0, 69.0, 59.5, 76.5, 73.5, 67.5, 52.5, 88.0, 49.0, 66.5, 98.0, 75.0, 64.0, 47.0, 81.5, 62.0, 96.0, 80.0, 86.0, 64.5, 94.0, 68.5, 85.0, 77.5, 77.0, 56.0, 50.0, 65.5, 78.0, 48.5, 79.0, 83.0, 45.0, 54.5, 57.5, 71.0, 93.0, 50.5, 58.0, 72.0, 51.0, 63.0, 48.0, 82.0, 60.0, 74.0, 66.0, 75.5, 68.0, 53.0, 61.0, 53.5, 59.0, 81.0, 78.5, 46.0, 57.0, 87.0, 60.5, 69.5, 73.0, 87.5, 99.0, 95.0, 102.0, 84.0, 92.0, 52.0, 97.0, 62.5, 89.0, 55.0, 70.5, 55.5, 84.5, 65.0, 51.5, 54.0, 76.0, 90.0, 91.0]

# %%
print([row['USER_V3' ] for row in df_formato.select('USER_V3').distinct().collect()])
print([row['campania' ] for row in df_formato.select('campania').distinct().collect()])
print([row['TIPO_BASE' ] for row in df_formato.select('TIPO_BASE').distinct().collect()])
print([row['PROPENSION_IC' ] for row in df_formato.select('PROPENSION_IC').distinct().collect()])
print([row['OFERTA_MAX' ] for row in df_formato.select('OFERTA_MAX').distinct().collect()])
print([row['Edad' ] for row in df_formato.select('Edad').distinct().collect()])
print([row['GRUPO_TASA' ] for row in df_formato.select('GRUPO_TASA').distinct().collect()])
print([row['GRUPO_MONTO' ] for row in df_formato.select('GRUPO_MONTO').distinct().collect()])
print([row['color_final' ] for row in df_formato.select('color_final').distinct().collect()])
print([row['Region_comercial' ] for row in df_formato.select('Region_comercial').distinct().collect()])
print([row['Tasa_1' ] for row in df_formato.select('Tasa_1').distinct().collect()])
# Out:
# ['3. MES + PLD Peers', '1. sunedu & sunarp A', '12. Independiente A', '8. Tarjetero Cash', '5. MES A', '2. sunedu & sunarp B', '7. Peers', '13. No dependiente + Convenios', '6. MES B', '11. Dependiente Banca', '10. Dependiente + Convenios', '4. MES + PLD No Peers', '9. Dependiente BN', '14. Otros Bancarizados']
# ['MUJER', 'BANTRAD', 'SDFCP100', 'SOLO CON DNI - RECUPERO', 'SD PE', 'SD FCP', 'SOLO CON DNI - ZONA COBERTURA', 'SOLODNI']
# ['Blacklist', 'Regular', 'SALDO COMPETIDOR']
# ['3', '5', '6', '1', '4', '2']
# [5300, 9900, 21700, 18800, 11500, 16500, 15100, 19200, 11800, 24200, 6500, 13500, 23000, 5100, 16800, 21200, 20800, 23100, 7800, 8500, 6300, 16000, 9700, 23900, 10800, 24900, 17400, 19100, 6100, 7600, 12000, 10600, 19000, 15700, 5500, 20900, 13000, 7400, 20700, 18100, 18900, 8200, 16400, 18500, 23700, 14600, 5900, 10900, 22500, 5000, 12500, 7500, 14500, 15200, 16300, 24000, 22400, 8800, 13300, 25000, 6900, 18700, 11900, 8700, 10000, 6600, 22000, 15400, 17500, 14800, 24300, 17900, 6700, 9300, 19300, 21800, 17100, 20000, 13200, 24700, 11700, 13800, 24400, 11400, 10100, 20500, 20100, 14300, 18300, 15800, 13700, 10300, 16700, 17700, 12400, 13900, 5800, 20200, 10200, 19500, 17800, 6400, 16900, 23400, 19800, 5600, 8300, 12700, 24100, 12100, 23200, 5200, 12300, 17200, 22600, 18600, 14900, 14700, 21400, 5400, 17300, 19600, 15300, 22300, 8400, 18200, 6200, 7200, 22100, 10400, 7100, 11200, 9600, 20400, 19400, 22900, 11300, 15000, 23800, 10700, 7900, 13600, 9800, 18000, 19900, 7700, 19700, 21600, 6000, 17000, 9200, 24800, 23500, 22200, 21900, 15500, 12800, 20300, 21100, 11000, 14400, 8100, 22700, 21500, 21000, 16100, 8600, 24500, 9000, 20600, 7300, 12900, 14200, 14000, 15900, 5700, 12200, 9100, 16600, 6800, 15600, 9400, 11600, 13400, 22800, 8000, 10500, 23600, 23300, 9500, 12600, 11100, 21300, 8900, 16200, 7000, 14100, 13100, 17600, 18400]
# [31, 65, 53, 78, 34, 28, 76, 44, 47, 52, 40, 57, 54, 48, 64, 41, 43, 37, 61, 72, 35, 59, 55, 39, 49, 51, 69, 63, 77, 50, 45, 38, 73, 70, 62, 29, 60, 32, 75, 56, 58, 33, 71, 68, 42, 79, 30, 66, 67, 46, 74, 36]
# ['Mantiene tasa', 'Mayor tasa', 'Menor tasa', None]
# ['Mantiene Monto', 'Disminuye Monto', 'Mejora Monto', None]
# ['NARANJA CLARO', 'AMARILLO CLARO', 'NARANJA OSCURO', 'AMARILLO OSCURO', 'VERDE OSCURO', 'VERDE CLARO']
# ['REGION SUR', 'REGION LIMA CENTRO', 'REGION LIMA SUR ORIENTE', 'REGION LIMA NORTE', 'REGION NORTE', None]
# [74.5, 67.0, 70.0, 69.0, 59.5, 76.5, 73.5, 67.5, 52.5, 88.0, 49.0, 66.5, 98.0, 75.0, 64.0, 47.0, 81.5, 62.0, 96.0, 80.0, 86.0, 64.5, 94.0, 68.5, 85.0, 77.5, 77.0, 56.0, 50.0, 65.5, 78.0, 48.5, 79.0, 83.0, 45.0, 54.5, 57.5, 71.0, 93.0, 50.5, 58.0, 72.0, 51.0, 63.0, 48.0, 82.0, 60.0, 74.0, 66.0, 75.5, 68.0, 53.0, 61.0, 53.5, 59.0, 81.0, 78.5, 46.0, 57.0, 87.0, 60.5, 69.5, 73.0, 87.5, 99.0, 95.0, 102.0, 84.0, 92.0, 52.0, 97.0, 62.5, 89.0, 55.0, 70.5, 55.5, 84.5, 65.0, 51.5, 54.0, 76.0, 90.0, 91.0]

# %%
print([row['FRESCURA' ] for row in df_formato.select('FRESCURA').distinct().collect()])
# Out:
# ['3', '0', '1', '4', '2']

# %%
df_list_filtrada = df_formato.toPandas()
ruta_archivo = os.path.join(ruta_csv, 'credicash_1.xlsx')
df_list_filtrada.to_excel(ruta_archivo, index=False)

# %%
['MUJER', 'BANTRAD', 'SDFCP100', 'SOLO CON DNI - RECUPERO', 'SD PE', 'SD FCP', 'SOLO CON DNI - ZONA COBERTURA', 'SOLODNI']

# %%
['3. MES + PLD Peers', '1. sunedu & sunarp A', '12. Independiente A', '8. Tarjetero Cash', '5. MES A', '2. sunedu & sunarp B', '7. Peers', '13. No dependiente + Convenios', '6. MES B', '11. Dependiente Banca', '10. Dependiente + Convenios', '4. MES + PLD No Peers', '9. Dependiente BN', '14. Otros Bancarizados']

# %%
# grupo_tasa=['None', '', '', '', '', ]
# agencia_comercial=[ 'SAN MIGUEL', 'MIRAFLORES']

df_filtrado = df_formato.filter(
    # (F.col('propension_ic').isin('1','2','3'))&
    # (F.col('proveedor').isin(['INVENTARIO TARGET 2', 'CET TARGET 2', 'CET TARGET 0', 'INVENTARIO TARGET 1', 'INVENTARIO TARGET 0', ]))&
    # (F.col('user_v3').isin(user_v3))&

    # (
    (F.col('propension_ic').isin('1'))&
    (F.col('frescura').isin('4','2'))&
    # )
    (F.col('USER_V3').isin('7. Peers','4. MES + PLD No Peers','3. MES + PLD Peers'))&
    (F.col('TIPO_CLIENTE').isin('INDEPENDIENTE'))&
    (F.col('Tasa_1')!=0)

)



print(df_filtrado.count())
print(df_filtrado.columns)
# Out:
# 5942
# ['TIPO_DOI', 'NUMERO_DOCUMENTO', 'NOMBRES', 'APELLIDO_PATERNO', 'APELLIDO_MATERNO', 'SUCURSAL', 'TIENDA', 'DEPARTAMENTO', 'PROVINCIA', 'DISTRITO', 'FEC_NACIMIENTO', 'OFERTA_MAX', 'OFERTA_REEN', 'Tipo_verificacion', 'GRUPO_RIESGO', 'proveedor', 'lote', 'RETIRO', 'Tasa_1', 'Tasa_2', 'Tasa_3', 'Tasa_4', 'Tasa_5', 'Tasa_6', 'Tasa_7', 'segmento', 'Campana', 'PLAZO', 'TEM', 'PROPENSION_IC', 'Desgravamen', 'CUOTA', 'Edad', 'Oferta_12M', 'Tasa_12M', 'Desgravamen_12M', 'CUOTA_12M', 'Oferta_18M', 'Tasa_18M', 'Desgravamen_18M', 'CUOTA_18M', 'Oferta_24M', 'Tasa_24M', 'Desgravamen_24M', 'CUOTA_24M', 'Oferta_36M', 'Tasa_36M', 'Desgravamen_36M', 'CUOTA_36M', 'Validador_Telefono', 'Prioridad', 'Nombre_prioridad', 'Deuda_1', 'Entidad_1', 'Deuda_2', 'Entidad_2', 'Deuda_3', 'Entidad_3', 'sucursal_comercial', 'Agencia_comercial', 'Region_comercial', 'Ubicacion', 'OfertaMaximaSinSeguro', 'color', 'color_final', 'PROPENSION', 'OFERTA_FINAL', 'GARANTIA', 'Oferta_Minima_Paperless', 'RANGO_OFERTA', 'RANGO_SUELDO', 'CAPACIDAD_MAX', 'PEER', 'PROP_COMER', 'TIPO_GEST', 'CLIENTE_NUEVO', 'GRUPO_TASA', 'NUEVOS_3M', 'NUEVOS_6M', 'NUEVOS_9M', 'NUEVOS_12M', 'NUEVOS_4M', 'GRUPO_MONTO', 'TASA_VS_MONTO', 'USUARIO', 'incremento_monto_riesgos', 'FLG_DEUDA_PLUS', 'tipo_cliente_riegos', 'USER_V3', 'LEAD_CALIDAD', 'SEGMENTO_USER', 'RANGO_EDAD', 'RANGO_OFERTA2', 'PERIODO', 'RETIRO_GEST', 'MEJOR_TIPIFICACION', 'STATUS', 'FECHA_SOL', 'BASE', 'RESULTADO', 'NUM_ENRIQUECIDO', 'TIPO_CONTACTO', 'Q_VENTAS', 'LOCALIDAD', 'DESEMBOLSADO', 'MONTO_DESEMBOLSADO', 'SBI', 'CRUCE', 'PREST_PREVIO', 'ID_CLIENTE', 'RANGO_EDAD2', 'Fecha_Envio', 'TIPO_BD', 'COD_BD', 'NOMB_BD', 'MES_GESTION', 'TIPO_CLIENTE', 'GRUPO_TASA_REENGANCHE', 'SALDO_DIFERENCIAL_REENG', 'FLAG_REENG', 'RETIRO_DESEMBOLSO', 'FRESCURA', 'flag_deuda_v_oferta', 'MGNEG', 'PERFIL_RO', 'TIPO_BASE', 'cl_telf1', 'cl_telf2', 'cl_telf3', 'cl_telf4', 'cl_telf5', 'cl_telf6', 'cl_telf7', 'cl_telf8', 'cl_telf9', 'cl_telf10', 'cl_movil', 'cl_celular', 'cl_telefono', 'cl_turno', 'cl_gestor', 'cl_asesor', 'cl_accion', 'cl_gestion', 'SERVICIO', 'cl_fecha_gestion', 'cl_hora_gestion', 'cl_hits', 'cl_fecha_llamar', 'cl_prioridad', 'cl_orden', 'cl_predictivo', 'cl_tiempo', 'cl_base', 'cl_mes', 'cl_carga', 'id_carga', 'cl_area', 'fecha_alimentacion', 'cl_base_ant', 'cl_accion_ant', 'cl_fecha_ant', 'campania', 'PROMOCION', 'PROMOCION2', 'nombre_base', 'NumEntidades', 'p_banco', 'PERFIL_GLOBAL', 'FLG_AAHH', 'SCORE_TELEFONO', 'PILOTO_PLAZAS', 'INTENSIDAD_MAX', 'marca1', 'marca2', 'marca3', 'AÑO_DURACION_BASE', 'MES_DURACION_BASE', 'FLAT2', 'REP1', 'REP2']

# %%
df_dni = df_filtrado.toPandas()

ruta_archivo = os.path.join(ruta_csv, 'df_parte_3.xlsx')

df_dni.to_excel(ruta_archivo, index=False)

# %%
df_filtrado_1=df_filtrado.select('VENDOR LEAD CODE','PHONE NUMBER','TIENDA_CERCANA_LIMPIA','AGENCIA','TIENDA_2_DIRECCION','OFERTA_MAX_TEXTO','ADDRESS1','campana')
df_filtrado_1.show()

# %%
df_list_filtrada = df_filtrado_1.toPandas()
ruta_archivo = os.path.join(ruta_csv, 'alfin_1.xlsx')
df_list_filtrada.to_excel(ruta_archivo, index=False)

# %% [markdown]
# ### lista agente

# %%
query = """
    select *
    from DANTALION.dbo.Base_Maestra_ALFIN_BK_Vigente
    where (cl_telf1 is not null and cl_telf1<>0) 
    and cl_base='julio 2026'
    and OFERTA_MAX>=5000
    and cl_telf1<>0
    and cl_telf1 is not null
    AND LOTE<>'BOT'
    """
df_formato=obtener_tabla_sql(spark,query,server_kishin,user_kishin,pwd_kishin,db_kishin)

# %%
query = """
    SELECT NUMERO_DOCUMENTO FROM maeba.[ADM_OBJ_TG].[tGestionMesAlfin]
    where RECORRIDO = 0
    """
df_recorrido=obtener_tabla_sql(spark,query,server_zeus,user_zeus,pwd_zeus,db_zeus)

# %%
df_formato=df_formato.join(df_recorrido,['NUMERO_DOCUMENTO'],'leftanti')

# %%
print([row['LOTE' ] for row in df_formato.select('LOTE').distinct().collect()])
# Out:
# ['BOT', 'NO CLIENTE', 'NO CLIENTE CET']

# %%
# grupo_tasa=['None', '', '', '', '', ]
# agencia_comercial=[ 'SAN MIGUEL', 'MIRAFLORES']

df_filtrado = df_formato.filter(
    # (F.col('propension_ic').isin('1','2','3'))&
    # (F.col('proveedor').isin(['INVENTARIO TARGET 2', 'CET TARGET 2', 'CET TARGET 0', 'INVENTARIO TARGET 1', 'INVENTARIO TARGET 0', ]))&
    # (F.col('user_v3').isin(user_v3))&

    # (
    (F.col('propension_ic').isin('1'))&
    (F.col('frescura').isin('1','4'))&
    # )
    (F.col('USER_V3').isin('7. Peers','4. MES + PLD No Peers','3. MES + PLD Peers'))&
    # (F.col('TIPO_CLIENTE').isin('INDEPENDIENTE'))&
    (F.col('Tasa_1')!=0)

)



print(df_filtrado.count())
print(df_filtrado.columns)
# Out:
# 4392
# ['NUMERO_DOCUMENTO', 'TIPO_DOI', 'NOMBRES', 'APELLIDO_PATERNO', 'APELLIDO_MATERNO', 'SUCURSAL', 'TIENDA', 'DEPARTAMENTO', 'PROVINCIA', 'DISTRITO', 'FEC_NACIMIENTO', 'OFERTA_MAX', 'OFERTA_REEN', 'Tipo_verificacion', 'GRUPO_RIESGO', 'proveedor', 'lote', 'RETIRO', 'Tasa_1', 'Tasa_2', 'Tasa_3', 'Tasa_4', 'Tasa_5', 'Tasa_6', 'Tasa_7', 'segmento', 'Campana', 'PLAZO', 'TEM', 'PROPENSION_IC', 'Desgravamen', 'CUOTA', 'Edad', 'Oferta_12M', 'Tasa_12M', 'Desgravamen_12M', 'CUOTA_12M', 'Oferta_18M', 'Tasa_18M', 'Desgravamen_18M', 'CUOTA_18M', 'Oferta_24M', 'Tasa_24M', 'Desgravamen_24M', 'CUOTA_24M', 'Oferta_36M', 'Tasa_36M', 'Desgravamen_36M', 'CUOTA_36M', 'Validador_Telefono', 'Prioridad', 'Nombre_prioridad', 'Deuda_1', 'Entidad_1', 'Deuda_2', 'Entidad_2', 'Deuda_3', 'Entidad_3', 'sucursal_comercial', 'Agencia_comercial', 'Region_comercial', 'Ubicacion', 'OfertaMaximaSinSeguro', 'color', 'color_final', 'PROPENSION', 'OFERTA_FINAL', 'GARANTIA', 'Oferta_Minima_Paperless', 'RANGO_OFERTA', 'RANGO_SUELDO', 'CAPACIDAD_MAX', 'PEER', 'PROP_COMER', 'TIPO_GEST', 'CLIENTE_NUEVO', 'GRUPO_TASA', 'NUEVOS_3M', 'NUEVOS_6M', 'NUEVOS_9M', 'NUEVOS_12M', 'NUEVOS_4M', 'GRUPO_MONTO', 'TASA_VS_MONTO', 'USUARIO', 'incremento_monto_riesgos', 'FLG_DEUDA_PLUS', 'tipo_cliente_riegos', 'USER_V3', 'LEAD_CALIDAD', 'SEGMENTO_USER', 'RANGO_EDAD', 'RANGO_OFERTA2', 'PERIODO', 'RETIRO_GEST', 'MEJOR_TIPIFICACION', 'STATUS', 'FECHA_SOL', 'BASE', 'RESULTADO', 'NUM_ENRIQUECIDO', 'TIPO_CONTACTO', 'Q_VENTAS', 'LOCALIDAD', 'DESEMBOLSADO', 'MONTO_DESEMBOLSADO', 'SBI', 'CRUCE', 'PREST_PREVIO', 'ID_CLIENTE', 'RANGO_EDAD2', 'Fecha_Envio', 'TIPO_BD', 'COD_BD', 'NOMB_BD', 'MES_GESTION', 'TIPO_CLIENTE', 'GRUPO_TASA_REENGANCHE', 'SALDO_DIFERENCIAL_REENG', 'FLAG_REENG', 'RETIRO_DESEMBOLSO', 'FRESCURA', 'flag_deuda_v_oferta', 'MGNEG', 'PERFIL_RO', 'TIPO_BASE', 'cl_telf1', 'cl_telf2', 'cl_telf3', 'cl_telf4', 'cl_telf5', 'cl_telf6', 'cl_telf7', 'cl_telf8', 'cl_telf9', 'cl_telf10', 'cl_movil', 'cl_celular', 'cl_telefono', 'cl_turno', 'cl_gestor', 'cl_asesor', 'cl_accion', 'cl_gestion', 'SERVICIO', 'cl_fecha_gestion', 'cl_hora_gestion', 'cl_hits', 'cl_fecha_llamar', 'cl_prioridad', 'cl_orden', 'cl_predictivo', 'cl_tiempo', 'cl_base', 'cl_mes', 'cl_carga', 'id_carga', 'cl_area', 'fecha_alimentacion', 'cl_base_ant', 'cl_accion_ant', 'cl_fecha_ant', 'campania', 'PROMOCION', 'PROMOCION2', 'nombre_base', 'NumEntidades', 'p_banco', 'PERFIL_GLOBAL', 'FLG_AAHH', 'SCORE_TELEFONO', 'PILOTO_PLAZAS', 'INTENSIDAD_MAX', 'marca1', 'marca2', 'marca3', 'AÑO_DURACION_BASE', 'MES_DURACION_BASE', 'FLAT2', 'REP1', 'REP2']

# %%
print(df_filtrado.columns)
# Out:
# ['NUMERO_DOCUMENTO', 'TIPO_DOI', 'NOMBRES', 'APELLIDO_PATERNO', 'APELLIDO_MATERNO', 'SUCURSAL', 'TIENDA', 'DEPARTAMENTO', 'PROVINCIA', 'DISTRITO', 'FEC_NACIMIENTO', 'OFERTA_MAX', 'OFERTA_REEN', 'Tipo_verificacion', 'GRUPO_RIESGO', 'proveedor', 'lote', 'RETIRO', 'Tasa_1', 'Tasa_2', 'Tasa_3', 'Tasa_4', 'Tasa_5', 'Tasa_6', 'Tasa_7', 'segmento', 'Campana', 'PLAZO', 'TEM', 'PROPENSION_IC', 'Desgravamen', 'CUOTA', 'Edad', 'Oferta_12M', 'Tasa_12M', 'Desgravamen_12M', 'CUOTA_12M', 'Oferta_18M', 'Tasa_18M', 'Desgravamen_18M', 'CUOTA_18M', 'Oferta_24M', 'Tasa_24M', 'Desgravamen_24M', 'CUOTA_24M', 'Oferta_36M', 'Tasa_36M', 'Desgravamen_36M', 'CUOTA_36M', 'Validador_Telefono', 'Prioridad', 'Nombre_prioridad', 'Deuda_1', 'Entidad_1', 'Deuda_2', 'Entidad_2', 'Deuda_3', 'Entidad_3', 'sucursal_comercial', 'Agencia_comercial', 'Region_comercial', 'Ubicacion', 'OfertaMaximaSinSeguro', 'color', 'color_final', 'PROPENSION', 'OFERTA_FINAL', 'GARANTIA', 'Oferta_Minima_Paperless', 'RANGO_OFERTA', 'RANGO_SUELDO', 'CAPACIDAD_MAX', 'PEER', 'PROP_COMER', 'TIPO_GEST', 'CLIENTE_NUEVO', 'GRUPO_TASA', 'NUEVOS_3M', 'NUEVOS_6M', 'NUEVOS_9M', 'NUEVOS_12M', 'NUEVOS_4M', 'GRUPO_MONTO', 'TASA_VS_MONTO', 'USUARIO', 'incremento_monto_riesgos', 'FLG_DEUDA_PLUS', 'tipo_cliente_riegos', 'USER_V3', 'LEAD_CALIDAD', 'SEGMENTO_USER', 'RANGO_EDAD', 'RANGO_OFERTA2', 'PERIODO', 'RETIRO_GEST', 'MEJOR_TIPIFICACION', 'STATUS', 'FECHA_SOL', 'BASE', 'RESULTADO', 'NUM_ENRIQUECIDO', 'TIPO_CONTACTO', 'Q_VENTAS', 'LOCALIDAD', 'DESEMBOLSADO', 'MONTO_DESEMBOLSADO', 'SBI', 'CRUCE', 'PREST_PREVIO', 'ID_CLIENTE', 'RANGO_EDAD2', 'Fecha_Envio', 'TIPO_BD', 'COD_BD', 'NOMB_BD', 'MES_GESTION', 'TIPO_CLIENTE', 'GRUPO_TASA_REENGANCHE', 'SALDO_DIFERENCIAL_REENG', 'FLAG_REENG', 'RETIRO_DESEMBOLSO', 'FRESCURA', 'flag_deuda_v_oferta', 'MGNEG', 'PERFIL_RO', 'TIPO_BASE', 'cl_telf1', 'cl_telf2', 'cl_telf3', 'cl_telf4', 'cl_telf5', 'cl_telf6', 'cl_telf7', 'cl_telf8', 'cl_telf9', 'cl_telf10', 'cl_movil', 'cl_celular', 'cl_telefono', 'cl_turno', 'cl_gestor', 'cl_asesor', 'cl_accion', 'cl_gestion', 'SERVICIO', 'cl_fecha_gestion', 'cl_hora_gestion', 'cl_hits', 'cl_fecha_llamar', 'cl_prioridad', 'cl_orden', 'cl_predictivo', 'cl_tiempo', 'cl_base', 'cl_mes', 'cl_carga', 'id_carga', 'cl_area', 'fecha_alimentacion', 'cl_base_ant', 'cl_accion_ant', 'cl_fecha_ant', 'campania', 'PROMOCION', 'PROMOCION2', 'nombre_base', 'NumEntidades', 'p_banco', 'PERFIL_GLOBAL', 'FLG_AAHH', 'SCORE_TELEFONO', 'PILOTO_PLAZAS', 'INTENSIDAD_MAX', 'marca1', 'marca2', 'marca3', 'AÑO_DURACION_BASE', 'MES_DURACION_BASE', 'FLAT2', 'REP1', 'REP2']

# %%
df_filtrado=df_filtrado.withColumnRenamed('NUMERO_DOCUMENTO','vendor_lead_code')
df_filtrado=df_filtrado.withColumnRenamed('cl_telf1','phone_number')
# df_filtrado=df_filtrado.withColumnRenamed('NOMBRES','address1')

df_filtrado = df_filtrado.withColumn(
    "address1",
    F.concat_ws(
        " ",
        F.col("NOMBRES"),
        F.col("APELLIDO_PATERNO"),
        F.col("APELLIDO_MATERNO")
    )
)

df_filtrado = df_filtrado.withColumn(
    "security_phrase",
    F.concat_ws(
        " ",
        F.lit("Oferta:"),
        F.col("OFERTA_MAX")
    )
)
df_filtrado = df_filtrado.withColumn(
    "city",
    F.concat_ws(
        " ",
        F.lit("Departamento:"),
        F.col("DEPARTAMENTO")
    )
)
df_filtrado = df_filtrado.withColumn(
    "province",
    F.concat_ws(
        " ",
        F.lit("Distrito:"),
        F.col("DISTRITO")
    )
)

df_filtrado.count()
# Out:
# 5942

# %%
df_filtrado=df_filtrado.select('vendor_lead_code','phone_number','address1','security_phrase','city','province')

# %%
df_filtrado=df_filtrado.dropDuplicates(['vendor_lead_code'])

# %%
df_filtrado.count()
# Out:
# 5942

# %%
df_list_filtrada = df_filtrado.toPandas()
ruta_archivo = os.path.join(ruta_csv, 'alfin.xlsx')
df_list_filtrada.to_excel(ruta_archivo, index=False)

# %% [markdown]
# ### simular

# %%
import sys 
sys.path.append('C:/Users/DATA/Documents/datos/01_script/inicio/funciones')
from funciones import *
from funciones_spark import *
from variables_inicio import *
from utils_sql import *

spark = SparkSession.builder \
    .appName("SparkExample") \
    .master("local[*]") \
    .config('spark.driver.extraClassPath', 'C:/spark/jars/mssql-jdbc-13.2.1.jre11.jar') \
    .config('spark.executor.extraClassPath', 'C:/spark/jars/mssql-jdbc-13.2.1.jre11.jar') \
    .config('spark.executor.memory', '8g') \
    .config('spark.driver.memory', '8g') \
    .getOrCreate()

# %%
query = """
    select NUMERO_DOCUMENTO as Dni,cl_telf1 as PHONE_NUMBER
    from DANTALION.dbo.Base_Maestra_ALFIN_BK_Vigente
    where cl_base='julio 2026'
    and cl_telf1<>0
    and cl_telf1 is not null
    """
df_formato=obtener_tabla_sql(spark,query,server_kishin,user_kishin,pwd_kishin,db_kishin)
print(df_formato.columns)
# Out:
# ['Dni', 'PHONE_NUMBER']

# %%
query = """
    select NUMERO_DOCUMENTO as Dni,PROPENSION_IC,FRESCURA,USER_V3,TIPO_LOTE,lote
    from maeba.[ADM_OBJ_TG].[tGestionMesAlfin]
    where retiro='Activo'
    and recorrido=1
    """
df_ref_1=obtener_tabla_sql(spark,query,server_zeus,user_zeus,pwd_zeus,db_zeus)
print(df_ref.count())
# Out:
# 129832

# %%
df_ref_1=df_ref_1.join(df_formato,['Dni'],'inner')
df_ref_1.count()
# Out:
# 129809

# %%
df_ref=df_ref_1.filter(
        (
            F.col('lote')=='NO CLIENTE')&(F.col('USER_V3').isin('7. Peers'))&(F.col('PROPENSION_IC').isin(1))&(F.col('frescura').isin(1)
        )|
        (
           ( F.col('lote')=='BOT')&(F.col('PROPENSION_IC').isin(3,2,5,4,1))&(F.col('frescura').isin(1,2,3,4,5))
        )
    )
df_ref.count()
# Out:
# 33719

# %%
df_ref.show()
# Out:
# +--------+-------------+--------+--------------------+------------+----------+------------+
# |     Dni|PROPENSION_IC|FRESCURA|             USER_V3|   TIPO_LOTE|      lote|PHONE_NUMBER|
# +--------+-------------+--------+--------------------+------------+----------+------------+
# |01336535|            5|       2|14. Otros Bancari...|    BASE BOT|       BOT|   980703559|
# |01225454|            2|       1|2. sunedu & sunarp B|    BASE BOT|       BOT|   978596492|
# |03238433|            4|       3|14. Otros Bancari...|    BASE BOT|       BOT|   941799996|
# |07148138|            3|       4|14. Otros Bancari...|    BASE BOT|       BOT|   992308745|
# |04428228|            4|       4|14. Otros Bancari...|    BASE BOT|       BOT|   959131814|
# |04435537|            5|       2|2. sunedu & sunarp B|    BASE BOT|       BOT|   998557787|
# |06157500|            5|       4|2. sunedu & sunarp B|    BASE BOT|       BOT|   990978522|
# |04748027|            2|       2|14. Otros Bancari...|    BASE BOT|       BOT|   953674029|
# |02816894|            1|       1|            7. Peers|BASE REGULAR|NO CLIENTE|   920128688|
# |06149751|            5|       4|2. sunedu & sunarp B|    BASE BOT|       BOT|   991050729|
# |06155455|            5|       4|2. sunedu & sunarp B|    BASE BOT|       BOT|   990922408|
# |07177590|            5|       3|14. Otros Bancari...|    BASE BOT|       BOT|   987496366|
# |05407991|            2|       4|2. sunedu & sunarp B|    BASE BOT|       BOT|   902361679|
# |07166409|            5|       4|            6. MES B|    BASE BOT|       BOT|   953077894|
# |03645364|            5|       3|            6. MES B|    BASE BOT|       BOT|   942095263|
# |04008798|            4|       3|2. sunedu & sunarp B|    BASE BOT|       BOT|   989995920|
# |03899001|            2|       4|2. sunedu & sunarp B|    BASE BOT|       BOT|   952024866|
# |06926116|            3|       2|            6. MES B|    BASE BOT|       BOT|   965094715|
# |07369427|            5|       3|14. Otros Bancari...|    BASE BOT|       BOT|   994913084|
# |06757331|            5|       4|14. Otros Bancari...|    BASE BOT|       BOT|   986957833|
# +--------+-------------+--------+--------------------+------------+----------+------------+
# only showing top 20 rows

# %%
df_ref.groupBy('USER_V3') \
    .count() \
    .orderBy('USER_V3') \
    .show(30,truncate=False)
# Out:
# +------------------------------+-----+
# |USER_V3                       |count|
# +------------------------------+-----+
# |1. sunedu & sunarp A          |1684 |
# |10. Dependiente + Convenios   |35   |
# |11. Dependiente Banca         |74   |
# |12. Independiente A           |23   |
# |13. No dependiente + Convenios|22   |
# |14. Otros Bancarizados        |37128|
# |2. sunedu & sunarp B          |13431|
# |3. MES + PLD Peers            |1030 |
# |4. MES + PLD No Peers         |287  |
# |5. MES A                      |741  |
# |6. MES B                      |19882|
# |7. Peers                      |2962 |
# |8. Tarjetero Cash             |168  |
# |9. Dependiente BN             |73   |
# +------------------------------+-----+

# %%
query = """
SELECT *
FROM OPENQUERY([192.168.2.100], '
    select *,dni_cliente as Dni from Alice.prospectos_correos_alfin
    WHERE fecha_dia IN (''2026-07-10'', ''2026-07-01'')
')
    """
df_crm=obtener_tabla_sql(spark,query,server_zeus,user_zeus,pwd_zeus,db_zeus)
df_crm=df_crm.select( 'Dni', 'fecha_visita', 'hora_visita', 'fecha_envio', 'intentos_realizados', 'fecha_registro','estado')

df_crm=df_crm.withColumn('ref',when(F.col('estado')=='ENVIADO',1).otherwise(2))

window_spec = Window.partitionBy("Dni").orderBy(col("ref").asc_nulls_last())
df_crm = df_crm.withColumn("n_mejor_resul_dia", row_number().over(window_spec))
df_crm=df_crm.filter((F.col('n_mejor_resul_dia')==1)&(F.col('ref')==1)).drop('ref','n_mejor_resul_dia')

# %%
# df_crm=df_crm.withColumnRenamed('Dni','DNI')
df_crm = df_crm.withColumn(
    "Dni",
    F.right(
        F.concat(F.lit("00000000"), F.col("Dni")),
        F.lit(8)
    )

)

# %%
df_ref=df_ref.join(df_crm,['Dni'],'left')

# %%
w = Window.partitionBy('lote','PROPENSION_IC','FRESCURA','USER_V3').orderBy(F.rand())

df_split = df_ref.withColumn("por_dia", F.ntile(2).over(w))

# %%
df_split=df_split.withColumn('por_dia',when(F.col('por_dia')==2,10).otherwise(F.col('por_dia')))

# %%
df_split.groupBy('por_dia') \
    .count() \
    .orderBy('por_dia') \
    .show(30)
# Out:
# +-------+-----+
# |por_dia|count|
# +-------+-----+
# |      1|16883|
# |     10|16836|
# +-------+-----+

# %%
df_split = df_split.withColumn(
    "por_dia",
    F.when(F.to_date("fecha_registro") == F.lit("2026-07-08"), 6)
     .when(F.to_date("fecha_registro") == F.lit("2026-07-09"), 7)
     .otherwise(F.col("por_dia"))
)

# %%
df_split=df_split.withColumn('Numero_Campana',F.lit('401'))
df_split=df_split.withColumn('list_description',F.lit('provicional'))
df_split=df_split.withColumn('list_name',F.lit('provicional'))
df_split=df_split.withColumn('Nombre_Campana',when(F.lit('lote')=='BOT',F.lit('BOT_ALFIN')).otherwise(F.lit('2026-07 BCO ALFIN')))

# %%
df_split=df_split.withColumn('por_dia',when(F.col('por_dia')==5,6)
.when(F.col('por_dia')==6,7)
.when(F.col('por_dia')==7,8).otherwise(F.col('por_dia')))

# %%
df_split = df_split.withColumn(
    "Fecha_Llamada",
    F.to_date(
        F.concat(
            F.lit("2026-07-"),
            F.lpad(F.col("por_dia").cast("string"), 2, "0")
        )
    )
)

# %%
query = """
select top(10)* From SAMANTHA.dbo.tmp_llamadas_mes
    """
df_necesito=obtener_tabla_sql(spark,query,server_zeus,user_zeus,pwd_zeus,db_zeus)
df_necesito=df_necesito.select('Dni', 'DNI_Ejecutivo', 'Ejecutivo', 'Fecha_Hora_Llamada', 'segundos', 'Fecha_Llamada', 'Trama_Hora', 'PHONE_NUMBER', 'Codigo_Paleta', 'Inicio', 'Fin','Numero_Campana','Trama_Hora','list_name','list_description')

# %%
query = """
select top(10)* From SAMANTHA.dbo.tmp_llamadas_mes
    """
df_necesito=obtener_tabla_sql(spark,query,server_zeus,user_zeus,pwd_zeus,db_zeus)
df_necesito.show(4)
# Out:
# +--------+--------------+--------------------+-------------+------------------+-------------------+--------+-------------+----------+-------+----------+-----------+--------------------+--------------------+------------+------------+-----------+-------------+-------------------+-------------------+-------+
# |     Dni|Numero_Campana|      Nombre_Campana|DNI_Ejecutivo|         Ejecutivo| Fecha_Hora_Llamada|segundos|Fecha_Llamada|Trama_Hora|Estados|Sub_estado|Descripcion|    list_description|           list_name|PHONE_NUMBER|Fecha_Agenda|Comentarios|Codigo_Paleta|             Inicio|                Fin|lead_id|
# +--------+--------------+--------------------+-------------+------------------+-------------------+--------+-------------+----------+-------+----------+-----------+--------------------+--------------------+------------+------------+-----------+-------------+-------------------+-------------------+-------+
# |72048296|            80|2023-11 CENCOSUD ...|         VDAD|Outbound Auto Dial|2023-11-24 17:34:47|       0|   2023-11-24|        17|       |          |  Busy Auto|CENCOSAE_DISC_24N...|CENCOSAE_DISC_24N...|   922488467|            |        SAE|           AB|2023-11-24 17:34:47|2023-11-24 17:34:47|5570023|
# |29690194|            80|2023-11 CENCOSUD ...|         VDAD|Outbound Auto Dial|2023-11-24 17:34:47|       0|   2023-11-24|        17|       |          |  Busy Auto|CENCOSAE_DISC_24N...|CENCOSAE_DISC_24N...|   983941534|            |        SAE|           AB|2023-11-24 17:34:47|2023-11-24 17:34:47|5578870|
# |29637063|            80|2023-11 CENCOSUD ...|         VDAD|Outbound Auto Dial|2023-11-24 17:34:47|       0|   2023-11-24|        17|       |          |  Busy Auto|CENCOSAE_DISC_24N...|CENCOSAE_DISC_24N...|   904003542|            |        SAE|           AB|2023-11-24 17:34:47|2023-11-24 17:34:47|5575613|
# |40983037|            80|2023-11 CENCOSUD ...|         VDAD|Outbound Auto Dial|2023-11-24 17:34:47|       0|   2023-11-24|        17|       |          |  Busy Auto|CENCOSAE_DISC_24N...|CENCOSAE_DISC_24N...|   939265399|            |        SAE|           AB|2023-11-24 17:34:47|2023-11-24 17:34:47|5576254|
# +--------+--------------+--------------------+-------------+------------------+-------------------+--------+-------------+----------+-------+----------+-----------+--------------------+--------------------+------------+------------+-----------+-------------+-------------------+-------------------+-------+
# only showing top 4 rows

# %%
usuarios_regular = [
    "PEC200",
    "PEC188",
    "PEC136",
    "PEC139",
    "PEC184",
    'VDAD'
]
usuarios_bot = [
    "49587612",
    'VDAD'
]

# %%
# Probabilidad base de VDAD por TIPO_LOTE
df_split = df_split.withColumn(
    "prob_vdad_base",
    F.when(F.col("TIPO_LOTE") == "BASE REGULAR", F.lit(0.43))
     .when(F.col("TIPO_LOTE") == "BASE BOT", F.lit(0.96))
     .otherwise(F.lit(0.43))
)

# Score: mientras más alto PROPENSION_IC y FRESCURA, más chance de VDAD
df_split = df_split.withColumn(
    "score_vdad",
    (
        (F.col("PROPENSION_IC") - 1) / F.lit(5) +   # PROPENSION_IC 1 a 6
        (F.col("FRESCURA") / F.lit(5))           # FRESCURA 0 a 5
    ) / F.lit(2)
)

# Ajustamos la probabilidad de VDAD
# Ejemplo: puede subir hasta +15 puntos porcentuales
df_split = df_split.withColumn(
    "prob_vdad_final",
    F.least(
        F.col("prob_vdad_base") + (F.col("score_vdad") * F.lit(0.15)),
        F.lit(0.99)
    )
)

# Número aleatorio
df_split = df_split.withColumn("rnd", F.rand())

# Asignar primero VDAD según probabilidad
df_split = df_split.withColumn(
    "DNI_Ejecutivo",
    F.when(F.col("rnd") <= F.col("prob_vdad_final"), F.lit("VDAD"))
)

# Para los demás, asignación uniforme según TIPO_LOTE
regular_sin_vdad = [x for x in usuarios_regular if x != "VDAD"]
bot_sin_vdad = [x for x in usuarios_bot if x != "VDAD"]

df_split = df_split.withColumn(
    "DNI_Ejecutivo",
    F.when(
        F.col("DNI_Ejecutivo").isNull() & (F.col("TIPO_LOTE") == "BASE REGULAR"),
        F.array(*[F.lit(x) for x in regular_sin_vdad])[
            F.floor(F.rand() * F.lit(len(regular_sin_vdad))).cast("int")
        ]
    )
    .when(
        F.col("DNI_Ejecutivo").isNull() & (F.col("TIPO_LOTE") == "BASE BOT"),
        F.array(*[F.lit(x) for x in bot_sin_vdad])[
            F.floor(F.rand() * F.lit(len(bot_sin_vdad))).cast("int")
        ]
    )
    .otherwise(F.col("DNI_Ejecutivo"))
)

df_split = df_split.drop("prob_vdad_base", "score_vdad", "prob_vdad_final", "rnd")

# %%
df_split = df_split.withColumn(
    "Ejecutivo",
    F.when(
        (F.col("TIPO_LOTE") == "BASE BOT") & (F.col("DNI_Ejecutivo") == "VDAD"),
        F.lit("Outbound Auto Dial")
    )
    .when(
        (F.col("TIPO_LOTE") == "BASE BOT") & (F.col("DNI_Ejecutivo") != "VDAD"),
        F.lit("Bot Bco Alfin")
    )
    .when(
        (F.col("TIPO_LOTE") == "BASE REGULAR") & 
        (F.col("DNI_Ejecutivo").isin([u for u in usuarios_regular if u != "VDAD"])),
        F.lit("Agente BCO Alfin")
    )
    .when(
        (F.col("TIPO_LOTE") == "BASE REGULAR") & (F.col("DNI_Ejecutivo") == "VDAD"),
        F.lit("Outbound Auto Dial")
    )
    .otherwise(F.lit(None))
)

# %%
codigos_vdad = ["PDROP", "NA", "AB"]

codigos_regular = ["zzz29", "zzz32", "zzz30", "zzz34", "zzz10", "zzz56", "zzz5", "zzz13", "zzz10", "zzz9"]

codigos_bot = ["zzz29", "zzz32", "zzz30", "zzz34", "zzz10", "zzz9", "zzz56", "zzz13"]

arr_vdad = F.array(*[F.lit(x) for x in codigos_vdad])
arr_regular = F.array(*[F.lit(x) for x in codigos_regular])
arr_bot = F.array(*[F.lit(x) for x in codigos_bot])

df_split = df_split.withColumn(
    "Codigo_Paleta",
    F.when(
        F.col("DNI_Ejecutivo") == "VDAD",
        arr_vdad[F.floor(F.rand() * F.lit(len(codigos_vdad))).cast("int")]
    )
    .when(
        (F.col("TIPO_LOTE") == "BASE REGULAR") & (F.col("DNI_Ejecutivo") != "VDAD"),
        arr_regular[F.floor(F.rand() * F.lit(len(codigos_regular))).cast("int")]
    )
    .when(
        (F.col("TIPO_LOTE") == "BASE BOT") & (F.col("DNI_Ejecutivo") != "VDAD"),
        arr_bot[F.floor(F.rand() * F.lit(len(codigos_bot))).cast("int")]
    )
    .otherwise(F.lit(None))
)

# %%
df_split=df_split.withColumn('Codigo_Paleta',when(F.col('estado').isNotNull(),'zzz2').otherwise(F.col('Codigo_Paleta')))

# %%
df_split = df_split.withColumn(
    "segundos",
    F.when(
        F.col("Codigo_Paleta").isin("PDROP", "AB", "NA", "zzz50"),
        F.lit(0)
    )
    .when(
        F.col("Codigo_Paleta") == "zzz2",
        F.floor(F.rand() * 51 + 100).cast("int")   # 100 a 150
    )
    .when(
        F.col("Codigo_Paleta").isin("zzz29", "zzz30", "zzz34", "zzz9", "zzz32", "zzz56", "zzz10", "zzz13"),
        F.floor(F.rand() * 51 + 30).cast("int")    # 30 a 80
    )
    .when(
        F.col("Codigo_Paleta").isin("zzz29", "zzz30", "zzz34", "zzz9", "zzz32", "zzz56", "zzz10", "zzz13","zzz5", "zzz13", "zzz10", "zzz9"),
        F.floor(F.rand() * 51 + 30).cast("int")    # 30 a 80
    )
    .otherwise(F.lit(0))
)

# %% [markdown]
# ## mas atento

# %%
from pyspark.sql.window import Window

fecha_col = "Fecha_Llamada"  # cambia esto si tu columna se llama fecha_envio, Fecha_Llamada, etc.

inicio = 9 * 3600          # 09:00:00
fin = 17 * 3600 + 50 * 60  # 17:50:00
rango = fin - inicio

df_split = df_split.withColumn("_id", F.monotonically_increasing_id())

# Duración de llamada
df_split = df_split.withColumn(
    "_duracion",
    F.when(F.col("segundos").isNull(), F.lit(0))
     .otherwise(F.col("segundos").cast("int"))
)

# =========================
# 1. VDAD: horario libre
# =========================
df_vdad = df_split.filter(F.col("DNI_Ejecutivo") == "VDAD") \
    .withColumn(
        "_seg_inicio",
        F.floor(F.rand() * rango + inicio).cast("int")
    )

# =========================
# 2. BASE REGULAR: sin cruce por agente y fecha
# =========================
df_regular = df_split.filter(
    (F.col("TIPO_LOTE") == "BASE REGULAR") &
    (F.col("DNI_Ejecutivo") != "VDAD")
)

w_reg = Window.partitionBy(fecha_col, "DNI_Ejecutivo").orderBy(F.rand())

df_regular = df_regular.withColumn("_rn", F.row_number().over(w_reg))

# pequeño espacio aleatorio entre llamadas: 5 a 20 segundos
df_regular = df_regular.withColumn(
    "_gap",
    F.floor(F.rand() * 16 + 5).cast("int")
)

w_reg_acum = Window.partitionBy(fecha_col, "DNI_Ejecutivo") \
    .orderBy("_rn") \
    .rowsBetween(Window.unboundedPreceding, -1)

df_regular = df_regular.withColumn(
    "_seg_inicio",
    inicio + F.coalesce(
        F.sum(F.col("_duracion") + F.col("_gap")).over(w_reg_acum),
        F.lit(0)
    )
)

# =========================
# 3. BASE BOT: hasta 15 llamadas al mismo tiempo
# =========================
df_bot = df_split.filter(
    (F.col("TIPO_LOTE") == "BASE REGULAR") &
    (F.col("DNI_Ejecutivo") != "VDAD")
)

w_bot = Window.partitionBy(fecha_col, "DNI_Ejecutivo").orderBy(F.rand())

df_bot = df_bot.withColumn("_rn", F.row_number().over(w_bot))

# cada grupo de 15 llamadas comparte la misma hora
df_bot = df_bot.withColumn(
    "_grupo_bot",
    F.floor((F.col("_rn") - 1) / 15).cast("int")
)

df_bot_grupos = df_bot.groupBy(fecha_col, "DNI_Ejecutivo", "_grupo_bot") \
    .agg(F.max("_duracion").alias("_duracion_grupo"))

df_bot_grupos = df_bot_grupos.withColumn(
    "_gap_grupo",
    F.floor(F.rand() * 16 + 5).cast("int")
)

w_bot_acum = Window.partitionBy(fecha_col, "DNI_Ejecutivo") \
    .orderBy("_grupo_bot") \
    .rowsBetween(Window.unboundedPreceding, -1)

df_bot_grupos = df_bot_grupos.withColumn(
    "_seg_inicio",
    inicio + F.coalesce(
        F.sum(F.col("_duracion_grupo") + F.col("_gap_grupo")).over(w_bot_acum),
        F.lit(0)
    )
)

# %%
df_bot = df_bot.join(
    df_bot_grupos.select(fecha_col, "DNI_Ejecutivo", "_grupo_bot", "_seg_inicio"),
    on=[fecha_col, "DNI_Ejecutivo", "_grupo_bot"],
    how="left"
)

# %%
# =========================
# Unir todo
# =========================
df_split = df_regular.unionByName(df_bot, allowMissingColumns=True) \
                     .unionByName(df_vdad, allowMissingColumns=True)

# Si se pasa de 17:50, lo limitamos a 17:50
df_split = df_split.withColumn(
    "_seg_inicio",
    F.when(F.col("_seg_inicio") > fin, F.lit(fin))
     .otherwise(F.col("_seg_inicio").cast("int"))
)

# Crear hora formato HH:mm:ss
df_split = df_split.withColumn(
    "hora",
    F.date_format(
        F.from_unixtime(F.col("_seg_inicio")),
        "HH:mm:ss"
    )
)

# Limpiar columnas auxiliares
df_split = df_split.drop(
    "_id", "_duracion", "_rn", "_gap",
    "_grupo_bot", "_seg_inicio",
    "_duracion_grupo", "_gap_grupo"
)

# %%
from pyspark.sql import functions as F

df_split = df_split.withColumn(
    "Fecha_Hora_Llamada",
    F.to_timestamp(
        F.concat_ws(
            " ",
            F.date_format(F.col("Fecha_Llamada"), "yyyy-MM-dd"),
            F.col("hora")
        ),
        "yyyy-MM-dd HH:mm:ss"
    )
)

df_split = df_split.withColumn(
    "Inicio",
    F.col("Fecha_Hora_Llamada")
)

df_split = df_split.withColumn(
    "Fin",
    F.from_unixtime(
        F.unix_timestamp(F.col("Inicio")) + F.col("segundos").cast("int")
    ).cast("timestamp")
)

df_split = df_split.withColumn(
    "Trama_Hora",
    F.hour(F.col("Inicio"))
)

# %%
df_split = df_split.withColumn(
    "Trama_Hora",
    F.hour(F.col("Inicio"))
)

# %%
df_split=df_split.dropDuplicates(['Dni'])

# %%
df_split = df_split.withColumn(
    "Codigo_Paleta",
    F.col("Codigo_Paleta").cast("string")
)

# %%
df_split.select('Dni', 'DNI_Ejecutivo', 'Ejecutivo', 'Fecha_Hora_Llamada', 'segundos', 'Fecha_Llamada', 'Trama_Hora', 'PHONE_NUMBER', 'Codigo_Paleta', 'Inicio', 'Fin','Numero_Campana','Trama_Hora','list_name','list_description').show(3)
# Out:
# +--------+-------------+------------------+-------------------+--------+-------------+----------+------------+-------------+-------------------+-------------------+--------------+----------+-----------+----------------+
# |     Dni|DNI_Ejecutivo|         Ejecutivo| Fecha_Hora_Llamada|segundos|Fecha_Llamada|Trama_Hora|PHONE_NUMBER|Codigo_Paleta|             Inicio|                Fin|Numero_Campana|Trama_Hora|  list_name|list_description|
# +--------+-------------+------------------+-------------------+--------+-------------+----------+------------+-------------+-------------------+-------------------+--------------+----------+-----------+----------------+
# |00005798|         VDAD|Outbound Auto Dial|2026-07-10 10:13:15|       0|   2026-07-10|        10|   964376735|           NA|2026-07-10 10:13:15|2026-07-10 10:13:15|           401|        10|provicional|     provicional|
# |00005965|         VDAD|Outbound Auto Dial|2026-07-01 05:43:32|       0|   2026-07-01|         5|   956621221|           AB|2026-07-01 05:43:32|2026-07-01 05:43:32|           401|         5|provicional|     provicional|
# |00006534|         VDAD|Outbound Auto Dial|2026-07-10 06:04:31|       0|   2026-07-10|         6|   961091285|        PDROP|2026-07-10 06:04:31|2026-07-10 06:04:31|           401|         6|provicional|     provicional|
# +--------+-------------+------------------+-------------------+--------+-------------+----------+------------+-------------+-------------------+-------------------+--------------+----------+-----------+----------------+
# only showing top 3 rows

# %%
df_split=df_split.withColumn('Sub_estado',F.lit(''))
df_split=df_split.withColumn('Estados',F.lit(''))

# %%
df_split=df_split.select('Dni', 'DNI_Ejecutivo', 'Ejecutivo', 'Fecha_Hora_Llamada', 'segundos', 'Fecha_Llamada', 'PHONE_NUMBER', 'Codigo_Paleta', 'Inicio', 'Fin','Numero_Campana','Trama_Hora','list_name','list_description','Estados','Sub_estado')

# %%
df_split.groupBy('Fecha_Llamada') \
    .count() \
    .orderBy('Fecha_Llamada') \
    .show(30)
# Out:
# +-------------+-----+
# |Fecha_Llamada|count|
# +-------------+-----+
# |   2026-07-01|16719|
# |   2026-07-10|16693|
# +-------------+-----+

# %%
append_table_SQL(spark,df_split,f'tmp_llamadas_mes_que',server_zeus,user_zeus,pwd_zeus,'SAMANTHA')

# %%
print([row['estado' ] for row in df_split.select('estado').distinct().collect()])
# Out:
# ['ENVIADO   ', None]

# %%
df_necesito.show(2)
# df_necesito=df_necesito.withColumn('Numero_Campana',F.lit('401'))
# df_necesito=df_necesito.withColumn('list_description',F.lit('provicional'))
# df_necesito=df_necesito.withColumn('list_name',F.lit('provicional'))
# df_necesito=df_necesito.withColumn('Nombre_Campana',F.lit('BOT_ALFIN'))
# df_necesito=df_necesito.withColumn('Nombre_Campana',F.lit('2026-07 BCO ALFIN'))
# Out:
# +--------+-------------+------------------+-------------------+--------+-------------+----------+------------+-------------+-------------------+-------------------+
# |     Dni|DNI_Ejecutivo|         Ejecutivo| Fecha_Hora_Llamada|segundos|Fecha_Llamada|Trama_Hora|PHONE_NUMBER|Codigo_Paleta|             Inicio|                Fin|
# +--------+-------------+------------------+-------------------+--------+-------------+----------+------------+-------------+-------------------+-------------------+
# |72048296|         VDAD|Outbound Auto Dial|2023-11-24 17:34:47|       0|   2023-11-24|        17|   922488467|           AB|2023-11-24 17:34:47|2023-11-24 17:34:47|
# |29690194|         VDAD|Outbound Auto Dial|2023-11-24 17:34:47|       0|   2023-11-24|        17|   983941534|           AB|2023-11-24 17:34:47|2023-11-24 17:34:47|
# +--------+-------------+------------------+-------------------+--------+-------------+----------+------------+-------------+-------------------+-------------------+
# only showing top 2 rows

# %%
df_split.show(5)
# Out:
# +--------+-------------+--------+--------------------+---------+----+------------+------------+-----------+-----------+-------------------+--------------+------+-------+--------------+----------------+-----------+-----------------+-------------+-------------+------------------+-------------+
# |     Dni|PROPENSION_IC|FRESCURA|             USER_V3|TIPO_LOTE|lote|PHONE_NUMBER|fecha_visita|hora_visita|fecha_envio|intentos_realizados|fecha_registro|estado|por_dia|Numero_Campana|list_description|  list_name|   Nombre_Campana|Fecha_Llamada|DNI_Ejecutivo|         Ejecutivo|Codigo_Paleta|
# +--------+-------------+--------+--------------------+---------+----+------------+------------+-----------+-----------+-------------------+--------------+------+-------+--------------+----------------+-----------+-----------------+-------------+-------------+------------------+-------------+
# |47319495|            1|       0|2. sunedu & sunarp B| BASE BOT| BOT|   954821826|        NULL|       NULL|       NULL|               NULL|          NULL|  NULL|      1|           401|     provicional|provicional|2026-07 BCO ALFIN|   2026-07-01|         VDAD|Outbound Auto Dial|           AB|
# |15298787|            1|       0|2. sunedu & sunarp B| BASE BOT| BOT|   961849090|        NULL|       NULL|       NULL|               NULL|          NULL|  NULL|      2|           401|     provicional|provicional|2026-07 BCO ALFIN|   2026-07-02|         VDAD|Outbound Auto Dial|        PDROP|
# |80386614|            1|       3|14. Otros Bancari...| BASE BOT| BOT|   984486874|        NULL|       NULL|       NULL|               NULL|          NULL|  NULL|      1|           401|     provicional|provicional|2026-07 BCO ALFIN|   2026-07-01|         VDAD|Outbound Auto Dial|           NA|
# |02838423|            1|       3|14. Otros Bancari...| BASE BOT| BOT|   944839522|        NULL|       NULL|       NULL|               NULL|          NULL|  NULL|      1|           401|     provicional|provicional|2026-07 BCO ALFIN|   2026-07-01|         VDAD|Outbound Auto Dial|           NA|
# |72507063|            1|       3|14. Otros Bancari...| BASE BOT| BOT|   956552545|        NULL|       NULL|       NULL|               NULL|          NULL|  NULL|      1|           401|     provicional|provicional|2026-07 BCO ALFIN|   2026-07-01|         VDAD|Outbound Auto Dial|        PDROP|
# +--------+-------------+--------+--------------------+---------+----+------------+------------+-----------+-----------+-------------------+--------------+------+-------+--------------+----------------+-----------+-----------------+-------------+-------------+------------------+-------------+
# only showing top 5 rows

# %%
Bot Bco Alfin

# %%
query = """
select top(10)* From [THOTH].dbo.Tmp_LLamadas_Alfin_bot
    """
df_llamadas_bot=obtener_tabla_sql(spark,query,server_zeus,user_zeus,pwd_zeus,db_zeus)
df_llamadas_bot.show()
# Out:
# +--------+--------------+--------------+-------------+------------------+-------------------+--------+-------------+----------+-------+----------+--------------------+----------------+----------------+------------+------------+-----------+-------------+-------------------+-------------------+--------+--------+--------------------+--------------------+-----+------------------+----------+------------+---+-------+
# |     Dni|Numero_Campana|Nombre_Campana|DNI_Ejecutivo|         Ejecutivo| Fecha_Hora_Llamada|segundos|Fecha_Llamada|Trama_Hora|Estados|Sub_estado|         Descripcion|list_description|       list_name|PHONE_NUMBER|Fecha_Agenda|Comentarios|Codigo_Paleta|             Inicio|                Fin| lead_id| Estado_|         Sub_Estado_|        Descripcion_|Pesos|            Enlace|Fecha_Llam|Hora_Llamada| RH|COD_BCO|
# +--------+--------------+--------------+-------------+------------------+-------------------+--------+-------------+----------+-------+----------+--------------------+----------------+----------------+------------+------------+-----------+-------------+-------------------+-------------------+--------+--------+--------------------+--------------------+-----+------------------+----------+------------+---+-------+
# |70525025|           401|     BOT_ALFIN|         VDAD|Outbound Auto Dial|2026-07-03 16:21:08|       0|   2026-07-03|        16|       |          |Outbound Pre-Rout...|Prueba_bot_alfin|Prueba_bot_alfin|   983926830|        NULL|       NULL|        PDROP|2026-07-03 16:21:08|2026-07-03 16:21:08|20805511|DISCADOR|REGISTRO SIN GESTION|REGISTRO NO GESTI...|   76|70525025 983926830|2026-07-03|          16|  3|   NULL|
# |32106760|           401|     BOT_ALFIN|         VDAD|Outbound Auto Dial|2026-07-03 16:21:08|       0|   2026-07-03|        16|       |          |           Busy Auto|Prueba_bot_alfin|Prueba_bot_alfin|   917929957|        NULL|       NULL|           AB|2026-07-03 16:21:08|2026-07-03 16:21:08|20797763|DISCADOR|NO SE CONCRETO LL...|TELEFONO FUERA DE...|   56|32106760 917929957|2026-07-03|          16|  3|   NULL|
# |21254137|           401|     BOT_ALFIN|     49587612|     Bot Bco Alfin|2026-07-03 16:21:05|       0|   2026-07-03|        16|       |          |                NULL|Prueba_bot_alfin|Prueba_bot_alfin|   995489999|        NULL|       NULL|            9|2026-07-03 16:21:05|2026-07-03 16:24:01|20807728|    NULL|                NULL|                NULL| NULL|21254137 995489999|2026-07-03|          16|  3|   NULL|
# |70457732|           401|     BOT_ALFIN|         VDAD|Outbound Auto Dial|2026-07-03 16:21:00|       0|   2026-07-03|        16|       |          |Outbound Pre-Rout...|Prueba_bot_alfin|Prueba_bot_alfin|   923283203|        NULL|       NULL|        PDROP|2026-07-03 16:21:00|2026-07-03 16:21:00|20798037|DISCADOR|REGISTRO SIN GESTION|REGISTRO NO GESTI...|   76|70457732 923283203|2026-07-03|          16|  3|   NULL|
# |10199713|           401|     BOT_ALFIN|         VDAD|Outbound Auto Dial|2026-07-03 16:21:00|       0|   2026-07-03|        16|       |          |           Busy Auto|Prueba_bot_alfin|Prueba_bot_alfin|   933629604|        NULL|       NULL|           AB|2026-07-03 16:21:00|2026-07-03 16:21:00|20798526|DISCADOR|NO SE CONCRETO LL...|TELEFONO FUERA DE...|   56|10199713 933629604|2026-07-03|          16|  3|   NULL|
# |46859735|           401|     BOT_ALFIN|         VDAD|Outbound Auto Dial|2026-07-03 16:21:00|       0|   2026-07-03|        16|       |          |Outbound Pre-Rout...|Prueba_bot_alfin|Prueba_bot_alfin|   920248003|        NULL|       NULL|        PDROP|2026-07-03 16:21:00|2026-07-03 16:21:00|20797835|DISCADOR|REGISTRO SIN GESTION|REGISTRO NO GESTI...|   76|46859735 920248003|2026-07-03|          16|  3|   NULL|
# |01155024|           401|     BOT_ALFIN|         VDAD|Outbound Auto Dial|2026-07-03 16:21:00|       0|   2026-07-03|        16|       |          |Outbound Pre-Rout...|Prueba_bot_alfin|Prueba_bot_alfin|   939618365|        NULL|       NULL|        PDROP|2026-07-03 16:21:00|2026-07-03 16:21:00|20798974|DISCADOR|REGISTRO SIN GESTION|REGISTRO NO GESTI...|   76|01155024 939618365|2026-07-03|          16|  3|   NULL|
# |42155640|           401|     BOT_ALFIN|         VDAD|Outbound Auto Dial|2026-07-03 16:21:00|       0|   2026-07-03|        16|       |          |Outbound Pre-Rout...|Prueba_bot_alfin|Prueba_bot_alfin|   917879589|        NULL|       NULL|        PDROP|2026-07-03 16:21:00|2026-07-03 16:21:00|20797761|DISCADOR|REGISTRO SIN GESTION|REGISTRO NO GESTI...|   76|42155640 917879589|2026-07-03|          16|  3|   NULL|
# |46626284|           401|     BOT_ALFIN|         VDAD|Outbound Auto Dial|2026-07-03 16:20:56|       0|   2026-07-03|        16|       |          |           Busy Auto|Prueba_bot_alfin|Prueba_bot_alfin|   967651131|        NULL|       NULL|           AB|2026-07-03 16:20:56|2026-07-03 16:20:56|20803381|DISCADOR|NO SE CONCRETO LL...|TELEFONO FUERA DE...|   56|46626284 967651131|2026-07-03|          16|  3|   NULL|
# |09605280|           401|     BOT_ALFIN|         VDAD|Outbound Auto Dial|2026-07-03 16:20:56|       0|   2026-07-03|        16|       |          |           Busy Auto|Prueba_bot_alfin|Prueba_bot_alfin|   962042460|        NULL|       NULL|           AB|2026-07-03 16:20:56|2026-07-03 16:20:56|20802638|DISCADOR|NO SE CONCRETO LL...|TELEFONO FUERA DE...|   56|09605280 962042460|2026-07-03|          16|  3|   NULL|
# +--------+--------------+--------------+-------------+------------------+-------------------+--------+-------------+----------+-------+----------+--------------------+----------------+----------------+------------+------------+-----------+-------------+-------------------+-------------------+--------+--------+--------------------+--------------------+-----+------------------+----------+------------+---+-------+

# %%
print([row['DNI_Ejecutivo' ] for row in df_llamadas_bot.select('DNI_Ejecutivo').distinct().collect()])
# Out:
# ['49587612', 'VDAD']

# %%
print(41539-41668)
# Out:
# -129

# %%
nocet 41668
1760 odo
bot 43428

# %%
49587612
# Out:
# ['ACTIVO', 'RETIVO_CORREO']

# %%
print(86857*.50,'bot')
print((102599+2779)*.3,'hum')
print(192235)
# Out:
# 43428.5 bot
# 31613.399999999998 hum
# 192235

# %%
print([row['estado' ] for row in df_crm.select('estado').distinct().collect()])
# print([row['codigo_ejecutivo_id' ] for row in df_crm.select('codigo_ejecutivo_id').distinct().collect()])
# Out:
# ['PENDIENTE ', 'ERROR     ', 'ENVIADO   ']

# %%
['NUMERO_DOCUMENTO', 'NRG', 'Dni', 'TIPO_GESTION', 'GESTION', 'SUBGESTION', 'TIPO_GESTION_hum', 'GESTION_hum', 'SUBGESTION_hum', 'TIPO_GESTION_bot', 'GESTION_bot', 'SUBGESTION_bot', 'TIPO', 'RECORRIDO', 'RECORRIDO_hum', 'RECORRIDO_bot', 'CET', 'CET_hum', 'CET_bot', 'CONT_GEN', 'CONT_GEN_hum', 'CONT_GEN_bot', 'Hora_Llamada', 'Mejor_Telefono', 'TELEFONO', 'FECHA_LLAMADA', 'DIA', 'Ejecutivo', 'RHFC', 'SUPERVISOR', 'segundos', 'AGENDADOS', 'AGENDADOS_hum', 'AGENDADOS_bot', 'SOLO FH1', 'SOLO FH2', 'SOLO FH3', 'DOBLE FH', 'TRIPLE FH', 'NUMXDNI', 'Estado', 'CntEstado', 'MntOferta', 'CNTVTAS', 'NUM_DIA_HABIL', 'Semana_Mes', 'tMontoDesem', 'CNT_LLAMADAS', 'CNT_LLAMADAS_hum', 'CNT_LLAMADAS_bot', 'AÑO_DURACION_BASE', 'MES_DURACION_BASE', 'FECHA_ENVIO', 'SERVICIO', 'RETIRO', 'REP1', 'REP2', 'FLG_SIN_ENR', 'tMesGestion', 'DESCRIPCION', 'DESCRIPCION2', 'llave', 'DEPARTAMENTO', 'DISTRITO', 'PROPENSION_IC', 'CUOTA', 'Agencia_comercial', 'Region_comercial', 'color_final', 'GRUPO_TASA', 'GRUPO_MONTO', 'tipo_cliente_riegos', 'USER_V3', 'TIPO_CLIENTE', 'FRESCURA', 'TIPO_BASE', 'campania', 'FLG_AAHH', 'INTENSIDAD_MAX', 'REGION', 'RANGO_EDAD', 'RANGO_OFERTA', 'RANGO_TASA', 'TIPO_LOTE', 'TIPO_TELF', 'lote', 'tMontoDesemFugas']prop
# Out:
# ['NUMERO_DOCUMENTO', 'NRG', 'Dni', 'TIPO_GESTION', 'GESTION', 'SUBGESTION', 'TIPO_GESTION_hum', 'GESTION_hum', 'SUBGESTION_hum', 'TIPO_GESTION_bot', 'GESTION_bot', 'SUBGESTION_bot', 'TIPO', 'RECORRIDO', 'RECORRIDO_hum', 'RECORRIDO_bot', 'CET', 'CET_hum', 'CET_bot', 'CONT_GEN', 'CONT_GEN_hum', 'CONT_GEN_bot', 'Hora_Llamada', 'Mejor_Telefono', 'TELEFONO', 'FECHA_LLAMADA', 'DIA', 'Ejecutivo', 'RHFC', 'SUPERVISOR', 'segundos', 'AGENDADOS', 'AGENDADOS_hum', 'AGENDADOS_bot', 'SOLO FH1', 'SOLO FH2', 'SOLO FH3', 'DOBLE FH', 'TRIPLE FH', 'NUMXDNI', 'Estado', 'CntEstado', 'MntOferta', 'CNTVTAS', 'NUM_DIA_HABIL', 'Semana_Mes', 'tMontoDesem', 'CNT_LLAMADAS', 'CNT_LLAMADAS_hum', 'CNT_LLAMADAS_bot', 'AÑO_DURACION_BASE', 'MES_DURACION_BASE', 'FECHA_ENVIO', 'SERVICIO', 'RETIRO', 'REP1', 'REP2', 'FLG_SIN_ENR', 'tMesGestion', 'DESCRIPCION', 'DESCRIPCION2', 'llave', 'DEPARTAMENTO', 'DISTRITO', 'PROPENSION_IC', 'CUOTA', 'Agencia_comercial', 'Region_comercial', 'color_final', 'GRUPO_TASA', 'GRUPO_MONTO', 'tipo_cliente_riegos', 'USER_V3', 'TIPO_CLIENTE', 'FRESCURA', 'TIPO_BASE', 'campania', 'FLG_AAHH', 'INTENSIDAD_MAX', 'REGION', 'RANGO_EDAD', 'RANGO_OFERTA', 'RANGO_TASA', 'TIPO_LOTE', 'TIPO_TELF', 'lote', 'tMontoDesemFugas']

# %%
query = """
    SELECT * FROM maeba.[ADM_OBJ_TG].[tGestionMesAlfin]
    where RECORRIDO = 0
    """
df_recorrido=obtener_tabla_sql(spark,query,server_zeus,user_zeus,pwd_zeus,db_zeus)
df_recorrido.count()
# Out:
# 156930

# %%
df_formato.join(df_recorrido,['NUMERO_DOCUMENTO'],'inner').count()
# Out:
# 0

# %%
df_recorrido.show()
# Out:
# +----------------+---+----+------------+----------+----------+----------------+-----------+--------------+----------------+-----------+--------------+----------+---------+-------------+-------------+---+-------+-------+--------+------------+------------+------------+--------------+--------+-------------+----+---------+----+-----------+--------+---------+-------------+-------------+--------+--------+--------+--------+---------+-------+------+---------+---------+-------+-------------+----------+-----------+------------+----------------+----------------+-----------------+-----------------+-----------+--------+------+-----+-----+-----------+-----------+--------------------+------------------+-------------------+------------+--------------------+-------------+-------+--------------------+--------------------+---------------+-------------+---------------+-------------------+--------------------+-------------+--------+----------------+--------+------------+--------------+---------------+------------+--------------------+------------+------------+---------+--------------+----------------+
# |NUMERO_DOCUMENTO|NRG| Dni|TIPO_GESTION|   GESTION|SUBGESTION|TIPO_GESTION_hum|GESTION_hum|SUBGESTION_hum|TIPO_GESTION_bot|GESTION_bot|SUBGESTION_bot|      TIPO|RECORRIDO|RECORRIDO_hum|RECORRIDO_bot|CET|CET_hum|CET_bot|CONT_GEN|CONT_GEN_hum|CONT_GEN_bot|Hora_Llamada|Mejor_Telefono|TELEFONO|FECHA_LLAMADA| DIA|Ejecutivo|RHFC| SUPERVISOR|segundos|AGENDADOS|AGENDADOS_hum|AGENDADOS_bot|SOLO FH1|SOLO FH2|SOLO FH3|DOBLE FH|TRIPLE FH|NUMXDNI|Estado|CntEstado|MntOferta|CNTVTAS|NUM_DIA_HABIL|Semana_Mes|tMontoDesem|CNT_LLAMADAS|CNT_LLAMADAS_hum|CNT_LLAMADAS_bot|AÑO_DURACION_BASE|MES_DURACION_BASE|FECHA_ENVIO|SERVICIO|RETIRO| REP1| REP2|FLG_SIN_ENR|tMesGestion|         DESCRIPCION|      DESCRIPCION2|              llave|DEPARTAMENTO|            DISTRITO|PROPENSION_IC|  CUOTA|   Agencia_comercial|    Region_comercial|    color_final|   GRUPO_TASA|    GRUPO_MONTO|tipo_cliente_riegos|             USER_V3| TIPO_CLIENTE|FRESCURA|       TIPO_BASE|campania|    FLG_AAHH|INTENSIDAD_MAX|         REGION|  RANGO_EDAD|        RANGO_OFERTA|  RANGO_TASA|   TIPO_LOTE|TIPO_TELF|          lote|tMontoDesemFugas|
# +----------------+---+----+------------+----------+----------+----------------+-----------+--------------+----------------+-----------+--------------+----------+---------+-------------+-------------+---+-------+-------+--------+------------+------------+------------+--------------+--------+-------------+----+---------+----+-----------+--------+---------+-------------+-------------+--------+--------+--------+--------+---------+-------+------+---------+---------+-------+-------------+----------+-----------+------------+----------------+----------------+-----------------+-----------------+-----------+--------+------+-----+-----+-----------+-----------+--------------------+------------------+-------------------+------------+--------------------+-------------+-------+--------------------+--------------------+---------------+-------------+---------------+-------------------+--------------------+-------------+--------+----------------+--------+------------+--------------+---------------+------------+--------------------+------------+------------+---------+--------------+----------------+
# |        02831141|  1|NULL|  NO DISCADO|NO DISCADO|NO DISCADO|      NO DISCADO| NO DISCADO|    NO DISCADO|      NO DISCADO| NO DISCADO|    NO DISCADO|NO DISCADO|        0|            0|            0|  0|      0|      0|       0|           0|           0|        NULL|          NULL|    NULL|         NULL|NULL|     NULL|NULL|Sin_Asignar|    NULL|        0|            0|            0|       0|       0|       0|       0|        0|      2|  NULL|     NULL|     NULL|   NULL|         NULL|      NULL|       NULL|        NULL|            NULL|            NULL|             2026|               07| 2026-07-01|      12|ACTIVO|NUEVO|NUEVO|       NULL|      Julio|REGISTROS ENTREGADOS|REGISTROS CARGADOS|02831141 2026-07-01|      TUMBES|              TUMBES|            2|  221.8|              TUMBES|        REGION NORTE|AMARILLO OSCURO|   Mayor tasa| Mantiene Monto|       3.NO CLIENTE|  3. MES + PLD Peers|  DEPENDIENTE|       2|         Regular| BANTRAD|NO EMERGENTE|             8|Leads Provincia|06.[55 - 59]|  01.[2,500 - 5,000)|06.[75 - 80)|BASE REGULAR|    TIENE|NO CLIENTE CET|            NULL|
# |        02804418|  1|NULL|  NO DISCADO|NO DISCADO|NO DISCADO|      NO DISCADO| NO DISCADO|    NO DISCADO|      NO DISCADO| NO DISCADO|    NO DISCADO|NO DISCADO|        0|            0|            0|  0|      0|      0|       0|           0|           0|        NULL|          NULL|    NULL|         NULL|NULL|     NULL|NULL|Sin_Asignar|    NULL|        0|            0|            0|       0|       0|       0|       0|        0|      4|  NULL|     NULL|     NULL|   NULL|         NULL|      NULL|       NULL|        NULL|            NULL|            NULL|             2026|               07| 2026-07-01|      12|ACTIVO|NUEVO|NUEVO|       NULL|      Julio|REGISTROS ENTREGADOS|REGISTROS CARGADOS|02804418 2026-07-01|       PIURA|               PIURA|            1| 624.74|            CASTILLA|        REGION NORTE|    VERDE CLARO|Mantiene tasa|   Mejora Monto|       3.NO CLIENTE|1. sunedu & sunarp A|  DEPENDIENTE|       4|SALDO COMPETIDOR|SDFCP100|   EMERGENTE|             8|Leads Provincia|06.[55 - 59]|05.[12,500 - 15,000)|01.[50 - 55)|BASE REGULAR|    TIENE|NO CLIENTE CET|            NULL|
# |        09597633|  1|NULL|  NO DISCADO|NO DISCADO|NO DISCADO|      NO DISCADO| NO DISCADO|    NO DISCADO|      NO DISCADO| NO DISCADO|    NO DISCADO|NO DISCADO|        0|            0|            0|  0|      0|      0|       0|           0|           0|        NULL|          NULL|    NULL|         NULL|NULL|     NULL|NULL|Sin_Asignar|    NULL|        0|            0|            0|       0|       0|       0|       0|        0|      2|  NULL|     NULL|     NULL|   NULL|         NULL|      NULL|       NULL|        NULL|            NULL|            NULL|             2026|               07| 2026-07-01|      12|ACTIVO|NUEVO|NUEVO|       NULL|      Julio|REGISTROS ENTREGADOS|REGISTROS CARGADOS|09597633 2026-07-01|        LIMA|           SAN BORJA|            2| 331.42|          MIRAFLORES|  REGION LIMA CENTRO|AMARILLO OSCURO|   Mayor tasa| Mantiene Monto|       3.NO CLIENTE|            7. Peers|  DEPENDIENTE|       4|SALDO COMPETIDOR| SOLODNI|NO EMERGENTE|             7|     Leads Lima|05.[50 - 54]|  02.[5,000 - 7,500)|05.[70 - 75)|BASE REGULAR|    TIENE|NO CLIENTE CET|            NULL|
# |        09601136|  1|NULL|  NO DISCADO|NO DISCADO|NO DISCADO|      NO DISCADO| NO DISCADO|    NO DISCADO|      NO DISCADO| NO DISCADO|    NO DISCADO|NO DISCADO|        0|            0|            0|  0|      0|      0|       0|           0|           0|        NULL|          NULL|    NULL|         NULL|NULL|     NULL|NULL|Sin_Asignar|    NULL|        0|            0|            0|       0|       0|       0|       0|        0|      5|  NULL|     NULL|     NULL|   NULL|         NULL|      NULL|       NULL|        NULL|            NULL|            NULL|             2026|               07| 2026-07-01|      12|ACTIVO|NUEVO|NUEVO|       NULL|      Julio|REGISTROS ENTREGADOS|REGISTROS CARGADOS|09601136 2026-07-01|        LIMA|         PUNTA NEGRA|            2|  745.8| VILLA EL SALVADOR 2|REGION LIMA SUR O...|   VERDE OSCURO|   Menor tasa|   Mejora Monto|       3.NO CLIENTE|   8. Tarjetero Cash|  DEPENDIENTE|       2|         Regular|   MUJER|NO EMERGENTE|             8|     Leads Lima|06.[55 - 59]|06.[15,000 - 17,500)|02.[55 - 60)|BASE REGULAR|    TIENE|NO CLIENTE CET|            NULL|
# |        08351597|  1|NULL|  NO DISCADO|NO DISCADO|NO DISCADO|      NO DISCADO| NO DISCADO|    NO DISCADO|      NO DISCADO| NO DISCADO|    NO DISCADO|NO DISCADO|        0|            0|            0|  0|      0|      0|       0|           0|           0|        NULL|          NULL|    NULL|         NULL|NULL|     NULL|NULL|Sin_Asignar|    NULL|        0|            0|            0|       0|       0|       0|       0|        0|      2|  NULL|     NULL|     NULL|   NULL|         NULL|      NULL|       NULL|        NULL|            NULL|            NULL|             2026|               07| 2026-07-01|      12|ACTIVO|NUEVO|NUEVO|       NULL|      Julio|REGISTROS ENTREGADOS|REGISTROS CARGADOS|08351597 2026-07-01|        LIMA|SAN JUAN DE MIRAF...|            2| 164.65|SAN JUAN DE MIRAF...|REGION LIMA SUR O...| AMARILLO CLARO|   Mayor tasa|Disminuye Monto|       3.NO CLIENTE|4. MES + PLD No P...|  DEPENDIENTE|       4|         Regular|   MUJER|NO EMERGENTE|             8|     Leads Lima|08.[65 - 69]|  01.[2,500 - 5,000)|06.[75 - 80)|BASE REGULAR|    TIENE|NO CLIENTE CET|            NULL|
# |        08380749|  1|NULL|  NO DISCADO|NO DISCADO|NO DISCADO|      NO DISCADO| NO DISCADO|    NO DISCADO|      NO DISCADO| NO DISCADO|    NO DISCADO|NO DISCADO|        0|            0|            0|  0|      0|      0|       0|           0|           0|        NULL|          NULL|    NULL|         NULL|NULL|     NULL|NULL|Sin_Asignar|    NULL|        0|            0|            0|       0|       0|       0|       0|        0|      2|  NULL|     NULL|     NULL|   NULL|         NULL|      NULL|       NULL|        NULL|            NULL|            NULL|             2026|               07| 2026-07-01|      12|ACTIVO|NUEVO|NUEVO|       NULL|      Julio|REGISTROS ENTREGADOS|REGISTROS CARGADOS|08380749 2026-07-01|        LIMA|   SANTIAGO DE SURCO|            2| 233.68|          MIRAFLORES|  REGION LIMA CENTRO|    VERDE CLARO|   Mayor tasa|   Mejora Monto|       3.NO CLIENTE|            7. Peers|INDEPENDIENTE|       4|SALDO COMPETIDOR|   MUJER|NO EMERGENTE|             7|     Leads Lima|08.[65 - 69]|  01.[2,500 - 5,000)|01.[50 - 55)|BASE REGULAR|    TIENE|NO CLIENTE CET|            NULL|
# |        08423100|  1|NULL|  NO DISCADO|NO DISCADO|NO DISCADO|      NO DISCADO| NO DISCADO|    NO DISCADO|      NO DISCADO| NO DISCADO|    NO DISCADO|NO DISCADO|        0|            0|            0|  0|      0|      0|       0|           0|           0|        NULL|          NULL|    NULL|         NULL|NULL|     NULL|NULL|Sin_Asignar|    NULL|        0|            0|            0|       0|       0|       0|       0|        0|      5|  NULL|     NULL|     NULL|   NULL|         NULL|      NULL|       NULL|        NULL|            NULL|            NULL|             2026|               07| 2026-07-01|      12|ACTIVO|NUEVO|NUEVO|       NULL|      Julio|REGISTROS ENTREGADOS|REGISTROS CARGADOS|08423100 2026-07-01|        LIMA|         SANTA ANITA|            6| 577.07|         SANTA ANITA|  REGION LIMA CENTRO| AMARILLO CLARO|   Mayor tasa|   Mejora Monto|       3.NO CLIENTE|1. sunedu & sunarp A|INDEPENDIENTE|       1|         Regular|SDFCP100|NO EMERGENTE|             5|     Leads Lima|09.[70 - 74]|04.[10,000 - 12,500)|06.[75 - 80)|BASE REGULAR|    TIENE|NO CLIENTE CET|            NULL|
# |        08398030|  1|NULL|  NO DISCADO|NO DISCADO|NO DISCADO|      NO DISCADO| NO DISCADO|    NO DISCADO|      NO DISCADO| NO DISCADO|    NO DISCADO|NO DISCADO|        0|            0|            0|  0|      0|      0|       0|           0|           0|        NULL|          NULL|    NULL|         NULL|NULL|     NULL|NULL|Sin_Asignar|    NULL|        0|            0|            0|       0|       0|       0|       0|        0|      3|  NULL|     NULL|     NULL|   NULL|         NULL|      NULL|       NULL|        NULL|            NULL|            NULL|             2026|               07| 2026-07-01|      12|ACTIVO|NUEVO|NUEVO|       NULL|      Julio|REGISTROS ENTREGADOS|REGISTROS CARGADOS|08398030 2026-07-01|        LIMA|SAN JUAN DE MIRAF...|            2| 545.35|SAN JUAN DE MIRAF...|REGION LIMA SUR O...|AMARILLO OSCURO|   Mayor tasa|   Mejora Monto|       3.NO CLIENTE|            7. Peers|  DEPENDIENTE|       4|         Regular|  SD FCP|NO EMERGENTE|             7|     Leads Lima|09.[70 - 74]|  01.[2,500 - 5,000)|05.[70 - 75)|BASE REGULAR|    TIENE|NO CLIENTE CET|            NULL|
# |        08163137|  1|NULL|  NO DISCADO|NO DISCADO|NO DISCADO|      NO DISCADO| NO DISCADO|    NO DISCADO|      NO DISCADO| NO DISCADO|    NO DISCADO|NO DISCADO|        0|            0|            0|  0|      0|      0|       0|           0|           0|        NULL|          NULL|    NULL|         NULL|NULL|     NULL|NULL|Sin_Asignar|    NULL|        0|            0|            0|       0|       0|       0|       0|        0|      6|  NULL|     NULL|     NULL|   NULL|         NULL|      NULL|       NULL|        NULL|            NULL|            NULL|             2026|               07| 2026-07-01|      12|ACTIVO|NUEVO|NUEVO|       NULL|      Julio|REGISTROS ENTREGADOS|REGISTROS CARGADOS|08163137 2026-07-01|        LIMA|               RIMAC|            2|1070.82|        EMANCIPACION|  REGION LIMA CENTRO|    VERDE CLARO|   Mayor tasa| Mantiene Monto|       3.NO CLIENTE|            7. Peers|INDEPENDIENTE|       4|SALDO COMPETIDOR|   MUJER|NO EMERGENTE|             7|     Leads Lima|05.[50 - 54]|09.[22,500 - 25,000)|01.[50 - 55)|BASE REGULAR|    TIENE|NO CLIENTE CET|            NULL|
# |        08530740|  1|NULL|  NO DISCADO|NO DISCADO|NO DISCADO|      NO DISCADO| NO DISCADO|    NO DISCADO|      NO DISCADO| NO DISCADO|    NO DISCADO|NO DISCADO|        0|            0|            0|  0|      0|      0|       0|           0|           0|        NULL|          NULL|    NULL|         NULL|NULL|     NULL|NULL|Sin_Asignar|    NULL|        0|            0|            0|       0|       0|       0|       0|        0|      7|  NULL|     NULL|     NULL|   NULL|         NULL|      NULL|       NULL|        NULL|            NULL|            NULL|             2026|               07| 2026-07-01|      12|ACTIVO|NUEVO|NUEVO|       NULL|      Julio|REGISTROS ENTREGADOS|REGISTROS CARGADOS|08530740 2026-07-01|        LIMA|SAN JUAN DE LURIG...|            1| 383.71|SAN JUAN DE LURIG...|  REGION LIMA CENTRO|AMARILLO OSCURO|   Mayor tasa| Mantiene Monto|       3.NO CLIENTE|            7. Peers|     INFORMAL|       2|SALDO COMPETIDOR| SOLODNI|   EMERGENTE|             7|     Leads Lima|07.[60 - 64]|  02.[5,000 - 7,500)|05.[70 - 75)|BASE REGULAR|    TIENE|NO CLIENTE CET|            NULL|
# |        08532924|  1|NULL|  NO DISCADO|NO DISCADO|NO DISCADO|      NO DISCADO| NO DISCADO|    NO DISCADO|      NO DISCADO| NO DISCADO|    NO DISCADO|NO DISCADO|        0|            0|            0|  0|      0|      0|       0|           0|           0|        NULL|          NULL|    NULL|         NULL|NULL|     NULL|NULL|Sin_Asignar|    NULL|        0|            0|            0|       0|       0|       0|       0|        0|      3|  NULL|     NULL|     NULL|   NULL|         NULL|      NULL|       NULL|        NULL|            NULL|            NULL|             2026|               07| 2026-07-01|      12|ACTIVO|NUEVO|NUEVO|       NULL|      Julio|REGISTROS ENTREGADOS|REGISTROS CARGADOS|08532924 2026-07-01|        LIMA|SAN MARTIN DE PORRES|            2| 771.34|          SAN MARTIN|   REGION LIMA NORTE|   VERDE OSCURO|   Mayor tasa|   Mejora Monto|       3.NO CLIENTE|            7. Peers|  DEPENDIENTE|       4|SALDO COMPETIDOR|   MUJER|NO EMERGENTE|             7|     Leads Lima|08.[65 - 69]|06.[15,000 - 17,500)|02.[55 - 60)|BASE REGULAR|    TIENE|NO CLIENTE CET|            NULL|
# |        09276322|  1|NULL|  NO DISCADO|NO DISCADO|NO DISCADO|      NO DISCADO| NO DISCADO|    NO DISCADO|      NO DISCADO| NO DISCADO|    NO DISCADO|NO DISCADO|        0|            0|            0|  0|      0|      0|       0|           0|           0|        NULL|          NULL|    NULL|         NULL|NULL|     NULL|NULL|Sin_Asignar|    NULL|        0|            0|            0|       0|       0|       0|       0|        0|      5|  NULL|     NULL|     NULL|   NULL|         NULL|      NULL|       NULL|        NULL|            NULL|            NULL|             2026|               07| 2026-07-01|      12|ACTIVO|NUEVO|NUEVO|       NULL|      Julio|REGISTROS ENTREGADOS|REGISTROS CARGADOS|09276322 2026-07-01|        LIMA|SAN JUAN DE MIRAF...|            6| 903.04|SAN JUAN DE MIRAF...|REGION LIMA SUR O...|   VERDE OSCURO|   Mayor tasa| Mantiene Monto|       3.NO CLIENTE|   8. Tarjetero Cash|INDEPENDIENTE|       4|         Regular| SOLODNI|   EMERGENTE|            10|     Leads Lima|06.[55 - 59]|07.[17,500 - 20,000)|03.[60 - 65)|BASE REGULAR|    TIENE|NO CLIENTE CET|            NULL|
# |        06546519|  1|NULL|  NO DISCADO|NO DISCADO|NO DISCADO|      NO DISCADO| NO DISCADO|    NO DISCADO|      NO DISCADO| NO DISCADO|    NO DISCADO|NO DISCADO|        0|            0|            0|  0|      0|      0|       0|           0|           0|        NULL|          NULL|    NULL|         NULL|NULL|     NULL|NULL|Sin_Asignar|    NULL|        0|            0|            0|       0|       0|       0|       0|        0|      5|  NULL|     NULL|     NULL|   NULL|         NULL|      NULL|       NULL|        NULL|            NULL|            NULL|             2026|               07| 2026-07-01|      12|ACTIVO|NUEVO|NUEVO|       NULL|      Julio|REGISTROS ENTREGADOS|REGISTROS CARGADOS|06546519 2026-07-01|        LIMA|               ANCON|            1| 692.24|       PUENTE PIEDRA|   REGION LIMA NORTE| AMARILLO CLARO|   Menor tasa|   Mejora Monto|       3.NO CLIENTE|            7. Peers|  DEPENDIENTE|       4|SALDO COMPETIDOR|  SD FCP|NO EMERGENTE|             7|     Leads Lima|05.[50 - 54]|  02.[5,000 - 7,500)|04.[65 - 70)|BASE REGULAR|    TIENE|NO CLIENTE CET|            NULL|
# |        03379797|  1|NULL|  NO DISCADO|NO DISCADO|NO DISCADO|      NO DISCADO| NO DISCADO|    NO DISCADO|      NO DISCADO| NO DISCADO|    NO DISCADO|NO DISCADO|        0|            0|            0|  0|      0|      0|       0|           0|           0|        NULL|          NULL|    NULL|         NULL|NULL|     NULL|NULL|Sin_Asignar|    NULL|        0|            0|            0|       0|       0|       0|       0|        0|      8|  NULL|     NULL|     NULL|   NULL|         NULL|      NULL|       NULL|        NULL|            NULL|            NULL|             2026|               07| 2026-07-01|      12|ACTIVO|NUEVO|NUEVO|       NULL|      Julio|REGISTROS ENTREGADOS|REGISTROS CARGADOS|03379797 2026-07-01|  LAMBAYEQUE|            CHICLAYO|            1|  607.8|      CHICLAYO BALTA|        REGION NORTE|   VERDE OSCURO|Mantiene tasa|Disminuye Monto|       3.NO CLIENTE|  3. MES + PLD Peers|  DEPENDIENTE|       4|         Regular|   MUJER|NO EMERGENTE|             7|Leads Provincia|04.[45 - 49]|04.[10,000 - 12,500)|03.[60 - 65)|BASE REGULAR|    TIENE|NO CLIENTE CET|            NULL|
# |        03380820|  1|NULL|  NO DISCADO|NO DISCADO|NO DISCADO|      NO DISCADO| NO DISCADO|    NO DISCADO|      NO DISCADO| NO DISCADO|    NO DISCADO|NO DISCADO|        0|            0|            0|  0|      0|      0|       0|           0|           0|        NULL|          NULL|    NULL|         NULL|NULL|     NULL|NULL|Sin_Asignar|    NULL|        0|            0|            0|       0|       0|       0|       0|        0|      3|  NULL|     NULL|     NULL|   NULL|         NULL|      NULL|       NULL|        NULL|            NULL|            NULL|             2026|               07| 2026-07-01|      12|ACTIVO|NUEVO|NUEVO|       NULL|      Julio|REGISTROS ENTREGADOS|REGISTROS CARGADOS|03380820 2026-07-01|        LIMA|   VILLA EL SALVADOR|            2| 175.74| VILLA EL SALVADOR 2|REGION LIMA SUR O...|AMARILLO OSCURO|   Mayor tasa| Mantiene Monto|       3.NO CLIENTE|            7. Peers|     INFORMAL|       4|SALDO COMPETIDOR| SOLODNI|NO EMERGENTE|             8|     Leads Lima|04.[45 - 49]|  01.[2,500 - 5,000)|04.[65 - 70)|BASE REGULAR|    TIENE|NO CLIENTE CET|            NULL|
# |        02862041|  1|NULL|  NO DISCADO|NO DISCADO|NO DISCADO|      NO DISCADO| NO DISCADO|    NO DISCADO|      NO DISCADO| NO DISCADO|    NO DISCADO|NO DISCADO|        0|            0|            0|  0|      0|      0|       0|           0|           0|        NULL|          NULL|    NULL|         NULL|NULL|     NULL|NULL|Sin_Asignar|    NULL|        0|            0|            0|       0|       0|       0|       0|        0|      3|  NULL|     NULL|     NULL|   NULL|         NULL|      NULL|       NULL|        NULL|            NULL|            NULL|             2026|               07| 2026-07-01|      12|ACTIVO|NUEVO|NUEVO|       NULL|      Julio|REGISTROS ENTREGADOS|REGISTROS CARGADOS|02862041 2026-07-01|       PIURA|             SECHURA|            2|1205.36|            CASTILLA|        REGION NORTE|    VERDE CLARO|   Mayor tasa|   Mejora Monto|       3.NO CLIENTE|4. MES + PLD No P...|  DEPENDIENTE|       4|       Blacklist| SOLODNI|   EMERGENTE|             7|Leads Provincia|05.[50 - 54]|09.[22,500 - 25,000)|04.[65 - 70)|BASE REGULAR|    TIENE|NO CLIENTE CET|            NULL|
# |        04070523|  1|NULL|  NO DISCADO|NO DISCADO|NO DISCADO|      NO DISCADO| NO DISCADO|    NO DISCADO|      NO DISCADO| NO DISCADO|    NO DISCADO|NO DISCADO|        0|            0|            0|  0|      0|      0|       0|           0|           0|        NULL|          NULL|    NULL|         NULL|NULL|     NULL|NULL|Sin_Asignar|    NULL|        0|            0|            0|       0|       0|       0|       0|        0|      2|  NULL|     NULL|     NULL|   NULL|         NULL|      NULL|       NULL|        NULL|            NULL|            NULL|             2026|               07| 2026-07-01|      12|ACTIVO|NUEVO|NUEVO|       NULL|      Julio|REGISTROS ENTREGADOS|REGISTROS CARGADOS|04070523 2026-07-01|       PASCO|         CHAUPIMARCA|            1| 624.74|             HUANUCO|REGION LIMA SUR O...|    VERDE CLARO|   Mayor tasa|Disminuye Monto|       3.NO CLIENTE|            7. Peers|  DEPENDIENTE|       3|         Regular|SDFCP100|NO EMERGENTE|            10|Leads Provincia|05.[50 - 54]|05.[12,500 - 15,000)|01.[50 - 55)|BASE REGULAR|    TIENE|NO CLIENTE CET|            NULL|
# |        04012373|  1|NULL|  NO DISCADO|NO DISCADO|NO DISCADO|      NO DISCADO| NO DISCADO|    NO DISCADO|      NO DISCADO| NO DISCADO|    NO DISCADO|NO DISCADO|        0|            0|            0|  0|      0|      0|       0|           0|           0|        NULL|          NULL|    NULL|         NULL|NULL|     NULL|NULL|Sin_Asignar|    NULL|        0|            0|            0|       0|       0|       0|       0|        0|      6|  NULL|     NULL|     NULL|   NULL|         NULL|      NULL|       NULL|        NULL|            NULL|            NULL|             2026|               07| 2026-07-01|      12|ACTIVO|NUEVO|NUEVO|       NULL|      Julio|REGISTROS ENTREGADOS|REGISTROS CARGADOS|04012373 2026-07-01|       PASCO|         CHAUPIMARCA|            4| 310.16|             HUANUCO|REGION LIMA SUR O...|    VERDE CLARO|Mantiene tasa|   Mejora Monto|       3.NO CLIENTE|2. sunedu & sunarp B|INDEPENDIENTE|       3|         Regular|   MUJER|   EMERGENTE|             5|Leads Provincia|06.[55 - 59]|  02.[5,000 - 7,500)|04.[65 - 70)|BASE REGULAR|    TIENE|NO CLIENTE CET|            NULL|
# |        06009051|  1|NULL|  NO DISCADO|NO DISCADO|NO DISCADO|      NO DISCADO| NO DISCADO|    NO DISCADO|      NO DISCADO| NO DISCADO|    NO DISCADO|NO DISCADO|        0|            0|            0|  0|      0|      0|       0|           0|           0|        NULL|          NULL|    NULL|         NULL|NULL|     NULL|NULL|Sin_Asignar|    NULL|        0|            0|            0|       0|       0|       0|       0|        0|      4|  NULL|     NULL|     NULL|   NULL|         NULL|      NULL|       NULL|        NULL|            NULL|            NULL|             2026|               07| 2026-07-01|      12|ACTIVO|NUEVO|NUEVO|       NULL|      Julio|REGISTROS ENTREGADOS|REGISTROS CARGADOS|06009051 2026-07-01|        LIMA|              BREÃ‘A|            1| 624.74|        EMANCIPACION|  REGION LIMA CENTRO|    VERDE CLARO|   Menor tasa|   Mejora Monto|       3.NO CLIENTE|            7. Peers|  DEPENDIENTE|       4|SALDO COMPETIDOR|SDFCP100|NO EMERGENTE|             7|     Leads Lima|07.[60 - 64]|05.[12,500 - 15,000)|00.[45 - 50)|BASE REGULAR|    TIENE|NO CLIENTE CET|            NULL|
# |        04338574|  1|NULL|  NO DISCADO|NO DISCADO|NO DISCADO|      NO DISCADO| NO DISCADO|    NO DISCADO|      NO DISCADO| NO DISCADO|    NO DISCADO|NO DISCADO|        0|            0|            0|  0|      0|      0|       0|           0|           0|        NULL|          NULL|    NULL|         NULL|NULL|     NULL|NULL|Sin_Asignar|    NULL|        0|            0|            0|       0|       0|       0|       0|        0|      2|  NULL|     NULL|     NULL|   NULL|         NULL|      NULL|       NULL|        NULL|            NULL|            NULL|             2026|               07| 2026-07-01|      12|ACTIVO|NUEVO|NUEVO|       NULL|      Julio|REGISTROS ENTREGADOS|REGISTROS CARGADOS|04338574 2026-07-01|       PASCO|            OXAPAMPA|            2| 609.95|         PC HUANCAYO|REGION LIMA SUR O...| AMARILLO CLARO|         NULL|           NULL|       3.NO CLIENTE|            5. MES A|INDEPENDIENTE|       2|         Regular|SDFCP100|NO EMERGENTE|            10|Leads Provincia|06.[55 - 59]| 03.[7,500 - 10,000)|07.[80 - 85)|BASE REGULAR|    TIENE|NO CLIENTE CET|            NULL|
# +----------------+---+----+------------+----------+----------+----------------+-----------+--------------+----------------+-----------+--------------+----------+---------+-------------+-------------+---+-------+-------+--------+------------+------------+------------+--------------+--------+-------------+----+---------+----+-----------+--------+---------+-------------+-------------+--------+--------+--------+--------+---------+-------+------+---------+---------+-------+-------------+----------+-----------+------------+----------------+----------------+-----------------+-----------------+-----------+--------+------+-----+-----+-----------+-----------+--------------------+------------------+-------------------+------------+--------------------+-------------+-------+--------------------+--------------------+---------------+-------------+---------------+-------------------+--------------------+-------------+--------+----------------+--------+------------+--------------+---------------+------------+--------------------+------------+------------+---------+--------------+----------------+
# only showing top 20 rows

# %%
df_recorrido.count()
# Out:
# 1999

# %%
# print([row['FEC_NAC' ] for row in df_list.select('FEC_NAC').distinct().collect()])
df_recorrido.groupBy('PROPENSION_IC') \
    .count() \
    .orderBy('PROPENSION_IC') \
    .show(30)
# Out:
# +-------------+-----+
# |PROPENSION_IC|count|
# +-------------+-----+
# |            1|  572|
# |            2|  980|
# |            3|  132|
# |            4|  122|
# |            5|  116|
# |            6|   77|
# +-------------+-----+

# %%
df_recorrido

# %%
query = """
    select top(10)* From SAMANTHA..tmp_llamadas_mes
    """
df_recorrido=obtener_tabla_sql(spark,query,server_zeus,user_zeus,pwd_zeus,db_zeus)
df_recorrido.show(2)
# Out:
# +--------+--------------+--------------------+-------------+------------------+-------------------+--------+-------------+----------+-------+----------+-----------+--------------------+--------------------+------------+------------+-----------+-------------+-------------------+-------------------+-------+
# |     Dni|Numero_Campana|      Nombre_Campana|DNI_Ejecutivo|         Ejecutivo| Fecha_Hora_Llamada|segundos|Fecha_Llamada|Trama_Hora|Estados|Sub_estado|Descripcion|    list_description|           list_name|PHONE_NUMBER|Fecha_Agenda|Comentarios|Codigo_Paleta|             Inicio|                Fin|lead_id|
# +--------+--------------+--------------------+-------------+------------------+-------------------+--------+-------------+----------+-------+----------+-----------+--------------------+--------------------+------------+------------+-----------+-------------+-------------------+-------------------+-------+
# |72048296|            80|2023-11 CENCOSUD ...|         VDAD|Outbound Auto Dial|2023-11-24 17:34:47|       0|   2023-11-24|        17|       |          |  Busy Auto|CENCOSAE_DISC_24N...|CENCOSAE_DISC_24N...|   922488467|            |        SAE|           AB|2023-11-24 17:34:47|2023-11-24 17:34:47|5570023|
# |29690194|            80|2023-11 CENCOSUD ...|         VDAD|Outbound Auto Dial|2023-11-24 17:34:47|       0|   2023-11-24|        17|       |          |  Busy Auto|CENCOSAE_DISC_24N...|CENCOSAE_DISC_24N...|   983941534|            |        SAE|           AB|2023-11-24 17:34:47|2023-11-24 17:34:47|5578870|
# +--------+--------------+--------------------+-------------+------------------+-------------------+--------+-------------+----------+-------+----------+-----------+--------------------+--------------------+------------+------------+-----------+-------------+-------------------+-------------------+-------+
# only showing top 2 rows

# %%
RetiroDefinitivo_BlackList
